# %%
import numpy as np, pandas as pd, tensorflow as tf, random, time, os
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import *

from scipy.stats import ttest_rel, chi2, binom
from itertools import combinations

# ================= CONFIG =================
LR=0.001; ROUNDS=30; LOCAL_EPOCHS=2; BATCH=16
CLIENTS=4; SEEDS=[42,3,7,72,82]
MODELS=["CNN","LSTM","BiLSTM","GRU","BiGRU"]
CLIENT_TEST_SIZE=0.2   # local train/test split ratio inside each client
MODEL_SAVE_DIR="saved_models"
os.makedirs(MODEL_SAVE_DIR,exist_ok=True)

# ================= LOAD =================
df=pd.read_csv("url_features_extracted1(100K).csv")

# remove text columns like .txt
for col in df.columns:
    if df[col].dtype==object and df[col].astype(str).str.contains(".txt",na=False).any():
        df.drop(columns=[col],inplace=True)

df=df.fillna("unknown")

for col in df.columns:
    if df[col].dtype==object:
        df[col]=LabelEncoder().fit_transform(df[col].astype(str))

X=df.drop("ClassLabel",axis=1).values
y=df["ClassLabel"].values

X=StandardScaler().fit_transform(X)

# NOTE: no upfront global train_test_split anymore.
# IID partitioning is applied to the WHOLE dataset per seed below,
# then each client locally splits its own IID shard into train/test.

# ================= HELPERS =================
def set_seed(s):
    random.seed(s); np.random.seed(s); tf.random.set_seed(s)

def iid_partition(X,y,K):
    # IID partition: each class shuffled and split evenly across clients
    idx=np.arange(len(y))
    clients=[[] for _ in range(K)]
    for c in np.unique(y):
        c_idx=idx[y==c]; np.random.shuffle(c_idx)
        split=np.array_split(c_idx,K)
        for i in range(K): clients[i].extend(split[i])
    return [(X[c],y[c]) for c in clients]

def format_xy(Xc,model_name):
    return Xc.reshape(len(Xc),-1,1)

def scaffold_aggregate(global_model,c_global,client_weight_deltas,client_c_deltas):
    """SCAFFOLD server update (post-hoc correction style):
    - Global weights move by the UNIFORM average of client weight deltas.
    - Global control variate moves by the UNIFORM average of client control deltas.
    (Matches the validated formulation: correction is applied once to each client's
    final local weights, not injected into every mini-batch gradient — this avoids
    destabilizing Adam's adaptive moment estimates.)"""
    gw=global_model.get_weights()
    new_weights=[]
    for j in range(len(gw)):
        avg_dw=np.mean([dw[j] for dw in client_weight_deltas],axis=0)
        new_weights.append(gw[j]+avg_dw)
    global_model.set_weights(new_weights)

    for j in range(len(c_global)):
        c_global[j]=c_global[j]+np.mean([dc[j] for dc in client_c_deltas],axis=0)

def model_size(model):
    model.save("tmp.h5", include_optimizer=False)
    size=os.path.getsize("tmp.h5")/(1024*1024)
    os.remove("tmp.h5")
    return size

def stats(x,metric):
    x=np.asarray(x,dtype=float)
    x=x[~np.isnan(x)]
    if len(x)==0:
        return np.nan,np.nan,np.nan,np.nan
    mean=np.mean(x); sd=np.std(x)
    ci=1.96*sd/np.sqrt(len(x))
    low,high=mean-ci,mean+ci
    if metric in ["Accuracy","Precision","Recall","F1","AUC","Specificity"]:
        low=max(0,low); high=min(1,high)
    if metric=="MCC":
        low=max(-1,low); high=min(1,high)
    return mean,sd,low,high

def mcnemar_test(y_true_a,y_pred_a,y_true_b,y_pred_b):
    """McNemar's test between two classifiers evaluated on the SAME samples.
    Uses only the discordant pairs (one right, one wrong). Exact binomial
    for small discordant counts (n<25), continuity-corrected chi-square
    otherwise."""
    y_true_a=np.asarray(y_true_a).flatten()
    y_true_b=np.asarray(y_true_b).flatten()
    assert len(y_true_a)==len(y_true_b), "test sets must be the same size"
    assert np.array_equal(y_true_a,y_true_b), "test sets must match (same seed/instances)"

    correct_a=(np.asarray(y_pred_a).flatten()==y_true_a)
    correct_b=(np.asarray(y_pred_b).flatten()==y_true_b)

    n01=int(np.sum(correct_a & ~correct_b))   # A correct, B wrong
    n10=int(np.sum(~correct_a & correct_b))   # A wrong, B correct
    n=n01+n10

    if n==0:
        return np.nan,1.0,n01,n10
    if n<25:
        p=2*min(binom.cdf(min(n01,n10),n,0.5),0.5)   # exact two-sided binomial
        p=min(p,1.0)
        stat=np.nan
    else:
        stat=((abs(n01-n10)-1)**2)/n                  # continuity-corrected chi-square
        p=1-chi2.cdf(stat,1)
    return stat,p,n01,n10

# ================= MODELS =================
def build(name,shape=None,dim=None):
    if name=="CNN":
        m=Sequential([
            Input(shape),
            Conv1D(64,3,activation="relu"),
            Dropout(0.5),
            Conv1D(32,3,activation="relu"),
            GlobalMaxPooling1D(),
            Dense(32,activation="relu"),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="LSTM":
        m=Sequential([
            Input(shape),
            LSTM(128,return_sequences=True),
            Dropout(0.5),
            LSTM(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiLSTM":
        m=Sequential([
            Input(shape),
            Bidirectional(LSTM(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(LSTM(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="GRU":
        m=Sequential([
            Input(shape),
            GRU(128,return_sequences=True),
            Dropout(0.5),
            GRU(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiGRU":
        m=Sequential([
            Input(shape),
            Bidirectional(GRU(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(GRU(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    m.compile(optimizer=Adam(LR),loss="binary_crossentropy",metrics=["accuracy"])
    return m

# ================= STORAGE =================
rows=[]          # global (union-of-clients) test metrics, per (model, seed)
client_rows=[]   # per-client local test metrics, per (model, seed, client)
results_round={m:{"acc":[],"loss":[],"cm":[]} for m in MODELS}

# per-instance predictions, needed for McNemar's test
y_preds={}        # (model, seed) -> y_pred array (0/1), aligned to y_trues[seed]
y_trues={}        # seed -> y_test_global array (0/1) -- same across all models for a given seed

# ================= TRAIN =================
for model_name in MODELS:
    print(f"\n================ MODEL: {model_name} ================")

    for seed in SEEDS:
        print(f"\n------ SEED {seed} ------")
        set_seed(seed)

        # ---- IID partition of the WHOLE dataset across clients ----
        client_full=iid_partition(X,y,CLIENTS)

        # ---- Each client locally splits its own shard into train/test ----
        client_train,client_test=[],[]
        for cid,(Xc,yc) in enumerate(client_full):
            try:
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,stratify=yc,random_state=seed
                )
            except ValueError:
                # fallback if a client shard doesn't have enough of a class to stratify
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,random_state=seed
                )
            client_train.append((Xc_tr,yc_tr))
            client_test.append((Xc_te,yc_te))

        # ---- Global (centralized) test set = union of all clients' local test shards ----
        X_test_global=np.concatenate([Xc for Xc,_ in client_test],axis=0)
        y_test_global=np.concatenate([yc for _,yc in client_test],axis=0)

        create=lambda:build(model_name,shape=(X.shape[1],1))

        fmt=lambda Xc: format_xy(Xc,model_name)

        global_model=create()

        # ---- SCAFFOLD control variates ----
        c_global=[np.zeros_like(w) for w in global_model.get_weights()]              # global control c
        c_clients=[[np.zeros_like(w) for w in global_model.get_weights()]
                   for _ in range(CLIENTS)]                                          # per-client control c_i

        acc_hist,loss_hist=[],[]
        comm=0
        total_train_time=0.0

        for r in range(ROUNDS):
            print(f"\n[Model={model_name} | Seed={seed} | Round={r+1}]")

            global_weights=global_model.get_weights()
            client_weight_deltas=[]; client_c_deltas=[]; sizes=[]

            for cid,(Xc,yc) in enumerate(client_train):
                m=create()
                m.set_weights(global_weights)
                w_init=[w.copy() for w in global_weights]

                t0=time.time()
                history=m.fit(fmt(Xc),yc,epochs=LOCAL_EPOCHS,batch_size=BATCH,verbose=0)
                t1=time.time()
                total_train_time+=(t1-t0)

                train_loss=history.history["loss"][-1]
                train_acc=history.history["accuracy"][-1]
                print(f" Client {cid} → Loss={train_loss:.4f}, Acc={train_acc:.4f}, Time={t1-t0:.2f}s, N={len(yc)}")

                w_final=m.get_weights()

                # ---- SCAFFOLD correction (post-hoc, applied once after local training) ----
                corrected_weights=[
                    w_final[j]-LR*(c_global[j]-c_clients[cid][j])
                    for j in range(len(w_final))
                ]
                m.set_weights(corrected_weights)

                delta_w=[corrected_weights[j]-w_init[j] for j in range(len(w_init))]

                # ---- update client control variate ----
                delta_c=[
                    c_global[j]-c_clients[cid][j]-(1/(LOCAL_EPOCHS*LR))*delta_w[j]
                    for j in range(len(w_init))
                ]
                c_clients[cid]=[c_clients[cid][j]+delta_c[j] for j in range(len(delta_c))]

                client_weight_deltas.append(delta_w)
                client_c_deltas.append(delta_c)
                sizes.append(len(yc))

            scaffold_aggregate(global_model,c_global,client_weight_deltas,client_c_deltas)

            loss,acc=global_model.evaluate(fmt(X_test_global),y_test_global,verbose=0)

            print(f" >>> GLOBAL (centralized test) → Loss={loss:.4f}, Acc={acc:.4f}")

            acc_hist.append(acc); loss_hist.append(loss)

            # bytes per weight (float32=4 bytes), sent down to each client AND back up from each client
            # (SCAFFOLD also exchanges control variates, same size as the weight vector, each round)
            weight_bytes=sum([w.size for w in global_model.get_weights()])*4
            comm+=weight_bytes*CLIENTS*2*2   # x2 for control variates traveling alongside weights

        # ================= FINAL GLOBAL TEST METRICS =================
        t0=time.time()
        y_prob=global_model.predict(fmt(X_test_global),verbose=0)
        inference_time=time.time()-t0

        y_pred=(y_prob>0.5).astype(int)

        # ---- Save per-instance predictions for McNemar's test ----
        y_preds[(model_name,seed)]=y_pred.flatten()
        if seed not in y_trues:
            y_trues[seed]=y_test_global.flatten()
        else:
            # sanity check: every model must see the identical test set for this seed
            assert np.array_equal(y_trues[seed],y_test_global.flatten()), \
                f"Test set mismatch for seed {seed} — McNemar's test requires identical instances across models."

        tn,fp,fn,tp=confusion_matrix(y_test_global,y_pred).ravel()

        # ---- Save this trained global model to disk ----
        model_path=os.path.join(MODEL_SAVE_DIR,f"{model_name}_seed{seed}.keras")
        global_model.save(model_path)
        print(f" [saved] {model_path}")

        rows.append({
            "Model":model_name,
            "Seed":seed,
            "Loss":log_loss(y_test_global,y_prob),
            "Accuracy":accuracy_score(y_test_global,y_pred),
            "Precision":precision_score(y_test_global,y_pred),
            "Recall":recall_score(y_test_global,y_pred),
            "F1":f1_score(y_test_global,y_pred),
            "MCC":matthews_corrcoef(y_test_global,y_pred),
            "AUC":roc_auc_score(y_test_global,y_prob),
            "Specificity":tn/(tn+fp),
            "Training_Time_sec":total_train_time,
            "Inference_Time_sec":inference_time,
            "Model_Size_MB":model_size(global_model),
            "Comm_per_round_MB":comm/(ROUNDS*1024*1024),
            "Total_Comm_MB":comm/(1024*1024),
            "Saved_Model_Path":model_path
        })

        results_round[model_name]["acc"].append(acc_hist)
        results_round[model_name]["loss"].append(loss_hist)
        results_round[model_name]["cm"].append(confusion_matrix(y_test_global,y_pred))

        # ================= PER-CLIENT LOCAL TEST EVALUATION =================
        for cid,(Xc_te,yc_te) in enumerate(client_test):
            yc_prob=global_model.predict(fmt(Xc_te),verbose=0)
            yc_pred=(yc_prob>0.5).astype(int)

            cm_c=confusion_matrix(yc_te,yc_pred,labels=[0,1])
            tn_c,fp_c,fn_c,tp_c=cm_c.ravel()

            auc_val=roc_auc_score(yc_te,yc_prob) if len(np.unique(yc_te))>1 else np.nan

            client_rows.append({
                "Model":model_name,
                "Seed":seed,
                "Client":cid,
                "N_test":len(yc_te),
                "Loss":log_loss(yc_te,yc_prob,labels=[0,1]),
                "Accuracy":accuracy_score(yc_te,yc_pred),
                "Precision":precision_score(yc_te,yc_pred,zero_division=0),
                "Recall":recall_score(yc_te,yc_pred,zero_division=0),
                "F1":f1_score(yc_te,yc_pred,zero_division=0),
                "MCC":matthews_corrcoef(yc_te,yc_pred),
                "AUC":auc_val,
                "Specificity":(tn_c/(tn_c+fp_c)) if (tn_c+fp_c)>0 else np.nan
            })

# ================= PRINT ALL CONFUSION MATRICES PER SEED (GLOBAL TEST) =================
for m in MODELS:
    print(f"\n=== {m}: Global Test Confusion Matrices per Seed ===")
    for seed,cm in zip(SEEDS,results_round[m]["cm"]):
        print(f"Seed {seed}:\n{cm}")

# ================= MEAN OVER SEEDS (GLOBAL TEST, per-round curves + avg cm) =================
for m in MODELS:
    results_round[m]["acc"]=np.mean(results_round[m]["acc"],axis=0)
    results_round[m]["loss"]=np.mean(results_round[m]["loss"],axis=0)
    results_round[m]["cm"]=np.mean(results_round[m]["cm"],axis=0)

for m in MODELS:
    print(f"\n=== {m} (Global Test, averaged over {len(SEEDS)} seeds) ===")
    print("Confusion Matrix (avg):\n",np.round(results_round[m]["cm"],2))
    print("Accuracy per round:",np.round(results_round[m]["acc"],4))
    print("Loss per round:",np.round(results_round[m]["loss"],4))

# ================= PER-MODEL SUMMARY (ALL METRICS incl. time & comm cost, avg over 5 seeds) =================
results_df=pd.DataFrame(rows)

summary_metrics=["Loss","Accuracy","Precision","Recall","F1","MCC","AUC","Specificity",
                  "Training_Time_sec","Inference_Time_sec","Model_Size_MB",
                  "Comm_per_round_MB","Total_Comm_MB"]

per_model_summary=[]
for m in MODELS:
    sub=results_df[results_df["Model"]==m]
    for metric in summary_metrics:
        mean,sd,low,high=stats(sub[metric],metric)
        per_model_summary.append({
            "Model":m,
            "Metric":metric,
            "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
            "95% CI":f"[{low:.4f}, {high:.4f}]"
        })

per_model_summary_df=pd.DataFrame(per_model_summary)
print(f"\nPER-MODEL SUMMARY (mean ± sd, 95% CI over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_summary_df.to_string(index=False))

# wide pivot: one row per model, one column per metric, "mean [low, high]"
per_model_wide=per_model_summary_df.copy()
per_model_wide["Mean [95% CI]"]=per_model_wide.apply(
    lambda r: r["Mean ± SD"].split(" ± ")[0]+" "+r["95% CI"], axis=1
)
per_model_wide=per_model_wide.pivot(index="Model",columns="Metric",values="Mean [95% CI]")
per_model_wide=per_model_wide[summary_metrics]  # keep original metric order
print(f"\nPER-MODEL SUMMARY, WIDE (mean [95% CI] over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_wide.to_string())

# overall pooled summary (all models & seeds together) kept for reference
overall_summary=[]
for metric in summary_metrics:
    mean,sd,low,high=stats(results_df[metric],metric)
    overall_summary.append({
        "Metric":metric,
        "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
        "95% CI":f"[{low:.4f},{high:.4f}]"
    })
overall_summary_df=pd.DataFrame(overall_summary)
print(f"\nSAVED MODELS ({len(results_df)} total, in '{MODEL_SAVE_DIR}/'):\n",
      results_df[["Model","Seed","Saved_Model_Path"]].to_string(index=False))
print("\nOVERALL SUMMARY (all models & seeds pooled):\n",overall_summary_df)

# ================= PER-CLIENT TEST SUMMARY, averaged over 5 seeds =================
client_df=pd.DataFrame(client_rows)
client_metrics=["Accuracy","Precision","Recall","F1","MCC","AUC","Specificity","Loss"]

per_client_summary=(
    client_df.groupby(["Model","Client"])[client_metrics]
    .agg(["mean","std"])
    .round(4)
)
print(f"\nPER-CLIENT TEST SUMMARY (mean/std over {len(SEEDS)} seeds):\n",per_client_summary)

# ================= PAIRWISE PAIRED T-TESTS ACROSS MODELS (same seeds) =================
paired_test_metrics=["Accuracy","F1","AUC","Loss"]

pairwise_rows=[]
for metric in paired_test_metrics:
    for m1,m2 in combinations(MODELS,2):
        a=results_df[results_df["Model"]==m1].sort_values("Seed")[metric].values
        b=results_df[results_df["Model"]==m2].sort_values("Seed")[metric].values
        t_stat,p_val=ttest_rel(a,b)
        pairwise_rows.append({
            "Metric":metric,"Model A":m1,"Model B":m2,
            "Mean A":round(a.mean(),4),"Mean B":round(b.mean(),4),
            "t-stat":round(t_stat,4),"p-value":round(p_val,4),
            "Significant (p<0.05)":p_val<0.05
        })

pairwise_df=pd.DataFrame(pairwise_rows)
print(f"\nPAIRWISE PAIRED T-TESTS across {len(SEEDS)} seeds (Global Test Set):\n",
      pairwise_df.to_string(index=False))

# ================= McNEMAR'S TEST (per-instance, per seed + pooled across seeds) =================
mcnemar_per_seed_rows=[]
for seed in SEEDS:
    y_true=y_trues[seed]
    for m1,m2 in combinations(MODELS,2):
        stat,p,n01,n10=mcnemar_test(y_true,y_preds[(m1,seed)],y_true,y_preds[(m2,seed)])
        mcnemar_per_seed_rows.append({
            "Seed":seed,"Model A":m1,"Model B":m2,
            "A right/B wrong":n01,"A wrong/B right":n10,
            "stat":round(stat,4) if not np.isnan(stat) else "exact",
            "p-value":round(p,4),"Significant (p<0.05)":p<0.05
        })

mcnemar_per_seed_df=pd.DataFrame(mcnemar_per_seed_rows)
print(f"\nMcNEMAR'S TEST — PER SEED (instance-level, Global Test Set):\n",
      mcnemar_per_seed_df.to_string(index=False))

# pooled version: sum discordant counts across all 5 seeds (more statistical power)
mcnemar_pooled_rows=[]
for m1,m2 in combinations(MODELS,2):
    n01_total=0; n10_total=0
    for seed in SEEDS:
        y_true=y_trues[seed]
        correct_a=(y_preds[(m1,seed)]==y_true)
        correct_b=(y_preds[(m2,seed)]==y_true)
        n01_total+=int(np.sum(correct_a & ~correct_b))
        n10_total+=int(np.sum(~correct_a & correct_b))
    n=n01_total+n10_total
    if n==0:
        stat,p=np.nan,1.0
    elif n<25:
        p=min(2*min(binom.cdf(min(n01_total,n10_total),n,0.5),0.5),1.0); stat=np.nan
    else:
        stat=((abs(n01_total-n10_total)-1)**2)/n
        p=1-chi2.cdf(stat,1)
    mcnemar_pooled_rows.append({
        "Model A":m1,"Model B":m2,
        "A right/B wrong (pooled)":n01_total,"A wrong/B right (pooled)":n10_total,
        "stat":round(stat,4) if not np.isnan(stat) else "exact",
        "p-value":round(p,4),"Significant (p<0.05)":p<0.05
    })

mcnemar_pooled_df=pd.DataFrame(mcnemar_pooled_rows)
print(f"\nMcNEMAR'S TEST — POOLED ACROSS {len(SEEDS)} SEEDS (Global Test Set):\n",
      mcnemar_pooled_df.to_string(index=False))

# ================= PLOTS =================
rounds=np.arange(1,ROUNDS+1)

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["acc"],label=m)
plt.title("Accuracy vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Accuracy")
plt.legend(); plt.grid(); plt.show()

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["loss"],label=m)
plt.title("Loss vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Loss")
plt.legend(); plt.grid(); plt.show()
# Out:
# C:\Users\USER\anaconda3\envs\py310\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.5.0) or chardet (6.0.0.post1)/charset_normalizer (3.4.3) doesn't match a supported version!
#   warnings.warn(
# ================ MODEL: CNN ================
#
# ------ SEED 42 ------
#
# [Model=CNN | Seed=42 | Round=1]
#  Client 0 → Loss=0.0540, Acc=0.9871, Time=6.38s, N=20244
#  Client 1 → Loss=0.0586, Acc=0.9853, Time=4.61s, N=20244
#  Client 2 → Loss=0.0549, Acc=0.9872, Time=4.55s, N=20243
#  Client 3 → Loss=0.0559, Acc=0.9870, Time=4.52s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0332, Acc=0.9917
#
# [Model=CNN | Seed=42 | Round=2]
#  Client 0 → Loss=0.0297, Acc=0.9921, Time=4.38s, N=20244
#  Client 1 → Loss=0.0358, Acc=0.9917, Time=4.48s, N=20244
#  Client 2 → Loss=0.0277, Acc=0.9929, Time=4.65s, N=20243
#  Client 3 → Loss=0.0307, Acc=0.9918, Time=5.01s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0134, Acc=0.9949
#
# [Model=CNN | Seed=42 | Round=3]
#  Client 0 → Loss=0.0198, Acc=0.9944, Time=4.48s, N=20244
#  Client 1 → Loss=0.0237, Acc=0.9932, Time=5.23s, N=20244
#  Client 2 → Loss=0.0180, Acc=0.9945, Time=5.11s, N=20243
#  Client 3 → Loss=0.0219, Acc=0.9932, Time=4.38s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0083, Acc=0.9958
#
# [Model=CNN | Seed=42 | Round=4]
#  Client 0 → Loss=0.0151, Acc=0.9950, Time=4.53s, N=20244
#  Client 1 → Loss=0.0183, Acc=0.9942, Time=4.58s, N=20244
#  Client 2 → Loss=0.0142, Acc=0.9951, Time=4.41s, N=20243
#  Client 3 → Loss=0.0172, Acc=0.9943, Time=4.44s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0074, Acc=0.9957
#
# [Model=CNN | Seed=42 | Round=5]
#  Client 0 → Loss=0.0137, Acc=0.9957, Time=4.46s, N=20244
#  Client 1 → Loss=0.0162, Acc=0.9947, Time=4.45s, N=20244
#  Client 2 → Loss=0.0124, Acc=0.9952, Time=4.41s, N=20243
#  Client 3 → Loss=0.0144, Acc=0.9953, Time=4.30s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0067, Acc=0.9964
#
# [Model=CNN | Seed=42 | Round=6]
#  Client 0 → Loss=0.0109, Acc=0.9963, Time=4.35s, N=20244
#  Client 1 → Loss=0.0143, Acc=0.9950, Time=4.49s, N=20244
#  Client 2 → Loss=0.0115, Acc=0.9961, Time=4.50s, N=20243
#  Client 3 → Loss=0.0123, Acc=0.9957, Time=4.66s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0064, Acc=0.9966
#
# [Model=CNN | Seed=42 | Round=7]
#  Client 0 → Loss=0.0099, Acc=0.9967, Time=4.53s, N=20244
#  Client 1 → Loss=0.0118, Acc=0.9956, Time=4.36s, N=20244
#  Client 2 → Loss=0.0124, Acc=0.9961, Time=4.40s, N=20243
#  Client 3 → Loss=0.0114, Acc=0.9960, Time=4.50s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0066, Acc=0.9964
#
# [Model=CNN | Seed=42 | Round=8]
#  Client 0 → Loss=0.0093, Acc=0.9966, Time=4.42s, N=20244
#  Client 1 → Loss=0.0125, Acc=0.9957, Time=4.45s, N=20244
#  Client 2 → Loss=0.0094, Acc=0.9969, Time=4.54s, N=20243
#  Client 3 → Loss=0.0119, Acc=0.9958, Time=4.51s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0062, Acc=0.9970
#
# [Model=CNN | Seed=42 | Round=9]
#  Client 0 → Loss=0.0088, Acc=0.9967, Time=4.67s, N=20244
#  Client 1 → Loss=0.0111, Acc=0.9957, Time=4.49s, N=20244
#  Client 2 → Loss=0.0080, Acc=0.9971, Time=4.56s, N=20243
#  Client 3 → Loss=0.0107, Acc=0.9957, Time=4.70s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0063, Acc=0.9969
#
# [Model=CNN | Seed=42 | Round=10]
#  Client 0 → Loss=0.0087, Acc=0.9967, Time=4.66s, N=20244
#  Client 1 → Loss=0.0126, Acc=0.9950, Time=4.55s, N=20244
#  Client 2 → Loss=0.0079, Acc=0.9975, Time=4.63s, N=20243
#  Client 3 → Loss=0.0097, Acc=0.9964, Time=4.73s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0061, Acc=0.9974
#
# [Model=CNN | Seed=42 | Round=11]
#  Client 0 → Loss=0.0071, Acc=0.9972, Time=4.92s, N=20244
#  Client 1 → Loss=0.0107, Acc=0.9956, Time=4.63s, N=20244
#  Client 2 → Loss=0.0070, Acc=0.9973, Time=4.68s, N=20243
#  Client 3 → Loss=0.0096, Acc=0.9965, Time=4.48s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0064, Acc=0.9972
#
# [Model=CNN | Seed=42 | Round=12]
#  Client 0 → Loss=0.0064, Acc=0.9971, Time=4.62s, N=20244
#  Client 1 → Loss=0.0115, Acc=0.9959, Time=4.42s, N=20244
#  Client 2 → Loss=0.0087, Acc=0.9967, Time=4.37s, N=20243
#  Client 3 → Loss=0.0110, Acc=0.9963, Time=4.56s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0061, Acc=0.9972
#
# [Model=CNN | Seed=42 | Round=13]
#  Client 0 → Loss=0.0070, Acc=0.9967, Time=4.63s, N=20244
#  Client 1 → Loss=0.0117, Acc=0.9959, Time=4.84s, N=20244
#  Client 2 → Loss=0.0078, Acc=0.9973, Time=4.63s, N=20243
#  Client 3 → Loss=0.0079, Acc=0.9969, Time=4.71s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0065, Acc=0.9972
#
# [Model=CNN | Seed=42 | Round=14]
#  Client 0 → Loss=0.0066, Acc=0.9973, Time=4.63s, N=20244
#  Client 1 → Loss=0.0093, Acc=0.9964, Time=4.79s, N=20244
#  Client 2 → Loss=0.0077, Acc=0.9967, Time=4.72s, N=20243
#  Client 3 → Loss=0.0085, Acc=0.9970, Time=4.42s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0064, Acc=0.9973
#
# [Model=CNN | Seed=42 | Round=15]
#  Client 0 → Loss=0.0074, Acc=0.9971, Time=4.53s, N=20244
#  Client 1 → Loss=0.0106, Acc=0.9967, Time=4.30s, N=20244
#  Client 2 → Loss=0.0065, Acc=0.9972, Time=4.37s, N=20243
#  Client 3 → Loss=0.0080, Acc=0.9967, Time=4.49s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0065, Acc=0.9972
#
# [Model=CNN | Seed=42 | Round=16]
#  Client 0 → Loss=0.0076, Acc=0.9972, Time=4.28s, N=20244
#  Client 1 → Loss=0.0105, Acc=0.9963, Time=4.28s, N=20244
#  Client 2 → Loss=0.0073, Acc=0.9969, Time=4.32s, N=20243
#  Client 3 → Loss=0.0069, Acc=0.9970, Time=4.31s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0064, Acc=0.9972
#
# [Model=CNN | Seed=42 | Round=17]
#  Client 0 → Loss=0.0050, Acc=0.9978, Time=4.30s, N=20244
#  Client 1 → Loss=0.0102, Acc=0.9965, Time=4.36s, N=20244
#  Client 2 → Loss=0.0089, Acc=0.9968, Time=4.59s, N=20243
#  Client 3 → Loss=0.0069, Acc=0.9974, Time=4.41s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0065, Acc=0.9971
#
# [Model=CNN | Seed=42 | Round=18]
#  Client 0 → Loss=0.0063, Acc=0.9974, Time=4.34s, N=20244
#  Client 1 → Loss=0.0093, Acc=0.9965, Time=4.43s, N=20244
#  Client 2 → Loss=0.0060, Acc=0.9979, Time=4.29s, N=20243
#  Client 3 → Loss=0.0085, Acc=0.9965, Time=4.42s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0060, Acc=0.9971
#
# [Model=CNN | Seed=42 | Round=19]
#  Client 0 → Loss=0.0100, Acc=0.9967, Time=4.53s, N=20244
#  Client 1 → Loss=0.0102, Acc=0.9968, Time=4.42s, N=20244
#  Client 2 → Loss=0.0063, Acc=0.9978, Time=4.36s, N=20243
#  Client 3 → Loss=0.0075, Acc=0.9974, Time=4.79s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0067, Acc=0.9971
#
# [Model=CNN | Seed=42 | Round=20]
#  Client 0 → Loss=0.0050, Acc=0.9977, Time=4.55s, N=20244
#  Client 1 → Loss=0.0092, Acc=0.9963, Time=4.26s, N=20244
#  Client 2 → Loss=0.0059, Acc=0.9979, Time=4.37s, N=20243
#  Client 3 → Loss=0.0095, Acc=0.9968, Time=4.53s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0060, Acc=0.9973
#
# [Model=CNN | Seed=42 | Round=21]
#  Client 0 → Loss=0.0071, Acc=0.9975, Time=4.44s, N=20244
#  Client 1 → Loss=0.0086, Acc=0.9976, Time=4.36s, N=20244
#  Client 2 → Loss=0.0068, Acc=0.9970, Time=4.23s, N=20243
#  Client 3 → Loss=0.0063, Acc=0.9973, Time=4.22s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0064, Acc=0.9974
#
# [Model=CNN | Seed=42 | Round=22]
#  Client 0 → Loss=0.0036, Acc=0.9974, Time=4.15s, N=20244
#  Client 1 → Loss=0.0089, Acc=0.9968, Time=4.28s, N=20244
#  Client 2 → Loss=0.0048, Acc=0.9980, Time=4.17s, N=20243
#  Client 3 → Loss=0.0070, Acc=0.9974, Time=4.20s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0065, Acc=0.9972
#
# [Model=CNN | Seed=42 | Round=23]
#  Client 0 → Loss=0.0065, Acc=0.9972, Time=4.20s, N=20244
#  Client 1 → Loss=0.0079, Acc=0.9969, Time=4.36s, N=20244
#  Client 2 → Loss=0.0066, Acc=0.9977, Time=4.37s, N=20243
#  Client 3 → Loss=0.0083, Acc=0.9969, Time=4.30s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0065, Acc=0.9973
#
# [Model=CNN | Seed=42 | Round=24]
#  Client 0 → Loss=0.0063, Acc=0.9965, Time=4.61s, N=20244
#  Client 1 → Loss=0.0084, Acc=0.9966, Time=4.50s, N=20244
#  Client 2 → Loss=0.0090, Acc=0.9974, Time=4.49s, N=20243
#  Client 3 → Loss=0.0084, Acc=0.9969, Time=4.39s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0071, Acc=0.9971
#
# [Model=CNN | Seed=42 | Round=25]
#  Client 0 → Loss=0.0055, Acc=0.9976, Time=4.37s, N=20244
#  Client 1 → Loss=0.0087, Acc=0.9971, Time=4.32s, N=20244
#  Client 2 → Loss=0.0060, Acc=0.9980, Time=4.34s, N=20243
#  Client 3 → Loss=0.0075, Acc=0.9971, Time=4.49s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0060, Acc=0.9973
#
# [Model=CNN | Seed=42 | Round=26]
#  Client 0 → Loss=0.0029, Acc=0.9980, Time=4.51s, N=20244
#  Client 1 → Loss=0.0096, Acc=0.9969, Time=4.46s, N=20244
#  Client 2 → Loss=0.0059, Acc=0.9975, Time=4.62s, N=20243
#  Client 3 → Loss=0.0065, Acc=0.9975, Time=4.36s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0068, Acc=0.9968
#
# [Model=CNN | Seed=42 | Round=27]
#  Client 0 → Loss=0.0029, Acc=0.9980, Time=4.43s, N=20244
#  Client 1 → Loss=0.0119, Acc=0.9962, Time=4.41s, N=20244
#  Client 2 → Loss=0.0064, Acc=0.9978, Time=4.37s, N=20243
#  Client 3 → Loss=0.0074, Acc=0.9971, Time=4.34s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0062, Acc=0.9972
#
# [Model=CNN | Seed=42 | Round=28]
#  Client 0 → Loss=0.0020, Acc=0.9978, Time=4.44s, N=20244
#  Client 1 → Loss=0.0086, Acc=0.9972, Time=4.60s, N=20244
#  Client 2 → Loss=0.0067, Acc=0.9978, Time=4.45s, N=20243
#  Client 3 → Loss=0.0082, Acc=0.9971, Time=4.37s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0058, Acc=0.9975
#
# [Model=CNN | Seed=42 | Round=29]
#  Client 0 → Loss=0.0070, Acc=0.9975, Time=4.48s, N=20244
#  Client 1 → Loss=0.0098, Acc=0.9970, Time=4.77s, N=20244
#  Client 2 → Loss=0.0058, Acc=0.9981, Time=4.78s, N=20243
#  Client 3 → Loss=0.0053, Acc=0.9980, Time=4.90s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0066, Acc=0.9972
#
# [Model=CNN | Seed=42 | Round=30]
#  Client 0 → Loss=0.0018, Acc=0.9978, Time=4.89s, N=20244
#  Client 1 → Loss=0.0107, Acc=0.9970, Time=4.60s, N=20244
#  Client 2 → Loss=0.0078, Acc=0.9976, Time=4.85s, N=20243
#  Client 3 → Loss=0.0061, Acc=0.9975, Time=4.58s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0059, Acc=0.9974
#  [saved] saved_models\CNN_seed42.keras
#
# ------ SEED 3 ------
#
# [Model=CNN | Seed=3 | Round=1]
#  Client 0 → Loss=0.0636, Acc=0.9836, Time=4.51s, N=20244
#  Client 1 → Loss=0.0634, Acc=0.9851, Time=4.47s, N=20244
#  Client 2 → Loss=0.0622, Acc=0.9855, Time=4.41s, N=20243
#  Client 3 → Loss=0.0590, Acc=0.9858, Time=4.31s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0479, Acc=0.9917
#
# [Model=CNN | Seed=3 | Round=2]
#  Client 0 → Loss=0.0341, Acc=0.9912, Time=4.25s, N=20244
#  Client 1 → Loss=0.0336, Acc=0.9919, Time=4.24s, N=20244
#  Client 2 → Loss=0.0363, Acc=0.9910, Time=4.47s, N=20243
#  Client 3 → Loss=0.0332, Acc=0.9915, Time=4.99s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0155, Acc=0.9949
#
# [Model=CNN | Seed=3 | Round=3]
#  Client 0 → Loss=0.0219, Acc=0.9934, Time=4.66s, N=20244
#  Client 1 → Loss=0.0229, Acc=0.9945, Time=4.62s, N=20244
#  Client 2 → Loss=0.0246, Acc=0.9937, Time=4.55s, N=20243
#  Client 3 → Loss=0.0235, Acc=0.9936, Time=4.46s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0111, Acc=0.9965
#
# [Model=CNN | Seed=3 | Round=4]
#  Client 0 → Loss=0.0165, Acc=0.9951, Time=4.45s, N=20244
#  Client 1 → Loss=0.0179, Acc=0.9955, Time=4.44s, N=20244
#  Client 2 → Loss=0.0186, Acc=0.9947, Time=4.37s, N=20243
#  Client 3 → Loss=0.0180, Acc=0.9953, Time=4.45s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0098, Acc=0.9967
#
# [Model=CNN | Seed=3 | Round=5]
#  Client 0 → Loss=0.0134, Acc=0.9956, Time=4.27s, N=20244
#  Client 1 → Loss=0.0159, Acc=0.9954, Time=4.37s, N=20244
#  Client 2 → Loss=0.0161, Acc=0.9952, Time=4.42s, N=20243
#  Client 3 → Loss=0.0152, Acc=0.9956, Time=4.37s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0090, Acc=0.9967
#
# [Model=CNN | Seed=3 | Round=6]
#  Client 0 → Loss=0.0116, Acc=0.9959, Time=4.24s, N=20244
#  Client 1 → Loss=0.0135, Acc=0.9962, Time=4.31s, N=20244
#  Client 2 → Loss=0.0145, Acc=0.9954, Time=4.39s, N=20243
#  Client 3 → Loss=0.0121, Acc=0.9964, Time=4.53s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0082, Acc=0.9966
#
# [Model=CNN | Seed=3 | Round=7]
#  Client 0 → Loss=0.0107, Acc=0.9961, Time=4.34s, N=20244
#  Client 1 → Loss=0.0126, Acc=0.9966, Time=4.63s, N=20244
#  Client 2 → Loss=0.0129, Acc=0.9959, Time=4.38s, N=20243
#  Client 3 → Loss=0.0122, Acc=0.9960, Time=4.37s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0077, Acc=0.9969
#
# [Model=CNN | Seed=3 | Round=8]
#  Client 0 → Loss=0.0098, Acc=0.9964, Time=4.40s, N=20244
#  Client 1 → Loss=0.0111, Acc=0.9970, Time=4.56s, N=20244
#  Client 2 → Loss=0.0111, Acc=0.9962, Time=4.48s, N=20243
#  Client 3 → Loss=0.0104, Acc=0.9969, Time=4.49s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0076, Acc=0.9969
#
# [Model=CNN | Seed=3 | Round=9]
#  Client 0 → Loss=0.0076, Acc=0.9965, Time=4.64s, N=20244
#  Client 1 → Loss=0.0115, Acc=0.9970, Time=4.76s, N=20244
#  Client 2 → Loss=0.0129, Acc=0.9959, Time=4.58s, N=20243
#  Client 3 → Loss=0.0101, Acc=0.9966, Time=4.57s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0073, Acc=0.9969
#
# [Model=CNN | Seed=3 | Round=10]
#  Client 0 → Loss=0.0087, Acc=0.9968, Time=4.40s, N=20244
#  Client 1 → Loss=0.0094, Acc=0.9969, Time=4.77s, N=20244
#  Client 2 → Loss=0.0118, Acc=0.9964, Time=4.64s, N=20243
#  Client 3 → Loss=0.0082, Acc=0.9975, Time=4.42s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0071, Acc=0.9970
#
# [Model=CNN | Seed=3 | Round=11]
#  Client 0 → Loss=0.0083, Acc=0.9961, Time=4.55s, N=20244
#  Client 1 → Loss=0.0099, Acc=0.9974, Time=4.53s, N=20244
#  Client 2 → Loss=0.0088, Acc=0.9968, Time=4.45s, N=20243
#  Client 3 → Loss=0.0086, Acc=0.9973, Time=4.58s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0071, Acc=0.9970
#
# [Model=CNN | Seed=3 | Round=12]
#  Client 0 → Loss=0.0079, Acc=0.9968, Time=4.85s, N=20244
#  Client 1 → Loss=0.0074, Acc=0.9973, Time=4.62s, N=20244
#  Client 2 → Loss=0.0114, Acc=0.9963, Time=4.48s, N=20243
#  Client 3 → Loss=0.0086, Acc=0.9973, Time=4.51s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0076, Acc=0.9971
#
# [Model=CNN | Seed=3 | Round=13]
#  Client 0 → Loss=0.0083, Acc=0.9966, Time=4.51s, N=20244
#  Client 1 → Loss=0.0079, Acc=0.9979, Time=4.37s, N=20244
#  Client 2 → Loss=0.0114, Acc=0.9964, Time=4.52s, N=20243
#  Client 3 → Loss=0.0073, Acc=0.9976, Time=4.56s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0069, Acc=0.9970
#
# [Model=CNN | Seed=3 | Round=14]
#  Client 0 → Loss=0.0069, Acc=0.9967, Time=4.39s, N=20244
#  Client 1 → Loss=0.0084, Acc=0.9976, Time=4.36s, N=20244
#  Client 2 → Loss=0.0078, Acc=0.9972, Time=4.42s, N=20243
#  Client 3 → Loss=0.0072, Acc=0.9976, Time=4.33s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0072, Acc=0.9970
#
# [Model=CNN | Seed=3 | Round=15]
#  Client 0 → Loss=0.0069, Acc=0.9975, Time=4.30s, N=20244
#  Client 1 → Loss=0.0086, Acc=0.9975, Time=4.38s, N=20244
#  Client 2 → Loss=0.0105, Acc=0.9964, Time=4.28s, N=20243
#  Client 3 → Loss=0.0085, Acc=0.9973, Time=4.40s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0070, Acc=0.9969
#
# [Model=CNN | Seed=3 | Round=16]
#  Client 0 → Loss=0.0079, Acc=0.9965, Time=4.48s, N=20244
#  Client 1 → Loss=0.0099, Acc=0.9977, Time=4.40s, N=20244
#  Client 2 → Loss=0.0093, Acc=0.9967, Time=4.35s, N=20243
#  Client 3 → Loss=0.0083, Acc=0.9974, Time=4.57s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0070, Acc=0.9970
#
# [Model=CNN | Seed=3 | Round=17]
#  Client 0 → Loss=0.0058, Acc=0.9968, Time=4.38s, N=20244
#  Client 1 → Loss=0.0103, Acc=0.9977, Time=4.54s, N=20244
#  Client 2 → Loss=0.0106, Acc=0.9962, Time=4.38s, N=20243
#  Client 3 → Loss=0.0081, Acc=0.9973, Time=4.49s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0078, Acc=0.9970
#
# [Model=CNN | Seed=3 | Round=18]
#  Client 0 → Loss=0.0036, Acc=0.9976, Time=4.40s, N=20244
#  Client 1 → Loss=0.0077, Acc=0.9978, Time=4.27s, N=20244
#  Client 2 → Loss=0.0082, Acc=0.9972, Time=4.34s, N=20243
#  Client 3 → Loss=0.0079, Acc=0.9980, Time=4.31s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0076, Acc=0.9971
#
# [Model=CNN | Seed=3 | Round=19]
#  Client 0 → Loss=0.0071, Acc=0.9963, Time=4.39s, N=20244
#  Client 1 → Loss=0.0097, Acc=0.9978, Time=4.52s, N=20244
#  Client 2 → Loss=0.0091, Acc=0.9972, Time=4.40s, N=20243
#  Client 3 → Loss=0.0061, Acc=0.9980, Time=4.34s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0071, Acc=0.9972
#
# [Model=CNN | Seed=3 | Round=20]
#  Client 0 → Loss=0.0036, Acc=0.9975, Time=4.68s, N=20244
#  Client 1 → Loss=0.0101, Acc=0.9980, Time=4.50s, N=20244
#  Client 2 → Loss=0.0086, Acc=0.9973, Time=4.38s, N=20243
#  Client 3 → Loss=0.0077, Acc=0.9980, Time=4.44s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0075, Acc=0.9966
#
# [Model=CNN | Seed=3 | Round=21]
#  Client 0 → Loss=0.0045, Acc=0.9974, Time=4.59s, N=20244
#  Client 1 → Loss=0.0081, Acc=0.9981, Time=4.46s, N=20244
#  Client 2 → Loss=0.0081, Acc=0.9972, Time=4.67s, N=20243
#  Client 3 → Loss=0.0081, Acc=0.9978, Time=4.86s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0077, Acc=0.9969
#
# [Model=CNN | Seed=3 | Round=22]
#  Client 0 → Loss=0.0063, Acc=0.9967, Time=4.65s, N=20244
#  Client 1 → Loss=0.0104, Acc=0.9974, Time=4.73s, N=20244
#  Client 2 → Loss=0.0103, Acc=0.9969, Time=4.76s, N=20243
#  Client 3 → Loss=0.0068, Acc=0.9981, Time=4.50s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0070, Acc=0.9971
#
# [Model=CNN | Seed=3 | Round=23]
#  Client 0 → Loss=0.0043, Acc=0.9977, Time=4.44s, N=20244
#  Client 1 → Loss=0.0071, Acc=0.9982, Time=4.59s, N=20244
#  Client 2 → Loss=0.0095, Acc=0.9971, Time=4.40s, N=20243
#  Client 3 → Loss=0.0063, Acc=0.9983, Time=4.18s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0076, Acc=0.9971
#
# [Model=CNN | Seed=3 | Round=24]
#  Client 0 → Loss=0.0087, Acc=0.9966, Time=4.25s, N=20244
#  Client 1 → Loss=0.0069, Acc=0.9983, Time=4.28s, N=20244
#  Client 2 → Loss=0.0093, Acc=0.9973, Time=4.26s, N=20243
#  Client 3 → Loss=0.0077, Acc=0.9982, Time=4.34s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0085, Acc=0.9962
#
# [Model=CNN | Seed=3 | Round=25]
#  Client 0 → Loss=0.0035, Acc=0.9975, Time=4.34s, N=20244
#  Client 1 → Loss=0.0052, Acc=0.9985, Time=4.53s, N=20244
#  Client 2 → Loss=0.0095, Acc=0.9972, Time=4.58s, N=20243
#  Client 3 → Loss=0.0050, Acc=0.9984, Time=4.36s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0080, Acc=0.9971
#
# [Model=CNN | Seed=3 | Round=26]
#  Client 0 → Loss=0.0049, Acc=0.9975, Time=4.29s, N=20244
#  Client 1 → Loss=0.0057, Acc=0.9985, Time=4.38s, N=20244
#  Client 2 → Loss=0.0083, Acc=0.9973, Time=4.33s, N=20243
#  Client 3 → Loss=0.0052, Acc=0.9986, Time=4.36s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0068, Acc=0.9972
#
# [Model=CNN | Seed=3 | Round=27]
#  Client 0 → Loss=0.0035, Acc=0.9973, Time=4.47s, N=20244
#  Client 1 → Loss=0.0084, Acc=0.9980, Time=4.40s, N=20244
#  Client 2 → Loss=0.0103, Acc=0.9969, Time=4.47s, N=20243
#  Client 3 → Loss=0.0069, Acc=0.9982, Time=4.47s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0072, Acc=0.9970
#
# [Model=CNN | Seed=3 | Round=28]
#  Client 0 → Loss=0.0036, Acc=0.9974, Time=4.59s, N=20244
#  Client 1 → Loss=0.0075, Acc=0.9979, Time=4.47s, N=20244
#  Client 2 → Loss=0.0073, Acc=0.9978, Time=4.44s, N=20243
#  Client 3 → Loss=0.0067, Acc=0.9983, Time=4.49s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0079, Acc=0.9971
#
# [Model=CNN | Seed=3 | Round=29]
#  Client 0 → Loss=0.0030, Acc=0.9979, Time=4.55s, N=20244
#  Client 1 → Loss=0.0082, Acc=0.9979, Time=4.54s, N=20244
#  Client 2 → Loss=0.0101, Acc=0.9972, Time=4.54s, N=20243
#  Client 3 → Loss=0.0069, Acc=0.9981, Time=4.60s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0081, Acc=0.9970
#
# [Model=CNN | Seed=3 | Round=30]
#  Client 0 → Loss=0.0104, Acc=0.9963, Time=4.57s, N=20244
#  Client 1 → Loss=0.0122, Acc=0.9976, Time=4.58s, N=20244
#  Client 2 → Loss=0.0105, Acc=0.9970, Time=4.20s, N=20243
#  Client 3 → Loss=0.0047, Acc=0.9986, Time=4.16s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0077, Acc=0.9968
#  [saved] saved_models\CNN_seed3.keras
#
# ------ SEED 7 ------
#
# [Model=CNN | Seed=7 | Round=1]
#  Client 0 → Loss=0.0660, Acc=0.9841, Time=4.54s, N=20244
#  Client 1 → Loss=0.0570, Acc=0.9859, Time=4.32s, N=20244
#  Client 2 → Loss=0.0640, Acc=0.9836, Time=4.52s, N=20243
#  Client 3 → Loss=0.0596, Acc=0.9851, Time=4.53s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0413, Acc=0.9906
#
# [Model=CNN | Seed=7 | Round=2]
#  Client 0 → Loss=0.0397, Acc=0.9895, Time=4.65s, N=20244
#  Client 1 → Loss=0.0302, Acc=0.9919, Time=4.68s, N=20244
#  Client 2 → Loss=0.0327, Acc=0.9910, Time=4.54s, N=20243
#  Client 3 → Loss=0.0323, Acc=0.9913, Time=4.31s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0178, Acc=0.9943
#
# [Model=CNN | Seed=7 | Round=3]
#  Client 0 → Loss=0.0257, Acc=0.9920, Time=4.62s, N=20244
#  Client 1 → Loss=0.0198, Acc=0.9941, Time=4.48s, N=20244
#  Client 2 → Loss=0.0218, Acc=0.9931, Time=4.49s, N=20243
#  Client 3 → Loss=0.0198, Acc=0.9940, Time=4.32s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0143, Acc=0.9956
#
# [Model=CNN | Seed=7 | Round=4]
#  Client 0 → Loss=0.0201, Acc=0.9928, Time=4.35s, N=20244
#  Client 1 → Loss=0.0161, Acc=0.9950, Time=4.47s, N=20244
#  Client 2 → Loss=0.0162, Acc=0.9943, Time=4.42s, N=20243
#  Client 3 → Loss=0.0153, Acc=0.9947, Time=4.50s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0119, Acc=0.9961
#
# [Model=CNN | Seed=7 | Round=5]
#  Client 0 → Loss=0.0170, Acc=0.9933, Time=4.50s, N=20244
#  Client 1 → Loss=0.0125, Acc=0.9953, Time=4.45s, N=20244
#  Client 2 → Loss=0.0131, Acc=0.9957, Time=4.40s, N=20243
#  Client 3 → Loss=0.0132, Acc=0.9953, Time=4.39s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0113, Acc=0.9961
#
# [Model=CNN | Seed=7 | Round=6]
#  Client 0 → Loss=0.0152, Acc=0.9941, Time=4.29s, N=20244
#  Client 1 → Loss=0.0107, Acc=0.9963, Time=4.51s, N=20244
#  Client 2 → Loss=0.0136, Acc=0.9951, Time=4.34s, N=20243
#  Client 3 → Loss=0.0114, Acc=0.9954, Time=4.42s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0101, Acc=0.9966
#
# [Model=CNN | Seed=7 | Round=7]
#  Client 0 → Loss=0.0140, Acc=0.9947, Time=4.41s, N=20244
#  Client 1 → Loss=0.0110, Acc=0.9962, Time=4.38s, N=20244
#  Client 2 → Loss=0.0124, Acc=0.9954, Time=4.37s, N=20243
#  Client 3 → Loss=0.0113, Acc=0.9957, Time=4.42s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0103, Acc=0.9967
#
# [Model=CNN | Seed=7 | Round=8]
#  Client 0 → Loss=0.0128, Acc=0.9951, Time=4.36s, N=20244
#  Client 1 → Loss=0.0113, Acc=0.9961, Time=4.47s, N=20244
#  Client 2 → Loss=0.0120, Acc=0.9963, Time=4.47s, N=20243
#  Client 3 → Loss=0.0108, Acc=0.9963, Time=4.41s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0099, Acc=0.9969
#
# [Model=CNN | Seed=7 | Round=9]
#  Client 0 → Loss=0.0129, Acc=0.9950, Time=4.46s, N=20244
#  Client 1 → Loss=0.0096, Acc=0.9965, Time=4.48s, N=20244
#  Client 2 → Loss=0.0126, Acc=0.9953, Time=4.38s, N=20243
#  Client 3 → Loss=0.0093, Acc=0.9962, Time=4.43s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0107, Acc=0.9966
#
# [Model=CNN | Seed=7 | Round=10]
#  Client 0 → Loss=0.0112, Acc=0.9951, Time=4.58s, N=20244
#  Client 1 → Loss=0.0073, Acc=0.9971, Time=4.30s, N=20244
#  Client 2 → Loss=0.0110, Acc=0.9963, Time=4.29s, N=20243
#  Client 3 → Loss=0.0086, Acc=0.9963, Time=4.37s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0100, Acc=0.9972
#
# [Model=CNN | Seed=7 | Round=11]
#  Client 0 → Loss=0.0118, Acc=0.9951, Time=4.30s, N=20244
#  Client 1 → Loss=0.0088, Acc=0.9962, Time=4.35s, N=20244
#  Client 2 → Loss=0.0103, Acc=0.9963, Time=4.58s, N=20243
#  Client 3 → Loss=0.0094, Acc=0.9965, Time=4.64s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0103, Acc=0.9971
#
# [Model=CNN | Seed=7 | Round=12]
#  Client 0 → Loss=0.0110, Acc=0.9955, Time=4.56s, N=20244
#  Client 1 → Loss=0.0081, Acc=0.9967, Time=4.47s, N=20244
#  Client 2 → Loss=0.0104, Acc=0.9961, Time=4.68s, N=20243
#  Client 3 → Loss=0.0090, Acc=0.9964, Time=4.52s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0101, Acc=0.9974
#
# [Model=CNN | Seed=7 | Round=13]
#  Client 0 → Loss=0.0079, Acc=0.9962, Time=4.48s, N=20244
#  Client 1 → Loss=0.0088, Acc=0.9968, Time=4.38s, N=20244
#  Client 2 → Loss=0.0105, Acc=0.9965, Time=4.33s, N=20243
#  Client 3 → Loss=0.0093, Acc=0.9969, Time=4.35s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0108, Acc=0.9969
#
# [Model=CNN | Seed=7 | Round=14]
#  Client 0 → Loss=0.0104, Acc=0.9953, Time=4.28s, N=20244
#  Client 1 → Loss=0.0079, Acc=0.9968, Time=4.41s, N=20244
#  Client 2 → Loss=0.0080, Acc=0.9969, Time=4.32s, N=20243
#  Client 3 → Loss=0.0084, Acc=0.9969, Time=4.40s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0099, Acc=0.9972
#
# [Model=CNN | Seed=7 | Round=15]
#  Client 0 → Loss=0.0103, Acc=0.9957, Time=4.39s, N=20244
#  Client 1 → Loss=0.0087, Acc=0.9964, Time=4.33s, N=20244
#  Client 2 → Loss=0.0096, Acc=0.9966, Time=4.63s, N=20243
#  Client 3 → Loss=0.0088, Acc=0.9971, Time=4.53s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0112, Acc=0.9972
#
# [Model=CNN | Seed=7 | Round=16]
#  Client 0 → Loss=0.0088, Acc=0.9958, Time=4.84s, N=20244
#  Client 1 → Loss=0.0058, Acc=0.9973, Time=4.59s, N=20244
#  Client 2 → Loss=0.0089, Acc=0.9973, Time=4.66s, N=20243
#  Client 3 → Loss=0.0089, Acc=0.9965, Time=4.55s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0108, Acc=0.9973
#
# [Model=CNN | Seed=7 | Round=17]
#  Client 0 → Loss=0.0087, Acc=0.9962, Time=4.36s, N=20244
#  Client 1 → Loss=0.0088, Acc=0.9970, Time=4.41s, N=20244
#  Client 2 → Loss=0.0078, Acc=0.9976, Time=4.95s, N=20243
#  Client 3 → Loss=0.0081, Acc=0.9971, Time=4.84s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0110, Acc=0.9972
#
# [Model=CNN | Seed=7 | Round=18]
#  Client 0 → Loss=0.0082, Acc=0.9958, Time=4.79s, N=20244
#  Client 1 → Loss=0.0085, Acc=0.9968, Time=4.75s, N=20244
#  Client 2 → Loss=0.0105, Acc=0.9964, Time=4.64s, N=20243
#  Client 3 → Loss=0.0064, Acc=0.9978, Time=4.30s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0106, Acc=0.9974
#
# [Model=CNN | Seed=7 | Round=19]
#  Client 0 → Loss=0.0074, Acc=0.9962, Time=4.30s, N=20244
#  Client 1 → Loss=0.0062, Acc=0.9975, Time=4.38s, N=20244
#  Client 2 → Loss=0.0080, Acc=0.9967, Time=4.69s, N=20243
#  Client 3 → Loss=0.0083, Acc=0.9971, Time=4.32s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0106, Acc=0.9974
#
# [Model=CNN | Seed=7 | Round=20]
#  Client 0 → Loss=0.0054, Acc=0.9960, Time=4.37s, N=20244
#  Client 1 → Loss=0.0076, Acc=0.9968, Time=4.30s, N=20244
#  Client 2 → Loss=0.0063, Acc=0.9981, Time=4.32s, N=20243
#  Client 3 → Loss=0.0071, Acc=0.9971, Time=4.40s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0114, Acc=0.9972
#
# [Model=CNN | Seed=7 | Round=21]
#  Client 0 → Loss=0.0077, Acc=0.9959, Time=4.29s, N=20244
#  Client 1 → Loss=0.0078, Acc=0.9970, Time=4.37s, N=20244
#  Client 2 → Loss=0.0099, Acc=0.9968, Time=4.37s, N=20243
#  Client 3 → Loss=0.0090, Acc=0.9970, Time=4.35s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0130, Acc=0.9972
#
# [Model=CNN | Seed=7 | Round=22]
#  Client 0 → Loss=0.0051, Acc=0.9962, Time=4.29s, N=20244
#  Client 1 → Loss=0.0057, Acc=0.9977, Time=4.38s, N=20244
#  Client 2 → Loss=0.0074, Acc=0.9970, Time=4.43s, N=20243
#  Client 3 → Loss=0.0115, Acc=0.9973, Time=4.45s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0125, Acc=0.9972
#
# [Model=CNN | Seed=7 | Round=23]
#  Client 0 → Loss=0.0091, Acc=0.9959, Time=4.39s, N=20244
#  Client 1 → Loss=0.0083, Acc=0.9974, Time=4.28s, N=20244
#  Client 2 → Loss=0.0087, Acc=0.9969, Time=4.42s, N=20243
#  Client 3 → Loss=0.0076, Acc=0.9971, Time=4.37s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0136, Acc=0.9966
#
# [Model=CNN | Seed=7 | Round=24]
#  Client 0 → Loss=0.0060, Acc=0.9965, Time=4.44s, N=20244
#  Client 1 → Loss=0.0062, Acc=0.9976, Time=4.58s, N=20244
#  Client 2 → Loss=0.0076, Acc=0.9978, Time=4.40s, N=20243
#  Client 3 → Loss=0.0071, Acc=0.9970, Time=4.43s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0116, Acc=0.9972
#
# [Model=CNN | Seed=7 | Round=25]
#  Client 0 → Loss=0.0039, Acc=0.9961, Time=4.57s, N=20244
#  Client 1 → Loss=0.0078, Acc=0.9971, Time=4.42s, N=20244
#  Client 2 → Loss=0.0078, Acc=0.9970, Time=4.43s, N=20243
#  Client 3 → Loss=0.0084, Acc=0.9969, Time=4.42s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0128, Acc=0.9974
#
# [Model=CNN | Seed=7 | Round=26]
#  Client 0 → Loss=0.0072, Acc=0.9959, Time=4.43s, N=20244
#  Client 1 → Loss=0.0096, Acc=0.9964, Time=4.50s, N=20244
#  Client 2 → Loss=0.0099, Acc=0.9967, Time=4.42s, N=20243
#  Client 3 → Loss=0.0069, Acc=0.9972, Time=4.26s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0124, Acc=0.9970
#
# [Model=CNN | Seed=7 | Round=27]
#  Client 0 → Loss=0.0060, Acc=0.9959, Time=4.37s, N=20244
#  Client 1 → Loss=0.0077, Acc=0.9977, Time=4.44s, N=20244
#  Client 2 → Loss=0.0073, Acc=0.9976, Time=4.35s, N=20243
#  Client 3 → Loss=0.0109, Acc=0.9975, Time=4.48s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0118, Acc=0.9972
#
# [Model=CNN | Seed=7 | Round=28]
#  Client 0 → Loss=0.0047, Acc=0.9965, Time=4.48s, N=20244
#  Client 1 → Loss=0.0073, Acc=0.9979, Time=4.40s, N=20244
#  Client 2 → Loss=0.0068, Acc=0.9976, Time=4.45s, N=20243
#  Client 3 → Loss=0.0065, Acc=0.9974, Time=4.59s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0134, Acc=0.9970
#
# [Model=CNN | Seed=7 | Round=29]
#  Client 0 → Loss=0.0055, Acc=0.9961, Time=4.75s, N=20244
#  Client 1 → Loss=0.0098, Acc=0.9973, Time=4.44s, N=20244
#  Client 2 → Loss=0.0109, Acc=0.9965, Time=4.24s, N=20243
#  Client 3 → Loss=0.0073, Acc=0.9974, Time=4.28s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0135, Acc=0.9961
#
# [Model=CNN | Seed=7 | Round=30]
#  Client 0 → Loss=0.0066, Acc=0.9965, Time=4.48s, N=20244
#  Client 1 → Loss=0.0067, Acc=0.9977, Time=4.55s, N=20244
#  Client 2 → Loss=0.0096, Acc=0.9968, Time=4.53s, N=20243
#  Client 3 → Loss=0.0072, Acc=0.9974, Time=4.55s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0121, Acc=0.9974
#  [saved] saved_models\CNN_seed7.keras
#
# ------ SEED 72 ------
#
# [Model=CNN | Seed=72 | Round=1]
#  Client 0 → Loss=0.0679, Acc=0.9811, Time=4.67s, N=20244
#  Client 1 → Loss=0.0665, Acc=0.9846, Time=4.80s, N=20244
#  Client 2 → Loss=0.0665, Acc=0.9842, Time=4.51s, N=20243
#  Client 3 → Loss=0.0596, Acc=0.9830, Time=4.87s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0402, Acc=0.9865
#
# [Model=CNN | Seed=72 | Round=2]
#  Client 0 → Loss=0.0372, Acc=0.9895, Time=4.56s, N=20244
#  Client 1 → Loss=0.0360, Acc=0.9911, Time=4.41s, N=20244
#  Client 2 → Loss=0.0377, Acc=0.9905, Time=4.64s, N=20243
#  Client 3 → Loss=0.0351, Acc=0.9908, Time=4.46s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0192, Acc=0.9940
#
# [Model=CNN | Seed=72 | Round=3]
#  Client 0 → Loss=0.0257, Acc=0.9924, Time=4.47s, N=20244
#  Client 1 → Loss=0.0234, Acc=0.9930, Time=4.26s, N=20244
#  Client 2 → Loss=0.0258, Acc=0.9923, Time=4.29s, N=20243
#  Client 3 → Loss=0.0234, Acc=0.9929, Time=4.40s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0145, Acc=0.9956
#
# [Model=CNN | Seed=72 | Round=4]
#  Client 0 → Loss=0.0200, Acc=0.9935, Time=4.47s, N=20244
#  Client 1 → Loss=0.0170, Acc=0.9949, Time=4.42s, N=20244
#  Client 2 → Loss=0.0217, Acc=0.9932, Time=4.65s, N=20243
#  Client 3 → Loss=0.0171, Acc=0.9947, Time=4.72s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0117, Acc=0.9957
#
# [Model=CNN | Seed=72 | Round=5]
#  Client 0 → Loss=0.0158, Acc=0.9943, Time=4.76s, N=20244
#  Client 1 → Loss=0.0134, Acc=0.9961, Time=4.45s, N=20244
#  Client 2 → Loss=0.0184, Acc=0.9943, Time=4.58s, N=20243
#  Client 3 → Loss=0.0143, Acc=0.9948, Time=4.68s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0106, Acc=0.9955
#
# [Model=CNN | Seed=72 | Round=6]
#  Client 0 → Loss=0.0144, Acc=0.9953, Time=4.79s, N=20244
#  Client 1 → Loss=0.0123, Acc=0.9962, Time=4.78s, N=20244
#  Client 2 → Loss=0.0158, Acc=0.9950, Time=4.69s, N=20243
#  Client 3 → Loss=0.0123, Acc=0.9952, Time=4.82s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0096, Acc=0.9953
#
# [Model=CNN | Seed=72 | Round=7]
#  Client 0 → Loss=0.0118, Acc=0.9955, Time=4.43s, N=20244
#  Client 1 → Loss=0.0112, Acc=0.9964, Time=4.46s, N=20244
#  Client 2 → Loss=0.0129, Acc=0.9955, Time=4.41s, N=20243
#  Client 3 → Loss=0.0115, Acc=0.9963, Time=4.58s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0099, Acc=0.9953
#
# [Model=CNN | Seed=72 | Round=8]
#  Client 0 → Loss=0.0116, Acc=0.9952, Time=4.35s, N=20244
#  Client 1 → Loss=0.0104, Acc=0.9966, Time=4.37s, N=20244
#  Client 2 → Loss=0.0132, Acc=0.9951, Time=4.70s, N=20243
#  Client 3 → Loss=0.0103, Acc=0.9963, Time=4.24s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0097, Acc=0.9952
#
# [Model=CNN | Seed=72 | Round=9]
#  Client 0 → Loss=0.0095, Acc=0.9957, Time=4.38s, N=20244
#  Client 1 → Loss=0.0090, Acc=0.9965, Time=4.24s, N=20244
#  Client 2 → Loss=0.0128, Acc=0.9957, Time=4.85s, N=20243
#  Client 3 → Loss=0.0097, Acc=0.9963, Time=4.17s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0089, Acc=0.9954
#
# [Model=CNN | Seed=72 | Round=10]
#  Client 0 → Loss=0.0091, Acc=0.9962, Time=4.23s, N=20244
#  Client 1 → Loss=0.0096, Acc=0.9969, Time=4.20s, N=20244
#  Client 2 → Loss=0.0118, Acc=0.9958, Time=4.45s, N=20243
#  Client 3 → Loss=0.0093, Acc=0.9966, Time=4.47s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0092, Acc=0.9951
#
# [Model=CNN | Seed=72 | Round=11]
#  Client 0 → Loss=0.0081, Acc=0.9958, Time=4.29s, N=20244
#  Client 1 → Loss=0.0090, Acc=0.9971, Time=4.41s, N=20244
#  Client 2 → Loss=0.0118, Acc=0.9958, Time=4.56s, N=20243
#  Client 3 → Loss=0.0079, Acc=0.9969, Time=4.29s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0091, Acc=0.9954
#
# [Model=CNN | Seed=72 | Round=12]
#  Client 0 → Loss=0.0101, Acc=0.9960, Time=4.55s, N=20244
#  Client 1 → Loss=0.0102, Acc=0.9970, Time=4.47s, N=20244
#  Client 2 → Loss=0.0125, Acc=0.9956, Time=4.45s, N=20243
#  Client 3 → Loss=0.0116, Acc=0.9967, Time=4.52s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0094, Acc=0.9952
#
# [Model=CNN | Seed=72 | Round=13]
#  Client 0 → Loss=0.0084, Acc=0.9961, Time=4.26s, N=20244
#  Client 1 → Loss=0.0103, Acc=0.9969, Time=4.52s, N=20244
#  Client 2 → Loss=0.0121, Acc=0.9953, Time=4.46s, N=20243
#  Client 3 → Loss=0.0101, Acc=0.9971, Time=4.36s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0089, Acc=0.9954
#
# [Model=CNN | Seed=72 | Round=14]
#  Client 0 → Loss=0.0090, Acc=0.9963, Time=4.46s, N=20244
#  Client 1 → Loss=0.0090, Acc=0.9964, Time=4.46s, N=20244
#  Client 2 → Loss=0.0115, Acc=0.9960, Time=4.50s, N=20243
#  Client 3 → Loss=0.0096, Acc=0.9966, Time=4.42s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0087, Acc=0.9953
#
# [Model=CNN | Seed=72 | Round=15]
#  Client 0 → Loss=0.0063, Acc=0.9966, Time=4.36s, N=20244
#  Client 1 → Loss=0.0092, Acc=0.9970, Time=4.37s, N=20244
#  Client 2 → Loss=0.0111, Acc=0.9962, Time=4.44s, N=20243
#  Client 3 → Loss=0.0111, Acc=0.9966, Time=4.39s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0079, Acc=0.9958
#
# [Model=CNN | Seed=72 | Round=16]
#  Client 0 → Loss=0.0061, Acc=0.9969, Time=4.45s, N=20244
#  Client 1 → Loss=0.0074, Acc=0.9975, Time=4.33s, N=20244
#  Client 2 → Loss=0.0108, Acc=0.9958, Time=4.33s, N=20243
#  Client 3 → Loss=0.0096, Acc=0.9971, Time=4.36s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0087, Acc=0.9952
#
# [Model=CNN | Seed=72 | Round=17]
#  Client 0 → Loss=0.0088, Acc=0.9965, Time=4.37s, N=20244
#  Client 1 → Loss=0.0097, Acc=0.9973, Time=4.46s, N=20244
#  Client 2 → Loss=0.0108, Acc=0.9961, Time=4.54s, N=20243
#  Client 3 → Loss=0.0093, Acc=0.9968, Time=4.56s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0079, Acc=0.9958
#
# [Model=CNN | Seed=72 | Round=18]
#  Client 0 → Loss=0.0051, Acc=0.9968, Time=4.46s, N=20244
#  Client 1 → Loss=0.0103, Acc=0.9967, Time=4.62s, N=20244
#  Client 2 → Loss=0.0093, Acc=0.9968, Time=4.45s, N=20243
#  Client 3 → Loss=0.0068, Acc=0.9975, Time=4.38s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0081, Acc=0.9959
#
# [Model=CNN | Seed=72 | Round=19]
#  Client 0 → Loss=0.0065, Acc=0.9964, Time=4.43s, N=20244
#  Client 1 → Loss=0.0076, Acc=0.9976, Time=4.80s, N=20244
#  Client 2 → Loss=0.0106, Acc=0.9963, Time=4.53s, N=20243
#  Client 3 → Loss=0.0076, Acc=0.9972, Time=4.31s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0085, Acc=0.9956
#
# [Model=CNN | Seed=72 | Round=20]
#  Client 0 → Loss=0.0082, Acc=0.9961, Time=4.59s, N=20244
#  Client 1 → Loss=0.0125, Acc=0.9968, Time=4.51s, N=20244
#  Client 2 → Loss=0.0087, Acc=0.9966, Time=4.65s, N=20243
#  Client 3 → Loss=0.0077, Acc=0.9970, Time=4.55s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0079, Acc=0.9959
#
# [Model=CNN | Seed=72 | Round=21]
#  Client 0 → Loss=0.0061, Acc=0.9964, Time=4.79s, N=20244
#  Client 1 → Loss=0.0107, Acc=0.9973, Time=4.74s, N=20244
#  Client 2 → Loss=0.0090, Acc=0.9966, Time=4.58s, N=20243
#  Client 3 → Loss=0.0077, Acc=0.9972, Time=4.22s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0084, Acc=0.9958
#
# [Model=CNN | Seed=72 | Round=22]
#  Client 0 → Loss=0.0050, Acc=0.9968, Time=4.29s, N=20244
#  Client 1 → Loss=0.0079, Acc=0.9977, Time=4.55s, N=20244
#  Client 2 → Loss=0.0115, Acc=0.9959, Time=4.29s, N=20243
#  Client 3 → Loss=0.0113, Acc=0.9962, Time=4.51s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0086, Acc=0.9956
#
# [Model=CNN | Seed=72 | Round=23]
#  Client 0 → Loss=0.0053, Acc=0.9964, Time=4.42s, N=20244
#  Client 1 → Loss=0.0103, Acc=0.9967, Time=4.43s, N=20244
#  Client 2 → Loss=0.0105, Acc=0.9963, Time=4.40s, N=20243
#  Client 3 → Loss=0.0088, Acc=0.9974, Time=4.42s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0086, Acc=0.9956
#
# [Model=CNN | Seed=72 | Round=24]
#  Client 0 → Loss=0.0042, Acc=0.9967, Time=4.43s, N=20244
#  Client 1 → Loss=0.0104, Acc=0.9966, Time=4.59s, N=20244
#  Client 2 → Loss=0.0098, Acc=0.9972, Time=4.38s, N=20243
#  Client 3 → Loss=0.0110, Acc=0.9969, Time=4.61s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0090, Acc=0.9953
#
# [Model=CNN | Seed=72 | Round=25]
#  Client 0 → Loss=0.0058, Acc=0.9970, Time=4.47s, N=20244
#  Client 1 → Loss=0.0070, Acc=0.9979, Time=4.38s, N=20244
#  Client 2 → Loss=0.0094, Acc=0.9965, Time=4.41s, N=20243
#  Client 3 → Loss=0.0104, Acc=0.9969, Time=4.42s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0088, Acc=0.9955
#
# [Model=CNN | Seed=72 | Round=26]
#  Client 0 → Loss=0.0049, Acc=0.9964, Time=4.48s, N=20244
#  Client 1 → Loss=0.0089, Acc=0.9976, Time=4.59s, N=20244
#  Client 2 → Loss=0.0080, Acc=0.9971, Time=4.55s, N=20243
#  Client 3 → Loss=0.0061, Acc=0.9977, Time=4.59s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0088, Acc=0.9953
#
# [Model=CNN | Seed=72 | Round=27]
#  Client 0 → Loss=0.0011, Acc=0.9974, Time=4.57s, N=20244
#  Client 1 → Loss=0.0095, Acc=0.9972, Time=4.51s, N=20244
#  Client 2 → Loss=0.0090, Acc=0.9970, Time=4.57s, N=20243
#  Client 3 → Loss=0.0084, Acc=0.9973, Time=4.53s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0088, Acc=0.9953
#
# [Model=CNN | Seed=72 | Round=28]
#  Client 0 → Loss=0.0066, Acc=0.9965, Time=4.53s, N=20244
#  Client 1 → Loss=0.0086, Acc=0.9975, Time=4.67s, N=20244
#  Client 2 → Loss=0.0093, Acc=0.9970, Time=4.19s, N=20243
#  Client 3 → Loss=0.0083, Acc=0.9972, Time=4.17s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0084, Acc=0.9954
#
# [Model=CNN | Seed=72 | Round=29]
#  Client 0 → Loss=0.0047, Acc=0.9971, Time=4.21s, N=20244
#  Client 1 → Loss=0.0102, Acc=0.9974, Time=4.21s, N=20244
#  Client 2 → Loss=0.0139, Acc=0.9964, Time=4.69s, N=20243
#  Client 3 → Loss=0.0122, Acc=0.9965, Time=4.24s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0087, Acc=0.9955
#
# [Model=CNN | Seed=72 | Round=30]
#  Client 0 → Loss=0.0063, Acc=0.9964, Time=4.42s, N=20244
#  Client 1 → Loss=0.0077, Acc=0.9980, Time=4.57s, N=20244
#  Client 2 → Loss=0.0083, Acc=0.9969, Time=4.25s, N=20243
#  Client 3 → Loss=0.0114, Acc=0.9970, Time=4.68s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0096, Acc=0.9952
#  [saved] saved_models\CNN_seed72.keras
#
# ------ SEED 82 ------
#
# [Model=CNN | Seed=82 | Round=1]
#  Client 0 → Loss=0.0611, Acc=0.9846, Time=4.48s, N=20244
#  Client 1 → Loss=0.0620, Acc=0.9855, Time=4.43s, N=20244
#  Client 2 → Loss=0.0660, Acc=0.9831, Time=4.43s, N=20243
#  Client 3 → Loss=0.0628, Acc=0.9853, Time=4.41s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0419, Acc=0.9848
#
# [Model=CNN | Seed=82 | Round=2]
#  Client 0 → Loss=0.0336, Acc=0.9914, Time=4.37s, N=20244
#  Client 1 → Loss=0.0343, Acc=0.9907, Time=4.41s, N=20244
#  Client 2 → Loss=0.0382, Acc=0.9903, Time=4.39s, N=20243
#  Client 3 → Loss=0.0305, Acc=0.9922, Time=4.67s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0143, Acc=0.9955
#
# [Model=CNN | Seed=82 | Round=3]
#  Client 0 → Loss=0.0239, Acc=0.9932, Time=4.40s, N=20244
#  Client 1 → Loss=0.0252, Acc=0.9924, Time=4.44s, N=20244
#  Client 2 → Loss=0.0256, Acc=0.9926, Time=4.42s, N=20243
#  Client 3 → Loss=0.0213, Acc=0.9932, Time=4.54s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0122, Acc=0.9964
#
# [Model=CNN | Seed=82 | Round=4]
#  Client 0 → Loss=0.0185, Acc=0.9944, Time=4.43s, N=20244
#  Client 1 → Loss=0.0205, Acc=0.9939, Time=4.44s, N=20244
#  Client 2 → Loss=0.0199, Acc=0.9941, Time=4.53s, N=20243
#  Client 3 → Loss=0.0162, Acc=0.9945, Time=4.39s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0124, Acc=0.9958
#
# [Model=CNN | Seed=82 | Round=5]
#  Client 0 → Loss=0.0145, Acc=0.9952, Time=4.41s, N=20244
#  Client 1 → Loss=0.0167, Acc=0.9951, Time=4.55s, N=20244
#  Client 2 → Loss=0.0163, Acc=0.9947, Time=4.55s, N=20243
#  Client 3 → Loss=0.0135, Acc=0.9950, Time=4.68s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0102, Acc=0.9959
#
# [Model=CNN | Seed=82 | Round=6]
#  Client 0 → Loss=0.0125, Acc=0.9954, Time=4.79s, N=20244
#  Client 1 → Loss=0.0140, Acc=0.9952, Time=5.06s, N=20244
#  Client 2 → Loss=0.0137, Acc=0.9952, Time=4.80s, N=20243
#  Client 3 → Loss=0.0123, Acc=0.9956, Time=4.71s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0100, Acc=0.9961
#
# [Model=CNN | Seed=82 | Round=7]
#  Client 0 → Loss=0.0126, Acc=0.9957, Time=4.52s, N=20244
#  Client 1 → Loss=0.0123, Acc=0.9959, Time=4.45s, N=20244
#  Client 2 → Loss=0.0125, Acc=0.9955, Time=4.45s, N=20243
#  Client 3 → Loss=0.0100, Acc=0.9963, Time=4.35s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0102, Acc=0.9956
#
# [Model=CNN | Seed=82 | Round=8]
#  Client 0 → Loss=0.0108, Acc=0.9964, Time=4.60s, N=20244
#  Client 1 → Loss=0.0113, Acc=0.9959, Time=4.32s, N=20244
#  Client 2 → Loss=0.0109, Acc=0.9961, Time=4.52s, N=20243
#  Client 3 → Loss=0.0095, Acc=0.9964, Time=4.50s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0096, Acc=0.9958
#
# [Model=CNN | Seed=82 | Round=9]
#  Client 0 → Loss=0.0097, Acc=0.9965, Time=4.62s, N=20244
#  Client 1 → Loss=0.0108, Acc=0.9963, Time=4.55s, N=20244
#  Client 2 → Loss=0.0078, Acc=0.9972, Time=4.73s, N=20243
#  Client 3 → Loss=0.0095, Acc=0.9968, Time=4.47s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0096, Acc=0.9958
#
# [Model=CNN | Seed=82 | Round=10]
#  Client 0 → Loss=0.0094, Acc=0.9965, Time=4.49s, N=20244
#  Client 1 → Loss=0.0093, Acc=0.9971, Time=4.61s, N=20244
#  Client 2 → Loss=0.0080, Acc=0.9971, Time=4.39s, N=20243
#  Client 3 → Loss=0.0080, Acc=0.9971, Time=4.45s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0118, Acc=0.9953
#
# [Model=CNN | Seed=82 | Round=11]
#  Client 0 → Loss=0.0087, Acc=0.9964, Time=4.32s, N=20244
#  Client 1 → Loss=0.0096, Acc=0.9973, Time=4.31s, N=20244
#  Client 2 → Loss=0.0076, Acc=0.9975, Time=4.32s, N=20243
#  Client 3 → Loss=0.0094, Acc=0.9970, Time=4.21s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0130, Acc=0.9952
#
# [Model=CNN | Seed=82 | Round=12]
#  Client 0 → Loss=0.0094, Acc=0.9964, Time=4.28s, N=20244
#  Client 1 → Loss=0.0090, Acc=0.9969, Time=4.26s, N=20244
#  Client 2 → Loss=0.0081, Acc=0.9973, Time=4.24s, N=20243
#  Client 3 → Loss=0.0069, Acc=0.9973, Time=4.48s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0125, Acc=0.9952
#
# [Model=CNN | Seed=82 | Round=13]
#  Client 0 → Loss=0.0077, Acc=0.9965, Time=4.54s, N=20244
#  Client 1 → Loss=0.0077, Acc=0.9976, Time=4.39s, N=20244
#  Client 2 → Loss=0.0094, Acc=0.9964, Time=4.41s, N=20243
#  Client 3 → Loss=0.0077, Acc=0.9973, Time=4.31s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0083, Acc=0.9964
#
# [Model=CNN | Seed=82 | Round=14]
#  Client 0 → Loss=0.0086, Acc=0.9963, Time=4.33s, N=20244
#  Client 1 → Loss=0.0084, Acc=0.9970, Time=4.38s, N=20244
#  Client 2 → Loss=0.0077, Acc=0.9974, Time=4.35s, N=20243
#  Client 3 → Loss=0.0062, Acc=0.9976, Time=4.34s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0084, Acc=0.9962
#
# [Model=CNN | Seed=82 | Round=15]
#  Client 0 → Loss=0.0089, Acc=0.9965, Time=4.36s, N=20244
#  Client 1 → Loss=0.0081, Acc=0.9969, Time=4.52s, N=20244
#  Client 2 → Loss=0.0059, Acc=0.9980, Time=4.46s, N=20243
#  Client 3 → Loss=0.0086, Acc=0.9972, Time=4.56s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0103, Acc=0.9959
#
# [Model=CNN | Seed=82 | Round=16]
#  Client 0 → Loss=0.0078, Acc=0.9967, Time=4.66s, N=20244
#  Client 1 → Loss=0.0084, Acc=0.9972, Time=4.66s, N=20244
#  Client 2 → Loss=0.0078, Acc=0.9973, Time=4.48s, N=20243
#  Client 3 → Loss=0.0075, Acc=0.9974, Time=4.53s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0106, Acc=0.9955
#
# [Model=CNN | Seed=82 | Round=17]
#  Client 0 → Loss=0.0076, Acc=0.9966, Time=4.63s, N=20244
#  Client 1 → Loss=0.0074, Acc=0.9971, Time=4.38s, N=20244
#  Client 2 → Loss=0.0055, Acc=0.9978, Time=4.49s, N=20243
#  Client 3 → Loss=0.0071, Acc=0.9980, Time=4.16s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0120, Acc=0.9957
#
# [Model=CNN | Seed=82 | Round=18]
#  Client 0 → Loss=0.0064, Acc=0.9973, Time=4.16s, N=20244
#  Client 1 → Loss=0.0067, Acc=0.9977, Time=4.32s, N=20244
#  Client 2 → Loss=0.0064, Acc=0.9976, Time=4.26s, N=20243
#  Client 3 → Loss=0.0079, Acc=0.9977, Time=4.23s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0156, Acc=0.9949
#
# [Model=CNN | Seed=82 | Round=19]
#  Client 0 → Loss=0.0079, Acc=0.9968, Time=4.23s, N=20244
#  Client 1 → Loss=0.0068, Acc=0.9977, Time=4.43s, N=20244
#  Client 2 → Loss=0.0072, Acc=0.9973, Time=4.22s, N=20243
#  Client 3 → Loss=0.0070, Acc=0.9975, Time=4.38s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0119, Acc=0.9955
#
# [Model=CNN | Seed=82 | Round=20]
#  Client 0 → Loss=0.0091, Acc=0.9972, Time=4.49s, N=20244
#  Client 1 → Loss=0.0064, Acc=0.9975, Time=4.43s, N=20244
#  Client 2 → Loss=0.0050, Acc=0.9980, Time=4.26s, N=20243
#  Client 3 → Loss=0.0084, Acc=0.9974, Time=4.34s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0119, Acc=0.9955
#
# [Model=CNN | Seed=82 | Round=21]
#  Client 0 → Loss=0.0069, Acc=0.9975, Time=4.45s, N=20244
#  Client 1 → Loss=0.0076, Acc=0.9974, Time=4.53s, N=20244
#  Client 2 → Loss=0.0054, Acc=0.9977, Time=4.45s, N=20243
#  Client 3 → Loss=0.0061, Acc=0.9979, Time=4.58s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0127, Acc=0.9955
#
# [Model=CNN | Seed=82 | Round=22]
#  Client 0 → Loss=0.0045, Acc=0.9976, Time=4.28s, N=20244
#  Client 1 → Loss=0.0077, Acc=0.9972, Time=4.32s, N=20244
#  Client 2 → Loss=0.0063, Acc=0.9977, Time=4.42s, N=20243
#  Client 3 → Loss=0.0057, Acc=0.9979, Time=4.35s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0176, Acc=0.9944
#
# [Model=CNN | Seed=82 | Round=23]
#  Client 0 → Loss=0.0035, Acc=0.9978, Time=4.38s, N=20244
#  Client 1 → Loss=0.0074, Acc=0.9977, Time=4.59s, N=20244
#  Client 2 → Loss=0.0047, Acc=0.9983, Time=4.37s, N=20243
#  Client 3 → Loss=0.0072, Acc=0.9978, Time=4.35s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0117, Acc=0.9958
#
# [Model=CNN | Seed=82 | Round=24]
#  Client 0 → Loss=0.0046, Acc=0.9977, Time=4.36s, N=20244
#  Client 1 → Loss=0.0102, Acc=0.9975, Time=4.27s, N=20244
#  Client 2 → Loss=0.0042, Acc=0.9984, Time=4.42s, N=20243
#  Client 3 → Loss=0.0051, Acc=0.9981, Time=4.33s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0137, Acc=0.9957
#
# [Model=CNN | Seed=82 | Round=25]
#  Client 0 → Loss=0.0047, Acc=0.9975, Time=4.29s, N=20244
#  Client 1 → Loss=0.0082, Acc=0.9972, Time=4.34s, N=20244
#  Client 2 → Loss=0.0069, Acc=0.9978, Time=4.42s, N=20243
#  Client 3 → Loss=0.0051, Acc=0.9985, Time=4.56s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0175, Acc=0.9945
#
# [Model=CNN | Seed=82 | Round=26]
#  Client 0 → Loss=0.0056, Acc=0.9980, Time=4.37s, N=20244
#  Client 1 → Loss=0.0082, Acc=0.9975, Time=4.55s, N=20244
#  Client 2 → Loss=0.0056, Acc=0.9980, Time=4.42s, N=20243
#  Client 3 → Loss=0.0072, Acc=0.9978, Time=4.50s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0173, Acc=0.9947
#
# [Model=CNN | Seed=82 | Round=27]
#  Client 0 → Loss=0.0044, Acc=0.9981, Time=4.55s, N=20244
#  Client 1 → Loss=0.0070, Acc=0.9976, Time=4.48s, N=20244
#  Client 2 → Loss=0.0050, Acc=0.9981, Time=4.58s, N=20243
#  Client 3 → Loss=0.0054, Acc=0.9981, Time=4.63s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0182, Acc=0.9948
#
# [Model=CNN | Seed=82 | Round=28]
#  Client 0 → Loss=0.0068, Acc=0.9978, Time=4.48s, N=20244
#  Client 1 → Loss=0.0080, Acc=0.9979, Time=4.42s, N=20244
#  Client 2 → Loss=0.0074, Acc=0.9977, Time=4.49s, N=20243
#  Client 3 → Loss=0.0084, Acc=0.9980, Time=4.48s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0159, Acc=0.9945
#
# [Model=CNN | Seed=82 | Round=29]
#  Client 0 → Loss=0.0068, Acc=0.9976, Time=4.57s, N=20244
#  Client 1 → Loss=0.0085, Acc=0.9972, Time=4.45s, N=20244
#  Client 2 → Loss=0.0043, Acc=0.9988, Time=4.48s, N=20243
#  Client 3 → Loss=0.0051, Acc=0.9983, Time=4.49s, N=20243
#  >>> GLOBAL (centralized test) → Loss=0.0137, Acc=0.9952
#
# [Model=CNN | Seed=82 | Round=30]
# ...
#    CNN     3     saved_models\CNN_seed3.keras
#    CNN     7     saved_models\CNN_seed7.keras
#    CNN    72    saved_models\CNN_seed72.keras
#    CNN    82    saved_models\CNN_seed82.keras
#   LSTM    42   saved_models\LSTM_seed42.keras
#   LSTM     3    saved_models\LSTM_seed3.keras
#   LSTM     7    saved_models\LSTM_seed7.keras
#   LSTM    72   saved_models\LSTM_seed72.keras
#   LSTM    82   saved_models\LSTM_seed82.keras
# BiLSTM    42 saved_models\BiLSTM_seed42.keras
# BiLSTM     3  saved_models\BiLSTM_seed3.keras
# BiLSTM     7  saved_models\BiLSTM_seed7.keras
# BiLSTM    72 saved_models\BiLSTM_seed72.keras
# BiLSTM    82 saved_models\BiLSTM_seed82.keras
#    GRU    42    saved_models\GRU_seed42.keras
#    GRU     3     saved_models\GRU_seed3.keras
#    GRU     7     saved_models\GRU_seed7.keras
#    GRU    72    saved_models\GRU_seed72.keras
#    GRU    82    saved_models\GRU_seed82.keras
#  BiGRU    42  saved_models\BiGRU_seed42.keras
#  BiGRU     3   saved_models\BiGRU_seed3.keras
#  BiGRU     7   saved_models\BiGRU_seed7.keras
#  BiGRU    72  saved_models\BiGRU_seed72.keras
#  BiGRU    82  saved_models\BiGRU_seed82.keras
#
# OVERALL SUMMARY (all models & seeds pooled):
#                  Metric             Mean ± SD                 95% CI
# 0                 Loss       0.0076 ± 0.0030        [0.0065,0.0088]
# 1             Accuracy       0.9985 ± 0.0012        [0.9981,0.9990]
# 2            Precision       0.9971 ± 0.0031        [0.9959,0.9984]
# 3               Recall       0.9989 ± 0.0005        [0.9987,0.9990]
# 4                   F1       0.9980 ± 0.0016        [0.9974,0.9986]
# 5                  MCC       0.9968 ± 0.0025        [0.9958,0.9978]
# 6                  AUC       0.9999 ± 0.0001        [0.9999,1.0000]
# 7          Specificity       0.9983 ± 0.0019        [0.9976,0.9990]
# 8    Training_Time_sec  1343.9286 ± 534.2212  [1134.5139,1553.3433]
# 9   Inference_Time_sec       1.6190 ± 0.7458        [1.3267,1.9114]
# 10       Model_Size_MB       0.5846 ± 0.3965        [0.4292,0.7400]
# 11   Comm_per_round_MB       8.9497 ± 6.2607       [6.4955,11.4039]
# 12       Total_Comm_MB   268.4901 ± 187.8204    [194.8645,342.1157]
#
# PER-CLIENT TEST SUMMARY (mean/std over 5 seeds):
#                Accuracy         Precision          Recall              F1  \
#                   mean     std      mean     std    mean     std    mean
# Model  Client
# BiGRU  0        0.9990  0.0001    0.9981  0.0003  0.9992  0.0003  0.9987
#        1        0.9989  0.0002    0.9980  0.0007  0.9989  0.0008  0.9985
#        2        0.9992  0.0002    0.9995  0.0008  0.9985  0.0004  0.9990
#        3        0.9989  0.0004    0.9986  0.0013  0.9984  0.0014  0.9985
# BiLSTM 0        0.9990  0.0003    0.9980  0.0007  0.9993  0.0005  0.9986
#        1        0.9989  0.0004    0.9982  0.0006  0.9988  0.0004  0.9985
#        2        0.9993  0.0002    0.9989  0.0005  0.9991  0.0003  0.9990
#        3        0.9986  0.0005    0.9983  0.0011  0.9980  0.0020  0.9981
# CNN    0        0.9968  0.0014    0.9921  0.0040  0.9992  0.0008  0.9957
#        1        0.9961  0.0013    0.9911  0.0043  0.9984  0.0010  0.9947
#        2        0.9966  0.0012    0.9923  0.0032  0.9986  0.0006  0.9954
#        3        0.9961  0.0014    0.9908  0.0043  0.9988  0.0008  0.9948
# GRU    0        0.9993  0.0004    0.9986  0.0006  0.9995  0.0005  0.9990
#        1        0.9991  0.0005    0.9986  0.0010  0.9990  0.0007  0.9988
#        2        0.9994  0.0004    0.9989  0.0008  0.9996  0.0002  0.9993
#        3        0.9991  0.0006    0.9984  0.0017  0.9991  0.0005  0.9988
# LSTM   0        0.9991  0.0002    0.9987  0.0005  0.9987  0.0006  0.9987
#        1        0.9990  0.0006    0.9985  0.0010  0.9988  0.0009  0.9987
#        2        0.9990  0.0002    0.9989  0.0008  0.9983  0.0009  0.9986
#        3        0.9987  0.0006    0.9980  0.0015  0.9985  0.0010  0.9982
#
#                           MCC             AUC         Specificity          \
#                   std    mean     std    mean     std        mean     std
# Model  Client
# BiGRU  0       0.0002  0.9979  0.0003  0.9998  0.0002      0.9989  0.0002
#        1       0.0002  0.9975  0.0004  0.9999  0.0001      0.9988  0.0004
#        2       0.0002  0.9984  0.0004  0.9999  0.0001      0.9997  0.0004
#        3       0.0005  0.9976  0.0008  1.0000  0.0001      0.9992  0.0008
# BiLSTM 0       0.0004  0.9979  0.0006  0.9999  0.0001      0.9988  0.0004
#        1       0.0005  0.9976  0.0008  1.0000  0.0001      0.9989  0.0004
#        2       0.0003  0.9985  0.0005  1.0000  0.0001      0.9994  0.0003
#        3       0.0007  0.9970  0.0012  0.9999  0.0001      0.9990  0.0006
# CNN    0       0.0019  0.9931  0.0030  0.9999  0.0001      0.9954  0.0024
#        1       0.0018  0.9917  0.0028  0.9999  0.0002      0.9947  0.0026
#        2       0.0016  0.9927  0.0025  0.9999  0.0001      0.9954  0.0019
#        3       0.0019  0.9917  0.0030  0.9999  0.0001      0.9945  0.0026
# GRU    0       0.0005  0.9985  0.0008  1.0000  0.0001      0.9992  0.0003
#        1       0.0007  0.9981  0.0011  1.0000  0.0000      0.9992  0.0006
#        2       0.0005  0.9988  0.0008  1.0000  0.0001      0.9994  0.0005
#        3       0.0008  0.9981  0.0012  0.9999  0.0001      0.9991  0.0010
# LSTM   0       0.0002  0.9980  0.0004  1.0000  0.0000      0.9993  0.0003
#        1       0.0008  0.9979  0.0012  1.0000  0.0000      0.9991  0.0006
#        2       0.0003  0.9978  0.0005  1.0000  0.0000      0.9994  0.0005
#        3       0.0008  0.9972  0.0012  1.0000  0.0000      0.9988  0.0009
#
#                  Loss
#                  mean     std
# Model  Client
# BiGRU  0       0.0062  0.0026
#        1       0.0106  0.0039
#        2       0.0050  0.0037
#        3       0.0074  0.0028
# BiLSTM 0       0.0081  0.0041
#        1       0.0099  0.0058
#        2       0.0060  0.0041
#        3       0.0114  0.0050
# CNN    0       0.0082  0.0018
#        1       0.0106  0.0064
#        2       0.0105  0.0067
#        3       0.0120  0.0075
# GRU    0       0.0051  0.0033
#        1       0.0072  0.0048
#        2       0.0054  0.0037
#        3       0.0085  0.0030
# LSTM   0       0.0045  0.0028
#        1       0.0057  0.0038
#        2       0.0034  0.0012
#        3       0.0067  0.0019
#
# PAIRWISE PAIRED T-TESTS across 5 seeds (Global Test Set):
#    Metric Model A Model B  Mean A  Mean B  t-stat  p-value  Significant (p<0.05)
# Accuracy     CNN    LSTM  0.9964  0.9989 -4.6385   0.0097                  True
# Accuracy     CNN  BiLSTM  0.9964  0.9990 -4.9524   0.0077                  True
# Accuracy     CNN     GRU  0.9964  0.9992 -6.1518   0.0035                  True
# Accuracy     CNN   BiGRU  0.9964  0.9990 -5.1003   0.0070                  True
# Accuracy    LSTM  BiLSTM  0.9989  0.9990 -0.1728   0.8712                 False
# Accuracy    LSTM     GRU  0.9989  0.9992 -3.1235   0.0354                  True
# Accuracy    LSTM   BiGRU  0.9989  0.9990 -0.6286   0.5637                 False
# Accuracy  BiLSTM     GRU  0.9990  0.9992 -1.8584   0.1366                 False
# Accuracy  BiLSTM   BiGRU  0.9990  0.9990 -0.9129   0.4130                 False
# Accuracy     GRU   BiGRU  0.9992  0.9990  1.7366   0.1575                 False
#       F1     CNN    LSTM  0.9952  0.9986 -4.6557   0.0096                  True
#       F1     CNN  BiLSTM  0.9952  0.9986 -4.9757   0.0076                  True
#       F1     CNN     GRU  0.9952  0.9990 -6.1887   0.0035                  True
#       F1     CNN   BiGRU  0.9952  0.9987 -5.1251   0.0069                  True
#       F1    LSTM  BiLSTM  0.9986  0.9986 -0.1749   0.8697                 False
#       F1    LSTM     GRU  0.9986  0.9990 -3.1237   0.0354                  True
#       F1    LSTM   BiGRU  0.9986  0.9987 -0.6301   0.5628                 False
#       F1  BiLSTM     GRU  0.9986  0.9990 -1.8543   0.1373                 False
#       F1  BiLSTM   BiGRU  0.9986  0.9987 -0.9125   0.4131                 False
#       F1     GRU   BiGRU  0.9990  0.9987  1.7366   0.1575                 False
#      AUC     CNN    LSTM  0.9999  1.0000 -1.7905   0.1479                 False
#      AUC     CNN  BiLSTM  0.9999  0.9999 -0.7287   0.5065                 False
#      AUC     CNN     GRU  0.9999  1.0000 -1.1957   0.2979                 False
#      AUC     CNN   BiGRU  0.9999  0.9999 -0.4127   0.7010                 False
#      AUC    LSTM  BiLSTM  1.0000  0.9999  2.1073   0.1028                 False
#      AUC    LSTM     GRU  1.0000  1.0000  1.4152   0.2299                 False
#      AUC    LSTM   BiGRU  1.0000  0.9999  3.7958   0.0192                  True
#      AUC  BiLSTM     GRU  0.9999  1.0000 -1.0285   0.3619                 False
#      AUC  BiLSTM   BiGRU  0.9999  0.9999  3.3089   0.0297                  True
#      AUC     GRU   BiGRU  1.0000  0.9999  3.1637   0.0341                  True
#     Loss     CNN    LSTM  0.0103  0.0051  2.1640   0.0965                 False
#     Loss     CNN  BiLSTM  0.0103  0.0088  0.5389   0.6185                 False
#     Loss     CNN     GRU  0.0103  0.0066  1.6982   0.1647                 False
#     Loss     CNN   BiGRU  0.0103  0.0073  1.3126   0.2596                 False
#     Loss    LSTM  BiLSTM  0.0051  0.0088 -7.3680   0.0018                  True
#     Loss    LSTM     GRU  0.0051  0.0066 -2.3140   0.0817                 False
#     Loss    LSTM   BiGRU  0.0051  0.0073 -6.2190   0.0034                  True
#     Loss  BiLSTM     GRU  0.0088  0.0066  2.4906   0.0674                 False
#     Loss  BiLSTM   BiGRU  0.0088  0.0073  2.0383   0.1112                 False
#     Loss     GRU   BiGRU  0.0066  0.0073 -1.1657   0.3085                 False
#
# McNEMAR'S TEST — PER SEED (instance-level, Global Test Set):
#   Seed Model A Model B  A right/B wrong  A wrong/B right     stat  p-value  Significant (p<0.05)
#    42     CNN    LSTM               10               34  12.0227   0.0005                  True
#    42     CNN  BiLSTM                2               34  26.6944   0.0000                  True
#    42     CNN     GRU                4               37  24.9756   0.0000                  True
#    42     CNN   BiGRU                2               34  26.6944   0.0000                  True
#    42    LSTM  BiLSTM                8               16    exact   0.1516                 False
#    42    LSTM     GRU                5               14    exact   0.0636                 False
#    42    LSTM   BiGRU                6               14    exact   0.1153                 False
#    42  BiLSTM     GRU                5                6    exact   1.0000                 False
#    42  BiLSTM   BiGRU                7                7    exact   1.0000                 False
#    42     GRU   BiGRU                7                6    exact   1.0000                 False
#     3     CNN    LSTM                6               50  33.0179   0.0000                  True
#     3     CNN  BiLSTM               17               55  19.0139   0.0000                  True
#     3     CNN     GRU                4               59  46.2857   0.0000                  True
#     3     CNN   BiGRU               15               57  23.3472   0.0000                  True
#     3    LSTM  BiLSTM               17               11   0.8929   0.3447                 False
#     3    LSTM     GRU                2               13    exact   0.0074                  True
#     3    LSTM   BiGRU               16               14   0.0333   0.8551                 False
#     3  BiLSTM     GRU                3               20    exact   0.0005                  True
#     3  BiLSTM   BiGRU                8               12    exact   0.5034                 False
#     3     GRU   BiGRU               18                5    exact   0.0106                  True
#     7     CNN    LSTM                8               42    21.78   0.0000                  True
#     7     CNN  BiLSTM                5               39    24.75   0.0000                  True
#     7     CNN     GRU                2               44  36.5435   0.0000                  True
#     7     CNN   BiGRU                6               40  23.6739   0.0000                  True
#     7    LSTM  BiLSTM                7                7    exact   1.0000                 False
#     7    LSTM     GRU                0                8    exact   0.0078                  True
#     7    LSTM   BiGRU                6                6    exact   1.0000                 False
#     7  BiLSTM     GRU                1                9    exact   0.0215                  True
#     7  BiLSTM   BiGRU                6                6    exact   1.0000                 False
#     7     GRU   BiGRU                9                1    exact   0.0215                  True
#    72     CNN    LSTM                7               81  60.5568   0.0000                  True
#    72     CNN  BiLSTM                5               81   65.407   0.0000                  True
#    72     CNN     GRU                9               85  59.8404   0.0000                  True
#    72     CNN   BiGRU                6               85  66.8571   0.0000                  True
#    72    LSTM  BiLSTM                7                9    exact   0.8036                 False
#    72    LSTM     GRU                9               11    exact   0.8238                 False
#    72    LSTM   BiGRU                8               13    exact   0.3833                 False
#    72  BiLSTM     GRU               11               11    exact   1.0000                 False
#    72  BiLSTM   BiGRU                7               10    exact   0.6291                 False
#    72     GRU   BiGRU                7               10    exact   0.6291                 False
#    82     CNN    LSTM                7               87  66.3936   0.0000                  True
#    82     CNN  BiLSTM                7               85  64.4457   0.0000                  True
#    82     CNN     GRU                6               87  68.8172   0.0000                  True
#    82     CNN   BiGRU                5               81   65.407   0.0000                  True
#    82    LSTM  BiLSTM                7                5    exact   0.7744                 False
#    82    LSTM     GRU                5                6    exact   1.0000                 False
#    82    LSTM   BiGRU               10                6    exact   0.4545                 False
#    82  BiLSTM     GRU                6                9    exact   0.6072                 False
#    82  BiLSTM   BiGRU                8                6    exact   0.7905                 False
#    82     GRU   BiGRU               11                6    exact   0.3323                 False
#
# McNEMAR'S TEST — POOLED ACROSS 5 SEEDS (Global Test Set):
#  Model A Model B  A right/B wrong (pooled)  A wrong/B right (pooled)     stat  p-value  Significant (p<0.05)
#     CNN    LSTM                        38                       294 195.8584   0.0000                  True
#     CNN  BiLSTM                        36                       294 200.1485   0.0000                  True
#     CNN     GRU                        25                       312 242.7181   0.0000                  True
#     CNN   BiGRU                        34                       297 207.3837   0.0000                  True
#    LSTM  BiLSTM                        46                        48   0.0106   0.9179                 False
#    LSTM     GRU                        21                        52  12.3288   0.0004                  True
#    LSTM   BiGRU                        46                        53   0.3636   0.5465                 False
#  BiLSTM     GRU                        26                        55   9.6790   0.0019                  True
#  BiLSTM   BiGRU                        36                        41   0.2078   0.6485                 False
#     GRU   BiGRU                        52                        28   6.6125   0.0101                  True
