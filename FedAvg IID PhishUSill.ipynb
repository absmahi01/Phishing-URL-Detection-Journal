# %%
import numpy as np, pandas as pd, tensorflow as tf, random, time, os
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import *

from scipy.stats import ttest_rel, chi2, binom
from itertools import combinations

# ================= CONFIG =================
LR=0.001; ROUNDS=30; LOCAL_EPOCHS=2; BATCH=16
CLIENTS=4; SEEDS=[42,3,7,72,82]
MODELS=["CNN","LSTM","BiLSTM","GRU","BiGRU"]
CLIENT_TEST_SIZE=0.2   # local train/test split ratio inside each client
MODEL_SAVE_DIR="saved_models"
os.makedirs(MODEL_SAVE_DIR,exist_ok=True)

# ================= LOAD =================
df=pd.read_csv("PhiUSIIL_Phishing_URL_Dataset.csv")

# remove text columns like .txt
for col in df.columns:
    if df[col].dtype==object and df[col].astype(str).str.contains(".txt",na=False).any():
        df.drop(columns=[col],inplace=True)

df=df.fillna("unknown")

for col in df.columns:
    if df[col].dtype==object:
        df[col]=LabelEncoder().fit_transform(df[col].astype(str))

X=df.drop("label",axis=1).values
y=df["label"].values

X=StandardScaler().fit_transform(X)

# NOTE: no upfront global train_test_split anymore.
# IID partitioning is applied to the WHOLE dataset per seed below,
# then each client locally splits its own IID shard into train/test.

# ================= HELPERS =================
def set_seed(s):
    random.seed(s); np.random.seed(s); tf.random.set_seed(s)

def iid_partition(X,y,K):
    # IID partition: each class shuffled and split evenly across clients
    idx=np.arange(len(y))
    clients=[[] for _ in range(K)]
    for c in np.unique(y):
        c_idx=idx[y==c]; np.random.shuffle(c_idx)
        split=np.array_split(c_idx,K)
        for i in range(K): clients[i].extend(split[i])
    return [(X[c],y[c]) for c in clients]

def format_xy(Xc,model_name):
    return Xc.reshape(len(Xc),-1,1)

def fedavg(global_model,locals,sizes):
    w=[m.get_weights() for m in locals]
    new=[np.average(x,axis=0,weights=sizes) for x in zip(*w)]
    global_model.set_weights(new)

def model_size(model):
    model.save("tmp.h5", include_optimizer=False)
    size=os.path.getsize("tmp.h5")/(1024*1024)
    os.remove("tmp.h5")
    return size

def stats(x,metric):
    x=np.asarray(x,dtype=float)
    x=x[~np.isnan(x)]
    if len(x)==0:
        return np.nan,np.nan,np.nan,np.nan
    mean=np.mean(x); sd=np.std(x)
    ci=1.96*sd/np.sqrt(len(x))
    low,high=mean-ci,mean+ci
    if metric in ["Accuracy","Precision","Recall","F1","AUC","Specificity"]:
        low=max(0,low); high=min(1,high)
    if metric=="MCC":
        low=max(-1,low); high=min(1,high)
    return mean,sd,low,high

def mcnemar_test(y_true_a,y_pred_a,y_true_b,y_pred_b):
    """McNemar's test between two classifiers evaluated on the SAME samples.
    Uses only the discordant pairs (one right, one wrong). Exact binomial
    for small discordant counts (n<25), continuity-corrected chi-square
    otherwise."""
    y_true_a=np.asarray(y_true_a).flatten()
    y_true_b=np.asarray(y_true_b).flatten()
    assert len(y_true_a)==len(y_true_b), "test sets must be the same size"
    assert np.array_equal(y_true_a,y_true_b), "test sets must match (same seed/instances)"

    correct_a=(np.asarray(y_pred_a).flatten()==y_true_a)
    correct_b=(np.asarray(y_pred_b).flatten()==y_true_b)

    n01=int(np.sum(correct_a & ~correct_b))   # A correct, B wrong
    n10=int(np.sum(~correct_a & correct_b))   # A wrong, B correct
    n=n01+n10

    if n==0:
        return np.nan,1.0,n01,n10
    if n<25:
        p=2*min(binom.cdf(min(n01,n10),n,0.5),0.5)   # exact two-sided binomial
        p=min(p,1.0)
        stat=np.nan
    else:
        stat=((abs(n01-n10)-1)**2)/n                  # continuity-corrected chi-square
        p=1-chi2.cdf(stat,1)
    return stat,p,n01,n10

# ================= MODELS =================
def build(name,shape=None,dim=None):
    if name=="CNN":
        m=Sequential([
            Input(shape),
            Conv1D(64,3,activation="relu"),
            Dropout(0.5),
            Conv1D(32,3,activation="relu"),
            GlobalMaxPooling1D(),
            Dense(32,activation="relu"),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="LSTM":
        m=Sequential([
            Input(shape),
            LSTM(128,return_sequences=True),
            Dropout(0.5),
            LSTM(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiLSTM":
        m=Sequential([
            Input(shape),
            Bidirectional(LSTM(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(LSTM(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="GRU":
        m=Sequential([
            Input(shape),
            GRU(128,return_sequences=True),
            Dropout(0.5),
            GRU(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiGRU":
        m=Sequential([
            Input(shape),
            Bidirectional(GRU(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(GRU(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    m.compile(optimizer=Adam(LR),loss="binary_crossentropy",metrics=["accuracy"])
    return m

# ================= STORAGE =================
rows=[]          # global (union-of-clients) test metrics, per (model, seed)
client_rows=[]   # per-client local test metrics, per (model, seed, client)
results_round={m:{"acc":[],"loss":[],"cm":[]} for m in MODELS}

# per-instance predictions, needed for McNemar's test
y_preds={}        # (model, seed) -> y_pred array (0/1), aligned to y_trues[seed]
y_trues={}        # seed -> y_test_global array (0/1) -- same across all models for a given seed

# ================= TRAIN =================
for model_name in MODELS:
    print(f"\n================ MODEL: {model_name} ================")

    for seed in SEEDS:
        print(f"\n------ SEED {seed} ------")
        set_seed(seed)

        # ---- IID partition of the WHOLE dataset across clients ----
        client_full=iid_partition(X,y,CLIENTS)

        # ---- Each client locally splits its own shard into train/test ----
        client_train,client_test=[],[]
        for cid,(Xc,yc) in enumerate(client_full):
            try:
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,stratify=yc,random_state=seed
                )
            except ValueError:
                # fallback if a client shard doesn't have enough of a class to stratify
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,random_state=seed
                )
            client_train.append((Xc_tr,yc_tr))
            client_test.append((Xc_te,yc_te))

        # ---- Global (centralized) test set = union of all clients' local test shards ----
        X_test_global=np.concatenate([Xc for Xc,_ in client_test],axis=0)
        y_test_global=np.concatenate([yc for _,yc in client_test],axis=0)

        create=lambda:build(model_name,shape=(X.shape[1],1))

        fmt=lambda Xc: format_xy(Xc,model_name)

        global_model=create()

        acc_hist,loss_hist=[],[]
        comm=0
        total_train_time=0.0

        for r in range(ROUNDS):
            print(f"\n[Model={model_name} | Seed={seed} | Round={r+1}]")

            locals_=[]; sizes=[]

            for cid,(Xc,yc) in enumerate(client_train):
                m=create()
                m.set_weights(global_model.get_weights())

                t0=time.time()
                history=m.fit(fmt(Xc),yc,epochs=LOCAL_EPOCHS,batch_size=BATCH,verbose=0)
                t1=time.time()
                total_train_time+=(t1-t0)

                train_loss=history.history["loss"][-1]
                train_acc=history.history["accuracy"][-1]

                print(f" Client {cid} → Loss={train_loss:.4f}, Acc={train_acc:.4f}, Time={t1-t0:.2f}s, N={len(yc)}")

                locals_.append(m); sizes.append(len(yc))

            fedavg(global_model,locals_,sizes)

            loss,acc=global_model.evaluate(fmt(X_test_global),y_test_global,verbose=0)

            print(f" >>> GLOBAL (centralized test) → Loss={loss:.4f}, Acc={acc:.4f}")

            acc_hist.append(acc); loss_hist.append(loss)

            # bytes per weight (float32=4 bytes), sent down to each client AND back up from each client
            weight_bytes=sum([w.size for w in global_model.get_weights()])*4
            comm+=weight_bytes*CLIENTS*2

        # ================= FINAL GLOBAL TEST METRICS =================
        t0=time.time()
        y_prob=global_model.predict(fmt(X_test_global),verbose=0)
        inference_time=time.time()-t0

        y_pred=(y_prob>0.5).astype(int)

        # ---- Save per-instance predictions for McNemar's test ----
        y_preds[(model_name,seed)]=y_pred.flatten()
        if seed not in y_trues:
            y_trues[seed]=y_test_global.flatten()
        else:
            # sanity check: every model must see the identical test set for this seed
            assert np.array_equal(y_trues[seed],y_test_global.flatten()), \
                f"Test set mismatch for seed {seed} — McNemar's test requires identical instances across models."

        tn,fp,fn,tp=confusion_matrix(y_test_global,y_pred).ravel()

        # ---- Save this trained global model to disk ----
        model_path=os.path.join(MODEL_SAVE_DIR,f"{model_name}_seed{seed}.keras")
        global_model.save(model_path)
        print(f" [saved] {model_path}")

        rows.append({
            "Model":model_name,
            "Seed":seed,
            "Loss":log_loss(y_test_global,y_prob),
            "Accuracy":accuracy_score(y_test_global,y_pred),
            "Precision":precision_score(y_test_global,y_pred),
            "Recall":recall_score(y_test_global,y_pred),
            "F1":f1_score(y_test_global,y_pred),
            "MCC":matthews_corrcoef(y_test_global,y_pred),
            "AUC":roc_auc_score(y_test_global,y_prob),
            "Specificity":tn/(tn+fp),
            "Training_Time_sec":total_train_time,
            "Inference_Time_sec":inference_time,
            "Model_Size_MB":model_size(global_model),
            "Comm_per_round_MB":comm/(ROUNDS*1024*1024),
            "Total_Comm_MB":comm/(1024*1024),
            "Saved_Model_Path":model_path
        })

        results_round[model_name]["acc"].append(acc_hist)
        results_round[model_name]["loss"].append(loss_hist)
        results_round[model_name]["cm"].append(confusion_matrix(y_test_global,y_pred))

        # ================= PER-CLIENT LOCAL TEST EVALUATION =================
        for cid,(Xc_te,yc_te) in enumerate(client_test):
            yc_prob=global_model.predict(fmt(Xc_te),verbose=0)
            yc_pred=(yc_prob>0.5).astype(int)

            cm_c=confusion_matrix(yc_te,yc_pred,labels=[0,1])
            tn_c,fp_c,fn_c,tp_c=cm_c.ravel()

            auc_val=roc_auc_score(yc_te,yc_prob) if len(np.unique(yc_te))>1 else np.nan

            client_rows.append({
                "Model":model_name,
                "Seed":seed,
                "Client":cid,
                "N_test":len(yc_te),
                "Loss":log_loss(yc_te,yc_prob,labels=[0,1]),
                "Accuracy":accuracy_score(yc_te,yc_pred),
                "Precision":precision_score(yc_te,yc_pred,zero_division=0),
                "Recall":recall_score(yc_te,yc_pred,zero_division=0),
                "F1":f1_score(yc_te,yc_pred,zero_division=0),
                "MCC":matthews_corrcoef(yc_te,yc_pred),
                "AUC":auc_val,
                "Specificity":(tn_c/(tn_c+fp_c)) if (tn_c+fp_c)>0 else np.nan
            })

# ================= PRINT ALL CONFUSION MATRICES PER SEED (GLOBAL TEST) =================
for m in MODELS:
    print(f"\n=== {m}: Global Test Confusion Matrices per Seed ===")
    for seed,cm in zip(SEEDS,results_round[m]["cm"]):
        print(f"Seed {seed}:\n{cm}")

# ================= MEAN OVER SEEDS (GLOBAL TEST, per-round curves + avg cm) =================
for m in MODELS:
    results_round[m]["acc"]=np.mean(results_round[m]["acc"],axis=0)
    results_round[m]["loss"]=np.mean(results_round[m]["loss"],axis=0)
    results_round[m]["cm"]=np.mean(results_round[m]["cm"],axis=0)

for m in MODELS:
    print(f"\n=== {m} (Global Test, averaged over {len(SEEDS)} seeds) ===")
    print("Confusion Matrix (avg):\n",np.round(results_round[m]["cm"],2))
    print("Accuracy per round:",np.round(results_round[m]["acc"],4))
    print("Loss per round:",np.round(results_round[m]["loss"],4))

# ================= PER-MODEL SUMMARY (ALL METRICS incl. time & comm cost, avg over 5 seeds) =================
results_df=pd.DataFrame(rows)

summary_metrics=["Loss","Accuracy","Precision","Recall","F1","MCC","AUC","Specificity",
                  "Training_Time_sec","Inference_Time_sec","Model_Size_MB",
                  "Comm_per_round_MB","Total_Comm_MB"]

per_model_summary=[]
for m in MODELS:
    sub=results_df[results_df["Model"]==m]
    for metric in summary_metrics:
        mean,sd,low,high=stats(sub[metric],metric)
        per_model_summary.append({
            "Model":m,
            "Metric":metric,
            "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
            "95% CI":f"[{low:.4f}, {high:.4f}]"
        })

per_model_summary_df=pd.DataFrame(per_model_summary)
print(f"\nPER-MODEL SUMMARY (mean ± sd, 95% CI over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_summary_df.to_string(index=False))

# wide pivot: one row per model, one column per metric, "mean [low, high]"
per_model_wide=per_model_summary_df.copy()
per_model_wide["Mean [95% CI]"]=per_model_wide.apply(
    lambda r: r["Mean ± SD"].split(" ± ")[0]+" "+r["95% CI"], axis=1
)
per_model_wide=per_model_wide.pivot(index="Model",columns="Metric",values="Mean [95% CI]")
per_model_wide=per_model_wide[summary_metrics]  # keep original metric order
print(f"\nPER-MODEL SUMMARY, WIDE (mean [95% CI] over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_wide.to_string())

# overall pooled summary (all models & seeds together) kept for reference
overall_summary=[]
for metric in summary_metrics:
    mean,sd,low,high=stats(results_df[metric],metric)
    overall_summary.append({
        "Metric":metric,
        "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
        "95% CI":f"[{low:.4f},{high:.4f}]"
    })
overall_summary_df=pd.DataFrame(overall_summary)
print(f"\nSAVED MODELS ({len(results_df)} total, in '{MODEL_SAVE_DIR}/'):\n",
      results_df[["Model","Seed","Saved_Model_Path"]].to_string(index=False))
print("\nOVERALL SUMMARY (all models & seeds pooled):\n",overall_summary_df)

# ================= PER-CLIENT TEST SUMMARY, averaged over 5 seeds =================
client_df=pd.DataFrame(client_rows)
client_metrics=["Accuracy","Precision","Recall","F1","MCC","AUC","Specificity","Loss"]

per_client_summary=(
    client_df.groupby(["Model","Client"])[client_metrics]
    .agg(["mean","std"])
    .round(4)
)
print(f"\nPER-CLIENT TEST SUMMARY (mean/std over {len(SEEDS)} seeds):\n",per_client_summary)

# ================= PAIRWISE PAIRED T-TESTS ACROSS MODELS (same seeds) =================
paired_test_metrics=["Accuracy","F1","AUC","Loss"]

pairwise_rows=[]
for metric in paired_test_metrics:
    for m1,m2 in combinations(MODELS,2):
        a=results_df[results_df["Model"]==m1].sort_values("Seed")[metric].values
        b=results_df[results_df["Model"]==m2].sort_values("Seed")[metric].values
        t_stat,p_val=ttest_rel(a,b)
        pairwise_rows.append({
            "Metric":metric,"Model A":m1,"Model B":m2,
            "Mean A":round(a.mean(),4),"Mean B":round(b.mean(),4),
            "t-stat":round(t_stat,4),"p-value":round(p_val,4),
            "Significant (p<0.05)":p_val<0.05
        })

pairwise_df=pd.DataFrame(pairwise_rows)
print(f"\nPAIRWISE PAIRED T-TESTS across {len(SEEDS)} seeds (Global Test Set):\n",
      pairwise_df.to_string(index=False))

# ================= McNEMAR'S TEST (per-instance, per seed + pooled across seeds) =================
mcnemar_per_seed_rows=[]
for seed in SEEDS:
    y_true=y_trues[seed]
    for m1,m2 in combinations(MODELS,2):
        stat,p,n01,n10=mcnemar_test(y_true,y_preds[(m1,seed)],y_true,y_preds[(m2,seed)])
        mcnemar_per_seed_rows.append({
            "Seed":seed,"Model A":m1,"Model B":m2,
            "A right/B wrong":n01,"A wrong/B right":n10,
            "stat":round(stat,4) if not np.isnan(stat) else "exact",
            "p-value":round(p,4),"Significant (p<0.05)":p<0.05
        })

mcnemar_per_seed_df=pd.DataFrame(mcnemar_per_seed_rows)
print(f"\nMcNEMAR'S TEST — PER SEED (instance-level, Global Test Set):\n",
      mcnemar_per_seed_df.to_string(index=False))

# pooled version: sum discordant counts across all 5 seeds (more statistical power)
mcnemar_pooled_rows=[]
for m1,m2 in combinations(MODELS,2):
    n01_total=0; n10_total=0
    for seed in SEEDS:
        y_true=y_trues[seed]
        correct_a=(y_preds[(m1,seed)]==y_true)
        correct_b=(y_preds[(m2,seed)]==y_true)
        n01_total+=int(np.sum(correct_a & ~correct_b))
        n10_total+=int(np.sum(~correct_a & correct_b))
    n=n01_total+n10_total
    if n==0:
        stat,p=np.nan,1.0
    elif n<25:
        p=min(2*min(binom.cdf(min(n01_total,n10_total),n,0.5),0.5),1.0); stat=np.nan
    else:
        stat=((abs(n01_total-n10_total)-1)**2)/n
        p=1-chi2.cdf(stat,1)
    mcnemar_pooled_rows.append({
        "Model A":m1,"Model B":m2,
        "A right/B wrong (pooled)":n01_total,"A wrong/B right (pooled)":n10_total,
        "stat":round(stat,4) if not np.isnan(stat) else "exact",
        "p-value":round(p,4),"Significant (p<0.05)":p<0.05
    })

mcnemar_pooled_df=pd.DataFrame(mcnemar_pooled_rows)
print(f"\nMcNEMAR'S TEST — POOLED ACROSS {len(SEEDS)} SEEDS (Global Test Set):\n",
      mcnemar_pooled_df.to_string(index=False))

# ================= PLOTS =================
rounds=np.arange(1,ROUNDS+1)

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["acc"],label=m)
plt.title("Accuracy vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Accuracy")
plt.legend(); plt.grid(); plt.show()

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["loss"],label=m)
plt.title("Loss vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Loss")
plt.legend(); plt.grid(); plt.show()
# Out:
# C:\Users\USER\anaconda3\envs\py310\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.5.0) or chardet (6.0.0.post1)/charset_normalizer (3.4.3) doesn't match a supported version!
#   warnings.warn(
# ================ MODEL: CNN ================
#
# ------ SEED 42 ------
#
# [Model=CNN | Seed=42 | Round=1]
#  Client 0 → Loss=0.0840, Acc=0.9728, Time=15.82s, N=47160
#  Client 1 → Loss=0.0732, Acc=0.9775, Time=11.95s, N=47159
#  Client 2 → Loss=0.0791, Acc=0.9740, Time=10.80s, N=47158
#  Client 3 → Loss=0.0756, Acc=0.9754, Time=11.28s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.1987, Acc=0.9258
#
# [Model=CNN | Seed=42 | Round=2]
#  Client 0 → Loss=0.0316, Acc=0.9908, Time=11.04s, N=47160
#  Client 1 → Loss=0.0311, Acc=0.9908, Time=11.50s, N=47159
#  Client 2 → Loss=0.0306, Acc=0.9908, Time=10.81s, N=47158
#  Client 3 → Loss=0.0288, Acc=0.9912, Time=11.03s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0673, Acc=0.9731
#
# [Model=CNN | Seed=42 | Round=3]
#  Client 0 → Loss=0.0179, Acc=0.9946, Time=10.63s, N=47160
#  Client 1 → Loss=0.0184, Acc=0.9948, Time=10.80s, N=47159
#  Client 2 → Loss=0.0184, Acc=0.9944, Time=10.87s, N=47158
#  Client 3 → Loss=0.0167, Acc=0.9950, Time=10.44s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0165, Acc=0.9944
#
# [Model=CNN | Seed=42 | Round=4]
#  Client 0 → Loss=0.0137, Acc=0.9959, Time=10.41s, N=47160
#  Client 1 → Loss=0.0160, Acc=0.9962, Time=10.60s, N=47159
#  Client 2 → Loss=0.0129, Acc=0.9959, Time=10.42s, N=47158
#  Client 3 → Loss=0.0124, Acc=0.9962, Time=10.55s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0068, Acc=0.9978
#
# [Model=CNN | Seed=42 | Round=5]
#  Client 0 → Loss=0.0107, Acc=0.9970, Time=10.79s, N=47160
#  Client 1 → Loss=0.0144, Acc=0.9967, Time=10.86s, N=47159
#  Client 2 → Loss=0.0101, Acc=0.9970, Time=10.76s, N=47158
#  Client 3 → Loss=0.0119, Acc=0.9966, Time=10.45s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0066, Acc=0.9978
#
# [Model=CNN | Seed=42 | Round=6]
#  Client 0 → Loss=0.0093, Acc=0.9972, Time=10.78s, N=47160
#  Client 1 → Loss=0.0126, Acc=0.9973, Time=11.17s, N=47159
#  Client 2 → Loss=0.0091, Acc=0.9971, Time=11.31s, N=47158
#  Client 3 → Loss=0.0082, Acc=0.9973, Time=10.93s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0035, Acc=0.9989
#
# [Model=CNN | Seed=42 | Round=7]
#  Client 0 → Loss=0.0101, Acc=0.9973, Time=10.69s, N=47160
#  Client 1 → Loss=0.0087, Acc=0.9975, Time=10.74s, N=47159
#  Client 2 → Loss=0.0089, Acc=0.9975, Time=11.03s, N=47158
#  Client 3 → Loss=0.0069, Acc=0.9980, Time=10.82s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0038, Acc=0.9988
#
# [Model=CNN | Seed=42 | Round=8]
#  Client 0 → Loss=0.0072, Acc=0.9977, Time=10.95s, N=47160
#  Client 1 → Loss=0.0097, Acc=0.9978, Time=11.20s, N=47159
#  Client 2 → Loss=0.0115, Acc=0.9978, Time=10.94s, N=47158
#  Client 3 → Loss=0.0053, Acc=0.9981, Time=10.73s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0030, Acc=0.9989
#
# [Model=CNN | Seed=42 | Round=9]
#  Client 0 → Loss=0.0084, Acc=0.9977, Time=10.89s, N=47160
#  Client 1 → Loss=0.0070, Acc=0.9980, Time=10.64s, N=47159
#  Client 2 → Loss=0.0103, Acc=0.9976, Time=10.17s, N=47158
#  Client 3 → Loss=0.0071, Acc=0.9982, Time=10.12s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0034, Acc=0.9989
#
# [Model=CNN | Seed=42 | Round=10]
#  Client 0 → Loss=0.0083, Acc=0.9977, Time=10.26s, N=47160
#  Client 1 → Loss=0.0068, Acc=0.9981, Time=10.40s, N=47159
#  Client 2 → Loss=0.0108, Acc=0.9979, Time=10.52s, N=47158
#  Client 3 → Loss=0.0053, Acc=0.9983, Time=10.79s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0024, Acc=0.9993
#
# [Model=CNN | Seed=42 | Round=11]
#  Client 0 → Loss=0.0070, Acc=0.9979, Time=11.22s, N=47160
#  Client 1 → Loss=0.0098, Acc=0.9979, Time=10.80s, N=47159
#  Client 2 → Loss=0.0083, Acc=0.9982, Time=10.88s, N=47158
#  Client 3 → Loss=0.0045, Acc=0.9985, Time=10.66s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0038, Acc=0.9989
#
# [Model=CNN | Seed=42 | Round=12]
#  Client 0 → Loss=0.0062, Acc=0.9983, Time=10.61s, N=47160
#  Client 1 → Loss=0.0065, Acc=0.9985, Time=10.70s, N=47159
#  Client 2 → Loss=0.0060, Acc=0.9983, Time=10.50s, N=47158
#  Client 3 → Loss=0.0083, Acc=0.9982, Time=10.44s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0023, Acc=0.9993
#
# [Model=CNN | Seed=42 | Round=13]
#  Client 0 → Loss=0.0057, Acc=0.9983, Time=10.67s, N=47160
#  Client 1 → Loss=0.0048, Acc=0.9986, Time=10.68s, N=47159
#  Client 2 → Loss=0.0070, Acc=0.9980, Time=11.00s, N=47158
#  Client 3 → Loss=0.0050, Acc=0.9985, Time=10.65s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0040, Acc=0.9990
#
# [Model=CNN | Seed=42 | Round=14]
#  Client 0 → Loss=0.0057, Acc=0.9985, Time=10.59s, N=47160
#  Client 1 → Loss=0.0070, Acc=0.9983, Time=11.14s, N=47159
#  Client 2 → Loss=0.0050, Acc=0.9987, Time=11.35s, N=47158
#  Client 3 → Loss=0.0047, Acc=0.9986, Time=11.10s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0034, Acc=0.9990
#
# [Model=CNN | Seed=42 | Round=15]
#  Client 0 → Loss=0.0068, Acc=0.9986, Time=10.41s, N=47160
#  Client 1 → Loss=0.0049, Acc=0.9985, Time=10.76s, N=47159
#  Client 2 → Loss=0.0081, Acc=0.9986, Time=10.64s, N=47158
#  Client 3 → Loss=0.0075, Acc=0.9982, Time=10.47s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0023, Acc=0.9994
#
# [Model=CNN | Seed=42 | Round=16]
#  Client 0 → Loss=0.0054, Acc=0.9987, Time=10.56s, N=47160
#  Client 1 → Loss=0.0054, Acc=0.9985, Time=10.64s, N=47159
#  Client 2 → Loss=0.0065, Acc=0.9983, Time=10.72s, N=47158
#  Client 3 → Loss=0.0055, Acc=0.9987, Time=10.67s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0035, Acc=0.9993
#
# [Model=CNN | Seed=42 | Round=17]
#  Client 0 → Loss=0.0057, Acc=0.9986, Time=11.26s, N=47160
#  Client 1 → Loss=0.0048, Acc=0.9984, Time=11.25s, N=47159
#  Client 2 → Loss=0.0082, Acc=0.9986, Time=10.79s, N=47158
#  Client 3 → Loss=0.0041, Acc=0.9987, Time=10.48s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0030, Acc=0.9993
#
# [Model=CNN | Seed=42 | Round=18]
#  Client 0 → Loss=0.0062, Acc=0.9986, Time=10.53s, N=47160
#  Client 1 → Loss=0.0073, Acc=0.9984, Time=10.62s, N=47159
#  Client 2 → Loss=0.0037, Acc=0.9988, Time=10.63s, N=47158
#  Client 3 → Loss=0.0072, Acc=0.9989, Time=10.67s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0014, Acc=0.9995
#
# [Model=CNN | Seed=42 | Round=19]
#  Client 0 → Loss=0.0044, Acc=0.9987, Time=10.44s, N=47160
#  Client 1 → Loss=0.0061, Acc=0.9988, Time=10.64s, N=47159
#  Client 2 → Loss=0.0066, Acc=0.9986, Time=11.11s, N=47158
#  Client 3 → Loss=0.0040, Acc=0.9987, Time=10.52s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0027, Acc=0.9993
#
# [Model=CNN | Seed=42 | Round=20]
#  Client 0 → Loss=0.0067, Acc=0.9988, Time=10.25s, N=47160
#  Client 1 → Loss=0.0063, Acc=0.9987, Time=10.27s, N=47159
#  Client 2 → Loss=0.0070, Acc=0.9985, Time=10.38s, N=47158
#  Client 3 → Loss=0.0046, Acc=0.9988, Time=10.55s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0015, Acc=0.9995
#
# [Model=CNN | Seed=42 | Round=21]
#  Client 0 → Loss=0.0038, Acc=0.9988, Time=10.62s, N=47160
#  Client 1 → Loss=0.0051, Acc=0.9986, Time=10.55s, N=47159
#  Client 2 → Loss=0.0034, Acc=0.9990, Time=10.73s, N=47158
#  Client 3 → Loss=0.0066, Acc=0.9985, Time=10.56s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0028, Acc=0.9994
#
# [Model=CNN | Seed=42 | Round=22]
#  Client 0 → Loss=0.0061, Acc=0.9987, Time=10.35s, N=47160
#  Client 1 → Loss=0.0051, Acc=0.9989, Time=10.64s, N=47159
#  Client 2 → Loss=0.0154, Acc=0.9987, Time=11.05s, N=47158
#  Client 3 → Loss=0.0033, Acc=0.9990, Time=11.16s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0029, Acc=0.9994
#
# [Model=CNN | Seed=42 | Round=23]
#  Client 0 → Loss=0.0102, Acc=0.9984, Time=11.07s, N=47160
#  Client 1 → Loss=0.0035, Acc=0.9989, Time=10.51s, N=47159
#  Client 2 → Loss=0.0077, Acc=0.9987, Time=10.58s, N=47158
#  Client 3 → Loss=0.0049, Acc=0.9988, Time=11.05s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0013, Acc=0.9996
#
# [Model=CNN | Seed=42 | Round=24]
#  Client 0 → Loss=0.0066, Acc=0.9985, Time=10.96s, N=47160
#  Client 1 → Loss=0.0109, Acc=0.9988, Time=10.99s, N=47159
#  Client 2 → Loss=0.0036, Acc=0.9990, Time=10.49s, N=47158
#  Client 3 → Loss=0.0056, Acc=0.9989, Time=10.81s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0025, Acc=0.9994
#
# [Model=CNN | Seed=42 | Round=25]
#  Client 0 → Loss=0.0057, Acc=0.9989, Time=10.96s, N=47160
#  Client 1 → Loss=0.0054, Acc=0.9988, Time=10.83s, N=47159
#  Client 2 → Loss=0.0031, Acc=0.9990, Time=10.92s, N=47158
#  Client 3 → Loss=0.0075, Acc=0.9990, Time=11.04s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0021, Acc=0.9995
#
# [Model=CNN | Seed=42 | Round=26]
#  Client 0 → Loss=0.0048, Acc=0.9988, Time=10.59s, N=47160
#  Client 1 → Loss=0.0053, Acc=0.9989, Time=10.93s, N=47159
#  Client 2 → Loss=0.0059, Acc=0.9989, Time=10.97s, N=47158
#  Client 3 → Loss=0.0101, Acc=0.9989, Time=11.04s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0013, Acc=0.9995
#
# [Model=CNN | Seed=42 | Round=27]
#  Client 0 → Loss=0.0042, Acc=0.9987, Time=10.41s, N=47160
#  Client 1 → Loss=0.0064, Acc=0.9990, Time=10.64s, N=47159
#  Client 2 → Loss=0.0043, Acc=0.9989, Time=10.56s, N=47158
#  Client 3 → Loss=0.0045, Acc=0.9992, Time=10.88s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0024, Acc=0.9995
#
# [Model=CNN | Seed=42 | Round=28]
#  Client 0 → Loss=0.0042, Acc=0.9990, Time=10.55s, N=47160
#  Client 1 → Loss=0.0047, Acc=0.9992, Time=10.36s, N=47159
#  Client 2 → Loss=0.0057, Acc=0.9992, Time=10.25s, N=47158
#  Client 3 → Loss=0.0061, Acc=0.9987, Time=10.31s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0020, Acc=0.9996
#
# [Model=CNN | Seed=42 | Round=29]
#  Client 0 → Loss=0.0086, Acc=0.9988, Time=10.41s, N=47160
#  Client 1 → Loss=0.0094, Acc=0.9989, Time=10.66s, N=47159
#  Client 2 → Loss=0.0071, Acc=0.9989, Time=10.67s, N=47158
#  Client 3 → Loss=0.0062, Acc=0.9989, Time=10.64s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0020, Acc=0.9994
#
# [Model=CNN | Seed=42 | Round=30]
#  Client 0 → Loss=0.0047, Acc=0.9990, Time=10.85s, N=47160
#  Client 1 → Loss=0.0033, Acc=0.9990, Time=10.72s, N=47159
#  Client 2 → Loss=0.0056, Acc=0.9989, Time=10.96s, N=47158
#  Client 3 → Loss=0.0046, Acc=0.9991, Time=10.64s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0028, Acc=0.9994
#  [saved] saved_models\CNN_seed42.keras
#
# ------ SEED 3 ------
#
# [Model=CNN | Seed=3 | Round=1]
#  Client 0 → Loss=0.0803, Acc=0.9757, Time=10.61s, N=47160
#  Client 1 → Loss=0.0921, Acc=0.9708, Time=10.62s, N=47159
#  Client 2 → Loss=0.0822, Acc=0.9733, Time=10.58s, N=47158
#  Client 3 → Loss=0.0788, Acc=0.9747, Time=10.46s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.2524, Acc=0.8858
#
# [Model=CNN | Seed=3 | Round=2]
#  Client 0 → Loss=0.0385, Acc=0.9881, Time=10.43s, N=47160
#  Client 1 → Loss=0.0380, Acc=0.9883, Time=10.41s, N=47159
#  Client 2 → Loss=0.0424, Acc=0.9876, Time=10.71s, N=47158
#  Client 3 → Loss=0.0398, Acc=0.9872, Time=10.74s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0334, Acc=0.9888
#
# [Model=CNN | Seed=3 | Round=3]
#  Client 0 → Loss=0.0211, Acc=0.9941, Time=10.93s, N=47160
#  Client 1 → Loss=0.0222, Acc=0.9935, Time=11.17s, N=47159
#  Client 2 → Loss=0.0225, Acc=0.9933, Time=10.91s, N=47158
#  Client 3 → Loss=0.0215, Acc=0.9933, Time=10.57s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0100, Acc=0.9967
#
# [Model=CNN | Seed=3 | Round=4]
#  Client 0 → Loss=0.0141, Acc=0.9959, Time=10.22s, N=47160
#  Client 1 → Loss=0.0163, Acc=0.9948, Time=10.46s, N=47159
#  Client 2 → Loss=0.0149, Acc=0.9952, Time=10.67s, N=47158
#  Client 3 → Loss=0.0146, Acc=0.9953, Time=10.43s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0050, Acc=0.9983
#
# [Model=CNN | Seed=3 | Round=5]
#  Client 0 → Loss=0.0117, Acc=0.9966, Time=10.53s, N=47160
#  Client 1 → Loss=0.0122, Acc=0.9964, Time=10.75s, N=47159
#  Client 2 → Loss=0.0131, Acc=0.9963, Time=10.69s, N=47158
#  Client 3 → Loss=0.0120, Acc=0.9964, Time=10.90s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0063, Acc=0.9978
#
# [Model=CNN | Seed=3 | Round=6]
#  Client 0 → Loss=0.0111, Acc=0.9969, Time=10.53s, N=47160
#  Client 1 → Loss=0.0140, Acc=0.9969, Time=10.29s, N=47159
#  Client 2 → Loss=0.0097, Acc=0.9968, Time=10.49s, N=47158
#  Client 3 → Loss=0.0099, Acc=0.9970, Time=10.52s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0036, Acc=0.9987
#
# [Model=CNN | Seed=3 | Round=7]
#  Client 0 → Loss=0.0086, Acc=0.9975, Time=10.17s, N=47160
#  Client 1 → Loss=0.0112, Acc=0.9969, Time=10.49s, N=47159
#  Client 2 → Loss=0.0095, Acc=0.9971, Time=10.44s, N=47158
#  Client 3 → Loss=0.0083, Acc=0.9973, Time=10.60s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0033, Acc=0.9988
#
# [Model=CNN | Seed=3 | Round=8]
#  Client 0 → Loss=0.0097, Acc=0.9975, Time=10.58s, N=47160
#  Client 1 → Loss=0.0108, Acc=0.9974, Time=11.10s, N=47159
#  Client 2 → Loss=0.0074, Acc=0.9975, Time=11.59s, N=47158
#  Client 3 → Loss=0.0080, Acc=0.9979, Time=10.46s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0027, Acc=0.9990
#
# [Model=CNN | Seed=3 | Round=9]
#  Client 0 → Loss=0.0075, Acc=0.9978, Time=10.75s, N=47160
#  Client 1 → Loss=0.0109, Acc=0.9976, Time=10.60s, N=47159
#  Client 2 → Loss=0.0170, Acc=0.9978, Time=10.93s, N=47158
#  Client 3 → Loss=0.0065, Acc=0.9980, Time=10.70s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0031, Acc=0.9989
#
# [Model=CNN | Seed=3 | Round=10]
#  Client 0 → Loss=0.0077, Acc=0.9980, Time=10.70s, N=47160
#  Client 1 → Loss=0.0087, Acc=0.9977, Time=10.69s, N=47159
#  Client 2 → Loss=0.0085, Acc=0.9980, Time=10.72s, N=47158
#  Client 3 → Loss=0.0066, Acc=0.9980, Time=10.75s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0021, Acc=0.9993
#
# [Model=CNN | Seed=3 | Round=11]
#  Client 0 → Loss=0.0094, Acc=0.9979, Time=10.79s, N=47160
#  Client 1 → Loss=0.0077, Acc=0.9978, Time=10.88s, N=47159
#  Client 2 → Loss=0.0091, Acc=0.9980, Time=10.96s, N=47158
#  Client 3 → Loss=0.0065, Acc=0.9980, Time=10.91s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0024, Acc=0.9993
#
# [Model=CNN | Seed=3 | Round=12]
#  Client 0 → Loss=0.0093, Acc=0.9982, Time=10.76s, N=47160
#  Client 1 → Loss=0.0087, Acc=0.9981, Time=10.54s, N=47159
#  Client 2 → Loss=0.0083, Acc=0.9979, Time=10.30s, N=47158
#  Client 3 → Loss=0.0069, Acc=0.9983, Time=10.56s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0022, Acc=0.9994
#
# [Model=CNN | Seed=3 | Round=13]
#  Client 0 → Loss=0.0063, Acc=0.9981, Time=10.53s, N=47160
#  Client 1 → Loss=0.0054, Acc=0.9983, Time=10.12s, N=47159
#  Client 2 → Loss=0.0061, Acc=0.9985, Time=10.50s, N=47158
#  Client 3 → Loss=0.0052, Acc=0.9983, Time=10.66s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0021, Acc=0.9993
#
# [Model=CNN | Seed=3 | Round=14]
#  Client 0 → Loss=0.0072, Acc=0.9984, Time=10.86s, N=47160
#  Client 1 → Loss=0.0063, Acc=0.9981, Time=11.11s, N=47159
#  Client 2 → Loss=0.0070, Acc=0.9985, Time=10.86s, N=47158
#  Client 3 → Loss=0.0069, Acc=0.9980, Time=10.77s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0027, Acc=0.9991
#
# [Model=CNN | Seed=3 | Round=15]
#  Client 0 → Loss=0.0064, Acc=0.9986, Time=10.37s, N=47160
#  Client 1 → Loss=0.0081, Acc=0.9981, Time=10.48s, N=47159
#  Client 2 → Loss=0.0051, Acc=0.9985, Time=11.19s, N=47158
#  Client 3 → Loss=0.0053, Acc=0.9985, Time=10.59s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0020, Acc=0.9993
#
# [Model=CNN | Seed=3 | Round=16]
#  Client 0 → Loss=0.0053, Acc=0.9985, Time=10.59s, N=47160
#  Client 1 → Loss=0.0079, Acc=0.9981, Time=10.52s, N=47159
#  Client 2 → Loss=0.0131, Acc=0.9983, Time=10.55s, N=47158
#  Client 3 → Loss=0.0053, Acc=0.9985, Time=11.02s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0021, Acc=0.9993
#
# [Model=CNN | Seed=3 | Round=17]
#  Client 0 → Loss=0.0053, Acc=0.9987, Time=11.22s, N=47160
#  Client 1 → Loss=0.0067, Acc=0.9986, Time=10.92s, N=47159
#  Client 2 → Loss=0.0121, Acc=0.9984, Time=10.34s, N=47158
#  Client 3 → Loss=0.0041, Acc=0.9985, Time=10.93s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0018, Acc=0.9994
#
# [Model=CNN | Seed=3 | Round=18]
#  Client 0 → Loss=0.0097, Acc=0.9988, Time=10.54s, N=47160
#  Client 1 → Loss=0.0040, Acc=0.9987, Time=11.04s, N=47159
#  Client 2 → Loss=0.0081, Acc=0.9989, Time=10.76s, N=47158
#  Client 3 → Loss=0.0058, Acc=0.9986, Time=10.90s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0024, Acc=0.9993
#
# [Model=CNN | Seed=3 | Round=19]
#  Client 0 → Loss=0.0077, Acc=0.9985, Time=10.77s, N=47160
#  Client 1 → Loss=0.0076, Acc=0.9984, Time=10.93s, N=47159
#  Client 2 → Loss=0.0065, Acc=0.9986, Time=11.04s, N=47158
#  Client 3 → Loss=0.0098, Acc=0.9987, Time=10.91s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0025, Acc=0.9991
#
# [Model=CNN | Seed=3 | Round=20]
#  Client 0 → Loss=0.0047, Acc=0.9989, Time=10.68s, N=47160
#  Client 1 → Loss=0.0167, Acc=0.9982, Time=10.59s, N=47159
#  Client 2 → Loss=0.0092, Acc=0.9986, Time=10.73s, N=47158
#  Client 3 → Loss=0.0062, Acc=0.9987, Time=10.51s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0019, Acc=0.9994
#
# [Model=CNN | Seed=3 | Round=21]
#  Client 0 → Loss=0.0050, Acc=0.9986, Time=10.44s, N=47160
#  Client 1 → Loss=0.0078, Acc=0.9983, Time=10.06s, N=47159
#  Client 2 → Loss=0.0046, Acc=0.9986, Time=10.48s, N=47158
#  Client 3 → Loss=0.0051, Acc=0.9988, Time=10.61s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0016, Acc=0.9995
#
# [Model=CNN | Seed=3 | Round=22]
#  Client 0 → Loss=0.0056, Acc=0.9988, Time=10.41s, N=47160
#  Client 1 → Loss=0.0091, Acc=0.9983, Time=11.07s, N=47159
#  Client 2 → Loss=0.0056, Acc=0.9985, Time=10.93s, N=47158
#  Client 3 → Loss=0.0076, Acc=0.9984, Time=10.48s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0020, Acc=0.9993
#
# [Model=CNN | Seed=3 | Round=23]
#  Client 0 → Loss=0.0048, Acc=0.9989, Time=10.21s, N=47160
#  Client 1 → Loss=0.0067, Acc=0.9988, Time=10.32s, N=47159
#  Client 2 → Loss=0.0060, Acc=0.9989, Time=10.45s, N=47158
#  Client 3 → Loss=0.0074, Acc=0.9987, Time=10.54s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0018, Acc=0.9993
#
# [Model=CNN | Seed=3 | Round=24]
#  Client 0 → Loss=0.0052, Acc=0.9989, Time=10.78s, N=47160
#  Client 1 → Loss=0.0066, Acc=0.9985, Time=10.78s, N=47159
#  Client 2 → Loss=0.0067, Acc=0.9989, Time=10.49s, N=47158
#  Client 3 → Loss=0.0065, Acc=0.9988, Time=10.65s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0020, Acc=0.9993
#
# [Model=CNN | Seed=3 | Round=25]
#  Client 0 → Loss=0.0030, Acc=0.9991, Time=10.86s, N=47160
#  Client 1 → Loss=0.0104, Acc=0.9985, Time=10.87s, N=47159
#  Client 2 → Loss=0.0058, Acc=0.9988, Time=10.55s, N=47158
#  Client 3 → Loss=0.0035, Acc=0.9989, Time=10.68s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0018, Acc=0.9995
#
# [Model=CNN | Seed=3 | Round=26]
#  Client 0 → Loss=0.0051, Acc=0.9987, Time=10.60s, N=47160
#  Client 1 → Loss=0.0097, Acc=0.9983, Time=10.51s, N=47159
#  Client 2 → Loss=0.0062, Acc=0.9986, Time=10.32s, N=47158
#  Client 3 → Loss=0.0063, Acc=0.9987, Time=10.20s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0018, Acc=0.9995
#
# [Model=CNN | Seed=3 | Round=27]
#  Client 0 → Loss=0.0049, Acc=0.9989, Time=10.54s, N=47160
#  Client 1 → Loss=0.0047, Acc=0.9986, Time=10.65s, N=47159
#  Client 2 → Loss=0.0177, Acc=0.9988, Time=11.30s, N=47158
#  Client 3 → Loss=0.0065, Acc=0.9989, Time=11.21s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0015, Acc=0.9996
#
# [Model=CNN | Seed=3 | Round=28]
#  Client 0 → Loss=0.0040, Acc=0.9991, Time=11.05s, N=47160
#  Client 1 → Loss=0.0041, Acc=0.9987, Time=11.02s, N=47159
#  Client 2 → Loss=0.0078, Acc=0.9984, Time=10.56s, N=47158
#  Client 3 → Loss=0.0047, Acc=0.9988, Time=10.44s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0016, Acc=0.9995
#
# [Model=CNN | Seed=3 | Round=29]
#  Client 0 → Loss=0.0059, Acc=0.9989, Time=10.30s, N=47160
#  Client 1 → Loss=0.0138, Acc=0.9986, Time=10.35s, N=47159
#  Client 2 → Loss=0.0149, Acc=0.9986, Time=10.38s, N=47158
#  Client 3 → Loss=0.0055, Acc=0.9989, Time=10.53s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0017, Acc=0.9995
#
# [Model=CNN | Seed=3 | Round=30]
#  Client 0 → Loss=0.0039, Acc=0.9987, Time=10.82s, N=47160
#  Client 1 → Loss=0.0118, Acc=0.9984, Time=10.66s, N=47159
#  Client 2 → Loss=0.0053, Acc=0.9988, Time=11.15s, N=47158
#  Client 3 → Loss=0.0094, Acc=0.9989, Time=10.54s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0017, Acc=0.9995
#  [saved] saved_models\CNN_seed3.keras
#
# ------ SEED 7 ------
#
# [Model=CNN | Seed=7 | Round=1]
#  Client 0 → Loss=0.0927, Acc=0.9701, Time=11.27s, N=47160
#  Client 1 → Loss=0.0887, Acc=0.9707, Time=11.44s, N=47159
#  Client 2 → Loss=0.0927, Acc=0.9688, Time=11.08s, N=47158
#  Client 3 → Loss=0.0940, Acc=0.9683, Time=11.40s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.1899, Acc=0.9212
#
# [Model=CNN | Seed=7 | Round=2]
#  Client 0 → Loss=0.0387, Acc=0.9877, Time=11.10s, N=47160
#  Client 1 → Loss=0.0400, Acc=0.9878, Time=11.06s, N=47159
#  Client 2 → Loss=0.0363, Acc=0.9881, Time=11.70s, N=47158
#  Client 3 → Loss=0.0388, Acc=0.9879, Time=11.42s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0224, Acc=0.9927
#
# [Model=CNN | Seed=7 | Round=3]
#  Client 0 → Loss=0.0180, Acc=0.9948, Time=11.36s, N=47160
#  Client 1 → Loss=0.0190, Acc=0.9944, Time=11.81s, N=47159
#  Client 2 → Loss=0.0179, Acc=0.9948, Time=11.13s, N=47158
#  Client 3 → Loss=0.0195, Acc=0.9942, Time=11.25s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0072, Acc=0.9976
#
# [Model=CNN | Seed=7 | Round=4]
#  Client 0 → Loss=0.0205, Acc=0.9963, Time=25.56s, N=47160
#  Client 1 → Loss=0.0137, Acc=0.9961, Time=58.98s, N=47159
#  Client 2 → Loss=0.0127, Acc=0.9961, Time=11.06s, N=47158
#  Client 3 → Loss=0.0139, Acc=0.9957, Time=10.91s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0038, Acc=0.9987
#
# [Model=CNN | Seed=7 | Round=5]
#  Client 0 → Loss=0.0093, Acc=0.9973, Time=10.77s, N=47160
#  Client 1 → Loss=0.0104, Acc=0.9969, Time=10.74s, N=47159
#  Client 2 → Loss=0.0118, Acc=0.9965, Time=10.83s, N=47158
#  Client 3 → Loss=0.0121, Acc=0.9969, Time=10.82s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0039, Acc=0.9987
#
# [Model=CNN | Seed=7 | Round=6]
#  Client 0 → Loss=0.0074, Acc=0.9978, Time=10.81s, N=47160
#  Client 1 → Loss=0.0094, Acc=0.9972, Time=11.05s, N=47159
#  Client 2 → Loss=0.0089, Acc=0.9974, Time=10.83s, N=47158
#  Client 3 → Loss=0.0097, Acc=0.9972, Time=11.40s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0032, Acc=0.9991
#
# [Model=CNN | Seed=7 | Round=7]
#  Client 0 → Loss=0.0076, Acc=0.9982, Time=11.15s, N=47160
#  Client 1 → Loss=0.0077, Acc=0.9975, Time=11.03s, N=47159
#  Client 2 → Loss=0.0078, Acc=0.9977, Time=11.59s, N=47158
#  Client 3 → Loss=0.0071, Acc=0.9977, Time=10.68s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0018, Acc=0.9994
#
# [Model=CNN | Seed=7 | Round=8]
#  Client 0 → Loss=0.0060, Acc=0.9982, Time=11.20s, N=47160
#  Client 1 → Loss=0.0073, Acc=0.9979, Time=10.70s, N=47159
#  Client 2 → Loss=0.0075, Acc=0.9978, Time=10.84s, N=47158
#  Client 3 → Loss=0.0099, Acc=0.9977, Time=10.49s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0024, Acc=0.9993
#
# [Model=CNN | Seed=7 | Round=9]
#  Client 0 → Loss=0.0057, Acc=0.9986, Time=10.84s, N=47160
#  Client 1 → Loss=0.0065, Acc=0.9981, Time=11.39s, N=47159
#  Client 2 → Loss=0.0065, Acc=0.9979, Time=11.75s, N=47158
#  Client 3 → Loss=0.0080, Acc=0.9978, Time=11.69s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0021, Acc=0.9995
#
# [Model=CNN | Seed=7 | Round=10]
#  Client 0 → Loss=0.0051, Acc=0.9985, Time=11.23s, N=47160
#  Client 1 → Loss=0.0061, Acc=0.9981, Time=10.66s, N=47159
#  Client 2 → Loss=0.0067, Acc=0.9980, Time=10.73s, N=47158
#  Client 3 → Loss=0.0067, Acc=0.9980, Time=11.58s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0023, Acc=0.9995
#
# [Model=CNN | Seed=7 | Round=11]
#  Client 0 → Loss=0.0051, Acc=0.9990, Time=11.13s, N=47160
#  Client 1 → Loss=0.0118, Acc=0.9983, Time=11.15s, N=47159
#  Client 2 → Loss=0.0062, Acc=0.9984, Time=11.25s, N=47158
#  Client 3 → Loss=0.0057, Acc=0.9983, Time=10.81s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0015, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=12]
#  Client 0 → Loss=0.0045, Acc=0.9987, Time=11.29s, N=47160
#  Client 1 → Loss=0.0055, Acc=0.9985, Time=10.72s, N=47159
#  Client 2 → Loss=0.0047, Acc=0.9985, Time=10.69s, N=47158
#  Client 3 → Loss=0.0073, Acc=0.9981, Time=10.77s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0015, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=13]
#  Client 0 → Loss=0.0076, Acc=0.9986, Time=10.65s, N=47160
#  Client 1 → Loss=0.0069, Acc=0.9986, Time=10.44s, N=47159
#  Client 2 → Loss=0.0050, Acc=0.9986, Time=10.32s, N=47158
#  Client 3 → Loss=0.0083, Acc=0.9982, Time=10.54s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0015, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=14]
#  Client 0 → Loss=0.0150, Acc=0.9987, Time=10.84s, N=47160
#  Client 1 → Loss=0.0053, Acc=0.9985, Time=11.00s, N=47159
#  Client 2 → Loss=0.0039, Acc=0.9987, Time=10.93s, N=47158
#  Client 3 → Loss=0.0072, Acc=0.9982, Time=11.05s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0015, Acc=0.9996
#
# [Model=CNN | Seed=7 | Round=15]
#  Client 0 → Loss=0.0083, Acc=0.9987, Time=10.80s, N=47160
#  Client 1 → Loss=0.0052, Acc=0.9986, Time=10.70s, N=47159
#  Client 2 → Loss=0.0041, Acc=0.9987, Time=10.69s, N=47158
#  Client 3 → Loss=0.0063, Acc=0.9986, Time=11.03s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0014, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=16]
#  Client 0 → Loss=0.0057, Acc=0.9987, Time=11.00s, N=47160
#  Client 1 → Loss=0.0059, Acc=0.9987, Time=11.30s, N=47159
#  Client 2 → Loss=0.0058, Acc=0.9987, Time=11.18s, N=47158
#  Client 3 → Loss=0.0067, Acc=0.9987, Time=10.90s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0017, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=17]
#  Client 0 → Loss=0.0188, Acc=0.9987, Time=11.26s, N=47160
#  Client 1 → Loss=0.0046, Acc=0.9987, Time=11.33s, N=47159
#  Client 2 → Loss=0.0061, Acc=0.9988, Time=11.94s, N=47158
#  Client 3 → Loss=0.0079, Acc=0.9980, Time=11.78s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0017, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=18]
#  Client 0 → Loss=0.0060, Acc=0.9988, Time=11.15s, N=47160
#  Client 1 → Loss=0.0048, Acc=0.9985, Time=11.00s, N=47159
#  Client 2 → Loss=0.0048, Acc=0.9986, Time=11.32s, N=47158
#  Client 3 → Loss=0.0057, Acc=0.9986, Time=11.41s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0014, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=19]
#  Client 0 → Loss=0.0074, Acc=0.9990, Time=11.28s, N=47160
#  Client 1 → Loss=0.0051, Acc=0.9986, Time=17.75s, N=47159
#  Client 2 → Loss=0.0058, Acc=0.9987, Time=21.38s, N=47158
#  Client 3 → Loss=0.0079, Acc=0.9984, Time=11.32s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0014, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=20]
#  Client 0 → Loss=0.0059, Acc=0.9988, Time=11.12s, N=47160
#  Client 1 → Loss=0.0050, Acc=0.9988, Time=10.77s, N=47159
#  Client 2 → Loss=0.0040, Acc=0.9989, Time=10.96s, N=47158
#  Client 3 → Loss=0.0050, Acc=0.9988, Time=11.40s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0016, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=21]
#  Client 0 → Loss=0.0112, Acc=0.9990, Time=12.15s, N=47160
#  Client 1 → Loss=0.0072, Acc=0.9986, Time=11.47s, N=47159
#  Client 2 → Loss=0.0038, Acc=0.9987, Time=10.94s, N=47158
#  Client 3 → Loss=0.0038, Acc=0.9987, Time=10.95s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0015, Acc=0.9998
#
# [Model=CNN | Seed=7 | Round=22]
#  Client 0 → Loss=0.0033, Acc=0.9990, Time=11.16s, N=47160
#  Client 1 → Loss=0.0059, Acc=0.9985, Time=10.93s, N=47159
#  Client 2 → Loss=0.0041, Acc=0.9991, Time=11.18s, N=47158
#  Client 3 → Loss=0.0079, Acc=0.9989, Time=11.57s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0016, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=23]
#  Client 0 → Loss=0.0041, Acc=0.9991, Time=11.38s, N=47160
#  Client 1 → Loss=0.0045, Acc=0.9988, Time=11.18s, N=47159
#  Client 2 → Loss=0.0052, Acc=0.9990, Time=10.84s, N=47158
#  Client 3 → Loss=0.0033, Acc=0.9991, Time=11.30s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0014, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=24]
#  Client 0 → Loss=0.0027, Acc=0.9992, Time=11.08s, N=47160
#  Client 1 → Loss=0.0054, Acc=0.9985, Time=11.25s, N=47159
#  Client 2 → Loss=0.0047, Acc=0.9989, Time=11.38s, N=47158
#  Client 3 → Loss=0.0040, Acc=0.9992, Time=11.40s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0014, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=25]
#  Client 0 → Loss=0.0074, Acc=0.9992, Time=11.58s, N=47160
#  Client 1 → Loss=0.0070, Acc=0.9987, Time=11.23s, N=47159
#  Client 2 → Loss=0.0062, Acc=0.9987, Time=10.79s, N=47158
#  Client 3 → Loss=0.0031, Acc=0.9991, Time=11.02s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0018, Acc=0.9996
#
# [Model=CNN | Seed=7 | Round=26]
#  Client 0 → Loss=0.0078, Acc=0.9990, Time=10.96s, N=47160
#  Client 1 → Loss=0.0043, Acc=0.9987, Time=11.07s, N=47159
#  Client 2 → Loss=0.0056, Acc=0.9987, Time=11.07s, N=47158
#  Client 3 → Loss=0.0045, Acc=0.9989, Time=11.05s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0018, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=27]
#  Client 0 → Loss=0.0037, Acc=0.9991, Time=11.29s, N=47160
#  Client 1 → Loss=0.0050, Acc=0.9987, Time=11.25s, N=47159
#  Client 2 → Loss=0.0038, Acc=0.9989, Time=11.04s, N=47158
#  Client 3 → Loss=0.0055, Acc=0.9987, Time=11.02s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0017, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=28]
#  Client 0 → Loss=0.0035, Acc=0.9990, Time=11.15s, N=47160
#  Client 1 → Loss=0.0039, Acc=0.9989, Time=11.11s, N=47159
#  Client 2 → Loss=0.0057, Acc=0.9988, Time=10.95s, N=47158
#  Client 3 → Loss=0.0050, Acc=0.9990, Time=11.23s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0018, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=29]
#  Client 0 → Loss=0.0088, Acc=0.9987, Time=11.13s, N=47160
#  Client 1 → Loss=0.0046, Acc=0.9988, Time=11.00s, N=47159
#  Client 2 → Loss=0.0039, Acc=0.9990, Time=11.04s, N=47158
#  Client 3 → Loss=0.0094, Acc=0.9989, Time=11.24s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0016, Acc=0.9997
#
# [Model=CNN | Seed=7 | Round=30]
#  Client 0 → Loss=0.0038, Acc=0.9992, Time=11.35s, N=47160
#  Client 1 → Loss=0.0058, Acc=0.9990, Time=11.19s, N=47159
#  Client 2 → Loss=0.0076, Acc=0.9987, Time=11.13s, N=47158
#  Client 3 → Loss=0.0069, Acc=0.9987, Time=11.41s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0022, Acc=0.9997
#  [saved] saved_models\CNN_seed7.keras
#
# ------ SEED 72 ------
#
# [Model=CNN | Seed=72 | Round=1]
#  Client 0 → Loss=0.0803, Acc=0.9733, Time=11.48s, N=47160
#  Client 1 → Loss=0.0796, Acc=0.9749, Time=11.69s, N=47159
#  Client 2 → Loss=0.0797, Acc=0.9743, Time=11.34s, N=47158
#  Client 3 → Loss=0.0752, Acc=0.9752, Time=11.33s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.1523, Acc=0.9781
#
# [Model=CNN | Seed=72 | Round=2]
#  Client 0 → Loss=0.0317, Acc=0.9895, Time=22.34s, N=47160
#  Client 1 → Loss=0.0335, Acc=0.9894, Time=30.98s, N=47159
#  Client 2 → Loss=0.0321, Acc=0.9900, Time=10.88s, N=47158
#  Client 3 → Loss=0.0341, Acc=0.9897, Time=11.04s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0148, Acc=0.9951
#
# [Model=CNN | Seed=72 | Round=3]
#  Client 0 → Loss=0.0149, Acc=0.9954, Time=11.22s, N=47160
#  Client 1 → Loss=0.0158, Acc=0.9955, Time=11.33s, N=47159
#  Client 2 → Loss=0.0165, Acc=0.9948, Time=11.01s, N=47158
#  Client 3 → Loss=0.0170, Acc=0.9947, Time=11.02s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0118, Acc=0.9962
#
# [Model=CNN | Seed=72 | Round=4]
#  Client 0 → Loss=0.0106, Acc=0.9969, Time=11.45s, N=47160
#  Client 1 → Loss=0.0125, Acc=0.9964, Time=10.91s, N=47159
#  Client 2 → Loss=0.0120, Acc=0.9963, Time=11.02s, N=47158
#  Client 3 → Loss=0.0118, Acc=0.9965, Time=10.60s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0068, Acc=0.9980
#
# [Model=CNN | Seed=72 | Round=5]
#  Client 0 → Loss=0.0084, Acc=0.9973, Time=10.57s, N=47160
#  Client 1 → Loss=0.0105, Acc=0.9970, Time=10.67s, N=47159
#  Client 2 → Loss=0.0092, Acc=0.9971, Time=10.91s, N=47158
#  Client 3 → Loss=0.0103, Acc=0.9972, Time=11.07s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0047, Acc=0.9985
#
# [Model=CNN | Seed=72 | Round=6]
#  Client 0 → Loss=0.0086, Acc=0.9975, Time=10.99s, N=47160
#  Client 1 → Loss=0.0079, Acc=0.9976, Time=11.03s, N=47159
#  Client 2 → Loss=0.0081, Acc=0.9977, Time=11.22s, N=47158
#  Client 3 → Loss=0.0093, Acc=0.9973, Time=11.03s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0032, Acc=0.9990
#
# [Model=CNN | Seed=72 | Round=7]
#  Client 0 → Loss=0.0071, Acc=0.9979, Time=10.31s, N=47160
#  Client 1 → Loss=0.0071, Acc=0.9978, Time=10.42s, N=47159
#  Client 2 → Loss=0.0078, Acc=0.9976, Time=11.07s, N=47158
#  Client 3 → Loss=0.0064, Acc=0.9979, Time=10.74s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0038, Acc=0.9988
#
# [Model=CNN | Seed=72 | Round=8]
#  Client 0 → Loss=0.0066, Acc=0.9980, Time=10.75s, N=47160
#  Client 1 → Loss=0.0073, Acc=0.9978, Time=10.65s, N=47159
#  Client 2 → Loss=0.0067, Acc=0.9977, Time=10.62s, N=47158
#  Client 3 → Loss=0.0079, Acc=0.9980, Time=10.94s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0035, Acc=0.9989
#
# [Model=CNN | Seed=72 | Round=9]
#  Client 0 → Loss=0.0065, Acc=0.9980, Time=11.15s, N=47160
#  Client 1 → Loss=0.0056, Acc=0.9983, Time=11.27s, N=47159
#  Client 2 → Loss=0.0063, Acc=0.9979, Time=11.09s, N=47158
#  Client 3 → Loss=0.0056, Acc=0.9983, Time=10.63s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0037, Acc=0.9990
#
# [Model=CNN | Seed=72 | Round=10]
#  Client 0 → Loss=0.0059, Acc=0.9984, Time=11.07s, N=47160
#  Client 1 → Loss=0.0072, Acc=0.9983, Time=10.99s, N=47159
#  Client 2 → Loss=0.0060, Acc=0.9981, Time=11.07s, N=47158
#  Client 3 → Loss=0.0067, Acc=0.9981, Time=11.02s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0022, Acc=0.9995
#
# [Model=CNN | Seed=72 | Round=11]
#  Client 0 → Loss=0.0051, Acc=0.9985, Time=10.56s, N=47160
#  Client 1 → Loss=0.0059, Acc=0.9983, Time=10.32s, N=47159
#  Client 2 → Loss=0.0081, Acc=0.9984, Time=10.56s, N=47158
#  Client 3 → Loss=0.0069, Acc=0.9983, Time=10.87s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0033, Acc=0.9990
#
# [Model=CNN | Seed=72 | Round=12]
#  Client 0 → Loss=0.0056, Acc=0.9984, Time=10.90s, N=47160
#  Client 1 → Loss=0.0053, Acc=0.9986, Time=11.26s, N=47159
#  Client 2 → Loss=0.0061, Acc=0.9982, Time=11.19s, N=47158
#  Client 3 → Loss=0.0088, Acc=0.9981, Time=10.92s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0021, Acc=0.9994
#
# [Model=CNN | Seed=72 | Round=13]
#  Client 0 → Loss=0.0059, Acc=0.9984, Time=10.44s, N=47160
#  Client 1 → Loss=0.0055, Acc=0.9983, Time=10.33s, N=47159
#  Client 2 → Loss=0.0055, Acc=0.9985, Time=10.39s, N=47158
#  Client 3 → Loss=0.0068, Acc=0.9982, Time=10.51s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0027, Acc=0.9996
#
# [Model=CNN | Seed=72 | Round=14]
#  Client 0 → Loss=0.0048, Acc=0.9985, Time=10.51s, N=47160
#  Client 1 → Loss=0.0093, Acc=0.9983, Time=10.66s, N=47159
#  Client 2 → Loss=0.0056, Acc=0.9986, Time=10.77s, N=47158
#  Client 3 → Loss=0.0092, Acc=0.9981, Time=10.53s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0059, Acc=0.9988
#
# [Model=CNN | Seed=72 | Round=15]
#  Client 0 → Loss=0.0056, Acc=0.9985, Time=10.87s, N=47160
#  Client 1 → Loss=0.0120, Acc=0.9984, Time=10.77s, N=47159
#  Client 2 → Loss=0.0050, Acc=0.9985, Time=10.56s, N=47158
#  Client 3 → Loss=0.0064, Acc=0.9983, Time=10.39s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0032, Acc=0.9995
#
# [Model=CNN | Seed=72 | Round=16]
#  Client 0 → Loss=0.0048, Acc=0.9986, Time=10.82s, N=47160
#  Client 1 → Loss=0.0053, Acc=0.9987, Time=10.88s, N=47159
#  Client 2 → Loss=0.0058, Acc=0.9983, Time=10.97s, N=47158
#  Client 3 → Loss=0.0072, Acc=0.9981, Time=10.69s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0029, Acc=0.9995
#
# [Model=CNN | Seed=72 | Round=17]
#  Client 0 → Loss=0.0046, Acc=0.9988, Time=10.58s, N=47160
#  Client 1 → Loss=0.0061, Acc=0.9985, Time=11.07s, N=47159
#  Client 2 → Loss=0.0063, Acc=0.9983, Time=10.77s, N=47158
#  Client 3 → Loss=0.0059, Acc=0.9984, Time=11.32s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0019, Acc=0.9995
#
# [Model=CNN | Seed=72 | Round=18]
#  Client 0 → Loss=0.0078, Acc=0.9985, Time=11.26s, N=47160
#  Client 1 → Loss=0.0052, Acc=0.9987, Time=10.93s, N=47159
#  Client 2 → Loss=0.0040, Acc=0.9985, Time=10.84s, N=47158
#  Client 3 → Loss=0.0050, Acc=0.9987, Time=11.02s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0028, Acc=0.9995
#
# [Model=CNN | Seed=72 | Round=19]
#  Client 0 → Loss=0.0063, Acc=0.9986, Time=10.80s, N=47160
#  Client 1 → Loss=0.0044, Acc=0.9988, Time=10.62s, N=47159
#  Client 2 → Loss=0.0124, Acc=0.9986, Time=10.57s, N=47158
#  Client 3 → Loss=0.0058, Acc=0.9989, Time=10.94s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0044, Acc=0.9996
#
# [Model=CNN | Seed=72 | Round=20]
#  Client 0 → Loss=0.0063, Acc=0.9986, Time=11.09s, N=47160
#  Client 1 → Loss=0.0058, Acc=0.9987, Time=10.92s, N=47159
#  Client 2 → Loss=0.0057, Acc=0.9985, Time=10.87s, N=47158
#  Client 3 → Loss=0.0069, Acc=0.9984, Time=10.86s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0073, Acc=0.9996
#
# [Model=CNN | Seed=72 | Round=21]
#  Client 0 → Loss=0.0092, Acc=0.9983, Time=10.54s, N=47160
#  Client 1 → Loss=0.0039, Acc=0.9989, Time=10.76s, N=47159
#  Client 2 → Loss=0.0065, Acc=0.9986, Time=10.77s, N=47158
#  Client 3 → Loss=0.0077, Acc=0.9989, Time=11.37s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0084, Acc=0.9995
#
# [Model=CNN | Seed=72 | Round=22]
#  Client 0 → Loss=0.0057, Acc=0.9985, Time=11.27s, N=47160
#  Client 1 → Loss=0.0058, Acc=0.9988, Time=10.96s, N=47159
#  Client 2 → Loss=0.0057, Acc=0.9986, Time=10.50s, N=47158
#  Client 3 → Loss=0.0127, Acc=0.9983, Time=10.61s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0059, Acc=0.9996
#
# [Model=CNN | Seed=72 | Round=23]
#  Client 0 → Loss=0.0097, Acc=0.9985, Time=10.64s, N=47160
#  Client 1 → Loss=0.0034, Acc=0.9990, Time=10.43s, N=47159
#  Client 2 → Loss=0.0043, Acc=0.9987, Time=10.54s, N=47158
#  Client 3 → Loss=0.0055, Acc=0.9986, Time=10.81s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0097, Acc=0.9997
#
# [Model=CNN | Seed=72 | Round=24]
#  Client 0 → Loss=0.0083, Acc=0.9989, Time=10.66s, N=47160
#  Client 1 → Loss=0.0057, Acc=0.9990, Time=10.70s, N=47159
#  Client 2 → Loss=0.0055, Acc=0.9987, Time=10.72s, N=47158
#  Client 3 → Loss=0.0039, Acc=0.9988, Time=10.88s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0089, Acc=0.9993
#
# [Model=CNN | Seed=72 | Round=25]
#  Client 0 → Loss=0.0035, Acc=0.9989, Time=11.11s, N=47160
#  Client 1 → Loss=0.0048, Acc=0.9990, Time=10.68s, N=47159
#  Client 2 → Loss=0.0048, Acc=0.9986, Time=10.90s, N=47158
#  Client 3 → Loss=0.0054, Acc=0.9986, Time=11.37s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0062, Acc=0.9997
#
# [Model=CNN | Seed=72 | Round=26]
#  Client 0 → Loss=0.0038, Acc=0.9993, Time=11.23s, N=47160
#  Client 1 → Loss=0.0056, Acc=0.9991, Time=10.76s, N=47159
#  Client 2 → Loss=0.0120, Acc=0.9986, Time=10.54s, N=47158
#  Client 3 → Loss=0.0045, Acc=0.9988, Time=10.61s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0068, Acc=0.9993
#
# [Model=CNN | Seed=72 | Round=27]
#  Client 0 → Loss=0.0051, Acc=0.9989, Time=10.80s, N=47160
#  Client 1 → Loss=0.0082, Acc=0.9988, Time=11.00s, N=47159
#  Client 2 → Loss=0.0078, Acc=0.9985, Time=10.67s, N=47158
#  Client 3 → Loss=0.0067, Acc=0.9987, Time=11.02s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0047, Acc=0.9997
#
# [Model=CNN | Seed=72 | Round=28]
#  Client 0 → Loss=0.0049, Acc=0.9989, Time=10.82s, N=47160
#  Client 1 → Loss=0.0043, Acc=0.9989, Time=10.70s, N=47159
#  Client 2 → Loss=0.0093, Acc=0.9990, Time=10.65s, N=47158
#  Client 3 → Loss=0.0049, Acc=0.9989, Time=10.88s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0043, Acc=0.9997
#
# [Model=CNN | Seed=72 | Round=29]
#  Client 0 → Loss=0.0044, Acc=0.9993, Time=10.49s, N=47160
#  Client 1 → Loss=0.0054, Acc=0.9988, Time=10.60s, N=47159
#  Client 2 → Loss=0.0040, Acc=0.9990, Time=11.09s, N=47158
#  Client 3 → Loss=0.0076, Acc=0.9987, Time=10.72s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0059, Acc=0.9997
#
# [Model=CNN | Seed=72 | Round=30]
#  Client 0 → Loss=0.0104, Acc=0.9988, Time=10.69s, N=47160
#  Client 1 → Loss=0.0043, Acc=0.9988, Time=10.53s, N=47159
#  Client 2 → Loss=0.0089, Acc=0.9985, Time=10.88s, N=47158
#  Client 3 → Loss=0.0042, Acc=0.9989, Time=10.75s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0099, Acc=0.9996
#  [saved] saved_models\CNN_seed72.keras
#
# ------ SEED 82 ------
#
# [Model=CNN | Seed=82 | Round=1]
#  Client 0 → Loss=0.0807, Acc=0.9729, Time=11.25s, N=47160
#  Client 1 → Loss=0.0805, Acc=0.9738, Time=10.99s, N=47159
#  Client 2 → Loss=0.0799, Acc=0.9745, Time=10.64s, N=47158
#  Client 3 → Loss=0.0752, Acc=0.9747, Time=11.32s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.1417, Acc=0.9570
#
# [Model=CNN | Seed=82 | Round=2]
#  Client 0 → Loss=0.0378, Acc=0.9876, Time=11.25s, N=47160
#  Client 1 → Loss=0.0406, Acc=0.9869, Time=10.94s, N=47159
#  Client 2 → Loss=0.0403, Acc=0.9871, Time=10.95s, N=47158
#  Client 3 → Loss=0.0360, Acc=0.9883, Time=10.88s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0177, Acc=0.9953
#
# [Model=CNN | Seed=82 | Round=3]
#  Client 0 → Loss=0.0191, Acc=0.9943, Time=10.59s, N=47160
#  Client 1 → Loss=0.0177, Acc=0.9945, Time=10.97s, N=47159
#  Client 2 → Loss=0.0202, Acc=0.9941, Time=10.87s, N=47158
#  Client 3 → Loss=0.0202, Acc=0.9941, Time=11.61s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0064, Acc=0.9981
#
# [Model=CNN | Seed=82 | Round=4]
#  Client 0 → Loss=0.0136, Acc=0.9959, Time=11.78s, N=47160
#  Client 1 → Loss=0.0127, Acc=0.9961, Time=11.36s, N=47159
#  Client 2 → Loss=0.0146, Acc=0.9961, Time=11.53s, N=47158
#  Client 3 → Loss=0.0131, Acc=0.9965, Time=10.84s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0036, Acc=0.9988
#
# [Model=CNN | Seed=82 | Round=5]
#  Client 0 → Loss=0.0113, Acc=0.9966, Time=10.80s, N=47160
#  Client 1 → Loss=0.0100, Acc=0.9968, Time=10.79s, N=47159
#  Client 2 → Loss=0.0108, Acc=0.9968, Time=11.24s, N=47158
#  Client 3 → Loss=0.0106, Acc=0.9968, Time=11.07s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0035, Acc=0.9989
#
# [Model=CNN | Seed=82 | Round=6]
#  Client 0 → Loss=0.0107, Acc=0.9971, Time=11.63s, N=47160
#  Client 1 → Loss=0.0111, Acc=0.9972, Time=10.94s, N=47159
#  Client 2 → Loss=0.0090, Acc=0.9975, Time=10.61s, N=47158
#  Client 3 → Loss=0.0095, Acc=0.9973, Time=10.84s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0043, Acc=0.9988
#
# [Model=CNN | Seed=82 | Round=7]
#  Client 0 → Loss=0.0091, Acc=0.9973, Time=10.81s, N=47160
#  Client 1 → Loss=0.0090, Acc=0.9975, Time=10.97s, N=47159
#  Client 2 → Loss=0.0089, Acc=0.9979, Time=11.03s, N=47158
#  Client 3 → Loss=0.0066, Acc=0.9979, Time=10.28s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0053, Acc=0.9986
#
# [Model=CNN | Seed=82 | Round=8]
#  Client 0 → Loss=0.0090, Acc=0.9978, Time=10.93s, N=47160
#  Client 1 → Loss=0.0075, Acc=0.9979, Time=10.96s, N=47159
#  Client 2 → Loss=0.0073, Acc=0.9980, Time=10.47s, N=47158
#  Client 3 → Loss=0.0065, Acc=0.9980, Time=10.84s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0023, Acc=0.9992
#
# [Model=CNN | Seed=82 | Round=9]
#  Client 0 → Loss=0.0074, Acc=0.9978, Time=11.04s, N=47160
#  Client 1 → Loss=0.0072, Acc=0.9981, Time=10.36s, N=47159
#  Client 2 → Loss=0.0068, Acc=0.9980, Time=10.18s, N=47158
#  Client 3 → Loss=0.0059, Acc=0.9981, Time=10.35s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0026, Acc=0.9991
#
# [Model=CNN | Seed=82 | Round=10]
#  Client 0 → Loss=0.0065, Acc=0.9979, Time=10.39s, N=47160
#  Client 1 → Loss=0.0072, Acc=0.9980, Time=10.76s, N=47159
#  Client 2 → Loss=0.0065, Acc=0.9980, Time=10.71s, N=47158
#  Client 3 → Loss=0.0078, Acc=0.9981, Time=10.99s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0032, Acc=0.9992
#
# [Model=CNN | Seed=82 | Round=11]
#  Client 0 → Loss=0.0069, Acc=0.9979, Time=10.67s, N=47160
#  Client 1 → Loss=0.0059, Acc=0.9982, Time=10.84s, N=47159
#  Client 2 → Loss=0.0064, Acc=0.9981, Time=10.94s, N=47158
#  Client 3 → Loss=0.0062, Acc=0.9982, Time=11.30s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0038, Acc=0.9991
#
# [Model=CNN | Seed=82 | Round=12]
#  Client 0 → Loss=0.0075, Acc=0.9979, Time=11.86s, N=47160
#  Client 1 → Loss=0.0075, Acc=0.9984, Time=10.53s, N=47159
#  Client 2 → Loss=0.0063, Acc=0.9984, Time=10.75s, N=47158
#  Client 3 → Loss=0.0050, Acc=0.9984, Time=11.16s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0047, Acc=0.9991
#
# [Model=CNN | Seed=82 | Round=13]
#  Client 0 → Loss=0.0074, Acc=0.9978, Time=11.23s, N=47160
#  Client 1 → Loss=0.0074, Acc=0.9982, Time=11.26s, N=47159
#  Client 2 → Loss=0.0078, Acc=0.9983, Time=11.31s, N=47158
#  Client 3 → Loss=0.0066, Acc=0.9982, Time=11.39s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0039, Acc=0.9992
#
# [Model=CNN | Seed=82 | Round=14]
#  Client 0 → Loss=0.0054, Acc=0.9985, Time=11.43s, N=47160
#  Client 1 → Loss=0.0078, Acc=0.9981, Time=11.13s, N=47159
#  Client 2 → Loss=0.0067, Acc=0.9983, Time=11.04s, N=47158
#  Client 3 → Loss=0.0047, Acc=0.9984, Time=10.97s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0035, Acc=0.9992
#
# [Model=CNN | Seed=82 | Round=15]
#  Client 0 → Loss=0.0054, Acc=0.9984, Time=10.89s, N=47160
#  Client 1 → Loss=0.0090, Acc=0.9984, Time=10.57s, N=47159
#  Client 2 → Loss=0.0059, Acc=0.9983, Time=10.28s, N=47158
#  Client 3 → Loss=0.0056, Acc=0.9983, Time=10.25s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0042, Acc=0.9992
#
# [Model=CNN | Seed=82 | Round=16]
#  Client 0 → Loss=0.0059, Acc=0.9986, Time=10.70s, N=47160
#  Client 1 → Loss=0.0074, Acc=0.9983, Time=10.93s, N=47159
#  Client 2 → Loss=0.0096, Acc=0.9980, Time=11.29s, N=47158
#  Client 3 → Loss=0.0074, Acc=0.9980, Time=10.89s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0032, Acc=0.9993
#
# [Model=CNN | Seed=82 | Round=17]
#  Client 0 → Loss=0.0048, Acc=0.9984, Time=10.85s, N=47160
#  Client 1 → Loss=0.0046, Acc=0.9986, Time=10.68s, N=47159
#  Client 2 → Loss=0.0049, Acc=0.9986, Time=10.42s, N=47158
#  Client 3 → Loss=0.0041, Acc=0.9985, Time=10.33s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0043, Acc=0.9993
#
# [Model=CNN | Seed=82 | Round=18]
#  Client 0 → Loss=0.0041, Acc=0.9986, Time=10.42s, N=47160
#  Client 1 → Loss=0.0063, Acc=0.9983, Time=10.50s, N=47159
#  Client 2 → Loss=0.0069, Acc=0.9982, Time=11.20s, N=47158
#  Client 3 → Loss=0.0043, Acc=0.9985, Time=10.94s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0040, Acc=0.9993
#
# [Model=CNN | Seed=82 | Round=19]
#  Client 0 → Loss=0.0073, Acc=0.9985, Time=11.04s, N=47160
#  Client 1 → Loss=0.0088, Acc=0.9984, Time=10.81s, N=47159
#  Client 2 → Loss=0.0053, Acc=0.9984, Time=11.09s, N=47158
#  Client 3 → Loss=0.0060, Acc=0.9983, Time=10.96s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0061, Acc=0.9994
#
# [Model=CNN | Seed=82 | Round=20]
#  Client 0 → Loss=0.0202, Acc=0.9983, Time=10.84s, N=47160
#  Client 1 → Loss=0.0062, Acc=0.9985, Time=10.53s, N=47159
#  Client 2 → Loss=0.0051, Acc=0.9985, Time=10.71s, N=47158
#  Client 3 → Loss=0.0051, Acc=0.9984, Time=10.79s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0040, Acc=0.9994
#
# [Model=CNN | Seed=82 | Round=21]
#  Client 0 → Loss=0.0094, Acc=0.9982, Time=10.82s, N=47160
#  Client 1 → Loss=0.0064, Acc=0.9984, Time=10.49s, N=47159
#  Client 2 → Loss=0.0098, Acc=0.9985, Time=10.48s, N=47158
#  Client 3 → Loss=0.0074, Acc=0.9982, Time=11.02s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0066, Acc=0.9993
#
# [Model=CNN | Seed=82 | Round=22]
#  Client 0 → Loss=0.0042, Acc=0.9986, Time=10.78s, N=47160
#  Client 1 → Loss=0.0083, Acc=0.9982, Time=10.99s, N=47159
#  Client 2 → Loss=0.0045, Acc=0.9986, Time=10.70s, N=47158
#  Client 3 → Loss=0.0064, Acc=0.9986, Time=10.67s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0049, Acc=0.9993
#
# [Model=CNN | Seed=82 | Round=23]
#  Client 0 → Loss=0.0063, Acc=0.9986, Time=10.75s, N=47160
#  Client 1 → Loss=0.0143, Acc=0.9982, Time=10.49s, N=47159
#  Client 2 → Loss=0.0047, Acc=0.9987, Time=10.70s, N=47158
#  Client 3 → Loss=0.0065, Acc=0.9985, Time=10.46s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0082, Acc=0.9991
#
# [Model=CNN | Seed=82 | Round=24]
#  Client 0 → Loss=0.0066, Acc=0.9985, Time=10.42s, N=47160
#  Client 1 → Loss=0.0088, Acc=0.9979, Time=10.72s, N=47159
#  Client 2 → Loss=0.0050, Acc=0.9986, Time=10.56s, N=47158
#  Client 3 → Loss=0.0056, Acc=0.9985, Time=10.56s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0091, Acc=0.9993
#
# [Model=CNN | Seed=82 | Round=25]
#  Client 0 → Loss=0.0085, Acc=0.9986, Time=11.33s, N=47160
#  Client 1 → Loss=0.0076, Acc=0.9982, Time=10.99s, N=47159
#  Client 2 → Loss=0.0106, Acc=0.9984, Time=10.83s, N=47158
#  Client 3 → Loss=0.0044, Acc=0.9985, Time=10.70s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0079, Acc=0.9992
#
# [Model=CNN | Seed=82 | Round=26]
#  Client 0 → Loss=0.0063, Acc=0.9987, Time=10.59s, N=47160
#  Client 1 → Loss=0.0060, Acc=0.9983, Time=10.82s, N=47159
#  Client 2 → Loss=0.0065, Acc=0.9985, Time=11.47s, N=47158
#  Client 3 → Loss=0.0061, Acc=0.9987, Time=11.37s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0084, Acc=0.9993
#
# [Model=CNN | Seed=82 | Round=27]
#  Client 0 → Loss=0.0046, Acc=0.9987, Time=11.58s, N=47160
#  Client 1 → Loss=0.0094, Acc=0.9983, Time=10.80s, N=47159
#  Client 2 → Loss=0.0076, Acc=0.9983, Time=10.95s, N=47158
#  Client 3 → Loss=0.0064, Acc=0.9985, Time=10.73s, N=47158
#  >>> GLOBAL (centralized test) → Loss=0.0068, Acc=0.9992
#
# [Model=CNN | Seed=82 | Round=28]
# ...
#    CNN     3     saved_models\CNN_seed3.keras
#    CNN     7     saved_models\CNN_seed7.keras
#    CNN    72    saved_models\CNN_seed72.keras
#    CNN    82    saved_models\CNN_seed82.keras
#   LSTM    42   saved_models\LSTM_seed42.keras
#   LSTM     3    saved_models\LSTM_seed3.keras
#   LSTM     7    saved_models\LSTM_seed7.keras
#   LSTM    72   saved_models\LSTM_seed72.keras
#   LSTM    82   saved_models\LSTM_seed82.keras
# BiLSTM    42 saved_models\BiLSTM_seed42.keras
# BiLSTM     3  saved_models\BiLSTM_seed3.keras
# BiLSTM     7  saved_models\BiLSTM_seed7.keras
# BiLSTM    72 saved_models\BiLSTM_seed72.keras
# BiLSTM    82 saved_models\BiLSTM_seed82.keras
#    GRU    42    saved_models\GRU_seed42.keras
#    GRU     3     saved_models\GRU_seed3.keras
#    GRU     7     saved_models\GRU_seed7.keras
#    GRU    72    saved_models\GRU_seed72.keras
#    GRU    82    saved_models\GRU_seed82.keras
#  BiGRU    42  saved_models\BiGRU_seed42.keras
#  BiGRU     3   saved_models\BiGRU_seed3.keras
#  BiGRU     7   saved_models\BiGRU_seed7.keras
#  BiGRU    72  saved_models\BiGRU_seed72.keras
#  BiGRU    82  saved_models\BiGRU_seed82.keras
#
# OVERALL SUMMARY (all models & seeds pooled):
#                  Metric              Mean ± SD                 95% CI
# 0                 Loss        0.0007 ± 0.0008        [0.0004,0.0010]
# 1             Accuracy        0.9999 ± 0.0002        [0.9998,0.9999]
# 2            Precision        0.9998 ± 0.0003        [0.9996,0.9999]
# 3               Recall        1.0000 ± 0.0000        [1.0000,1.0000]
# 4                   F1        0.9999 ± 0.0002        [0.9998,0.9999]
# 5                  MCC        0.9997 ± 0.0004        [0.9995,0.9999]
# 6                  AUC        1.0000 ± 0.0000        [1.0000,1.0000]
# 7          Specificity        0.9997 ± 0.0005        [0.9995,0.9999]
# 8    Training_Time_sec  5691.6050 ± 3068.0486  [4488.9300,6894.2801]
# 9   Inference_Time_sec        6.6284 ± 3.9749        [5.0702,8.1865]
# 10       Model_Size_MB        0.5846 ± 0.3965        [0.4292,0.7400]
# 11   Comm_per_round_MB        4.4748 ± 3.1303        [3.2477,5.7019]
# 12       Total_Comm_MB     134.2451 ± 93.9102     [97.4323,171.0578]
#
# PER-CLIENT TEST SUMMARY (mean/std over 5 seeds):
#                Accuracy         Precision          Recall              F1  \
#                   mean     std      mean     std    mean     std    mean
# Model  Client
# BiGRU  0        1.0000  0.0000    0.9999  0.0001  1.0000  0.0000  1.0000
#        1        0.9999  0.0001    0.9998  0.0002  1.0000  0.0000  0.9999
#        2        0.9999  0.0000    0.9999  0.0001  1.0000  0.0000  0.9999
#        3        0.9999  0.0001    0.9999  0.0001  1.0000  0.0000  1.0000
# BiLSTM 0        0.9999  0.0000    0.9999  0.0001  1.0000  0.0001  1.0000
#        1        0.9999  0.0001    0.9999  0.0001  1.0000  0.0000  1.0000
#        2        1.0000  0.0000    0.9999  0.0001  1.0000  0.0000  1.0000
#        3        1.0000  0.0000    0.9999  0.0001  1.0000  0.0000  1.0000
# CNN    0        0.9997  0.0001    0.9994  0.0002  1.0000  0.0001  0.9997
#        1        0.9994  0.0003    0.9990  0.0004  0.9999  0.0001  0.9995
#        2        0.9994  0.0002    0.9992  0.0004  0.9998  0.0002  0.9995
#        3        0.9994  0.0005    0.9991  0.0007  0.9999  0.0002  0.9995
# GRU    0        1.0000  0.0000    1.0000  0.0001  1.0000  0.0000  1.0000
#        1        0.9999  0.0001    0.9999  0.0001  1.0000  0.0001  0.9999
#        2        1.0000  0.0000    0.9999  0.0001  1.0000  0.0000  1.0000
#        3        1.0000  0.0000    1.0000  0.0001  1.0000  0.0000  1.0000
# LSTM   0        1.0000  0.0000    0.9999  0.0001  1.0000  0.0000  1.0000
#        1        0.9999  0.0001    0.9999  0.0002  1.0000  0.0001  0.9999
#        2        1.0000  0.0000    0.9999  0.0001  1.0000  0.0000  1.0000
#        3        1.0000  0.0000    1.0000  0.0001  1.0000  0.0001  1.0000
#
#                           MCC             AUC         Specificity          \
#                   std    mean     std    mean     std        mean     std
# Model  Client
# BiGRU  0       0.0000  0.9999  0.0001  1.0000  0.0000      0.9999  0.0001
#        1       0.0001  0.9998  0.0002  1.0000  0.0000      0.9998  0.0002
#        2       0.0000  0.9999  0.0001  1.0000  0.0000      0.9998  0.0001
#        3       0.0001  0.9999  0.0002  1.0000  0.0000      0.9999  0.0002
# BiLSTM 0       0.0000  0.9999  0.0001  1.0000  0.0000      0.9999  0.0001
#        1       0.0001  0.9999  0.0002  1.0000  0.0000      0.9999  0.0002
#        2       0.0000  0.9999  0.0001  1.0000  0.0000      0.9999  0.0001
#        3       0.0000  0.9999  0.0001  1.0000  0.0000      0.9999  0.0001
# CNN    0       0.0001  0.9993  0.0002  1.0000  0.0000      0.9992  0.0003
#        1       0.0002  0.9988  0.0005  0.9999  0.0001      0.9987  0.0006
#        2       0.0001  0.9988  0.0003  1.0000  0.0000      0.9989  0.0006
#        3       0.0004  0.9988  0.0010  1.0000  0.0001      0.9987  0.0010
# GRU    0       0.0000  1.0000  0.0001  1.0000  0.0000      1.0000  0.0001
#        1       0.0001  0.9998  0.0001  1.0000  0.0000      0.9998  0.0001
#        2       0.0000  0.9999  0.0001  1.0000  0.0000      0.9999  0.0001
#        3       0.0000  1.0000  0.0001  1.0000  0.0000      1.0000  0.0001
# LSTM   0       0.0000  0.9999  0.0001  1.0000  0.0000      0.9999  0.0001
#        1       0.0001  0.9998  0.0002  1.0000  0.0000      0.9998  0.0003
#        2       0.0000  0.9999  0.0001  1.0000  0.0000      0.9999  0.0001
#        3       0.0000  0.9999  0.0001  1.0000  0.0000      1.0000  0.0001
#
#                  Loss
#                  mean     std
# Model  Client
# BiGRU  0       0.0002  0.0004
#        1       0.0009  0.0010
#        2       0.0004  0.0005
#        3       0.0004  0.0005
# BiLSTM 0       0.0007  0.0006
#        1       0.0004  0.0007
#        2       0.0004  0.0006
#        3       0.0001  0.0001
# CNN    0       0.0016  0.0006
#        1       0.0026  0.0010
#        2       0.0023  0.0007
#        3       0.0022  0.0018
# GRU    0       0.0001  0.0002
#        1       0.0006  0.0007
#        2       0.0004  0.0006
#        3       0.0001  0.0002
# LSTM   0       0.0003  0.0005
#        1       0.0006  0.0009
#        2       0.0001  0.0001
#        3       0.0001  0.0001
#
# PAIRWISE PAIRED T-TESTS across 5 seeds (Global Test Set):
#    Metric Model A Model B  Mean A  Mean B  t-stat  p-value  Significant (p<0.05)
# Accuracy     CNN    LSTM  0.9995  1.0000 -5.0943   0.0070                  True
# Accuracy     CNN  BiLSTM  0.9995  1.0000 -5.4463   0.0055                  True
# Accuracy     CNN     GRU  0.9995  1.0000 -5.1549   0.0067                  True
# Accuracy     CNN   BiGRU  0.9995  0.9999 -4.9765   0.0076                  True
# Accuracy    LSTM  BiLSTM  1.0000  1.0000 -0.4082   0.7040                 False
# Accuracy    LSTM     GRU  1.0000  1.0000 -1.6330   0.1778                 False
# Accuracy    LSTM   BiGRU  1.0000  0.9999  1.2060   0.2943                 False
# Accuracy  BiLSTM     GRU  1.0000  1.0000 -0.5345   0.6213                 False
# Accuracy  BiLSTM   BiGRU  1.0000  0.9999  1.5811   0.1890                 False
# Accuracy     GRU   BiGRU  1.0000  0.9999  2.0580   0.1087                 False
#       F1     CNN    LSTM  0.9995  1.0000 -5.0962   0.0070                  True
#       F1     CNN  BiLSTM  0.9995  1.0000 -5.4486   0.0055                  True
#       F1     CNN     GRU  0.9995  1.0000 -5.1569   0.0067                  True
#       F1     CNN   BiGRU  0.9995  0.9999 -4.9784   0.0076                  True
#       F1    LSTM  BiLSTM  1.0000  1.0000 -0.4083   0.7040                 False
#       F1    LSTM     GRU  1.0000  1.0000 -1.6331   0.1778                 False
#       F1    LSTM   BiGRU  1.0000  0.9999  1.2060   0.2943                 False
#       F1  BiLSTM     GRU  1.0000  1.0000 -0.5345   0.6213                 False
#       F1  BiLSTM   BiGRU  1.0000  0.9999  1.5811   0.1890                 False
#       F1     GRU   BiGRU  1.0000  0.9999  2.0580   0.1087                 False
#      AUC     CNN    LSTM  1.0000  1.0000 -2.4953   0.0671                 False
#      AUC     CNN  BiLSTM  1.0000  1.0000 -2.2492   0.0877                 False
#      AUC     CNN     GRU  1.0000  1.0000 -1.7261   0.1594                 False
#      AUC     CNN   BiGRU  1.0000  1.0000 -2.4969   0.0670                 False
#      AUC    LSTM  BiLSTM  1.0000  1.0000  0.5313   0.6234                 False
#      AUC    LSTM     GRU  1.0000  1.0000  0.9928   0.3770                 False
#      AUC    LSTM   BiGRU  1.0000  1.0000 -1.3180   0.2579                 False
#      AUC  BiLSTM     GRU  1.0000  1.0000 -0.0005   0.9996                 False
#      AUC  BiLSTM   BiGRU  1.0000  1.0000 -0.5354   0.6207                 False
#      AUC     GRU   BiGRU  1.0000  1.0000 -1.0004   0.3737                 False
#     Loss     CNN    LSTM  0.0022  0.0003  9.1984   0.0008                  True
#     Loss     CNN  BiLSTM  0.0022  0.0004  7.6685   0.0016                  True
#     Loss     CNN     GRU  0.0022  0.0003  8.2463   0.0012                  True
#     Loss     CNN   BiGRU  0.0022  0.0005 11.0605   0.0004                  True
#     Loss    LSTM  BiLSTM  0.0003  0.0004 -1.1328   0.3206                 False
#     Loss    LSTM     GRU  0.0003  0.0003 -0.1904   0.8583                 False
#     Loss    LSTM   BiGRU  0.0003  0.0005 -2.9916   0.0403                  True
#     Loss  BiLSTM     GRU  0.0004  0.0003  2.5777   0.0615                 False
#     Loss  BiLSTM   BiGRU  0.0004  0.0005 -0.9567   0.3929                 False
#     Loss     GRU   BiGRU  0.0003  0.0005 -2.3890   0.0753                 False
#
# McNEMAR'S TEST — PER SEED (instance-level, Global Test Set):
#   Seed Model A Model B  A right/B wrong  A wrong/B right     stat  p-value  Significant (p<0.05)
#    42     CNN    LSTM                2               30  22.7812   0.0000                  True
#    42     CNN  BiLSTM                1               29     24.3   0.0000                  True
#    42     CNN     GRU                1               29     24.3   0.0000                  True
#    42     CNN   BiGRU                1               28  23.3103   0.0000                  True
#    42    LSTM  BiLSTM                1                1    exact   1.0000                 False
#    42    LSTM     GRU                1                1    exact   1.0000                 False
#    42    LSTM   BiGRU                2                1    exact   1.0000                 False
#    42  BiLSTM     GRU                0                0    exact   1.0000                 False
#    42  BiLSTM   BiGRU                1                0    exact   1.0000                 False
#    42     GRU   BiGRU                1                0    exact   1.0000                 False
#     3     CNN    LSTM                1               25  20.3462   0.0000                  True
#     3     CNN  BiLSTM                1               24    19.36   0.0000                  True
#     3     CNN     GRU                1               25  20.3462   0.0000                  True
#     3     CNN   BiGRU                1               25  20.3462   0.0000                  True
#     3    LSTM  BiLSTM                1                0    exact   1.0000                 False
#     3    LSTM     GRU                0                0    exact   1.0000                 False
#     3    LSTM   BiGRU                0                0    exact   1.0000                 False
#     3  BiLSTM     GRU                0                1    exact   1.0000                 False
#     3  BiLSTM   BiGRU                0                1    exact   1.0000                 False
#     3     GRU   BiGRU                0                0    exact   1.0000                 False
#     7     CNN    LSTM                1               12    exact   0.0034                  True
#     7     CNN  BiLSTM                0               13    exact   0.0002                  True
#     7     CNN     GRU                0               12    exact   0.0005                  True
#     7     CNN   BiGRU                1               13    exact   0.0018                  True
#     7    LSTM  BiLSTM                0                2    exact   0.5000                 False
#     7    LSTM     GRU                0                1    exact   1.0000                 False
#     7    LSTM   BiGRU                1                2    exact   1.0000                 False
#     7  BiLSTM     GRU                1                0    exact   1.0000                 False
#     7  BiLSTM   BiGRU                1                0    exact   1.0000                 False
#     7     GRU   BiGRU                1                1    exact   1.0000                 False
#    72     CNN    LSTM                2               18    exact   0.0004                  True
#    72     CNN  BiLSTM                2               18    exact   0.0004                  True
#    72     CNN     GRU                1               17    exact   0.0001                  True
#    72     CNN   BiGRU                4               17    exact   0.0072                  True
#    72    LSTM  BiLSTM                0                0    exact   1.0000                 False
#    72    LSTM     GRU                1                1    exact   1.0000                 False
#    72    LSTM   BiGRU                3                0    exact   0.2500                 False
#    72  BiLSTM     GRU                1                1    exact   1.0000                 False
#    72  BiLSTM   BiGRU                3                0    exact   0.2500                 False
#    72     GRU   BiGRU                3                0    exact   0.2500                 False
#    82     CNN    LSTM                1               38  33.2308   0.0000                  True
#    82     CNN  BiLSTM                0               37   35.027   0.0000                  True
#    82     CNN     GRU                1               39   34.225   0.0000                  True
#    82     CNN   BiGRU                0               36  34.0278   0.0000                  True
#    82    LSTM  BiLSTM                1                1    exact   1.0000                 False
#    82    LSTM     GRU                1                2    exact   1.0000                 False
#    82    LSTM   BiGRU                2                1    exact   1.0000                 False
#    82  BiLSTM     GRU                1                2    exact   1.0000                 False
#    82  BiLSTM   BiGRU                1                0    exact   1.0000                 False
#    82     GRU   BiGRU                3                1    exact   0.6250                 False
#
# McNEMAR'S TEST — POOLED ACROSS 5 SEEDS (Global Test Set):
#  Model A Model B  A right/B wrong (pooled)  A wrong/B right (pooled)      stat  p-value  Significant (p<0.05)
#     CNN    LSTM                         7                       123  101.7308   0.0000                  True
#     CNN  BiLSTM                         4                       121   107.648   0.0000                  True
#     CNN     GRU                         4                       122  108.6429   0.0000                  True
#     CNN   BiGRU                         7                       119   97.7857   0.0000                  True
#    LSTM  BiLSTM                         3                         4     exact   1.0000                 False
#    LSTM     GRU                         3                         5     exact   0.7266                 False
#    LSTM   BiGRU                         8                         4     exact   0.3877                 False
#  BiLSTM     GRU                         3                         4     exact   1.0000                 False
#  BiLSTM   BiGRU                         6                         1     exact   0.1250                 False
#     GRU   BiGRU                         8                         2     exact   0.1094                 False
