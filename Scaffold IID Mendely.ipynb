# %%
import numpy as np, pandas as pd, tensorflow as tf, random, time, os
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import *

from scipy.stats import ttest_rel, chi2, binom
from itertools import combinations

# ================= CONFIG =================
LR=0.001; ROUNDS=30; LOCAL_EPOCHS=2; BATCH=16
CLIENTS=4; SEEDS=[42,3,7,72,82]
MODELS=["CNN","LSTM","BiLSTM","GRU","BiGRU"]
CLIENT_TEST_SIZE=0.2   # local train/test split ratio inside each client
MODEL_SAVE_DIR="saved_models"
os.makedirs(MODEL_SAVE_DIR,exist_ok=True)

# ================= LOAD =================
df=pd.read_csv("dataset_phishing(11k).csv")

# remove text columns like .txt
for col in df.columns:
    if df[col].dtype==object and df[col].astype(str).str.contains(".txt",na=False).any():
        df.drop(columns=[col],inplace=True)

df=df.fillna("unknown")

for col in df.columns:
    if df[col].dtype==object:
        df[col]=LabelEncoder().fit_transform(df[col].astype(str))

X=df.drop("status",axis=1).values
y=df["status"].values

X=StandardScaler().fit_transform(X)

# NOTE: no upfront global train_test_split anymore.
# IID partitioning is applied to the WHOLE dataset per seed below,
# then each client locally splits its own IID shard into train/test.

# ================= HELPERS =================
def set_seed(s):
    random.seed(s); np.random.seed(s); tf.random.set_seed(s)

def iid_partition(X,y,K):
    # IID partition: each class shuffled and split evenly across clients
    idx=np.arange(len(y))
    clients=[[] for _ in range(K)]
    for c in np.unique(y):
        c_idx=idx[y==c]; np.random.shuffle(c_idx)
        split=np.array_split(c_idx,K)
        for i in range(K): clients[i].extend(split[i])
    return [(X[c],y[c]) for c in clients]

def format_xy(Xc,model_name):
    return Xc.reshape(len(Xc),-1,1)

def scaffold_aggregate(global_model,c_global,client_weight_deltas,client_c_deltas):
    """SCAFFOLD server update (post-hoc correction style):
    - Global weights move by the UNIFORM average of client weight deltas.
    - Global control variate moves by the UNIFORM average of client control deltas.
    (Matches the validated formulation: correction is applied once to each client's
    final local weights, not injected into every mini-batch gradient — this avoids
    destabilizing Adam's adaptive moment estimates.)"""
    gw=global_model.get_weights()
    new_weights=[]
    for j in range(len(gw)):
        avg_dw=np.mean([dw[j] for dw in client_weight_deltas],axis=0)
        new_weights.append(gw[j]+avg_dw)
    global_model.set_weights(new_weights)

    for j in range(len(c_global)):
        c_global[j]=c_global[j]+np.mean([dc[j] for dc in client_c_deltas],axis=0)

def model_size(model):
    model.save("tmp.h5", include_optimizer=False)
    size=os.path.getsize("tmp.h5")/(1024*1024)
    os.remove("tmp.h5")
    return size

def stats(x,metric):
    x=np.asarray(x,dtype=float)
    x=x[~np.isnan(x)]
    if len(x)==0:
        return np.nan,np.nan,np.nan,np.nan
    mean=np.mean(x); sd=np.std(x)
    ci=1.96*sd/np.sqrt(len(x))
    low,high=mean-ci,mean+ci
    if metric in ["Accuracy","Precision","Recall","F1","AUC","Specificity"]:
        low=max(0,low); high=min(1,high)
    if metric=="MCC":
        low=max(-1,low); high=min(1,high)
    return mean,sd,low,high

def mcnemar_test(y_true_a,y_pred_a,y_true_b,y_pred_b):
    """McNemar's test between two classifiers evaluated on the SAME samples.
    Uses only the discordant pairs (one right, one wrong). Exact binomial
    for small discordant counts (n<25), continuity-corrected chi-square
    otherwise."""
    y_true_a=np.asarray(y_true_a).flatten()
    y_true_b=np.asarray(y_true_b).flatten()
    assert len(y_true_a)==len(y_true_b), "test sets must be the same size"
    assert np.array_equal(y_true_a,y_true_b), "test sets must match (same seed/instances)"

    correct_a=(np.asarray(y_pred_a).flatten()==y_true_a)
    correct_b=(np.asarray(y_pred_b).flatten()==y_true_b)

    n01=int(np.sum(correct_a & ~correct_b))   # A correct, B wrong
    n10=int(np.sum(~correct_a & correct_b))   # A wrong, B correct
    n=n01+n10

    if n==0:
        return np.nan,1.0,n01,n10
    if n<25:
        p=2*min(binom.cdf(min(n01,n10),n,0.5),0.5)   # exact two-sided binomial
        p=min(p,1.0)
        stat=np.nan
    else:
        stat=((abs(n01-n10)-1)**2)/n                  # continuity-corrected chi-square
        p=1-chi2.cdf(stat,1)
    return stat,p,n01,n10

# ================= MODELS =================
def build(name,shape=None,dim=None):
    if name=="CNN":
        m=Sequential([
            Input(shape),
            Conv1D(64,3,activation="relu"),
            Dropout(0.5),
            Conv1D(32,3,activation="relu"),
            GlobalMaxPooling1D(),
            Dense(32,activation="relu"),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="LSTM":
        m=Sequential([
            Input(shape),
            LSTM(128,return_sequences=True),
            Dropout(0.5),
            LSTM(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiLSTM":
        m=Sequential([
            Input(shape),
            Bidirectional(LSTM(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(LSTM(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="GRU":
        m=Sequential([
            Input(shape),
            GRU(128,return_sequences=True),
            Dropout(0.5),
            GRU(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiGRU":
        m=Sequential([
            Input(shape),
            Bidirectional(GRU(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(GRU(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    m.compile(optimizer=Adam(LR),loss="binary_crossentropy",metrics=["accuracy"])
    return m

# ================= STORAGE =================
rows=[]          # global (union-of-clients) test metrics, per (model, seed)
client_rows=[]   # per-client local test metrics, per (model, seed, client)
results_round={m:{"acc":[],"loss":[],"cm":[]} for m in MODELS}

# per-instance predictions, needed for McNemar's test
y_preds={}        # (model, seed) -> y_pred array (0/1), aligned to y_trues[seed]
y_trues={}        # seed -> y_test_global array (0/1) -- same across all models for a given seed

# ================= TRAIN =================
for model_name in MODELS:
    print(f"\n================ MODEL: {model_name} ================")

    for seed in SEEDS:
        print(f"\n------ SEED {seed} ------")
        set_seed(seed)

        # ---- IID partition of the WHOLE dataset across clients ----
        client_full=iid_partition(X,y,CLIENTS)

        # ---- Each client locally splits its own shard into train/test ----
        client_train,client_test=[],[]
        for cid,(Xc,yc) in enumerate(client_full):
            try:
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,stratify=yc,random_state=seed
                )
            except ValueError:
                # fallback if a client shard doesn't have enough of a class to stratify
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,random_state=seed
                )
            client_train.append((Xc_tr,yc_tr))
            client_test.append((Xc_te,yc_te))

        # ---- Global (centralized) test set = union of all clients' local test shards ----
        X_test_global=np.concatenate([Xc for Xc,_ in client_test],axis=0)
        y_test_global=np.concatenate([yc for _,yc in client_test],axis=0)

        create=lambda:build(model_name,shape=(X.shape[1],1))

        fmt=lambda Xc: format_xy(Xc,model_name)

        global_model=create()

        # ---- SCAFFOLD control variates ----
        c_global=[np.zeros_like(w) for w in global_model.get_weights()]              # global control c
        c_clients=[[np.zeros_like(w) for w in global_model.get_weights()]
                   for _ in range(CLIENTS)]                                          # per-client control c_i

        acc_hist,loss_hist=[],[]
        comm=0
        total_train_time=0.0

        for r in range(ROUNDS):
            print(f"\n[Model={model_name} | Seed={seed} | Round={r+1}]")

            global_weights=global_model.get_weights()
            client_weight_deltas=[]; client_c_deltas=[]; sizes=[]

            for cid,(Xc,yc) in enumerate(client_train):
                m=create()
                m.set_weights(global_weights)
                w_init=[w.copy() for w in global_weights]

                t0=time.time()
                history=m.fit(fmt(Xc),yc,epochs=LOCAL_EPOCHS,batch_size=BATCH,verbose=0)
                t1=time.time()
                total_train_time+=(t1-t0)

                train_loss=history.history["loss"][-1]
                train_acc=history.history["accuracy"][-1]
                print(f" Client {cid} → Loss={train_loss:.4f}, Acc={train_acc:.4f}, Time={t1-t0:.2f}s, N={len(yc)}")

                w_final=m.get_weights()

                # ---- SCAFFOLD correction (post-hoc, applied once after local training) ----
                corrected_weights=[
                    w_final[j]-LR*(c_global[j]-c_clients[cid][j])
                    for j in range(len(w_final))
                ]
                m.set_weights(corrected_weights)

                delta_w=[corrected_weights[j]-w_init[j] for j in range(len(w_init))]

                # ---- update client control variate ----
                delta_c=[
                    c_global[j]-c_clients[cid][j]-(1/(LOCAL_EPOCHS*LR))*delta_w[j]
                    for j in range(len(w_init))
                ]
                c_clients[cid]=[c_clients[cid][j]+delta_c[j] for j in range(len(delta_c))]

                client_weight_deltas.append(delta_w)
                client_c_deltas.append(delta_c)
                sizes.append(len(yc))

            scaffold_aggregate(global_model,c_global,client_weight_deltas,client_c_deltas)

            loss,acc=global_model.evaluate(fmt(X_test_global),y_test_global,verbose=0)

            print(f" >>> GLOBAL (centralized test) → Loss={loss:.4f}, Acc={acc:.4f}")

            acc_hist.append(acc); loss_hist.append(loss)

            # bytes per weight (float32=4 bytes), sent down to each client AND back up from each client
            # (SCAFFOLD also exchanges control variates, same size as the weight vector, each round)
            weight_bytes=sum([w.size for w in global_model.get_weights()])*4
            comm+=weight_bytes*CLIENTS*2*2   # x2 for control variates traveling alongside weights

        # ================= FINAL GLOBAL TEST METRICS =================
        t0=time.time()
        y_prob=global_model.predict(fmt(X_test_global),verbose=0)
        inference_time=time.time()-t0

        y_pred=(y_prob>0.5).astype(int)

        # ---- Save per-instance predictions for McNemar's test ----
        y_preds[(model_name,seed)]=y_pred.flatten()
        if seed not in y_trues:
            y_trues[seed]=y_test_global.flatten()
        else:
            # sanity check: every model must see the identical test set for this seed
            assert np.array_equal(y_trues[seed],y_test_global.flatten()), \
                f"Test set mismatch for seed {seed} — McNemar's test requires identical instances across models."

        tn,fp,fn,tp=confusion_matrix(y_test_global,y_pred).ravel()

        # ---- Save this trained global model to disk ----
        model_path=os.path.join(MODEL_SAVE_DIR,f"{model_name}_seed{seed}.keras")
        global_model.save(model_path)
        print(f" [saved] {model_path}")

        rows.append({
            "Model":model_name,
            "Seed":seed,
            "Loss":log_loss(y_test_global,y_prob),
            "Accuracy":accuracy_score(y_test_global,y_pred),
            "Precision":precision_score(y_test_global,y_pred),
            "Recall":recall_score(y_test_global,y_pred),
            "F1":f1_score(y_test_global,y_pred),
            "MCC":matthews_corrcoef(y_test_global,y_pred),
            "AUC":roc_auc_score(y_test_global,y_prob),
            "Specificity":tn/(tn+fp),
            "Training_Time_sec":total_train_time,
            "Inference_Time_sec":inference_time,
            "Model_Size_MB":model_size(global_model),
            "Comm_per_round_MB":comm/(ROUNDS*1024*1024),
            "Total_Comm_MB":comm/(1024*1024),
            "Saved_Model_Path":model_path
        })

        results_round[model_name]["acc"].append(acc_hist)
        results_round[model_name]["loss"].append(loss_hist)
        results_round[model_name]["cm"].append(confusion_matrix(y_test_global,y_pred))

        # ================= PER-CLIENT LOCAL TEST EVALUATION =================
        for cid,(Xc_te,yc_te) in enumerate(client_test):
            yc_prob=global_model.predict(fmt(Xc_te),verbose=0)
            yc_pred=(yc_prob>0.5).astype(int)

            cm_c=confusion_matrix(yc_te,yc_pred,labels=[0,1])
            tn_c,fp_c,fn_c,tp_c=cm_c.ravel()

            auc_val=roc_auc_score(yc_te,yc_prob) if len(np.unique(yc_te))>1 else np.nan

            client_rows.append({
                "Model":model_name,
                "Seed":seed,
                "Client":cid,
                "N_test":len(yc_te),
                "Loss":log_loss(yc_te,yc_prob,labels=[0,1]),
                "Accuracy":accuracy_score(yc_te,yc_pred),
                "Precision":precision_score(yc_te,yc_pred,zero_division=0),
                "Recall":recall_score(yc_te,yc_pred,zero_division=0),
                "F1":f1_score(yc_te,yc_pred,zero_division=0),
                "MCC":matthews_corrcoef(yc_te,yc_pred),
                "AUC":auc_val,
                "Specificity":(tn_c/(tn_c+fp_c)) if (tn_c+fp_c)>0 else np.nan
            })

# ================= PRINT ALL CONFUSION MATRICES PER SEED (GLOBAL TEST) =================
for m in MODELS:
    print(f"\n=== {m}: Global Test Confusion Matrices per Seed ===")
    for seed,cm in zip(SEEDS,results_round[m]["cm"]):
        print(f"Seed {seed}:\n{cm}")

# ================= MEAN OVER SEEDS (GLOBAL TEST, per-round curves + avg cm) =================
for m in MODELS:
    results_round[m]["acc"]=np.mean(results_round[m]["acc"],axis=0)
    results_round[m]["loss"]=np.mean(results_round[m]["loss"],axis=0)
    results_round[m]["cm"]=np.mean(results_round[m]["cm"],axis=0)

for m in MODELS:
    print(f"\n=== {m} (Global Test, averaged over {len(SEEDS)} seeds) ===")
    print("Confusion Matrix (avg):\n",np.round(results_round[m]["cm"],2))
    print("Accuracy per round:",np.round(results_round[m]["acc"],4))
    print("Loss per round:",np.round(results_round[m]["loss"],4))

# ================= PER-MODEL SUMMARY (ALL METRICS incl. time & comm cost, avg over 5 seeds) =================
results_df=pd.DataFrame(rows)

summary_metrics=["Loss","Accuracy","Precision","Recall","F1","MCC","AUC","Specificity",
                  "Training_Time_sec","Inference_Time_sec","Model_Size_MB",
                  "Comm_per_round_MB","Total_Comm_MB"]

per_model_summary=[]
for m in MODELS:
    sub=results_df[results_df["Model"]==m]
    for metric in summary_metrics:
        mean,sd,low,high=stats(sub[metric],metric)
        per_model_summary.append({
            "Model":m,
            "Metric":metric,
            "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
            "95% CI":f"[{low:.4f}, {high:.4f}]"
        })

per_model_summary_df=pd.DataFrame(per_model_summary)
print(f"\nPER-MODEL SUMMARY (mean ± sd, 95% CI over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_summary_df.to_string(index=False))

# wide pivot: one row per model, one column per metric, "mean [low, high]"
per_model_wide=per_model_summary_df.copy()
per_model_wide["Mean [95% CI]"]=per_model_wide.apply(
    lambda r: r["Mean ± SD"].split(" ± ")[0]+" "+r["95% CI"], axis=1
)
per_model_wide=per_model_wide.pivot(index="Model",columns="Metric",values="Mean [95% CI]")
per_model_wide=per_model_wide[summary_metrics]  # keep original metric order
print(f"\nPER-MODEL SUMMARY, WIDE (mean [95% CI] over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_wide.to_string())

# overall pooled summary (all models & seeds together) kept for reference
overall_summary=[]
for metric in summary_metrics:
    mean,sd,low,high=stats(results_df[metric],metric)
    overall_summary.append({
        "Metric":metric,
        "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
        "95% CI":f"[{low:.4f},{high:.4f}]"
    })
overall_summary_df=pd.DataFrame(overall_summary)
print(f"\nSAVED MODELS ({len(results_df)} total, in '{MODEL_SAVE_DIR}/'):\n",
      results_df[["Model","Seed","Saved_Model_Path"]].to_string(index=False))
print("\nOVERALL SUMMARY (all models & seeds pooled):\n",overall_summary_df)

# ================= PER-CLIENT TEST SUMMARY, averaged over 5 seeds =================
client_df=pd.DataFrame(client_rows)
client_metrics=["Accuracy","Precision","Recall","F1","MCC","AUC","Specificity","Loss"]

per_client_summary=(
    client_df.groupby(["Model","Client"])[client_metrics]
    .agg(["mean","std"])
    .round(4)
)
print(f"\nPER-CLIENT TEST SUMMARY (mean/std over {len(SEEDS)} seeds):\n",per_client_summary)

# ================= PAIRWISE PAIRED T-TESTS ACROSS MODELS (same seeds) =================
paired_test_metrics=["Accuracy","F1","AUC","Loss"]

pairwise_rows=[]
for metric in paired_test_metrics:
    for m1,m2 in combinations(MODELS,2):
        a=results_df[results_df["Model"]==m1].sort_values("Seed")[metric].values
        b=results_df[results_df["Model"]==m2].sort_values("Seed")[metric].values
        t_stat,p_val=ttest_rel(a,b)
        pairwise_rows.append({
            "Metric":metric,"Model A":m1,"Model B":m2,
            "Mean A":round(a.mean(),4),"Mean B":round(b.mean(),4),
            "t-stat":round(t_stat,4),"p-value":round(p_val,4),
            "Significant (p<0.05)":p_val<0.05
        })

pairwise_df=pd.DataFrame(pairwise_rows)
print(f"\nPAIRWISE PAIRED T-TESTS across {len(SEEDS)} seeds (Global Test Set):\n",
      pairwise_df.to_string(index=False))

# ================= McNEMAR'S TEST (per-instance, per seed + pooled across seeds) =================
mcnemar_per_seed_rows=[]
for seed in SEEDS:
    y_true=y_trues[seed]
    for m1,m2 in combinations(MODELS,2):
        stat,p,n01,n10=mcnemar_test(y_true,y_preds[(m1,seed)],y_true,y_preds[(m2,seed)])
        mcnemar_per_seed_rows.append({
            "Seed":seed,"Model A":m1,"Model B":m2,
            "A right/B wrong":n01,"A wrong/B right":n10,
            "stat":round(stat,4) if not np.isnan(stat) else "exact",
            "p-value":round(p,4),"Significant (p<0.05)":p<0.05
        })

mcnemar_per_seed_df=pd.DataFrame(mcnemar_per_seed_rows)
print(f"\nMcNEMAR'S TEST — PER SEED (instance-level, Global Test Set):\n",
      mcnemar_per_seed_df.to_string(index=False))

# pooled version: sum discordant counts across all 5 seeds (more statistical power)
mcnemar_pooled_rows=[]
for m1,m2 in combinations(MODELS,2):
    n01_total=0; n10_total=0
    for seed in SEEDS:
        y_true=y_trues[seed]
        correct_a=(y_preds[(m1,seed)]==y_true)
        correct_b=(y_preds[(m2,seed)]==y_true)
        n01_total+=int(np.sum(correct_a & ~correct_b))
        n10_total+=int(np.sum(~correct_a & correct_b))
    n=n01_total+n10_total
    if n==0:
        stat,p=np.nan,1.0
    elif n<25:
        p=min(2*min(binom.cdf(min(n01_total,n10_total),n,0.5),0.5),1.0); stat=np.nan
    else:
        stat=((abs(n01_total-n10_total)-1)**2)/n
        p=1-chi2.cdf(stat,1)
    mcnemar_pooled_rows.append({
        "Model A":m1,"Model B":m2,
        "A right/B wrong (pooled)":n01_total,"A wrong/B right (pooled)":n10_total,
        "stat":round(stat,4) if not np.isnan(stat) else "exact",
        "p-value":round(p,4),"Significant (p<0.05)":p<0.05
    })

mcnemar_pooled_df=pd.DataFrame(mcnemar_pooled_rows)
print(f"\nMcNEMAR'S TEST — POOLED ACROSS {len(SEEDS)} SEEDS (Global Test Set):\n",
      mcnemar_pooled_df.to_string(index=False))

# ================= PLOTS =================
rounds=np.arange(1,ROUNDS+1)

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["acc"],label=m)
plt.title("Accuracy vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Accuracy")
plt.legend(); plt.grid(); plt.show()

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["loss"],label=m)
plt.title("Loss vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Loss")
plt.legend(); plt.grid(); plt.show()
# Out:
# C:\Users\USER\anaconda3\envs\py310\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.5.0) or chardet (6.0.0.post1)/charset_normalizer (3.4.3) doesn't match a supported version!
#   warnings.warn(
# ================ MODEL: CNN ================
#
# ------ SEED 42 ------
#
# [Model=CNN | Seed=42 | Round=1]
#  Client 0 → Loss=0.6694, Acc=0.6155, Time=5.46s, N=2286
#  Client 1 → Loss=0.6724, Acc=0.6216, Time=0.78s, N=2286
#  Client 2 → Loss=0.6658, Acc=0.6142, Time=0.87s, N=2286
#  Client 3 → Loss=0.6522, Acc=0.6405, Time=0.85s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6625, Acc=0.6163
#
# [Model=CNN | Seed=42 | Round=2]
#  Client 0 → Loss=0.6506, Acc=0.6465, Time=0.79s, N=2286
#  Client 1 → Loss=0.6540, Acc=0.6369, Time=1.01s, N=2286
#  Client 2 → Loss=0.6476, Acc=0.6343, Time=0.77s, N=2286
#  Client 3 → Loss=0.6354, Acc=0.6519, Time=0.85s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6461, Acc=0.6346
#
# [Model=CNN | Seed=42 | Round=3]
#  Client 0 → Loss=0.6291, Acc=0.6588, Time=0.85s, N=2286
#  Client 1 → Loss=0.6355, Acc=0.6465, Time=0.80s, N=2286
#  Client 2 → Loss=0.6327, Acc=0.6514, Time=0.78s, N=2286
#  Client 3 → Loss=0.6183, Acc=0.6721, Time=0.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6384, Acc=0.6250
#
# [Model=CNN | Seed=42 | Round=4]
#  Client 0 → Loss=0.6052, Acc=0.6855, Time=0.79s, N=2286
#  Client 1 → Loss=0.6065, Acc=0.6745, Time=0.76s, N=2286
#  Client 2 → Loss=0.6082, Acc=0.6846, Time=0.83s, N=2286
#  Client 3 → Loss=0.5947, Acc=0.6861, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6186, Acc=0.6254
#
# [Model=CNN | Seed=42 | Round=5]
#  Client 0 → Loss=0.5560, Acc=0.7262, Time=0.78s, N=2286
#  Client 1 → Loss=0.5569, Acc=0.7231, Time=0.77s, N=2286
#  Client 2 → Loss=0.5579, Acc=0.7213, Time=0.78s, N=2286
#  Client 3 → Loss=0.5532, Acc=0.7224, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5805, Acc=0.6477
#
# [Model=CNN | Seed=42 | Round=6]
#  Client 0 → Loss=0.4995, Acc=0.7660, Time=0.76s, N=2286
#  Client 1 → Loss=0.4943, Acc=0.7747, Time=0.83s, N=2286
#  Client 2 → Loss=0.4911, Acc=0.7699, Time=0.82s, N=2286
#  Client 3 → Loss=0.4932, Acc=0.7658, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5121, Acc=0.7233
#
# [Model=CNN | Seed=42 | Round=7]
#  Client 0 → Loss=0.4482, Acc=0.7953, Time=0.76s, N=2286
#  Client 1 → Loss=0.4403, Acc=0.8031, Time=0.75s, N=2286
#  Client 2 → Loss=0.4396, Acc=0.8001, Time=0.76s, N=2286
#  Client 3 → Loss=0.4407, Acc=0.7951, Time=0.91s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4730, Acc=0.7688
#
# [Model=CNN | Seed=42 | Round=8]
#  Client 0 → Loss=0.4158, Acc=0.8193, Time=0.76s, N=2286
#  Client 1 → Loss=0.4040, Acc=0.8228, Time=0.72s, N=2286
#  Client 2 → Loss=0.4006, Acc=0.8250, Time=0.73s, N=2286
#  Client 3 → Loss=0.4061, Acc=0.8187, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4534, Acc=0.7841
#
# [Model=CNN | Seed=42 | Round=9]
#  Client 0 → Loss=0.3836, Acc=0.8360, Time=0.77s, N=2286
#  Client 1 → Loss=0.3760, Acc=0.8416, Time=0.80s, N=2286
#  Client 2 → Loss=0.3754, Acc=0.8408, Time=0.79s, N=2286
#  Client 3 → Loss=0.3843, Acc=0.8297, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4476, Acc=0.7889
#
# [Model=CNN | Seed=42 | Round=10]
#  Client 0 → Loss=0.3641, Acc=0.8500, Time=0.79s, N=2286
#  Client 1 → Loss=0.3588, Acc=0.8491, Time=0.81s, N=2286
#  Client 2 → Loss=0.3542, Acc=0.8491, Time=0.82s, N=2286
#  Client 3 → Loss=0.3622, Acc=0.8437, Time=0.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4589, Acc=0.7863
#
# [Model=CNN | Seed=42 | Round=11]
#  Client 0 → Loss=0.3470, Acc=0.8583, Time=0.78s, N=2286
#  Client 1 → Loss=0.3415, Acc=0.8591, Time=0.95s, N=2286
#  Client 2 → Loss=0.3348, Acc=0.8653, Time=0.75s, N=2286
#  Client 3 → Loss=0.3494, Acc=0.8520, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4530, Acc=0.7898
#
# [Model=CNN | Seed=42 | Round=12]
#  Client 0 → Loss=0.3318, Acc=0.8675, Time=0.81s, N=2286
#  Client 1 → Loss=0.3269, Acc=0.8675, Time=0.78s, N=2286
#  Client 2 → Loss=0.3216, Acc=0.8683, Time=0.78s, N=2286
#  Client 3 → Loss=0.3374, Acc=0.8586, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4567, Acc=0.7924
#
# [Model=CNN | Seed=42 | Round=13]
#  Client 0 → Loss=0.3185, Acc=0.8745, Time=0.73s, N=2286
#  Client 1 → Loss=0.3105, Acc=0.8775, Time=0.80s, N=2286
#  Client 2 → Loss=0.3081, Acc=0.8762, Time=0.76s, N=2286
#  Client 3 → Loss=0.3265, Acc=0.8634, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4668, Acc=0.7902
#
# [Model=CNN | Seed=42 | Round=14]
#  Client 0 → Loss=0.3095, Acc=0.8797, Time=0.82s, N=2286
#  Client 1 → Loss=0.3017, Acc=0.8788, Time=0.77s, N=2286
#  Client 2 → Loss=0.2977, Acc=0.8775, Time=0.89s, N=2286
#  Client 3 → Loss=0.3159, Acc=0.8726, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4696, Acc=0.7924
#
# [Model=CNN | Seed=42 | Round=15]
#  Client 0 → Loss=0.3029, Acc=0.8828, Time=0.78s, N=2286
#  Client 1 → Loss=0.2908, Acc=0.8885, Time=0.75s, N=2286
#  Client 2 → Loss=0.2946, Acc=0.8832, Time=0.74s, N=2286
#  Client 3 → Loss=0.3085, Acc=0.8713, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4672, Acc=0.7928
#
# [Model=CNN | Seed=42 | Round=16]
#  Client 0 → Loss=0.2919, Acc=0.8850, Time=0.82s, N=2286
#  Client 1 → Loss=0.2818, Acc=0.8911, Time=0.76s, N=2286
#  Client 2 → Loss=0.2837, Acc=0.8902, Time=0.78s, N=2286
#  Client 3 → Loss=0.3001, Acc=0.8783, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4824, Acc=0.7898
#
# [Model=CNN | Seed=42 | Round=17]
#  Client 0 → Loss=0.2852, Acc=0.8898, Time=0.80s, N=2286
#  Client 1 → Loss=0.2758, Acc=0.8906, Time=0.78s, N=2286
#  Client 2 → Loss=0.2748, Acc=0.8924, Time=0.84s, N=2286
#  Client 3 → Loss=0.2922, Acc=0.8831, Time=0.89s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4779, Acc=0.7950
#
# [Model=CNN | Seed=42 | Round=18]
#  Client 0 → Loss=0.2772, Acc=0.8928, Time=0.81s, N=2286
#  Client 1 → Loss=0.2704, Acc=0.8959, Time=0.77s, N=2286
#  Client 2 → Loss=0.2661, Acc=0.8959, Time=0.74s, N=2286
#  Client 3 → Loss=0.2836, Acc=0.8884, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4876, Acc=0.7924
#
# [Model=CNN | Seed=42 | Round=19]
#  Client 0 → Loss=0.2677, Acc=0.8990, Time=0.73s, N=2286
#  Client 1 → Loss=0.2612, Acc=0.8924, Time=0.73s, N=2286
#  Client 2 → Loss=0.2645, Acc=0.8941, Time=0.79s, N=2286
#  Client 3 → Loss=0.2756, Acc=0.8949, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5050, Acc=0.7876
#
# [Model=CNN | Seed=42 | Round=20]
#  Client 0 → Loss=0.2580, Acc=0.9055, Time=0.78s, N=2286
#  Client 1 → Loss=0.2559, Acc=0.8955, Time=0.78s, N=2286
#  Client 2 → Loss=0.2536, Acc=0.9020, Time=0.79s, N=2286
#  Client 3 → Loss=0.2674, Acc=0.8945, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5110, Acc=0.7893
#
# [Model=CNN | Seed=42 | Round=21]
#  Client 0 → Loss=0.2516, Acc=0.9055, Time=0.79s, N=2286
#  Client 1 → Loss=0.2472, Acc=0.9011, Time=0.83s, N=2286
#  Client 2 → Loss=0.2451, Acc=0.9011, Time=0.76s, N=2286
#  Client 3 → Loss=0.2603, Acc=0.8971, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5179, Acc=0.7880
#
# [Model=CNN | Seed=42 | Round=22]
#  Client 0 → Loss=0.2534, Acc=0.9055, Time=0.77s, N=2286
#  Client 1 → Loss=0.2392, Acc=0.9055, Time=0.78s, N=2286
#  Client 2 → Loss=0.2370, Acc=0.9073, Time=0.73s, N=2286
#  Client 3 → Loss=0.2549, Acc=0.9019, Time=0.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5368, Acc=0.7863
#
# [Model=CNN | Seed=42 | Round=23]
#  Client 0 → Loss=0.2428, Acc=0.9125, Time=0.79s, N=2286
#  Client 1 → Loss=0.2336, Acc=0.9086, Time=0.78s, N=2286
#  Client 2 → Loss=0.2352, Acc=0.9090, Time=0.77s, N=2286
#  Client 3 → Loss=0.2482, Acc=0.9046, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5528, Acc=0.7832
#
# [Model=CNN | Seed=42 | Round=24]
#  Client 0 → Loss=0.2400, Acc=0.9116, Time=0.95s, N=2286
#  Client 1 → Loss=0.2292, Acc=0.9073, Time=0.76s, N=2286
#  Client 2 → Loss=0.2271, Acc=0.9094, Time=0.84s, N=2286
#  Client 3 → Loss=0.2434, Acc=0.9059, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5780, Acc=0.7802
#
# [Model=CNN | Seed=42 | Round=25]
#  Client 0 → Loss=0.2437, Acc=0.9081, Time=0.77s, N=2286
#  Client 1 → Loss=0.2203, Acc=0.9112, Time=0.79s, N=2286
#  Client 2 → Loss=0.2239, Acc=0.9125, Time=0.79s, N=2286
#  Client 3 → Loss=0.2401, Acc=0.9102, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5387, Acc=0.7885
#
# [Model=CNN | Seed=42 | Round=26]
#  Client 0 → Loss=0.2268, Acc=0.9191, Time=0.85s, N=2286
#  Client 1 → Loss=0.2144, Acc=0.9156, Time=0.79s, N=2286
#  Client 2 → Loss=0.2184, Acc=0.9134, Time=0.79s, N=2286
#  Client 3 → Loss=0.2299, Acc=0.9151, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5611, Acc=0.7867
#
# [Model=CNN | Seed=42 | Round=27]
#  Client 0 → Loss=0.2276, Acc=0.9156, Time=0.75s, N=2286
#  Client 1 → Loss=0.2106, Acc=0.9178, Time=0.94s, N=2286
#  Client 2 → Loss=0.2154, Acc=0.9169, Time=0.77s, N=2286
#  Client 3 → Loss=0.2266, Acc=0.9120, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5803, Acc=0.7837
#
# [Model=CNN | Seed=42 | Round=28]
#  Client 0 → Loss=0.2165, Acc=0.9195, Time=0.77s, N=2286
#  Client 1 → Loss=0.2055, Acc=0.9191, Time=0.78s, N=2286
#  Client 2 → Loss=0.2102, Acc=0.9217, Time=0.79s, N=2286
#  Client 3 → Loss=0.2203, Acc=0.9190, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5823, Acc=0.7867
#
# [Model=CNN | Seed=42 | Round=29]
#  Client 0 → Loss=0.2120, Acc=0.9226, Time=0.80s, N=2286
#  Client 1 → Loss=0.1997, Acc=0.9204, Time=0.77s, N=2286
#  Client 2 → Loss=0.2033, Acc=0.9221, Time=0.75s, N=2286
#  Client 3 → Loss=0.2158, Acc=0.9208, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6060, Acc=0.7819
#
# [Model=CNN | Seed=42 | Round=30]
#  Client 0 → Loss=0.2137, Acc=0.9217, Time=0.76s, N=2286
#  Client 1 → Loss=0.1951, Acc=0.9239, Time=0.80s, N=2286
#  Client 2 → Loss=0.2010, Acc=0.9226, Time=0.94s, N=2286
#  Client 3 → Loss=0.2180, Acc=0.9203, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5928, Acc=0.7872
#  [saved] saved_models\CNN_seed42.keras
#
# ------ SEED 3 ------
#
# [Model=CNN | Seed=3 | Round=1]
#  Client 0 → Loss=0.6568, Acc=0.6129, Time=0.80s, N=2286
#  Client 1 → Loss=0.6571, Acc=0.6295, Time=0.78s, N=2286
#  Client 2 → Loss=0.6563, Acc=0.6413, Time=0.77s, N=2286
#  Client 3 → Loss=0.6671, Acc=0.5963, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6587, Acc=0.6464
#
# [Model=CNN | Seed=3 | Round=2]
#  Client 0 → Loss=0.6430, Acc=0.6356, Time=0.74s, N=2286
#  Client 1 → Loss=0.6435, Acc=0.6409, Time=0.76s, N=2286
#  Client 2 → Loss=0.6390, Acc=0.6527, Time=0.75s, N=2286
#  Client 3 → Loss=0.6533, Acc=0.6222, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6496, Acc=0.6442
#
# [Model=CNN | Seed=3 | Round=3]
#  Client 0 → Loss=0.6303, Acc=0.6509, Time=0.75s, N=2286
#  Client 1 → Loss=0.6285, Acc=0.6492, Time=0.76s, N=2286
#  Client 2 → Loss=0.6254, Acc=0.6632, Time=0.79s, N=2286
#  Client 3 → Loss=0.6444, Acc=0.6257, Time=0.91s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6412, Acc=0.6438
#
# [Model=CNN | Seed=3 | Round=4]
#  Client 0 → Loss=0.6198, Acc=0.6640, Time=0.74s, N=2286
#  Client 1 → Loss=0.6167, Acc=0.6597, Time=0.74s, N=2286
#  Client 2 → Loss=0.6139, Acc=0.6794, Time=0.76s, N=2286
#  Client 3 → Loss=0.6363, Acc=0.6419, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6376, Acc=0.6394
#
# [Model=CNN | Seed=3 | Round=5]
#  Client 0 → Loss=0.6023, Acc=0.6693, Time=0.74s, N=2286
#  Client 1 → Loss=0.5976, Acc=0.6785, Time=0.73s, N=2286
#  Client 2 → Loss=0.5972, Acc=0.6767, Time=0.73s, N=2286
#  Client 3 → Loss=0.6238, Acc=0.6528, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6254, Acc=0.6394
#
# [Model=CNN | Seed=3 | Round=6]
#  Client 0 → Loss=0.5711, Acc=0.6973, Time=0.74s, N=2286
#  Client 1 → Loss=0.5607, Acc=0.7143, Time=0.74s, N=2286
#  Client 2 → Loss=0.5679, Acc=0.7078, Time=0.78s, N=2286
#  Client 3 → Loss=0.5934, Acc=0.6848, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5899, Acc=0.6543
#
# [Model=CNN | Seed=3 | Round=7]
#  Client 0 → Loss=0.5256, Acc=0.7428, Time=0.92s, N=2286
#  Client 1 → Loss=0.5098, Acc=0.7528, Time=0.76s, N=2286
#  Client 2 → Loss=0.5219, Acc=0.7493, Time=0.77s, N=2286
#  Client 3 → Loss=0.5497, Acc=0.7347, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5369, Acc=0.7203
#
# [Model=CNN | Seed=3 | Round=8]
#  Client 0 → Loss=0.4860, Acc=0.7747, Time=0.72s, N=2286
#  Client 1 → Loss=0.4692, Acc=0.7795, Time=0.72s, N=2286
#  Client 2 → Loss=0.4829, Acc=0.7760, Time=0.73s, N=2286
#  Client 3 → Loss=0.5088, Acc=0.7627, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5144, Acc=0.7430
#
# [Model=CNN | Seed=3 | Round=9]
#  Client 0 → Loss=0.4602, Acc=0.7905, Time=0.71s, N=2286
#  Client 1 → Loss=0.4382, Acc=0.7983, Time=0.74s, N=2286
#  Client 2 → Loss=0.4512, Acc=0.7896, Time=0.71s, N=2286
#  Client 3 → Loss=0.4794, Acc=0.7776, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5001, Acc=0.7531
#
# [Model=CNN | Seed=3 | Round=10]
#  Client 0 → Loss=0.4377, Acc=0.8014, Time=0.81s, N=2286
#  Client 1 → Loss=0.4126, Acc=0.8110, Time=0.77s, N=2286
#  Client 2 → Loss=0.4296, Acc=0.8040, Time=0.76s, N=2286
#  Client 3 → Loss=0.4517, Acc=0.7964, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5092, Acc=0.7517
#
# [Model=CNN | Seed=3 | Round=11]
#  Client 0 → Loss=0.4169, Acc=0.8176, Time=0.74s, N=2286
#  Client 1 → Loss=0.3933, Acc=0.8285, Time=0.75s, N=2286
#  Client 2 → Loss=0.4116, Acc=0.8141, Time=0.78s, N=2286
#  Client 3 → Loss=0.4336, Acc=0.8069, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5169, Acc=0.7539
#
# [Model=CNN | Seed=3 | Round=12]
#  Client 0 → Loss=0.4015, Acc=0.8237, Time=0.72s, N=2286
#  Client 1 → Loss=0.3746, Acc=0.8368, Time=0.75s, N=2286
#  Client 2 → Loss=0.3916, Acc=0.8246, Time=0.73s, N=2286
#  Client 3 → Loss=0.4151, Acc=0.8179, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5246, Acc=0.7552
#
# [Model=CNN | Seed=3 | Round=13]
#  Client 0 → Loss=0.3890, Acc=0.8338, Time=0.70s, N=2286
#  Client 1 → Loss=0.3622, Acc=0.8425, Time=0.87s, N=2286
#  Client 2 → Loss=0.3768, Acc=0.8338, Time=0.71s, N=2286
#  Client 3 → Loss=0.3998, Acc=0.8214, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5390, Acc=0.7522
#
# [Model=CNN | Seed=3 | Round=14]
#  Client 0 → Loss=0.3763, Acc=0.8451, Time=0.73s, N=2286
#  Client 1 → Loss=0.3473, Acc=0.8539, Time=0.71s, N=2286
#  Client 2 → Loss=0.3619, Acc=0.8408, Time=0.72s, N=2286
#  Client 3 → Loss=0.3845, Acc=0.8314, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5480, Acc=0.7557
#
# [Model=CNN | Seed=3 | Round=15]
#  Client 0 → Loss=0.3620, Acc=0.8508, Time=0.72s, N=2286
#  Client 1 → Loss=0.3321, Acc=0.8644, Time=0.72s, N=2286
#  Client 2 → Loss=0.3528, Acc=0.8430, Time=0.77s, N=2286
#  Client 3 → Loss=0.3689, Acc=0.8446, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5621, Acc=0.7548
#
# [Model=CNN | Seed=3 | Round=16]
#  Client 0 → Loss=0.3528, Acc=0.8570, Time=0.72s, N=2286
#  Client 1 → Loss=0.3217, Acc=0.8648, Time=0.71s, N=2286
#  Client 2 → Loss=0.3388, Acc=0.8526, Time=0.73s, N=2286
#  Client 3 → Loss=0.3568, Acc=0.8503, Time=0.88s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5704, Acc=0.7601
#
# [Model=CNN | Seed=3 | Round=17]
#  Client 0 → Loss=0.3366, Acc=0.8635, Time=0.71s, N=2286
#  Client 1 → Loss=0.3096, Acc=0.8731, Time=0.69s, N=2286
#  Client 2 → Loss=0.3290, Acc=0.8587, Time=0.72s, N=2286
#  Client 3 → Loss=0.3458, Acc=0.8595, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6112, Acc=0.7517
#
# [Model=CNN | Seed=3 | Round=18]
#  Client 0 → Loss=0.3264, Acc=0.8736, Time=0.75s, N=2286
#  Client 1 → Loss=0.3001, Acc=0.8771, Time=0.72s, N=2286
#  Client 2 → Loss=0.3220, Acc=0.8596, Time=0.77s, N=2286
#  Client 3 → Loss=0.3312, Acc=0.8643, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6003, Acc=0.7592
#
# [Model=CNN | Seed=3 | Round=19]
#  Client 0 → Loss=0.3184, Acc=0.8793, Time=0.72s, N=2286
#  Client 1 → Loss=0.2948, Acc=0.8753, Time=0.71s, N=2286
#  Client 2 → Loss=0.3100, Acc=0.8688, Time=0.71s, N=2286
#  Client 3 → Loss=0.3212, Acc=0.8678, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6206, Acc=0.7561
#
# [Model=CNN | Seed=3 | Round=20]
#  Client 0 → Loss=0.3120, Acc=0.8815, Time=0.74s, N=2286
#  Client 1 → Loss=0.2841, Acc=0.8841, Time=0.73s, N=2286
#  Client 2 → Loss=0.3014, Acc=0.8679, Time=0.69s, N=2286
#  Client 3 → Loss=0.3123, Acc=0.8722, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6444, Acc=0.7544
#
# [Model=CNN | Seed=3 | Round=21]
#  Client 0 → Loss=0.2997, Acc=0.8876, Time=0.69s, N=2286
#  Client 1 → Loss=0.2781, Acc=0.8876, Time=0.73s, N=2286
#  Client 2 → Loss=0.2929, Acc=0.8762, Time=0.76s, N=2286
#  Client 3 → Loss=0.3037, Acc=0.8770, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6834, Acc=0.7509
#
# [Model=CNN | Seed=3 | Round=22]
#  Client 0 → Loss=0.2964, Acc=0.8893, Time=0.73s, N=2286
#  Client 1 → Loss=0.2688, Acc=0.8920, Time=0.71s, N=2286
#  Client 2 → Loss=0.2796, Acc=0.8836, Time=0.71s, N=2286
#  Client 3 → Loss=0.2922, Acc=0.8818, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6565, Acc=0.7596
#
# [Model=CNN | Seed=3 | Round=23]
#  Client 0 → Loss=0.2891, Acc=0.8885, Time=0.75s, N=2286
#  Client 1 → Loss=0.2634, Acc=0.8963, Time=0.93s, N=2286
#  Client 2 → Loss=0.2770, Acc=0.8819, Time=0.75s, N=2286
#  Client 3 → Loss=0.2854, Acc=0.8844, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6663, Acc=0.7592
#
# [Model=CNN | Seed=3 | Round=24]
#  Client 0 → Loss=0.2783, Acc=0.8959, Time=0.71s, N=2286
#  Client 1 → Loss=0.2578, Acc=0.9038, Time=0.75s, N=2286
#  Client 2 → Loss=0.2664, Acc=0.8863, Time=0.81s, N=2286
#  Client 3 → Loss=0.2794, Acc=0.8866, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6889, Acc=0.7583
#
# [Model=CNN | Seed=3 | Round=25]
#  Client 0 → Loss=0.2731, Acc=0.8937, Time=0.75s, N=2286
#  Client 1 → Loss=0.2515, Acc=0.9007, Time=0.73s, N=2286
#  Client 2 → Loss=0.2573, Acc=0.8937, Time=0.71s, N=2286
#  Client 3 → Loss=0.2742, Acc=0.8892, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6961, Acc=0.7627
#
# [Model=CNN | Seed=3 | Round=26]
#  Client 0 → Loss=0.2647, Acc=0.8998, Time=0.71s, N=2286
#  Client 1 → Loss=0.2464, Acc=0.9024, Time=0.69s, N=2286
#  Client 2 → Loss=0.2516, Acc=0.9020, Time=0.71s, N=2286
#  Client 3 → Loss=0.2656, Acc=0.8914, Time=0.86s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.7492, Acc=0.7548
#
# [Model=CNN | Seed=3 | Round=27]
#  Client 0 → Loss=0.2543, Acc=0.9020, Time=0.72s, N=2286
#  Client 1 → Loss=0.2381, Acc=0.9125, Time=0.70s, N=2286
#  Client 2 → Loss=0.2429, Acc=0.9024, Time=0.75s, N=2286
#  Client 3 → Loss=0.2595, Acc=0.8962, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.7656, Acc=0.7557
#
# [Model=CNN | Seed=3 | Round=28]
#  Client 0 → Loss=0.2577, Acc=0.9007, Time=0.79s, N=2286
#  Client 1 → Loss=0.2421, Acc=0.9055, Time=0.70s, N=2286
#  Client 2 → Loss=0.2341, Acc=0.9073, Time=0.72s, N=2286
#  Client 3 → Loss=0.2567, Acc=0.8984, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.7508, Acc=0.7592
#
# [Model=CNN | Seed=3 | Round=29]
#  Client 0 → Loss=0.2445, Acc=0.9073, Time=0.70s, N=2286
#  Client 1 → Loss=0.2302, Acc=0.9129, Time=0.70s, N=2286
#  Client 2 → Loss=0.2374, Acc=0.9068, Time=0.70s, N=2286
#  Client 3 → Loss=0.2513, Acc=0.8958, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.8238, Acc=0.7491
#
# [Model=CNN | Seed=3 | Round=30]
#  Client 0 → Loss=0.2387, Acc=0.9059, Time=0.77s, N=2286
#  Client 1 → Loss=0.2275, Acc=0.9151, Time=0.88s, N=2286
#  Client 2 → Loss=0.2233, Acc=0.9138, Time=0.71s, N=2286
#  Client 3 → Loss=0.2421, Acc=0.8975, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.8429, Acc=0.7522
#  [saved] saved_models\CNN_seed3.keras
#
# ------ SEED 7 ------
#
# [Model=CNN | Seed=7 | Round=1]
#  Client 0 → Loss=0.6653, Acc=0.6142, Time=0.75s, N=2286
#  Client 1 → Loss=0.6531, Acc=0.6391, Time=0.76s, N=2286
#  Client 2 → Loss=0.6666, Acc=0.6063, Time=0.72s, N=2286
#  Client 3 → Loss=0.6605, Acc=0.6095, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6555, Acc=0.6407
#
# [Model=CNN | Seed=7 | Round=2]
#  Client 0 → Loss=0.6470, Acc=0.6360, Time=0.71s, N=2286
#  Client 1 → Loss=0.6366, Acc=0.6610, Time=0.71s, N=2286
#  Client 2 → Loss=0.6507, Acc=0.6242, Time=0.70s, N=2286
#  Client 3 → Loss=0.6496, Acc=0.6318, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6405, Acc=0.6495
#
# [Model=CNN | Seed=7 | Round=3]
#  Client 0 → Loss=0.6331, Acc=0.6496, Time=0.70s, N=2286
#  Client 1 → Loss=0.6255, Acc=0.6732, Time=0.86s, N=2286
#  Client 2 → Loss=0.6375, Acc=0.6430, Time=0.71s, N=2286
#  Client 3 → Loss=0.6382, Acc=0.6335, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6261, Acc=0.6595
#
# [Model=CNN | Seed=7 | Round=4]
#  Client 0 → Loss=0.6192, Acc=0.6619, Time=0.69s, N=2286
#  Client 1 → Loss=0.6090, Acc=0.6763, Time=0.72s, N=2286
#  Client 2 → Loss=0.6222, Acc=0.6619, Time=0.80s, N=2286
#  Client 3 → Loss=0.6229, Acc=0.6480, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6056, Acc=0.6705
#
# [Model=CNN | Seed=7 | Round=5]
#  Client 0 → Loss=0.5946, Acc=0.6868, Time=0.71s, N=2286
#  Client 1 → Loss=0.5859, Acc=0.6925, Time=0.71s, N=2286
#  Client 2 → Loss=0.5980, Acc=0.6894, Time=0.69s, N=2286
#  Client 3 → Loss=0.5977, Acc=0.6782, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5660, Acc=0.6989
#
# [Model=CNN | Seed=7 | Round=6]
#  Client 0 → Loss=0.5455, Acc=0.7450, Time=0.69s, N=2286
#  Client 1 → Loss=0.5451, Acc=0.7200, Time=0.70s, N=2286
#  Client 2 → Loss=0.5570, Acc=0.7283, Time=0.70s, N=2286
#  Client 3 → Loss=0.5525, Acc=0.7246, Time=0.86s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5050, Acc=0.7758
#
# [Model=CNN | Seed=7 | Round=7]
#  Client 0 → Loss=0.4957, Acc=0.7817, Time=0.68s, N=2286
#  Client 1 → Loss=0.4939, Acc=0.7638, Time=0.70s, N=2286
#  Client 2 → Loss=0.5041, Acc=0.7664, Time=0.74s, N=2286
#  Client 3 → Loss=0.5030, Acc=0.7675, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4518, Acc=0.8103
#
# [Model=CNN | Seed=7 | Round=8]
#  Client 0 → Loss=0.4536, Acc=0.8058, Time=0.70s, N=2286
#  Client 1 → Loss=0.4505, Acc=0.7953, Time=0.68s, N=2286
#  Client 2 → Loss=0.4639, Acc=0.7900, Time=0.69s, N=2286
#  Client 3 → Loss=0.4584, Acc=0.7859, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4232, Acc=0.8195
#
# [Model=CNN | Seed=7 | Round=9]
#  Client 0 → Loss=0.4215, Acc=0.8246, Time=0.70s, N=2286
#  Client 1 → Loss=0.4193, Acc=0.8180, Time=0.69s, N=2286
#  Client 2 → Loss=0.4347, Acc=0.8071, Time=0.68s, N=2286
#  Client 3 → Loss=0.4325, Acc=0.8008, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3972, Acc=0.8300
#
# [Model=CNN | Seed=7 | Round=10]
#  Client 0 → Loss=0.3968, Acc=0.8285, Time=0.70s, N=2286
#  Client 1 → Loss=0.3965, Acc=0.8281, Time=0.70s, N=2286
#  Client 2 → Loss=0.4123, Acc=0.8250, Time=0.70s, N=2286
#  Client 3 → Loss=0.4104, Acc=0.8139, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3968, Acc=0.8260
#
# [Model=CNN | Seed=7 | Round=11]
#  Client 0 → Loss=0.3766, Acc=0.8451, Time=0.70s, N=2286
#  Client 1 → Loss=0.3782, Acc=0.8403, Time=0.75s, N=2286
#  Client 2 → Loss=0.3938, Acc=0.8316, Time=0.69s, N=2286
#  Client 3 → Loss=0.3941, Acc=0.8244, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3964, Acc=0.8204
#
# [Model=CNN | Seed=7 | Round=12]
#  Client 0 → Loss=0.3589, Acc=0.8513, Time=0.77s, N=2286
#  Client 1 → Loss=0.3641, Acc=0.8517, Time=0.76s, N=2286
#  Client 2 → Loss=0.3772, Acc=0.8386, Time=0.80s, N=2286
#  Client 3 → Loss=0.3779, Acc=0.8371, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3929, Acc=0.8186
#
# [Model=CNN | Seed=7 | Round=13]
#  Client 0 → Loss=0.3485, Acc=0.8530, Time=0.75s, N=2286
#  Client 1 → Loss=0.3498, Acc=0.8535, Time=0.93s, N=2286
#  Client 2 → Loss=0.3667, Acc=0.8421, Time=0.79s, N=2286
#  Client 3 → Loss=0.3668, Acc=0.8428, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3915, Acc=0.8199
#
# [Model=CNN | Seed=7 | Round=14]
#  Client 0 → Loss=0.3328, Acc=0.8605, Time=0.70s, N=2286
#  Client 1 → Loss=0.3379, Acc=0.8618, Time=0.75s, N=2286
#  Client 2 → Loss=0.3539, Acc=0.8508, Time=0.73s, N=2286
#  Client 3 → Loss=0.3530, Acc=0.8503, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4002, Acc=0.8212
#
# [Model=CNN | Seed=7 | Round=15]
#  Client 0 → Loss=0.3250, Acc=0.8631, Time=0.71s, N=2286
#  Client 1 → Loss=0.3292, Acc=0.8583, Time=0.70s, N=2286
#  Client 2 → Loss=0.3411, Acc=0.8609, Time=0.70s, N=2286
#  Client 3 → Loss=0.3447, Acc=0.8555, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4119, Acc=0.8164
#
# [Model=CNN | Seed=7 | Round=16]
#  Client 0 → Loss=0.3142, Acc=0.8710, Time=0.73s, N=2286
#  Client 1 → Loss=0.3192, Acc=0.8640, Time=0.70s, N=2286
#  Client 2 → Loss=0.3286, Acc=0.8644, Time=0.74s, N=2286
#  Client 3 → Loss=0.3326, Acc=0.8678, Time=0.88s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4179, Acc=0.8160
#
# [Model=CNN | Seed=7 | Round=17]
#  Client 0 → Loss=0.3051, Acc=0.8749, Time=0.70s, N=2286
#  Client 1 → Loss=0.3092, Acc=0.8723, Time=0.72s, N=2286
#  Client 2 → Loss=0.3176, Acc=0.8683, Time=0.72s, N=2286
#  Client 3 → Loss=0.3282, Acc=0.8669, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4212, Acc=0.8142
#
# [Model=CNN | Seed=7 | Round=18]
#  Client 0 → Loss=0.2998, Acc=0.8766, Time=0.69s, N=2286
#  Client 1 → Loss=0.2979, Acc=0.8766, Time=0.76s, N=2286
#  Client 2 → Loss=0.3071, Acc=0.8736, Time=0.72s, N=2286
#  Client 3 → Loss=0.3209, Acc=0.8700, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4186, Acc=0.8151
#
# [Model=CNN | Seed=7 | Round=19]
#  Client 0 → Loss=0.2901, Acc=0.8806, Time=0.70s, N=2286
#  Client 1 → Loss=0.2899, Acc=0.8836, Time=0.72s, N=2286
#  Client 2 → Loss=0.3013, Acc=0.8771, Time=0.78s, N=2286
#  Client 3 → Loss=0.3137, Acc=0.8765, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4258, Acc=0.8138
#
# [Model=CNN | Seed=7 | Round=20]
#  Client 0 → Loss=0.2844, Acc=0.8780, Time=0.72s, N=2286
#  Client 1 → Loss=0.2837, Acc=0.8850, Time=0.69s, N=2286
#  Client 2 → Loss=0.2929, Acc=0.8797, Time=0.72s, N=2286
#  Client 3 → Loss=0.3039, Acc=0.8800, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4309, Acc=0.8134
#
# [Model=CNN | Seed=7 | Round=21]
#  Client 0 → Loss=0.2771, Acc=0.8876, Time=0.72s, N=2286
#  Client 1 → Loss=0.2770, Acc=0.8863, Time=0.71s, N=2286
#  Client 2 → Loss=0.2832, Acc=0.8867, Time=0.72s, N=2286
#  Client 3 → Loss=0.2988, Acc=0.8813, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4300, Acc=0.8177
#
# [Model=CNN | Seed=7 | Round=22]
#  Client 0 → Loss=0.2668, Acc=0.8915, Time=0.71s, N=2286
#  Client 1 → Loss=0.2722, Acc=0.8906, Time=0.74s, N=2286
#  Client 2 → Loss=0.2746, Acc=0.8898, Time=0.72s, N=2286
#  Client 3 → Loss=0.2951, Acc=0.8862, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4176, Acc=0.8239
#
# [Model=CNN | Seed=7 | Round=23]
#  Client 0 → Loss=0.2615, Acc=0.8946, Time=0.71s, N=2286
#  Client 1 → Loss=0.2637, Acc=0.8941, Time=0.86s, N=2286
#  Client 2 → Loss=0.2666, Acc=0.8963, Time=0.73s, N=2286
#  Client 3 → Loss=0.2840, Acc=0.8910, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4399, Acc=0.8199
#
# [Model=CNN | Seed=7 | Round=24]
#  Client 0 → Loss=0.2554, Acc=0.8959, Time=0.72s, N=2286
#  Client 1 → Loss=0.2622, Acc=0.8928, Time=0.76s, N=2286
#  Client 2 → Loss=0.2647, Acc=0.8933, Time=0.70s, N=2286
#  Client 3 → Loss=0.2811, Acc=0.8905, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4547, Acc=0.8182
#
# [Model=CNN | Seed=7 | Round=25]
#  Client 0 → Loss=0.2456, Acc=0.9020, Time=0.73s, N=2286
#  Client 1 → Loss=0.2479, Acc=0.8994, Time=0.71s, N=2286
#  Client 2 → Loss=0.2610, Acc=0.8941, Time=0.71s, N=2286
#  Client 3 → Loss=0.2714, Acc=0.8919, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4613, Acc=0.8186
#
# [Model=CNN | Seed=7 | Round=26]
#  Client 0 → Loss=0.2421, Acc=0.9024, Time=0.73s, N=2286
#  Client 1 → Loss=0.2462, Acc=0.9029, Time=0.78s, N=2286
#  Client 2 → Loss=0.2552, Acc=0.9003, Time=0.71s, N=2286
#  Client 3 → Loss=0.2685, Acc=0.8989, Time=0.87s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4845, Acc=0.8125
#
# [Model=CNN | Seed=7 | Round=27]
#  Client 0 → Loss=0.2372, Acc=0.9086, Time=0.70s, N=2286
#  Client 1 → Loss=0.2382, Acc=0.9055, Time=0.70s, N=2286
#  Client 2 → Loss=0.2498, Acc=0.9042, Time=0.71s, N=2286
#  Client 3 → Loss=0.2597, Acc=0.9028, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4880, Acc=0.8147
#
# [Model=CNN | Seed=7 | Round=28]
#  Client 0 → Loss=0.2343, Acc=0.9090, Time=0.71s, N=2286
#  Client 1 → Loss=0.2333, Acc=0.9108, Time=0.72s, N=2286
#  Client 2 → Loss=0.2442, Acc=0.9064, Time=0.75s, N=2286
#  Client 3 → Loss=0.2546, Acc=0.9046, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4917, Acc=0.8182
#
# [Model=CNN | Seed=7 | Round=29]
#  Client 0 → Loss=0.2363, Acc=0.9051, Time=0.72s, N=2286
#  Client 1 → Loss=0.2267, Acc=0.9116, Time=0.71s, N=2286
#  Client 2 → Loss=0.2434, Acc=0.9064, Time=0.78s, N=2286
#  Client 3 → Loss=0.2450, Acc=0.9094, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5350, Acc=0.8051
#
# [Model=CNN | Seed=7 | Round=30]
#  Client 0 → Loss=0.2281, Acc=0.9112, Time=0.71s, N=2286
#  Client 1 → Loss=0.2202, Acc=0.9160, Time=0.76s, N=2286
#  Client 2 → Loss=0.2353, Acc=0.9081, Time=0.73s, N=2286
#  Client 3 → Loss=0.2435, Acc=0.9081, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5178, Acc=0.8142
#  [saved] saved_models\CNN_seed7.keras
#
# ------ SEED 72 ------
#
# [Model=CNN | Seed=72 | Round=1]
#  Client 0 → Loss=0.6735, Acc=0.5941, Time=0.79s, N=2286
#  Client 1 → Loss=0.6649, Acc=0.6260, Time=0.73s, N=2286
#  Client 2 → Loss=0.6619, Acc=0.6269, Time=0.78s, N=2286
#  Client 3 → Loss=0.6683, Acc=0.6003, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6666, Acc=0.6399
#
# [Model=CNN | Seed=72 | Round=2]
#  Client 0 → Loss=0.6657, Acc=0.6129, Time=0.78s, N=2286
#  Client 1 → Loss=0.6497, Acc=0.6260, Time=0.75s, N=2286
#  Client 2 → Loss=0.6463, Acc=0.6395, Time=0.77s, N=2286
#  Client 3 → Loss=0.6574, Acc=0.6335, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6469, Acc=0.6477
#
# [Model=CNN | Seed=72 | Round=3]
#  Client 0 → Loss=0.6494, Acc=0.6286, Time=0.74s, N=2286
#  Client 1 → Loss=0.6378, Acc=0.6404, Time=1.00s, N=2286
#  Client 2 → Loss=0.6333, Acc=0.6522, Time=0.80s, N=2286
#  Client 3 → Loss=0.6480, Acc=0.6375, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6357, Acc=0.6626
#
# [Model=CNN | Seed=72 | Round=4]
#  Client 0 → Loss=0.6376, Acc=0.6374, Time=0.72s, N=2286
#  Client 1 → Loss=0.6242, Acc=0.6474, Time=0.75s, N=2286
#  Client 2 → Loss=0.6246, Acc=0.6601, Time=0.77s, N=2286
#  Client 3 → Loss=0.6356, Acc=0.6475, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6262, Acc=0.6696
#
# [Model=CNN | Seed=72 | Round=5]
#  Client 0 → Loss=0.6246, Acc=0.6610, Time=0.75s, N=2286
#  Client 1 → Loss=0.6164, Acc=0.6522, Time=0.74s, N=2286
#  Client 2 → Loss=0.6133, Acc=0.6732, Time=0.78s, N=2286
#  Client 3 → Loss=0.6228, Acc=0.6546, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6213, Acc=0.6635
#
# [Model=CNN | Seed=72 | Round=6]
#  Client 0 → Loss=0.6121, Acc=0.6724, Time=0.77s, N=2286
#  Client 1 → Loss=0.6049, Acc=0.6667, Time=0.73s, N=2286
#  Client 2 → Loss=0.5994, Acc=0.6798, Time=0.76s, N=2286
#  Client 3 → Loss=0.6121, Acc=0.6633, Time=0.96s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6150, Acc=0.6525
#
# [Model=CNN | Seed=72 | Round=7]
#  Client 0 → Loss=0.5963, Acc=0.6815, Time=0.72s, N=2286
#  Client 1 → Loss=0.5910, Acc=0.6789, Time=0.78s, N=2286
#  Client 2 → Loss=0.5858, Acc=0.6907, Time=0.74s, N=2286
#  Client 3 → Loss=0.5989, Acc=0.6817, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6052, Acc=0.6512
#
# [Model=CNN | Seed=72 | Round=8]
#  Client 0 → Loss=0.5725, Acc=0.7025, Time=0.73s, N=2286
#  Client 1 → Loss=0.5641, Acc=0.7047, Time=0.74s, N=2286
#  Client 2 → Loss=0.5617, Acc=0.7082, Time=0.73s, N=2286
#  Client 3 → Loss=0.5760, Acc=0.7018, Time=0.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5861, Acc=0.6578
#
# [Model=CNN | Seed=72 | Round=9]
#  Client 0 → Loss=0.5333, Acc=0.7423, Time=0.74s, N=2286
#  Client 1 → Loss=0.5235, Acc=0.7367, Time=0.72s, N=2286
#  Client 2 → Loss=0.5239, Acc=0.7384, Time=0.71s, N=2286
#  Client 3 → Loss=0.5365, Acc=0.7412, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5485, Acc=0.7102
#
# [Model=CNN | Seed=72 | Round=10]
#  Client 0 → Loss=0.4950, Acc=0.7664, Time=0.76s, N=2286
#  Client 1 → Loss=0.4766, Acc=0.7747, Time=0.75s, N=2286
#  Client 2 → Loss=0.4792, Acc=0.7730, Time=0.74s, N=2286
#  Client 3 → Loss=0.4927, Acc=0.7671, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5017, Acc=0.7491
#
# [Model=CNN | Seed=72 | Round=11]
#  Client 0 → Loss=0.4642, Acc=0.7878, Time=0.83s, N=2286
#  Client 1 → Loss=0.4377, Acc=0.8014, Time=0.75s, N=2286
#  Client 2 → Loss=0.4410, Acc=0.8014, Time=0.76s, N=2286
#  Client 3 → Loss=0.4543, Acc=0.7890, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4809, Acc=0.7605
#
# [Model=CNN | Seed=72 | Round=12]
#  Client 0 → Loss=0.4408, Acc=0.7997, Time=0.78s, N=2286
#  Client 1 → Loss=0.4060, Acc=0.8171, Time=0.73s, N=2286
#  Client 2 → Loss=0.4133, Acc=0.8206, Time=0.79s, N=2286
#  Client 3 → Loss=0.4266, Acc=0.8060, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4669, Acc=0.7705
#
# [Model=CNN | Seed=72 | Round=13]
#  Client 0 → Loss=0.4188, Acc=0.8163, Time=0.75s, N=2286
#  Client 1 → Loss=0.3819, Acc=0.8373, Time=0.89s, N=2286
#  Client 2 → Loss=0.3921, Acc=0.8263, Time=0.70s, N=2286
#  Client 3 → Loss=0.4040, Acc=0.8253, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4496, Acc=0.7837
#
# [Model=CNN | Seed=72 | Round=14]
#  Client 0 → Loss=0.4007, Acc=0.8307, Time=0.70s, N=2286
#  Client 1 → Loss=0.3612, Acc=0.8469, Time=0.71s, N=2286
#  Client 2 → Loss=0.3745, Acc=0.8325, Time=0.76s, N=2286
#  Client 3 → Loss=0.3854, Acc=0.8384, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4419, Acc=0.7898
#
# [Model=CNN | Seed=72 | Round=15]
#  Client 0 → Loss=0.3851, Acc=0.8368, Time=0.71s, N=2286
#  Client 1 → Loss=0.3451, Acc=0.8548, Time=0.75s, N=2286
#  Client 2 → Loss=0.3591, Acc=0.8399, Time=0.72s, N=2286
#  Client 3 → Loss=0.3708, Acc=0.8481, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4300, Acc=0.7972
#
# [Model=CNN | Seed=72 | Round=16]
#  Client 0 → Loss=0.3695, Acc=0.8408, Time=0.71s, N=2286
#  Client 1 → Loss=0.3293, Acc=0.8631, Time=0.71s, N=2286
#  Client 2 → Loss=0.3438, Acc=0.8495, Time=0.75s, N=2286
#  Client 3 → Loss=0.3573, Acc=0.8533, Time=0.86s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4318, Acc=0.8042
#
# [Model=CNN | Seed=72 | Round=17]
#  Client 0 → Loss=0.3544, Acc=0.8456, Time=0.71s, N=2286
#  Client 1 → Loss=0.3181, Acc=0.8675, Time=0.71s, N=2286
#  Client 2 → Loss=0.3301, Acc=0.8648, Time=0.70s, N=2286
#  Client 3 → Loss=0.3438, Acc=0.8643, Time=0.69s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4379, Acc=0.7990
#
# [Model=CNN | Seed=72 | Round=18]
#  Client 0 → Loss=0.3447, Acc=0.8556, Time=0.70s, N=2286
#  Client 1 → Loss=0.3077, Acc=0.8745, Time=0.69s, N=2286
#  Client 2 → Loss=0.3205, Acc=0.8723, Time=0.75s, N=2286
#  Client 3 → Loss=0.3304, Acc=0.8643, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4315, Acc=0.8094
#
# [Model=CNN | Seed=72 | Round=19]
#  Client 0 → Loss=0.3337, Acc=0.8521, Time=0.70s, N=2286
#  Client 1 → Loss=0.2964, Acc=0.8771, Time=0.71s, N=2286
#  Client 2 → Loss=0.3127, Acc=0.8775, Time=0.69s, N=2286
#  Client 3 → Loss=0.3212, Acc=0.8730, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4504, Acc=0.8046
#
# [Model=CNN | Seed=72 | Round=20]
#  Client 0 → Loss=0.3215, Acc=0.8596, Time=0.71s, N=2286
#  Client 1 → Loss=0.2916, Acc=0.8836, Time=0.77s, N=2286
#  Client 2 → Loss=0.3028, Acc=0.8815, Time=0.71s, N=2286
#  Client 3 → Loss=0.3129, Acc=0.8752, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4637, Acc=0.7963
#
# [Model=CNN | Seed=72 | Round=21]
#  Client 0 → Loss=0.3149, Acc=0.8661, Time=0.70s, N=2286
#  Client 1 → Loss=0.2812, Acc=0.8871, Time=0.69s, N=2286
#  Client 2 → Loss=0.2973, Acc=0.8871, Time=0.70s, N=2286
#  Client 3 → Loss=0.3023, Acc=0.8835, Time=0.69s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4814, Acc=0.7876
#
# [Model=CNN | Seed=72 | Round=22]
#  Client 0 → Loss=0.3026, Acc=0.8731, Time=0.78s, N=2286
#  Client 1 → Loss=0.2773, Acc=0.8832, Time=0.71s, N=2286
#  Client 2 → Loss=0.2886, Acc=0.8906, Time=0.70s, N=2286
#  Client 3 → Loss=0.2950, Acc=0.8835, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4889, Acc=0.7876
#
# [Model=CNN | Seed=72 | Round=23]
#  Client 0 → Loss=0.2987, Acc=0.8705, Time=0.70s, N=2286
#  Client 1 → Loss=0.2694, Acc=0.8906, Time=0.73s, N=2286
#  Client 2 → Loss=0.2836, Acc=0.8972, Time=0.96s, N=2286
#  Client 3 → Loss=0.2867, Acc=0.8862, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4992, Acc=0.7880
#
# [Model=CNN | Seed=72 | Round=24]
#  Client 0 → Loss=0.2915, Acc=0.8727, Time=0.76s, N=2286
#  Client 1 → Loss=0.2637, Acc=0.8920, Time=0.77s, N=2286
#  Client 2 → Loss=0.2769, Acc=0.9016, Time=0.75s, N=2286
#  Client 3 → Loss=0.2813, Acc=0.8901, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5091, Acc=0.7828
#
# [Model=CNN | Seed=72 | Round=25]
#  Client 0 → Loss=0.2829, Acc=0.8806, Time=0.76s, N=2286
#  Client 1 → Loss=0.2566, Acc=0.8972, Time=0.85s, N=2286
#  Client 2 → Loss=0.2668, Acc=0.9042, Time=0.75s, N=2286
#  Client 3 → Loss=0.2714, Acc=0.8949, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5231, Acc=0.7784
#
# [Model=CNN | Seed=72 | Round=26]
#  Client 0 → Loss=0.2758, Acc=0.8810, Time=0.74s, N=2286
#  Client 1 → Loss=0.2510, Acc=0.9038, Time=0.74s, N=2286
#  Client 2 → Loss=0.2643, Acc=0.9024, Time=0.76s, N=2286
#  Client 3 → Loss=0.2702, Acc=0.8958, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5625, Acc=0.7670
#
# [Model=CNN | Seed=72 | Round=27]
#  Client 0 → Loss=0.2727, Acc=0.8815, Time=0.94s, N=2286
#  Client 1 → Loss=0.2439, Acc=0.9055, Time=0.75s, N=2286
#  Client 2 → Loss=0.2626, Acc=0.9033, Time=0.77s, N=2286
#  Client 3 → Loss=0.2605, Acc=0.8989, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5602, Acc=0.7649
#
# [Model=CNN | Seed=72 | Round=28]
#  Client 0 → Loss=0.2639, Acc=0.8885, Time=0.74s, N=2286
#  Client 1 → Loss=0.2420, Acc=0.9077, Time=0.79s, N=2286
#  Client 2 → Loss=0.2542, Acc=0.9064, Time=0.75s, N=2286
#  Client 3 → Loss=0.2570, Acc=0.9006, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5801, Acc=0.7605
#
# [Model=CNN | Seed=72 | Round=29]
#  Client 0 → Loss=0.2565, Acc=0.8963, Time=0.74s, N=2286
#  Client 1 → Loss=0.2358, Acc=0.9112, Time=0.73s, N=2286
#  Client 2 → Loss=0.2486, Acc=0.9081, Time=0.76s, N=2286
#  Client 3 → Loss=0.2499, Acc=0.9059, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5900, Acc=0.7583
#
# [Model=CNN | Seed=72 | Round=30]
#  Client 0 → Loss=0.2528, Acc=0.8994, Time=0.83s, N=2286
#  Client 1 → Loss=0.2317, Acc=0.9134, Time=0.91s, N=2286
#  Client 2 → Loss=0.2412, Acc=0.9108, Time=0.75s, N=2286
#  Client 3 → Loss=0.2471, Acc=0.9054, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6179, Acc=0.7509
#  [saved] saved_models\CNN_seed72.keras
#
# ------ SEED 82 ------
#
# [Model=CNN | Seed=82 | Round=1]
#  Client 0 → Loss=0.6673, Acc=0.6028, Time=0.79s, N=2286
#  Client 1 → Loss=0.6639, Acc=0.6207, Time=0.77s, N=2286
#  Client 2 → Loss=0.6592, Acc=0.6286, Time=0.73s, N=2286
#  Client 3 → Loss=0.6543, Acc=0.6270, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6607, Acc=0.6538
#
# [Model=CNN | Seed=82 | Round=2]
#  Client 0 → Loss=0.6562, Acc=0.6286, Time=0.72s, N=2286
#  Client 1 → Loss=0.6513, Acc=0.6207, Time=0.74s, N=2286
#  Client 2 → Loss=0.6455, Acc=0.6518, Time=0.75s, N=2286
#  Client 3 → Loss=0.6450, Acc=0.6419, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6520, Acc=0.6534
#
# [Model=CNN | Seed=82 | Round=3]
#  Client 0 → Loss=0.6451, Acc=0.6360, Time=0.77s, N=2286
#  Client 1 → Loss=0.6364, Acc=0.6317, Time=0.70s, N=2286
#  Client 2 → Loss=0.6363, Acc=0.6553, Time=0.87s, N=2286
#  Client 3 → Loss=0.6337, Acc=0.6537, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6436, Acc=0.6512
#
# [Model=CNN | Seed=82 | Round=4]
#  Client 0 → Loss=0.6311, Acc=0.6496, Time=0.78s, N=2286
#  Client 1 → Loss=0.6197, Acc=0.6544, Time=0.72s, N=2286
#  Client 2 → Loss=0.6225, Acc=0.6689, Time=0.70s, N=2286
#  Client 3 → Loss=0.6159, Acc=0.6699, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6378, Acc=0.6237
#
# [Model=CNN | Seed=82 | Round=5]
#  Client 0 → Loss=0.6081, Acc=0.6689, Time=0.72s, N=2286
#  Client 1 → Loss=0.5894, Acc=0.6829, Time=0.75s, N=2286
#  Client 2 → Loss=0.6017, Acc=0.6850, Time=0.76s, N=2286
#  Client 3 → Loss=0.5918, Acc=0.6878, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6115, Acc=0.6329
#
# [Model=CNN | Seed=82 | Round=6]
#  Client 0 → Loss=0.5658, Acc=0.7161, Time=0.71s, N=2286
#  Client 1 → Loss=0.5434, Acc=0.7301, Time=0.73s, N=2286
#  Client 2 → Loss=0.5576, Acc=0.7139, Time=0.75s, N=2286
#  Client 3 → Loss=0.5470, Acc=0.7342, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5692, Acc=0.6713
#
# [Model=CNN | Seed=82 | Round=7]
#  Client 0 → Loss=0.5137, Acc=0.7445, Time=0.87s, N=2286
#  Client 1 → Loss=0.4879, Acc=0.7695, Time=0.68s, N=2286
#  Client 2 → Loss=0.5007, Acc=0.7725, Time=0.76s, N=2286
#  Client 3 → Loss=0.5005, Acc=0.7671, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5324, Acc=0.7142
#
# [Model=CNN | Seed=82 | Round=8]
#  Client 0 → Loss=0.4769, Acc=0.7703, Time=0.72s, N=2286
#  Client 1 → Loss=0.4453, Acc=0.7905, Time=0.73s, N=2286
#  Client 2 → Loss=0.4569, Acc=0.7957, Time=0.73s, N=2286
#  Client 3 → Loss=0.4624, Acc=0.8004, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4930, Acc=0.7526
#
# [Model=CNN | Seed=82 | Round=9]
#  Client 0 → Loss=0.4437, Acc=0.7931, Time=0.72s, N=2286
#  Client 1 → Loss=0.4144, Acc=0.8110, Time=0.75s, N=2286
#  Client 2 → Loss=0.4234, Acc=0.8158, Time=0.73s, N=2286
#  Client 3 → Loss=0.4326, Acc=0.8117, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4710, Acc=0.7635
#
# [Model=CNN | Seed=82 | Round=10]
#  Client 0 → Loss=0.4198, Acc=0.8071, Time=0.79s, N=2286
#  Client 1 → Loss=0.3872, Acc=0.8276, Time=0.90s, N=2286
#  Client 2 → Loss=0.3961, Acc=0.8259, Time=0.73s, N=2286
#  Client 3 → Loss=0.4093, Acc=0.8249, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4657, Acc=0.7719
#
# [Model=CNN | Seed=82 | Round=11]
#  Client 0 → Loss=0.3970, Acc=0.8263, Time=0.75s, N=2286
#  Client 1 → Loss=0.3683, Acc=0.8412, Time=0.70s, N=2286
#  Client 2 → Loss=0.3728, Acc=0.8465, Time=0.74s, N=2286
#  Client 3 → Loss=0.3908, Acc=0.8358, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4659, Acc=0.7753
#
# [Model=CNN | Seed=82 | Round=12]
#  Client 0 → Loss=0.3834, Acc=0.8325, Time=0.73s, N=2286
#  Client 1 → Loss=0.3527, Acc=0.8500, Time=0.73s, N=2286
#  Client 2 → Loss=0.3540, Acc=0.8530, Time=0.75s, N=2286
#  Client 3 → Loss=0.3751, Acc=0.8389, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4625, Acc=0.7784
#
# [Model=CNN | Seed=82 | Round=13]
#  Client 0 → Loss=0.3632, Acc=0.8469, Time=0.74s, N=2286
#  Client 1 → Loss=0.3393, Acc=0.8587, Time=0.75s, N=2286
#  Client 2 → Loss=0.3373, Acc=0.8587, Time=0.74s, N=2286
#  Client 3 → Loss=0.3667, Acc=0.8459, Time=0.90s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4633, Acc=0.7810
#
# [Model=CNN | Seed=82 | Round=14]
#  Client 0 → Loss=0.3501, Acc=0.8565, Time=0.74s, N=2286
#  Client 1 → Loss=0.3270, Acc=0.8648, Time=0.72s, N=2286
#  Client 2 → Loss=0.3221, Acc=0.8683, Time=0.75s, N=2286
#  Client 3 → Loss=0.3555, Acc=0.8485, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4736, Acc=0.7758
#
# [Model=CNN | Seed=82 | Round=15]
#  Client 0 → Loss=0.3436, Acc=0.8605, Time=0.79s, N=2286
#  Client 1 → Loss=0.3172, Acc=0.8740, Time=0.73s, N=2286
#  Client 2 → Loss=0.3094, Acc=0.8705, Time=0.74s, N=2286
#  Client 3 → Loss=0.3444, Acc=0.8551, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4757, Acc=0.7771
#
# [Model=CNN | Seed=82 | Round=16]
#  Client 0 → Loss=0.3338, Acc=0.8648, Time=0.74s, N=2286
#  Client 1 → Loss=0.3094, Acc=0.8749, Time=0.74s, N=2286
#  Client 2 → Loss=0.2961, Acc=0.8753, Time=0.72s, N=2286
#  Client 3 → Loss=0.3357, Acc=0.8581, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4841, Acc=0.7806
#
# [Model=CNN | Seed=82 | Round=17]
#  Client 0 → Loss=0.3244, Acc=0.8723, Time=0.93s, N=2286
#  Client 1 → Loss=0.3006, Acc=0.8801, Time=0.73s, N=2286
#  Client 2 → Loss=0.2864, Acc=0.8823, Time=0.73s, N=2286
#  Client 3 → Loss=0.3276, Acc=0.8651, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4923, Acc=0.7788
#
# [Model=CNN | Seed=82 | Round=18]
#  Client 0 → Loss=0.3114, Acc=0.8766, Time=0.73s, N=2286
#  Client 1 → Loss=0.2927, Acc=0.8889, Time=0.71s, N=2286
#  Client 2 → Loss=0.2730, Acc=0.8920, Time=0.71s, N=2286
#  Client 3 → Loss=0.3196, Acc=0.8669, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5239, Acc=0.7653
#
# [Model=CNN | Seed=82 | Round=19]
#  Client 0 → Loss=0.3041, Acc=0.8806, Time=0.73s, N=2286
#  Client 1 → Loss=0.2856, Acc=0.8941, Time=0.77s, N=2286
#  Client 2 → Loss=0.2656, Acc=0.8946, Time=0.74s, N=2286
#  Client 3 → Loss=0.3137, Acc=0.8695, Time=0.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5101, Acc=0.7771
#
# [Model=CNN | Seed=82 | Round=20]
#  Client 0 → Loss=0.2968, Acc=0.8867, Time=0.74s, N=2286
#  Client 1 → Loss=0.2760, Acc=0.8963, Time=0.70s, N=2286
#  Client 2 → Loss=0.2540, Acc=0.9003, Time=0.90s, N=2286
#  Client 3 → Loss=0.3068, Acc=0.8700, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5115, Acc=0.7902
#
# [Model=CNN | Seed=82 | Round=21]
#  Client 0 → Loss=0.2872, Acc=0.8845, Time=0.71s, N=2286
#  Client 1 → Loss=0.2703, Acc=0.8990, Time=0.74s, N=2286
#  Client 2 → Loss=0.2477, Acc=0.9073, Time=0.71s, N=2286
#  Client 3 → Loss=0.3009, Acc=0.8700, Time=0.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5204, Acc=0.7920
#
# [Model=CNN | Seed=82 | Round=22]
#  Client 0 → Loss=0.2810, Acc=0.8915, Time=0.70s, N=2286
#  Client 1 → Loss=0.2616, Acc=0.8998, Time=0.71s, N=2286
#  Client 2 → Loss=0.2416, Acc=0.9073, Time=0.72s, N=2286
#  Client 3 → Loss=0.2987, Acc=0.8722, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5346, Acc=0.7876
#
# [Model=CNN | Seed=82 | Round=23]
#  Client 0 → Loss=0.2738, Acc=0.8933, Time=0.80s, N=2286
#  Client 1 → Loss=0.2507, Acc=0.9042, Time=0.70s, N=2286
#  Client 2 → Loss=0.2329, Acc=0.9108, Time=0.70s, N=2286
#  Client 3 → Loss=0.2952, Acc=0.8726, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5333, Acc=0.7915
#
# [Model=CNN | Seed=82 | Round=24]
#  Client 0 → Loss=0.2706, Acc=0.8946, Time=0.86s, N=2286
#  Client 1 → Loss=0.2505, Acc=0.8998, Time=0.70s, N=2286
#  Client 2 → Loss=0.2245, Acc=0.9108, Time=0.70s, N=2286
#  Client 3 → Loss=0.2906, Acc=0.8783, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5318, Acc=0.7898
#
# [Model=CNN | Seed=82 | Round=25]
#  Client 0 → Loss=0.2624, Acc=0.8990, Time=0.71s, N=2286
#  Client 1 → Loss=0.2417, Acc=0.9051, Time=0.71s, N=2286
#  Client 2 → Loss=0.2235, Acc=0.9151, Time=0.69s, N=2286
#  Client 3 → Loss=0.2877, Acc=0.8778, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5312, Acc=0.7950
#
# [Model=CNN | Seed=82 | Round=26]
#  Client 0 → Loss=0.2556, Acc=0.9007, Time=0.78s, N=2286
#  Client 1 → Loss=0.2346, Acc=0.9086, Time=0.72s, N=2286
#  Client 2 → Loss=0.2150, Acc=0.9199, Time=0.72s, N=2286
#  Client 3 → Loss=0.2844, Acc=0.8778, Time=0.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5399, Acc=0.7920
#
# [Model=CNN | Seed=82 | Round=27]
#  Client 0 → Loss=0.2511, Acc=0.9046, Time=0.72s, N=2286
#  Client 1 → Loss=0.2263, Acc=0.9138, Time=0.86s, N=2286
#  Client 2 → Loss=0.2107, Acc=0.9178, Time=0.72s, N=2286
#  Client 3 → Loss=0.2790, Acc=0.8888, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5572, Acc=0.7863
#
# [Model=CNN | Seed=82 | Round=28]
#  Client 0 → Loss=0.2412, Acc=0.9094, Time=0.76s, N=2286
#  Client 1 → Loss=0.2264, Acc=0.9116, Time=0.71s, N=2286
#  Client 2 → Loss=0.2031, Acc=0.9230, Time=0.70s, N=2286
#  Client 3 → Loss=0.2749, Acc=0.8857, Time=0.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5787, Acc=0.7858
#
# [Model=CNN | Seed=82 | Round=29]
#  Client 0 → Loss=0.2383, Acc=0.9103, Time=0.71s, N=2286
#  Client 1 → Loss=0.2123, Acc=0.9234, Time=0.71s, N=2286
#  Client 2 → Loss=0.1975, Acc=0.9274, Time=0.68s, N=2286
#  Client 3 → Loss=0.2837, Acc=0.8853, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5570, Acc=0.7920
#
# [Model=CNN | Seed=82 | Round=30]
#  Client 0 → Loss=0.2322, Acc=0.9173, Time=0.69s, N=2286
#  Client 1 → Loss=0.2089, Acc=0.9252, Time=0.70s, N=2286
#  Client 2 → Loss=0.1911, Acc=0.9283, Time=0.72s, N=2286
#  Client 3 → Loss=0.2707, Acc=0.8919, Time=0.88s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5992, Acc=0.7841
#  [saved] saved_models\CNN_seed82.keras
#
# ================ MODEL: LSTM ================
#
# ------ SEED 42 ------
#
# [Model=LSTM | Seed=42 | Round=1]
#  Client 0 → Loss=0.5420, Acc=0.7397, Time=4.44s, N=2286
#  Client 1 → Loss=0.5699, Acc=0.7187, Time=3.14s, N=2286
#  Client 2 → Loss=0.5785, Acc=0.7122, Time=3.32s, N=2286
# ...
#    CNN     3     saved_models\CNN_seed3.keras
#    CNN     7     saved_models\CNN_seed7.keras
#    CNN    72    saved_models\CNN_seed72.keras
#    CNN    82    saved_models\CNN_seed82.keras
#   LSTM    42   saved_models\LSTM_seed42.keras
#   LSTM     3    saved_models\LSTM_seed3.keras
#   LSTM     7    saved_models\LSTM_seed7.keras
#   LSTM    72   saved_models\LSTM_seed72.keras
#   LSTM    82   saved_models\LSTM_seed82.keras
# BiLSTM    42 saved_models\BiLSTM_seed42.keras
# BiLSTM     3  saved_models\BiLSTM_seed3.keras
# BiLSTM     7  saved_models\BiLSTM_seed7.keras
# BiLSTM    72 saved_models\BiLSTM_seed72.keras
# BiLSTM    82 saved_models\BiLSTM_seed82.keras
#    GRU    42    saved_models\GRU_seed42.keras
#    GRU     3     saved_models\GRU_seed3.keras
#    GRU     7     saved_models\GRU_seed7.keras
#    GRU    72    saved_models\GRU_seed72.keras
#    GRU    82    saved_models\GRU_seed82.keras
#  BiGRU    42  saved_models\BiGRU_seed42.keras
#  BiGRU     3   saved_models\BiGRU_seed3.keras
#  BiGRU     7   saved_models\BiGRU_seed7.keras
#  BiGRU    72  saved_models\BiGRU_seed72.keras
#  BiGRU    82  saved_models\BiGRU_seed82.keras
#
# OVERALL SUMMARY (all models & seeds pooled):
#                  Metric            Mean ± SD               95% CI
# 0                 Loss      0.3697 ± 0.1664      [0.3045,0.4349]
# 1             Accuracy      0.9088 ± 0.0669      [0.8826,0.9350]
# 2            Precision      0.9497 ± 0.0156      [0.9436,0.9558]
# 3               Recall      0.8657 ± 0.1497      [0.8070,0.9244]
# 4                   F1      0.8968 ± 0.0913      [0.8610,0.9326]
# 5                  MCC      0.8288 ± 0.1113      [0.7852,0.8724]
# 6                  AUC      0.9725 ± 0.0215      [0.9641,0.9809]
# 7          Specificity      0.9519 ± 0.0191      [0.9444,0.9594]
# 8    Training_Time_sec  466.4654 ± 239.0433  [372.7604,560.1704]
# 9   Inference_Time_sec      0.6605 ± 0.3444      [0.5254,0.7955]
# 10       Model_Size_MB      0.5846 ± 0.3965      [0.4292,0.7400]
# 11   Comm_per_round_MB      8.9497 ± 6.2607     [6.4955,11.4039]
# 12       Total_Comm_MB  268.4901 ± 187.8204  [194.8645,342.1157]
#
# PER-CLIENT TEST SUMMARY (mean/std over 5 seeds):
#                Accuracy         Precision          Recall              F1  \
#                   mean     std      mean     std    mean     std    mean
# Model  Client
# BiGRU  0        0.9409  0.0080    0.9390  0.0124  0.9434  0.0189  0.9410
#        1        0.9472  0.0065    0.9488  0.0051  0.9455  0.0118  0.9471
#        2        0.9451  0.0106    0.9494  0.0147  0.9406  0.0158  0.9448
#        3        0.9420  0.0050    0.9432  0.0062  0.9406  0.0102  0.9419
# BiLSTM 0        0.9535  0.0103    0.9527  0.0134  0.9545  0.0126  0.9535
#        1        0.9465  0.0098    0.9487  0.0091  0.9441  0.0160  0.9463
#        2        0.9476  0.0136    0.9532  0.0081  0.9413  0.0236  0.9471
#        3        0.9493  0.0087    0.9510  0.0127  0.9476  0.0102  0.9492
# CNN    0        0.7773  0.0262    0.9796  0.0103  0.5664  0.0542  0.7166
#        1        0.7748  0.0219    0.9666  0.0084  0.5692  0.0427  0.7158
#        2        0.7808  0.0355    0.9771  0.0069  0.5748  0.0702  0.7219
#        3        0.7780  0.0301    0.9764  0.0080  0.5699  0.0635  0.7180
# GRU    0        0.9290  0.0056    0.9313  0.0134  0.9266  0.0089  0.9289
#        1        0.9308  0.0092    0.9320  0.0121  0.9294  0.0076  0.9307
#        2        0.9280  0.0083    0.9329  0.0058  0.9224  0.0184  0.9275
#        3        0.9290  0.0090    0.9324  0.0076  0.9252  0.0152  0.9287
# LSTM   0        0.9455  0.0109    0.9469  0.0156  0.9441  0.0142  0.9454
#        1        0.9462  0.0146    0.9468  0.0147  0.9455  0.0154  0.9461
#        2        0.9416  0.0091    0.9441  0.0163  0.9392  0.0152  0.9415
#        3        0.9437  0.0062    0.9430  0.0111  0.9448  0.0179  0.9437
#
#                           MCC             AUC         Specificity          \
#                   std    mean     std    mean     std        mean     std
# Model  Client
# BiGRU  0       0.0083  0.8821  0.0161  0.9845  0.0049      0.9385  0.0135
#        1       0.0067  0.8945  0.0129  0.9840  0.0034      0.9490  0.0053
#        2       0.0107  0.8904  0.0214  0.9856  0.0034      0.9497  0.0152
#        3       0.0052  0.8840  0.0100  0.9843  0.0030      0.9434  0.0067
# BiLSTM 0       0.0103  0.9071  0.0207  0.9879  0.0051      0.9524  0.0137
#        1       0.0100  0.8931  0.0196  0.9848  0.0033      0.9490  0.0094
#        2       0.0141  0.8954  0.0271  0.9879  0.0031      0.9538  0.0080
#        3       0.0086  0.8987  0.0173  0.9879  0.0040      0.9510  0.0133
# CNN    0       0.0424  0.6119  0.0411  0.9341  0.0154      0.9881  0.0064
#        1       0.0345  0.6030  0.0358  0.9266  0.0123      0.9804  0.0047
#        2       0.0574  0.6164  0.0568  0.9285  0.0171      0.9867  0.0038
#        3       0.0498  0.6118  0.0456  0.9350  0.0112      0.9860  0.0055
# GRU    0       0.0052  0.8582  0.0114  0.9751  0.0061      0.9315  0.0145
#        1       0.0090  0.8616  0.0185  0.9741  0.0061      0.9322  0.0125
#        2       0.0089  0.8562  0.0167  0.9774  0.0065      0.9336  0.0065
#        3       0.0094  0.8582  0.0178  0.9766  0.0023      0.9329  0.0080
# LSTM   0       0.0108  0.8911  0.0219  0.9844  0.0051      0.9469  0.0161
#        1       0.0147  0.8923  0.0293  0.9833  0.0031      0.9469  0.0147
#        2       0.0089  0.8835  0.0183  0.9852  0.0042      0.9441  0.0173
#        3       0.0066  0.8877  0.0123  0.9830  0.0038      0.9427  0.0125
#
#                  Loss
#                  mean     std
# Model  Client
# BiGRU  0       0.3773  0.0640
#        1       0.3884  0.0631
#        2       0.3530  0.0432
#        3       0.3813  0.0590
# BiLSTM 0       0.1998  0.0648
#        1       0.2564  0.0495
#        2       0.2167  0.0458
#        3       0.2170  0.0570
# CNN    0       0.6282  0.1634
#        1       0.6594  0.1117
#        2       0.6398  0.0918
#        3       0.6016  0.1338
# GRU    0       0.4207  0.0757
#        1       0.4385  0.0829
#        2       0.4089  0.0797
#        3       0.4296  0.0417
# LSTM   0       0.1900  0.0414
#        1       0.1950  0.0340
#        2       0.1878  0.0376
#        3       0.2039  0.0283
#
# PAIRWISE PAIRED T-TESTS across 5 seeds (Global Test Set):
#    Metric Model A Model B  Mean A  Mean B   t-stat  p-value  Significant (p<0.05)
# Accuracy     CNN    LSTM  0.7777  0.9442 -15.6829   0.0001                  True
# Accuracy     CNN  BiLSTM  0.7777  0.9492 -16.0162   0.0001                  True
# Accuracy     CNN     GRU  0.7777  0.9292 -13.7896   0.0002                  True
# Accuracy     CNN   BiGRU  0.7777  0.9438 -14.8854   0.0001                  True
# Accuracy    LSTM  BiLSTM  0.9442  0.9492  -1.7495   0.1551                 False
# Accuracy    LSTM     GRU  0.9442  0.9292   5.5614   0.0051                  True
# Accuracy    LSTM   BiGRU  0.9442  0.9438   0.2357   0.8252                 False
# Accuracy  BiLSTM     GRU  0.9492  0.9292   7.4161   0.0018                  True
# Accuracy  BiLSTM   BiGRU  0.9492  0.9438   2.1437   0.0987                 False
# Accuracy     GRU   BiGRU  0.9292  0.9438 -12.0679   0.0003                  True
#       F1     CNN    LSTM  0.7182  0.9442 -12.4302   0.0002                  True
#       F1     CNN  BiLSTM  0.7182  0.9491 -12.7489   0.0002                  True
#       F1     CNN     GRU  0.7182  0.9290 -11.3592   0.0003                  True
#       F1     CNN   BiGRU  0.7182  0.9437 -12.0459   0.0003                  True
#       F1    LSTM  BiLSTM  0.9442  0.9491  -1.7239   0.1598                 False
#       F1    LSTM     GRU  0.9442  0.9290   5.6888   0.0047                  True
#       F1    LSTM   BiGRU  0.9442  0.9437   0.2812   0.7925                 False
#       F1  BiLSTM     GRU  0.9491  0.9290   7.5091   0.0017                  True
#       F1  BiLSTM   BiGRU  0.9491  0.9437   2.0817   0.1058                 False
#       F1     GRU   BiGRU  0.9290  0.9437 -11.7406   0.0003                  True
#      AUC     CNN    LSTM  0.9310  0.9839 -14.1136   0.0001                  True
#      AUC     CNN  BiLSTM  0.9310  0.9871 -13.1859   0.0002                  True
#      AUC     CNN     GRU  0.9310  0.9758 -13.4300   0.0002                  True
#      AUC     CNN   BiGRU  0.9310  0.9846 -11.7248   0.0003                  True
#      AUC    LSTM  BiLSTM  0.9839  0.9871  -4.4669   0.0111                  True
#      AUC    LSTM     GRU  0.9839  0.9758   6.9183   0.0023                  True
#      AUC    LSTM   BiGRU  0.9839  0.9846  -0.6234   0.5668                 False
#      AUC  BiLSTM     GRU  0.9871  0.9758   8.9157   0.0009                  True
#      AUC  BiLSTM   BiGRU  0.9871  0.9846   3.0351   0.0386                  True
#      AUC     GRU   BiGRU  0.9758  0.9846  -6.0467   0.0038                  True
#     Loss     CNN    LSTM  0.6323  0.1942   9.2161   0.0008                  True
#     Loss     CNN  BiLSTM  0.6323  0.2225   9.1282   0.0008                  True
#     Loss     CNN     GRU  0.6323  0.4244   3.5645   0.0235                  True
#     Loss     CNN   BiGRU  0.6323  0.3750   5.8953   0.0041                  True
#     Loss    LSTM  BiLSTM  0.1942  0.2225  -4.0852   0.0150                  True
#     Loss    LSTM     GRU  0.1942  0.4244 -20.2079   0.0000                  True
#     Loss    LSTM   BiGRU  0.1942  0.3750 -19.4605   0.0000                  True
#     Loss  BiLSTM     GRU  0.2225  0.4244 -12.2531   0.0003                  True
#     Loss  BiLSTM   BiGRU  0.2225  0.3750 -14.1326   0.0001                  True
#     Loss     GRU   BiGRU  0.4244  0.3750   2.7369   0.0521                 False
#
# McNEMAR'S TEST — PER SEED (instance-level, Global Test Set):
#   Seed Model A Model B  A right/B wrong  A wrong/B right     stat  p-value  Significant (p<0.05)
#    42     CNN    LSTM               36              404 306.1114   0.0000                  True
#    42     CNN  BiLSTM               40              426 318.0794   0.0000                  True
#    42     CNN     GRU               70              397 227.5717   0.0000                  True
#    42     CNN   BiGRU               53              411 274.6746   0.0000                  True
#    42    LSTM  BiLSTM               33               51   3.4405   0.0636                 False
#    42    LSTM     GRU               73               32  15.2381   0.0001                  True
#    42    LSTM   BiGRU               50               40   0.9000   0.3428                 False
#    42  BiLSTM     GRU               91               32  27.3496   0.0000                  True
#    42  BiLSTM   BiGRU               54               26   9.1125   0.0025                  True
#    42     GRU   BiGRU               35               66   8.9109   0.0028                  True
#     3     CNN    LSTM               65              485 319.2018   0.0000                  True
#     3     CNN  BiLSTM               58              492 340.8891   0.0000                  True
#     3     CNN     GRU               66              472 304.8792   0.0000                  True
#     3     CNN   BiGRU               56              488 341.4724   0.0000                  True
#     3    LSTM  BiLSTM               33               47   2.1125   0.1461                 False
#     3    LSTM     GRU               47               33   2.1125   0.1461                 False
#     3    LSTM   BiGRU               41               53   1.2872   0.2566                 False
#     3  BiLSTM     GRU               64               36   7.2900   0.0069                  True
#     3  BiLSTM   BiGRU               41               39   0.0125   0.9110                 False
#     3     GRU   BiGRU               44               70   5.4825   0.0192                  True
#     7     CNN    LSTM               48              357 234.2321   0.0000                  True
#     7     CNN  BiLSTM               47              353 232.5625   0.0000                  True
#     7     CNN     GRU               67              337 179.1114   0.0000                  True
#     7     CNN   BiGRU               55              358 220.8329   0.0000                  True
#     7    LSTM  BiLSTM               47               44   0.0440   0.8339                 False
#     7    LSTM     GRU               67               28  15.2000   0.0001                  True
#     7    LSTM   BiGRU               42               36   0.3205   0.5713                 False
#     7  BiLSTM     GRU               74               38  10.9375   0.0009                  True
#     7  BiLSTM   BiGRU               45               42   0.0460   0.8302                 False
#     7     GRU   BiGRU               32               65  10.5567   0.0012                  True
#    72     CNN    LSTM               54              502 359.3687   0.0000                  True
#    72     CNN  BiLSTM               53              498 357.7786   0.0000                  True
#    72     CNN     GRU               78              476 284.4928   0.0000                  True
#    72     CNN   BiGRU               61              502 343.8721   0.0000                  True
#    72    LSTM  BiLSTM               40               37   0.0519   0.8197                 False
#    72    LSTM     GRU               81               31  21.4375   0.0000                  True
#    72    LSTM   BiGRU               46               39   0.4235   0.5152                 False
#    72  BiLSTM     GRU               78               31  19.4128   0.0000                  True
#    72  BiLSTM   BiGRU               40               36   0.1184   0.7308                 False
#    72     GRU   BiGRU               38               81  14.8235   0.0001                  True
#    82     CNN    LSTM               65              425 263.0224   0.0000                  True
#    82     CNN  BiLSTM               43              434 318.8679   0.0000                  True
#    82     CNN     GRU               80              412 222.6850   0.0000                  True
#    82     CNN   BiGRU               59              425 275.2583   0.0000                  True
#    82    LSTM  BiLSTM               23               54  11.6883   0.0006                  True
#    82    LSTM     GRU               65               37   7.1471   0.0075                  True
#    82    LSTM   BiGRU               48               54   0.2451   0.6205                 False
#    82  BiLSTM     GRU               79               20  33.9798   0.0000                  True
#    82  BiLSTM   BiGRU               49               24   7.8904   0.0050                  True
#    82     GRU   BiGRU               40               74   9.5526   0.0020                  True
#
# McNEMAR'S TEST — POOLED ACROSS 5 SEEDS (Global Test Set):
#  Model A Model B  A right/B wrong (pooled)  A wrong/B right (pooled)      stat  p-value  Significant (p<0.05)
#     CNN    LSTM                       268                      2173 1485.1356   0.0000                  True
#     CNN  BiLSTM                       241                      2203 1573.4538   0.0000                  True
#     CNN     GRU                       361                      2094 1221.9242   0.0000                  True
#     CNN   BiGRU                       284                      2184 1461.1835   0.0000                  True
#    LSTM  BiLSTM                       176                       233    7.6675   0.0056                  True
#    LSTM     GRU                       333                       161   59.1923   0.0000                  True
#    LSTM   BiGRU                       227                       222    0.0356   0.8503                 False
#  BiLSTM     GRU                       386                       157   95.7348   0.0000                  True
#  BiLSTM   BiGRU                       229                       167    9.3965   0.0022                  True
#     GRU   BiGRU                       189                       356   50.5615   0.0000                  True
