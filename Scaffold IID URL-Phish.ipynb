# %%
import numpy as np, pandas as pd, tensorflow as tf, random, time, os
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import *

from scipy.stats import ttest_rel, chi2, binom
from itertools import combinations

# ================= CONFIG =================
LR=0.001; ROUNDS=30; LOCAL_EPOCHS=2; BATCH=16
CLIENTS=4; SEEDS=[42,3,7,72,82]
MODELS=["CNN","LSTM","BiLSTM","GRU","BiGRU"]
CLIENT_TEST_SIZE=0.2   # local train/test split ratio inside each client
MODEL_SAVE_DIR="saved_models"
os.makedirs(MODEL_SAVE_DIR,exist_ok=True)

# ================= LOAD =================
df=pd.read_csv("Dataset(111k).csv")

# remove text columns like .txt
for col in df.columns:
    if df[col].dtype==object and df[col].astype(str).str.contains(".txt",na=False).any():
        df.drop(columns=[col],inplace=True)

df=df.fillna("unknown")

for col in df.columns:
    if df[col].dtype==object:
        df[col]=LabelEncoder().fit_transform(df[col].astype(str))

X=df.drop("label",axis=1).values
y=df["label"].values

X=StandardScaler().fit_transform(X)


# ================= HELPERS =================
def set_seed(s):
    random.seed(s); np.random.seed(s); tf.random.set_seed(s)

def iid_partition(X,y,K):
    # IID partition: each class shuffled and split evenly across clients
    idx=np.arange(len(y))
    clients=[[] for _ in range(K)]
    for c in np.unique(y):
        c_idx=idx[y==c]; np.random.shuffle(c_idx)
        split=np.array_split(c_idx,K)
        for i in range(K): clients[i].extend(split[i])
    return [(X[c],y[c]) for c in clients]

def format_xy(Xc,model_name):
    return Xc.reshape(len(Xc),-1,1)

def scaffold_aggregate(global_model,c_global,client_weight_deltas,client_c_deltas):
    
    gw=global_model.get_weights()
    new_weights=[]
    for j in range(len(gw)):
        avg_dw=np.mean([dw[j] for dw in client_weight_deltas],axis=0)
        new_weights.append(gw[j]+avg_dw)
    global_model.set_weights(new_weights)

    for j in range(len(c_global)):
        c_global[j]=c_global[j]+np.mean([dc[j] for dc in client_c_deltas],axis=0)

def model_size(model):
    model.save("tmp.h5", include_optimizer=False)
    size=os.path.getsize("tmp.h5")/(1024*1024)
    os.remove("tmp.h5")
    return size

def stats(x,metric):
    x=np.asarray(x,dtype=float)
    x=x[~np.isnan(x)]
    if len(x)==0:
        return np.nan,np.nan,np.nan,np.nan
    mean=np.mean(x); sd=np.std(x)
    ci=1.96*sd/np.sqrt(len(x))
    low,high=mean-ci,mean+ci
    if metric in ["Accuracy","Precision","Recall","F1","AUC","Specificity"]:
        low=max(0,low); high=min(1,high)
    if metric=="MCC":
        low=max(-1,low); high=min(1,high)
    return mean,sd,low,high

def mcnemar_test(y_true_a,y_pred_a,y_true_b,y_pred_b):
   
    y_true_a=np.asarray(y_true_a).flatten()
    y_true_b=np.asarray(y_true_b).flatten()
    assert len(y_true_a)==len(y_true_b), "test sets must be the same size"
    assert np.array_equal(y_true_a,y_true_b), "test sets must match (same seed/instances)"

    correct_a=(np.asarray(y_pred_a).flatten()==y_true_a)
    correct_b=(np.asarray(y_pred_b).flatten()==y_true_b)

    n01=int(np.sum(correct_a & ~correct_b))   # A correct, B wrong
    n10=int(np.sum(~correct_a & correct_b))   # A wrong, B correct
    n=n01+n10

    if n==0:
        return np.nan,1.0,n01,n10
    if n<25:
        p=2*min(binom.cdf(min(n01,n10),n,0.5),0.5)   # exact two-sided binomial
        p=min(p,1.0)
        stat=np.nan
    else:
        stat=((abs(n01-n10)-1)**2)/n                  # continuity-corrected chi-square
        p=1-chi2.cdf(stat,1)
    return stat,p,n01,n10

# ================= MODELS =================
def build(name,shape=None,dim=None):
    if name=="CNN":
        m=Sequential([
            Input(shape),
            Conv1D(64,3,activation="relu"),
            Dropout(0.5),
            Conv1D(32,3,activation="relu"),
            GlobalMaxPooling1D(),
            Dense(32,activation="relu"),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="LSTM":
        m=Sequential([
            Input(shape),
            LSTM(128,return_sequences=True),
            Dropout(0.5),
            LSTM(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiLSTM":
        m=Sequential([
            Input(shape),
            Bidirectional(LSTM(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(LSTM(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="GRU":
        m=Sequential([
            Input(shape),
            GRU(128,return_sequences=True),
            Dropout(0.5),
            GRU(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiGRU":
        m=Sequential([
            Input(shape),
            Bidirectional(GRU(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(GRU(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    m.compile(optimizer=Adam(LR),loss="binary_crossentropy",metrics=["accuracy"])
    return m

# ================= STORAGE =================
rows=[]          # global (union-of-clients) test metrics, per (model, seed)
client_rows=[]   # per-client local test metrics, per (model, seed, client)
results_round={m:{"acc":[],"loss":[],"cm":[]} for m in MODELS}

# per-instance predictions, needed for McNemar's test
y_preds={}        # (model, seed) -> y_pred array (0/1), aligned to y_trues[seed]
y_trues={}        # seed -> y_test_global array (0/1) -- same across all models for a given seed

# ================= TRAIN =================
for model_name in MODELS:
    print(f"\n================ MODEL: {model_name} ================")

    for seed in SEEDS:
        print(f"\n------ SEED {seed} ------")
        set_seed(seed)

        # ---- IID partition of the WHOLE dataset across clients ----
        client_full=iid_partition(X,y,CLIENTS)

        # ---- Each client locally splits its own shard into train/test ----
        client_train,client_test=[],[]
        for cid,(Xc,yc) in enumerate(client_full):
            try:
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,stratify=yc,random_state=seed
                )
            except ValueError:
                # fallback if a client shard doesn't have enough of a class to stratify
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,random_state=seed
                )
            client_train.append((Xc_tr,yc_tr))
            client_test.append((Xc_te,yc_te))

        # ---- Global (centralized) test set = union of all clients' local test shards ----
        X_test_global=np.concatenate([Xc for Xc,_ in client_test],axis=0)
        y_test_global=np.concatenate([yc for _,yc in client_test],axis=0)

        create=lambda:build(model_name,shape=(X.shape[1],1))

        fmt=lambda Xc: format_xy(Xc,model_name)

        global_model=create()

        # ---- SCAFFOLD control variates ----
        c_global=[np.zeros_like(w) for w in global_model.get_weights()]              # global control c
        c_clients=[[np.zeros_like(w) for w in global_model.get_weights()]
                   for _ in range(CLIENTS)]                                          # per-client control c_i

        acc_hist,loss_hist=[],[]
        comm=0
        total_train_time=0.0

        for r in range(ROUNDS):
            print(f"\n[Model={model_name} | Seed={seed} | Round={r+1}]")

            global_weights=global_model.get_weights()
            client_weight_deltas=[]; client_c_deltas=[]; sizes=[]

            for cid,(Xc,yc) in enumerate(client_train):
                m=create()
                m.set_weights(global_weights)
                w_init=[w.copy() for w in global_weights]

                t0=time.time()
                history=m.fit(fmt(Xc),yc,epochs=LOCAL_EPOCHS,batch_size=BATCH,verbose=0)
                t1=time.time()
                total_train_time+=(t1-t0)

                train_loss=history.history["loss"][-1]
                train_acc=history.history["accuracy"][-1]
                print(f" Client {cid} → Loss={train_loss:.4f}, Acc={train_acc:.4f}, Time={t1-t0:.2f}s, N={len(yc)}")

                w_final=m.get_weights()

                # ---- SCAFFOLD correction (post-hoc, applied once after local training) ----
                corrected_weights=[
                    w_final[j]-LR*(c_global[j]-c_clients[cid][j])
                    for j in range(len(w_final))
                ]
                m.set_weights(corrected_weights)

                delta_w=[corrected_weights[j]-w_init[j] for j in range(len(w_init))]

                # ---- update client control variate ----
                delta_c=[
                    c_global[j]-c_clients[cid][j]-(1/(LOCAL_EPOCHS*LR))*delta_w[j]
                    for j in range(len(w_init))
                ]
                c_clients[cid]=[c_clients[cid][j]+delta_c[j] for j in range(len(delta_c))]

                client_weight_deltas.append(delta_w)
                client_c_deltas.append(delta_c)
                sizes.append(len(yc))

            scaffold_aggregate(global_model,c_global,client_weight_deltas,client_c_deltas)

            loss,acc=global_model.evaluate(fmt(X_test_global),y_test_global,verbose=0)

            print(f" >>> GLOBAL (centralized test) → Loss={loss:.4f}, Acc={acc:.4f}")

            acc_hist.append(acc); loss_hist.append(loss)

            # bytes per weight (float32=4 bytes), sent down to each client AND back up from each client
            # (SCAFFOLD also exchanges control variates, same size as the weight vector, each round)
            weight_bytes=sum([w.size for w in global_model.get_weights()])*4
            comm+=weight_bytes*CLIENTS*2*2   # x2 for control variates traveling alongside weights

        # ================= FINAL GLOBAL TEST METRICS =================
        t0=time.time()
        y_prob=global_model.predict(fmt(X_test_global),verbose=0)
        inference_time=time.time()-t0

        y_pred=(y_prob>0.5).astype(int)

        # ---- Save per-instance predictions for McNemar's test ----
        y_preds[(model_name,seed)]=y_pred.flatten()
        if seed not in y_trues:
            y_trues[seed]=y_test_global.flatten()
        else:
            # sanity check: every model must see the identical test set for this seed
            assert np.array_equal(y_trues[seed],y_test_global.flatten()), \
                f"Test set mismatch for seed {seed} — McNemar's test requires identical instances across models."

        tn,fp,fn,tp=confusion_matrix(y_test_global,y_pred).ravel()

        # ---- Save this trained global model to disk ----
        model_path=os.path.join(MODEL_SAVE_DIR,f"{model_name}_seed{seed}.keras")
        global_model.save(model_path)
        print(f" [saved] {model_path}")

        rows.append({
            "Model":model_name,
            "Seed":seed,
            "Loss":log_loss(y_test_global,y_prob),
            "Accuracy":accuracy_score(y_test_global,y_pred),
            "Precision":precision_score(y_test_global,y_pred),
            "Recall":recall_score(y_test_global,y_pred),
            "F1":f1_score(y_test_global,y_pred),
            "MCC":matthews_corrcoef(y_test_global,y_pred),
            "AUC":roc_auc_score(y_test_global,y_prob),
            "Specificity":tn/(tn+fp),
            "Training_Time_sec":total_train_time,
            "Inference_Time_sec":inference_time,
            "Model_Size_MB":model_size(global_model),
            "Comm_per_round_MB":comm/(ROUNDS*1024*1024),
            "Total_Comm_MB":comm/(1024*1024),
            "Saved_Model_Path":model_path
        })

        results_round[model_name]["acc"].append(acc_hist)
        results_round[model_name]["loss"].append(loss_hist)
        results_round[model_name]["cm"].append(confusion_matrix(y_test_global,y_pred))

        # ================= PER-CLIENT LOCAL TEST EVALUATION =================
        for cid,(Xc_te,yc_te) in enumerate(client_test):
            yc_prob=global_model.predict(fmt(Xc_te),verbose=0)
            yc_pred=(yc_prob>0.5).astype(int)

            cm_c=confusion_matrix(yc_te,yc_pred,labels=[0,1])
            tn_c,fp_c,fn_c,tp_c=cm_c.ravel()

            auc_val=roc_auc_score(yc_te,yc_prob) if len(np.unique(yc_te))>1 else np.nan

            client_rows.append({
                "Model":model_name,
                "Seed":seed,
                "Client":cid,
                "N_test":len(yc_te),
                "Loss":log_loss(yc_te,yc_prob,labels=[0,1]),
                "Accuracy":accuracy_score(yc_te,yc_pred),
                "Precision":precision_score(yc_te,yc_pred,zero_division=0),
                "Recall":recall_score(yc_te,yc_pred,zero_division=0),
                "F1":f1_score(yc_te,yc_pred,zero_division=0),
                "MCC":matthews_corrcoef(yc_te,yc_pred),
                "AUC":auc_val,
                "Specificity":(tn_c/(tn_c+fp_c)) if (tn_c+fp_c)>0 else np.nan
            })

# ================= PRINT ALL CONFUSION MATRICES PER SEED (GLOBAL TEST) =================
for m in MODELS:
    print(f"\n=== {m}: Global Test Confusion Matrices per Seed ===")
    for seed,cm in zip(SEEDS,results_round[m]["cm"]):
        print(f"Seed {seed}:\n{cm}")

# ================= MEAN OVER SEEDS (GLOBAL TEST, per-round curves + avg cm) =================
for m in MODELS:
    results_round[m]["acc"]=np.mean(results_round[m]["acc"],axis=0)
    results_round[m]["loss"]=np.mean(results_round[m]["loss"],axis=0)
    results_round[m]["cm"]=np.mean(results_round[m]["cm"],axis=0)

for m in MODELS:
    print(f"\n=== {m} (Global Test, averaged over {len(SEEDS)} seeds) ===")
    print("Confusion Matrix (avg):\n",np.round(results_round[m]["cm"],2))
    print("Accuracy per round:",np.round(results_round[m]["acc"],4))
    print("Loss per round:",np.round(results_round[m]["loss"],4))

# ================= PER-MODEL SUMMARY (ALL METRICS incl. time & comm cost, avg over 5 seeds) =================
results_df=pd.DataFrame(rows)

summary_metrics=["Loss","Accuracy","Precision","Recall","F1","MCC","AUC","Specificity",
                  "Training_Time_sec","Inference_Time_sec","Model_Size_MB",
                  "Comm_per_round_MB","Total_Comm_MB"]

per_model_summary=[]
for m in MODELS:
    sub=results_df[results_df["Model"]==m]
    for metric in summary_metrics:
        mean,sd,low,high=stats(sub[metric],metric)
        per_model_summary.append({
            "Model":m,
            "Metric":metric,
            "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
            "95% CI":f"[{low:.4f}, {high:.4f}]"
        })

per_model_summary_df=pd.DataFrame(per_model_summary)
print(f"\nPER-MODEL SUMMARY (mean ± sd, 95% CI over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_summary_df.to_string(index=False))

# wide pivot: one row per model, one column per metric, "mean [low, high]"
per_model_wide=per_model_summary_df.copy()
per_model_wide["Mean [95% CI]"]=per_model_wide.apply(
    lambda r: r["Mean ± SD"].split(" ± ")[0]+" "+r["95% CI"], axis=1
)
per_model_wide=per_model_wide.pivot(index="Model",columns="Metric",values="Mean [95% CI]")
per_model_wide=per_model_wide[summary_metrics]  # keep original metric order
print(f"\nPER-MODEL SUMMARY, WIDE (mean [95% CI] over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_wide.to_string())

# overall pooled summary (all models & seeds together) kept for reference
overall_summary=[]
for metric in summary_metrics:
    mean,sd,low,high=stats(results_df[metric],metric)
    overall_summary.append({
        "Metric":metric,
        "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
        "95% CI":f"[{low:.4f},{high:.4f}]"
    })
overall_summary_df=pd.DataFrame(overall_summary)
print(f"\nSAVED MODELS ({len(results_df)} total, in '{MODEL_SAVE_DIR}/'):\n",
      results_df[["Model","Seed","Saved_Model_Path"]].to_string(index=False))
print("\nOVERALL SUMMARY (all models & seeds pooled):\n",overall_summary_df)

# ================= PER-CLIENT TEST SUMMARY, averaged over 5 seeds =================
client_df=pd.DataFrame(client_rows)
client_metrics=["Accuracy","Precision","Recall","F1","MCC","AUC","Specificity","Loss"]

per_client_summary=(
    client_df.groupby(["Model","Client"])[client_metrics]
    .agg(["mean","std"])
    .round(4)
)
print(f"\nPER-CLIENT TEST SUMMARY (mean/std over {len(SEEDS)} seeds):\n",per_client_summary)

# ================= PAIRWISE PAIRED T-TESTS ACROSS MODELS (same seeds) =================
paired_test_metrics=["Accuracy","F1","AUC","Loss"]

pairwise_rows=[]
for metric in paired_test_metrics:
    for m1,m2 in combinations(MODELS,2):
        a=results_df[results_df["Model"]==m1].sort_values("Seed")[metric].values
        b=results_df[results_df["Model"]==m2].sort_values("Seed")[metric].values
        t_stat,p_val=ttest_rel(a,b)
        pairwise_rows.append({
            "Metric":metric,"Model A":m1,"Model B":m2,
            "Mean A":round(a.mean(),4),"Mean B":round(b.mean(),4),
            "t-stat":round(t_stat,4),"p-value":round(p_val,4),
            "Significant (p<0.05)":p_val<0.05
        })

pairwise_df=pd.DataFrame(pairwise_rows)
print(f"\nPAIRWISE PAIRED T-TESTS across {len(SEEDS)} seeds (Global Test Set):\n",
      pairwise_df.to_string(index=False))

# ================= McNEMAR'S TEST (per-instance, per seed + pooled across seeds) =================
mcnemar_per_seed_rows=[]
for seed in SEEDS:
    y_true=y_trues[seed]
    for m1,m2 in combinations(MODELS,2):
        stat,p,n01,n10=mcnemar_test(y_true,y_preds[(m1,seed)],y_true,y_preds[(m2,seed)])
        mcnemar_per_seed_rows.append({
            "Seed":seed,"Model A":m1,"Model B":m2,
            "A right/B wrong":n01,"A wrong/B right":n10,
            "stat":round(stat,4) if not np.isnan(stat) else "exact",
            "p-value":round(p,4),"Significant (p<0.05)":p<0.05
        })

mcnemar_per_seed_df=pd.DataFrame(mcnemar_per_seed_rows)
print(f"\nMcNEMAR'S TEST — PER SEED (instance-level, Global Test Set):\n",
      mcnemar_per_seed_df.to_string(index=False))

# pooled version: sum discordant counts across all 5 seeds (more statistical power)
mcnemar_pooled_rows=[]
for m1,m2 in combinations(MODELS,2):
    n01_total=0; n10_total=0
    for seed in SEEDS:
        y_true=y_trues[seed]
        correct_a=(y_preds[(m1,seed)]==y_true)
        correct_b=(y_preds[(m2,seed)]==y_true)
        n01_total+=int(np.sum(correct_a & ~correct_b))
        n10_total+=int(np.sum(~correct_a & correct_b))
    n=n01_total+n10_total
    if n==0:
        stat,p=np.nan,1.0
    elif n<25:
        p=min(2*min(binom.cdf(min(n01_total,n10_total),n,0.5),0.5),1.0); stat=np.nan
    else:
        stat=((abs(n01_total-n10_total)-1)**2)/n
        p=1-chi2.cdf(stat,1)
    mcnemar_pooled_rows.append({
        "Model A":m1,"Model B":m2,
        "A right/B wrong (pooled)":n01_total,"A wrong/B right (pooled)":n10_total,
        "stat":round(stat,4) if not np.isnan(stat) else "exact",
        "p-value":round(p,4),"Significant (p<0.05)":p<0.05
    })

mcnemar_pooled_df=pd.DataFrame(mcnemar_pooled_rows)
print(f"\nMcNEMAR'S TEST — POOLED ACROSS {len(SEEDS)} SEEDS (Global Test Set):\n",
      mcnemar_pooled_df.to_string(index=False))

# ================= PLOTS =================
rounds=np.arange(1,ROUNDS+1)

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["acc"],label=m)
plt.title("Accuracy vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Accuracy")
plt.legend(); plt.grid(); plt.show()

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["loss"],label=m)
plt.title("Loss vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Loss")
plt.legend(); plt.grid(); plt.show()
# Out:
# ================ MODEL: CNN ================
#
# ------ SEED 42 ------
#
# [Model=CNN | Seed=42 | Round=1]
#  Client 0 → Loss=0.2529, Acc=0.9031, Time=5.81s, N=23320
#  Client 1 → Loss=0.2525, Acc=0.9047, Time=5.78s, N=23320
#  Client 2 → Loss=0.2541, Acc=0.9057, Time=5.71s, N=23320
#  Client 3 → Loss=0.2629, Acc=0.9027, Time=5.63s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.2796, Acc=0.8664
#
# [Model=CNN | Seed=42 | Round=2]
#  Client 0 → Loss=0.1951, Acc=0.9276, Time=5.70s, N=23320
#  Client 1 → Loss=0.1948, Acc=0.9259, Time=5.70s, N=23320
#  Client 2 → Loss=0.1936, Acc=0.9278, Time=5.95s, N=23320
#  Client 3 → Loss=0.1943, Acc=0.9261, Time=5.59s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1479, Acc=0.9504
#
# [Model=CNN | Seed=42 | Round=3]
#  Client 0 → Loss=0.1665, Acc=0.9382, Time=5.67s, N=23320
#  Client 1 → Loss=0.1672, Acc=0.9365, Time=5.57s, N=23320
#  Client 2 → Loss=0.1660, Acc=0.9377, Time=5.63s, N=23320
#  Client 3 → Loss=0.1686, Acc=0.9382, Time=5.57s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1285, Acc=0.9569
#
# [Model=CNN | Seed=42 | Round=4]
#  Client 0 → Loss=0.1521, Acc=0.9431, Time=5.38s, N=23320
#  Client 1 → Loss=0.1526, Acc=0.9434, Time=5.60s, N=23320
#  Client 2 → Loss=0.1522, Acc=0.9434, Time=5.40s, N=23320
#  Client 3 → Loss=0.1526, Acc=0.9450, Time=5.45s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1172, Acc=0.9594
#
# [Model=CNN | Seed=42 | Round=5]
#  Client 0 → Loss=0.1431, Acc=0.9463, Time=5.30s, N=23320
#  Client 1 → Loss=0.1430, Acc=0.9475, Time=5.38s, N=23320
#  Client 2 → Loss=0.1426, Acc=0.9474, Time=5.33s, N=23320
#  Client 3 → Loss=0.1449, Acc=0.9471, Time=5.91s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1108, Acc=0.9599
#
# [Model=CNN | Seed=42 | Round=6]
#  Client 0 → Loss=0.1359, Acc=0.9501, Time=5.84s, N=23320
#  Client 1 → Loss=0.1369, Acc=0.9499, Time=5.68s, N=23320
#  Client 2 → Loss=0.1356, Acc=0.9504, Time=5.28s, N=23320
#  Client 3 → Loss=0.1368, Acc=0.9508, Time=5.75s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1068, Acc=0.9617
#
# [Model=CNN | Seed=42 | Round=7]
#  Client 0 → Loss=0.1310, Acc=0.9526, Time=5.42s, N=23320
#  Client 1 → Loss=0.1311, Acc=0.9526, Time=5.47s, N=23320
#  Client 2 → Loss=0.1306, Acc=0.9530, Time=5.48s, N=23320
#  Client 3 → Loss=0.1313, Acc=0.9532, Time=5.81s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1038, Acc=0.9639
#
# [Model=CNN | Seed=42 | Round=8]
#  Client 0 → Loss=0.1278, Acc=0.9533, Time=5.82s, N=23320
#  Client 1 → Loss=0.1267, Acc=0.9533, Time=5.81s, N=23320
#  Client 2 → Loss=0.1255, Acc=0.9534, Time=5.35s, N=23320
#  Client 3 → Loss=0.1263, Acc=0.9536, Time=5.48s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1009, Acc=0.9648
#
# [Model=CNN | Seed=42 | Round=9]
#  Client 0 → Loss=0.1254, Acc=0.9554, Time=5.39s, N=23320
#  Client 1 → Loss=0.1240, Acc=0.9540, Time=5.40s, N=23320
#  Client 2 → Loss=0.1231, Acc=0.9547, Time=5.27s, N=23320
#  Client 3 → Loss=0.1221, Acc=0.9555, Time=5.56s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0995, Acc=0.9655
#
# [Model=CNN | Seed=42 | Round=10]
#  Client 0 → Loss=0.1217, Acc=0.9567, Time=5.48s, N=23320
#  Client 1 → Loss=0.1226, Acc=0.9549, Time=5.35s, N=23320
#  Client 2 → Loss=0.1197, Acc=0.9568, Time=5.57s, N=23320
#  Client 3 → Loss=0.1206, Acc=0.9562, Time=5.60s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0993, Acc=0.9656
#
# [Model=CNN | Seed=42 | Round=11]
#  Client 0 → Loss=0.1201, Acc=0.9572, Time=5.58s, N=23320
#  Client 1 → Loss=0.1188, Acc=0.9560, Time=5.59s, N=23320
#  Client 2 → Loss=0.1166, Acc=0.9577, Time=5.60s, N=23320
#  Client 3 → Loss=0.1171, Acc=0.9577, Time=5.45s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0981, Acc=0.9663
#
# [Model=CNN | Seed=42 | Round=12]
#  Client 0 → Loss=0.1167, Acc=0.9581, Time=5.67s, N=23320
#  Client 1 → Loss=0.1168, Acc=0.9570, Time=5.51s, N=23320
#  Client 2 → Loss=0.1130, Acc=0.9589, Time=5.20s, N=23320
#  Client 3 → Loss=0.1169, Acc=0.9579, Time=5.17s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0968, Acc=0.9674
#
# [Model=CNN | Seed=42 | Round=13]
#  Client 0 → Loss=0.1155, Acc=0.9588, Time=5.60s, N=23320
#  Client 1 → Loss=0.1130, Acc=0.9584, Time=5.88s, N=23320
#  Client 2 → Loss=0.1107, Acc=0.9597, Time=5.95s, N=23320
#  Client 3 → Loss=0.1145, Acc=0.9590, Time=5.61s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0965, Acc=0.9673
#
# [Model=CNN | Seed=42 | Round=14]
#  Client 0 → Loss=0.1140, Acc=0.9587, Time=5.60s, N=23320
#  Client 1 → Loss=0.1125, Acc=0.9593, Time=5.54s, N=23320
#  Client 2 → Loss=0.1094, Acc=0.9606, Time=5.41s, N=23320
#  Client 3 → Loss=0.1116, Acc=0.9598, Time=5.36s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0963, Acc=0.9673
#
# [Model=CNN | Seed=42 | Round=15]
#  Client 0 → Loss=0.1122, Acc=0.9598, Time=5.33s, N=23320
#  Client 1 → Loss=0.1110, Acc=0.9590, Time=5.25s, N=23320
#  Client 2 → Loss=0.1070, Acc=0.9612, Time=5.24s, N=23320
#  Client 3 → Loss=0.1110, Acc=0.9603, Time=5.36s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0972, Acc=0.9686
#
# [Model=CNN | Seed=42 | Round=16]
#  Client 0 → Loss=0.1095, Acc=0.9596, Time=5.41s, N=23320
#  Client 1 → Loss=0.1100, Acc=0.9595, Time=5.37s, N=23320
#  Client 2 → Loss=0.1051, Acc=0.9614, Time=5.42s, N=23320
#  Client 3 → Loss=0.1089, Acc=0.9611, Time=5.46s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0953, Acc=0.9678
#
# [Model=CNN | Seed=42 | Round=17]
#  Client 0 → Loss=0.1105, Acc=0.9608, Time=5.70s, N=23320
#  Client 1 → Loss=0.1096, Acc=0.9596, Time=5.48s, N=23320
#  Client 2 → Loss=0.1038, Acc=0.9620, Time=5.47s, N=23320
#  Client 3 → Loss=0.1077, Acc=0.9615, Time=5.50s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0958, Acc=0.9689
#
# [Model=CNN | Seed=42 | Round=18]
#  Client 0 → Loss=0.1069, Acc=0.9614, Time=5.45s, N=23320
#  Client 1 → Loss=0.1081, Acc=0.9587, Time=5.50s, N=23320
#  Client 2 → Loss=0.1038, Acc=0.9616, Time=5.58s, N=23320
#  Client 3 → Loss=0.1076, Acc=0.9622, Time=5.61s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0963, Acc=0.9687
#
# [Model=CNN | Seed=42 | Round=19]
#  Client 0 → Loss=0.1058, Acc=0.9617, Time=5.54s, N=23320
#  Client 1 → Loss=0.1067, Acc=0.9600, Time=5.50s, N=23320
#  Client 2 → Loss=0.1039, Acc=0.9630, Time=5.66s, N=23320
#  Client 3 → Loss=0.1069, Acc=0.9626, Time=5.56s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0960, Acc=0.9691
#
# [Model=CNN | Seed=42 | Round=20]
#  Client 0 → Loss=0.1069, Acc=0.9623, Time=5.47s, N=23320
#  Client 1 → Loss=0.1056, Acc=0.9605, Time=5.60s, N=23320
#  Client 2 → Loss=0.1028, Acc=0.9631, Time=5.47s, N=23320
#  Client 3 → Loss=0.1063, Acc=0.9623, Time=5.44s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0963, Acc=0.9681
#
# [Model=CNN | Seed=42 | Round=21]
#  Client 0 → Loss=0.1056, Acc=0.9627, Time=5.48s, N=23320
#  Client 1 → Loss=0.1049, Acc=0.9609, Time=5.54s, N=23320
#  Client 2 → Loss=0.1012, Acc=0.9633, Time=5.37s, N=23320
#  Client 3 → Loss=0.1055, Acc=0.9630, Time=5.56s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0968, Acc=0.9682
#
# [Model=CNN | Seed=42 | Round=22]
#  Client 0 → Loss=0.1054, Acc=0.9621, Time=5.29s, N=23320
#  Client 1 → Loss=0.1035, Acc=0.9612, Time=5.38s, N=23320
#  Client 2 → Loss=0.1017, Acc=0.9624, Time=5.49s, N=23320
#  Client 3 → Loss=0.1058, Acc=0.9623, Time=5.52s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0985, Acc=0.9678
#
# [Model=CNN | Seed=42 | Round=23]
#  Client 0 → Loss=0.1029, Acc=0.9639, Time=5.45s, N=23320
#  Client 1 → Loss=0.1030, Acc=0.9617, Time=5.58s, N=23320
#  Client 2 → Loss=0.0973, Acc=0.9653, Time=5.67s, N=23320
#  Client 3 → Loss=0.1039, Acc=0.9630, Time=5.50s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0981, Acc=0.9686
#
# [Model=CNN | Seed=42 | Round=24]
#  Client 0 → Loss=0.1033, Acc=0.9630, Time=5.40s, N=23320
#  Client 1 → Loss=0.1023, Acc=0.9623, Time=5.38s, N=23320
#  Client 2 → Loss=0.0988, Acc=0.9647, Time=5.27s, N=23320
#  Client 3 → Loss=0.1034, Acc=0.9637, Time=5.25s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0971, Acc=0.9686
#
# [Model=CNN | Seed=42 | Round=25]
#  Client 0 → Loss=0.1016, Acc=0.9645, Time=5.29s, N=23320
#  Client 1 → Loss=0.1022, Acc=0.9618, Time=5.26s, N=23320
#  Client 2 → Loss=0.0985, Acc=0.9646, Time=5.30s, N=23320
#  Client 3 → Loss=0.1024, Acc=0.9645, Time=5.24s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0953, Acc=0.9679
#
# [Model=CNN | Seed=42 | Round=26]
#  Client 0 → Loss=0.1011, Acc=0.9632, Time=5.22s, N=23320
#  Client 1 → Loss=0.1000, Acc=0.9620, Time=5.32s, N=23320
#  Client 2 → Loss=0.0972, Acc=0.9665, Time=5.47s, N=23320
#  Client 3 → Loss=0.1029, Acc=0.9632, Time=5.63s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0976, Acc=0.9681
#
# [Model=CNN | Seed=42 | Round=27]
#  Client 0 → Loss=0.1002, Acc=0.9645, Time=5.39s, N=23320
#  Client 1 → Loss=0.1000, Acc=0.9631, Time=5.48s, N=23320
#  Client 2 → Loss=0.0982, Acc=0.9659, Time=5.35s, N=23320
#  Client 3 → Loss=0.1028, Acc=0.9641, Time=5.29s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0983, Acc=0.9680
#
# [Model=CNN | Seed=42 | Round=28]
#  Client 0 → Loss=0.0992, Acc=0.9648, Time=5.25s, N=23320
#  Client 1 → Loss=0.0995, Acc=0.9620, Time=5.41s, N=23320
#  Client 2 → Loss=0.0949, Acc=0.9660, Time=5.27s, N=23320
#  Client 3 → Loss=0.1010, Acc=0.9639, Time=5.28s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0995, Acc=0.9678
#
# [Model=CNN | Seed=42 | Round=29]
#  Client 0 → Loss=0.0991, Acc=0.9645, Time=5.68s, N=23320
#  Client 1 → Loss=0.0984, Acc=0.9634, Time=5.92s, N=23320
#  Client 2 → Loss=0.0949, Acc=0.9663, Time=5.81s, N=23320
#  Client 3 → Loss=0.1007, Acc=0.9643, Time=5.49s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0994, Acc=0.9681
#
# [Model=CNN | Seed=42 | Round=30]
#  Client 0 → Loss=0.0988, Acc=0.9650, Time=5.57s, N=23320
#  Client 1 → Loss=0.0989, Acc=0.9634, Time=5.37s, N=23320
#  Client 2 → Loss=0.0960, Acc=0.9671, Time=5.22s, N=23320
#  Client 3 → Loss=0.1012, Acc=0.9637, Time=5.21s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0981, Acc=0.9684
#  [saved] saved_models\CNN_seed42.keras
#
# ------ SEED 3 ------
#
# [Model=CNN | Seed=3 | Round=1]
#  Client 0 → Loss=0.2491, Acc=0.9037, Time=5.90s, N=23320
#  Client 1 → Loss=0.2531, Acc=0.9051, Time=6.05s, N=23320
#  Client 2 → Loss=0.2528, Acc=0.8988, Time=6.50s, N=23320
#  Client 3 → Loss=0.2538, Acc=0.8982, Time=5.83s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.2220, Acc=0.9088
#
# [Model=CNN | Seed=3 | Round=2]
#  Client 0 → Loss=0.2002, Acc=0.9216, Time=5.61s, N=23320
#  Client 1 → Loss=0.2005, Acc=0.9256, Time=5.47s, N=23320
#  Client 2 → Loss=0.1986, Acc=0.9221, Time=5.36s, N=23320
#  Client 3 → Loss=0.2049, Acc=0.9186, Time=5.36s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1510, Acc=0.9458
#
# [Model=CNN | Seed=3 | Round=3]
#  Client 0 → Loss=0.1764, Acc=0.9329, Time=5.52s, N=23320
#  Client 1 → Loss=0.1750, Acc=0.9366, Time=5.61s, N=23320
#  Client 2 → Loss=0.1716, Acc=0.9338, Time=5.60s, N=23320
#  Client 3 → Loss=0.1771, Acc=0.9325, Time=5.78s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1357, Acc=0.9518
#
# [Model=CNN | Seed=3 | Round=4]
#  Client 0 → Loss=0.1606, Acc=0.9402, Time=5.54s, N=23320
#  Client 1 → Loss=0.1624, Acc=0.9416, Time=5.49s, N=23320
#  Client 2 → Loss=0.1573, Acc=0.9406, Time=5.59s, N=23320
#  Client 3 → Loss=0.1630, Acc=0.9395, Time=5.67s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1274, Acc=0.9572
#
# [Model=CNN | Seed=3 | Round=5]
#  Client 0 → Loss=0.1502, Acc=0.9436, Time=5.75s, N=23320
#  Client 1 → Loss=0.1515, Acc=0.9465, Time=5.50s, N=23320
#  Client 2 → Loss=0.1483, Acc=0.9442, Time=5.71s, N=23320
#  Client 3 → Loss=0.1528, Acc=0.9446, Time=5.40s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1201, Acc=0.9597
#
# [Model=CNN | Seed=3 | Round=6]
#  Client 0 → Loss=0.1434, Acc=0.9462, Time=5.49s, N=23320
#  Client 1 → Loss=0.1447, Acc=0.9484, Time=5.20s, N=23320
#  Client 2 → Loss=0.1411, Acc=0.9471, Time=5.18s, N=23320
#  Client 3 → Loss=0.1462, Acc=0.9471, Time=5.22s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1164, Acc=0.9618
#
# [Model=CNN | Seed=3 | Round=7]
#  Client 0 → Loss=0.1366, Acc=0.9490, Time=5.21s, N=23320
#  Client 1 → Loss=0.1405, Acc=0.9491, Time=5.26s, N=23320
#  Client 2 → Loss=0.1355, Acc=0.9494, Time=5.10s, N=23320
#  Client 3 → Loss=0.1398, Acc=0.9485, Time=5.17s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1159, Acc=0.9618
#
# [Model=CNN | Seed=3 | Round=8]
#  Client 0 → Loss=0.1322, Acc=0.9497, Time=5.14s, N=23320
#  Client 1 → Loss=0.1359, Acc=0.9512, Time=5.84s, N=23320
#  Client 2 → Loss=0.1313, Acc=0.9516, Time=5.49s, N=23320
#  Client 3 → Loss=0.1361, Acc=0.9504, Time=5.45s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1114, Acc=0.9639
#
# [Model=CNN | Seed=3 | Round=9]
#  Client 0 → Loss=0.1292, Acc=0.9516, Time=5.90s, N=23320
#  Client 1 → Loss=0.1321, Acc=0.9527, Time=5.51s, N=23320
#  Client 2 → Loss=0.1278, Acc=0.9516, Time=5.49s, N=23320
#  Client 3 → Loss=0.1321, Acc=0.9518, Time=5.46s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1078, Acc=0.9648
#
# [Model=CNN | Seed=3 | Round=10]
#  Client 0 → Loss=0.1251, Acc=0.9522, Time=5.45s, N=23320
#  Client 1 → Loss=0.1293, Acc=0.9532, Time=5.40s, N=23320
#  Client 2 → Loss=0.1247, Acc=0.9537, Time=5.26s, N=23320
#  Client 3 → Loss=0.1290, Acc=0.9536, Time=5.28s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1057, Acc=0.9653
#
# [Model=CNN | Seed=3 | Round=11]
#  Client 0 → Loss=0.1231, Acc=0.9531, Time=5.57s, N=23320
#  Client 1 → Loss=0.1260, Acc=0.9543, Time=5.36s, N=23320
#  Client 2 → Loss=0.1230, Acc=0.9550, Time=5.29s, N=23320
#  Client 3 → Loss=0.1253, Acc=0.9546, Time=5.34s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1054, Acc=0.9647
#
# [Model=CNN | Seed=3 | Round=12]
#  Client 0 → Loss=0.1195, Acc=0.9545, Time=5.34s, N=23320
#  Client 1 → Loss=0.1235, Acc=0.9559, Time=5.51s, N=23320
#  Client 2 → Loss=0.1204, Acc=0.9562, Time=5.30s, N=23320
#  Client 3 → Loss=0.1238, Acc=0.9551, Time=5.35s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1048, Acc=0.9651
#
# [Model=CNN | Seed=3 | Round=13]
#  Client 0 → Loss=0.1176, Acc=0.9550, Time=5.32s, N=23320
#  Client 1 → Loss=0.1205, Acc=0.9567, Time=5.28s, N=23320
#  Client 2 → Loss=0.1189, Acc=0.9553, Time=5.41s, N=23320
#  Client 3 → Loss=0.1213, Acc=0.9557, Time=5.38s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1041, Acc=0.9652
#
# [Model=CNN | Seed=3 | Round=14]
#  Client 0 → Loss=0.1164, Acc=0.9554, Time=5.38s, N=23320
#  Client 1 → Loss=0.1200, Acc=0.9563, Time=5.38s, N=23320
#  Client 2 → Loss=0.1176, Acc=0.9571, Time=5.30s, N=23320
#  Client 3 → Loss=0.1205, Acc=0.9563, Time=5.51s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1038, Acc=0.9661
#
# [Model=CNN | Seed=3 | Round=15]
#  Client 0 → Loss=0.1139, Acc=0.9571, Time=5.78s, N=23320
#  Client 1 → Loss=0.1195, Acc=0.9575, Time=5.67s, N=23320
#  Client 2 → Loss=0.1159, Acc=0.9581, Time=5.76s, N=23320
#  Client 3 → Loss=0.1176, Acc=0.9572, Time=6.13s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1020, Acc=0.9656
#
# [Model=CNN | Seed=3 | Round=16]
#  Client 0 → Loss=0.1132, Acc=0.9567, Time=5.44s, N=23320
#  Client 1 → Loss=0.1179, Acc=0.9567, Time=5.24s, N=23320
#  Client 2 → Loss=0.1162, Acc=0.9578, Time=5.27s, N=23320
#  Client 3 → Loss=0.1169, Acc=0.9578, Time=5.22s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1018, Acc=0.9656
#
# [Model=CNN | Seed=3 | Round=17]
#  Client 0 → Loss=0.1113, Acc=0.9564, Time=5.28s, N=23320
#  Client 1 → Loss=0.1167, Acc=0.9580, Time=5.35s, N=23320
#  Client 2 → Loss=0.1147, Acc=0.9581, Time=5.36s, N=23320
#  Client 3 → Loss=0.1163, Acc=0.9575, Time=5.45s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1031, Acc=0.9655
#
# [Model=CNN | Seed=3 | Round=18]
#  Client 0 → Loss=0.1104, Acc=0.9583, Time=5.44s, N=23320
#  Client 1 → Loss=0.1150, Acc=0.9581, Time=5.40s, N=23320
#  Client 2 → Loss=0.1148, Acc=0.9581, Time=5.40s, N=23320
#  Client 3 → Loss=0.1154, Acc=0.9580, Time=5.40s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1024, Acc=0.9659
#
# [Model=CNN | Seed=3 | Round=19]
#  Client 0 → Loss=0.1096, Acc=0.9584, Time=5.47s, N=23320
#  Client 1 → Loss=0.1146, Acc=0.9589, Time=5.49s, N=23320
#  Client 2 → Loss=0.1125, Acc=0.9591, Time=5.47s, N=23320
#  Client 3 → Loss=0.1134, Acc=0.9585, Time=5.51s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1016, Acc=0.9660
#
# [Model=CNN | Seed=3 | Round=20]
#  Client 0 → Loss=0.1083, Acc=0.9586, Time=5.68s, N=23320
#  Client 1 → Loss=0.1134, Acc=0.9584, Time=5.87s, N=23320
#  Client 2 → Loss=0.1122, Acc=0.9594, Time=5.91s, N=23320
#  Client 3 → Loss=0.1125, Acc=0.9592, Time=6.06s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1029, Acc=0.9657
#
# [Model=CNN | Seed=3 | Round=21]
#  Client 0 → Loss=0.1079, Acc=0.9584, Time=5.77s, N=23320
#  Client 1 → Loss=0.1112, Acc=0.9597, Time=5.58s, N=23320
#  Client 2 → Loss=0.1136, Acc=0.9590, Time=5.44s, N=23320
#  Client 3 → Loss=0.1104, Acc=0.9594, Time=5.41s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1026, Acc=0.9658
#
# [Model=CNN | Seed=3 | Round=22]
#  Client 0 → Loss=0.1070, Acc=0.9595, Time=5.44s, N=23320
#  Client 1 → Loss=0.1105, Acc=0.9603, Time=5.30s, N=23320
#  Client 2 → Loss=0.1113, Acc=0.9592, Time=5.23s, N=23320
#  Client 3 → Loss=0.1094, Acc=0.9602, Time=5.35s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1045, Acc=0.9652
#
# [Model=CNN | Seed=3 | Round=23]
#  Client 0 → Loss=0.1065, Acc=0.9600, Time=5.36s, N=23320
#  Client 1 → Loss=0.1094, Acc=0.9601, Time=5.33s, N=23320
#  Client 2 → Loss=0.1095, Acc=0.9596, Time=5.30s, N=23320
#  Client 3 → Loss=0.1109, Acc=0.9594, Time=5.23s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1044, Acc=0.9650
#
# [Model=CNN | Seed=3 | Round=24]
#  Client 0 → Loss=0.1049, Acc=0.9596, Time=5.27s, N=23320
#  Client 1 → Loss=0.1095, Acc=0.9595, Time=5.41s, N=23320
#  Client 2 → Loss=0.1094, Acc=0.9598, Time=5.39s, N=23320
#  Client 3 → Loss=0.1084, Acc=0.9592, Time=5.58s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1086, Acc=0.9638
#
# [Model=CNN | Seed=3 | Round=25]
#  Client 0 → Loss=0.1052, Acc=0.9598, Time=5.52s, N=23320
#  Client 1 → Loss=0.1083, Acc=0.9603, Time=5.50s, N=23320
#  Client 2 → Loss=0.1074, Acc=0.9611, Time=5.54s, N=23320
#  Client 3 → Loss=0.1084, Acc=0.9597, Time=5.61s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1060, Acc=0.9649
#
# [Model=CNN | Seed=3 | Round=26]
#  Client 0 → Loss=0.1045, Acc=0.9607, Time=5.56s, N=23320
#  Client 1 → Loss=0.1081, Acc=0.9607, Time=5.61s, N=23320
#  Client 2 → Loss=0.1076, Acc=0.9603, Time=5.60s, N=23320
#  Client 3 → Loss=0.1082, Acc=0.9596, Time=5.38s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1058, Acc=0.9647
#
# [Model=CNN | Seed=3 | Round=27]
#  Client 0 → Loss=0.1058, Acc=0.9611, Time=5.36s, N=23320
#  Client 1 → Loss=0.1072, Acc=0.9610, Time=5.64s, N=23320
#  Client 2 → Loss=0.1064, Acc=0.9603, Time=5.40s, N=23320
#  Client 3 → Loss=0.1065, Acc=0.9608, Time=5.37s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1077, Acc=0.9635
#
# [Model=CNN | Seed=3 | Round=28]
#  Client 0 → Loss=0.1026, Acc=0.9612, Time=5.51s, N=23320
#  Client 1 → Loss=0.1079, Acc=0.9603, Time=5.48s, N=23320
#  Client 2 → Loss=0.1060, Acc=0.9611, Time=5.71s, N=23320
#  Client 3 → Loss=0.1060, Acc=0.9605, Time=5.49s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1043, Acc=0.9655
#
# [Model=CNN | Seed=3 | Round=29]
#  Client 0 → Loss=0.1015, Acc=0.9615, Time=5.42s, N=23320
#  Client 1 → Loss=0.1072, Acc=0.9606, Time=5.49s, N=23320
#  Client 2 → Loss=0.1060, Acc=0.9609, Time=5.44s, N=23320
#  Client 3 → Loss=0.1072, Acc=0.9601, Time=5.41s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1035, Acc=0.9657
#
# [Model=CNN | Seed=3 | Round=30]
#  Client 0 → Loss=0.1003, Acc=0.9612, Time=5.44s, N=23320
#  Client 1 → Loss=0.1063, Acc=0.9608, Time=5.38s, N=23320
#  Client 2 → Loss=0.1046, Acc=0.9612, Time=5.86s, N=23320
#  Client 3 → Loss=0.1058, Acc=0.9607, Time=5.85s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1068, Acc=0.9647
#  [saved] saved_models\CNN_seed3.keras
#
# ------ SEED 7 ------
#
# [Model=CNN | Seed=7 | Round=1]
#  Client 0 → Loss=0.2534, Acc=0.9078, Time=5.72s, N=23320
#  Client 1 → Loss=0.2554, Acc=0.9050, Time=5.71s, N=23320
#  Client 2 → Loss=0.2590, Acc=0.9057, Time=5.57s, N=23320
#  Client 3 → Loss=0.2570, Acc=0.9041, Time=5.42s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.2200, Acc=0.9151
#
# [Model=CNN | Seed=7 | Round=2]
#  Client 0 → Loss=0.2015, Acc=0.9240, Time=5.40s, N=23320
#  Client 1 → Loss=0.2013, Acc=0.9242, Time=5.25s, N=23320
#  Client 2 → Loss=0.2083, Acc=0.9218, Time=5.24s, N=23320
#  Client 3 → Loss=0.2104, Acc=0.9194, Time=5.26s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1624, Acc=0.9367
#
# [Model=CNN | Seed=7 | Round=3]
#  Client 0 → Loss=0.1752, Acc=0.9332, Time=5.29s, N=23320
#  Client 1 → Loss=0.1746, Acc=0.9355, Time=5.38s, N=23320
#  Client 2 → Loss=0.1806, Acc=0.9310, Time=5.42s, N=23320
#  Client 3 → Loss=0.1842, Acc=0.9300, Time=5.47s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1362, Acc=0.9490
#
# [Model=CNN | Seed=7 | Round=4]
#  Client 0 → Loss=0.1609, Acc=0.9415, Time=5.41s, N=23320
#  Client 1 → Loss=0.1601, Acc=0.9412, Time=5.44s, N=23320
#  Client 2 → Loss=0.1629, Acc=0.9386, Time=5.44s, N=23320
#  Client 3 → Loss=0.1697, Acc=0.9373, Time=5.44s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1235, Acc=0.9551
#
# [Model=CNN | Seed=7 | Round=5]
#  Client 0 → Loss=0.1517, Acc=0.9442, Time=5.41s, N=23320
#  Client 1 → Loss=0.1487, Acc=0.9456, Time=6.12s, N=23320
#  Client 2 → Loss=0.1524, Acc=0.9431, Time=5.89s, N=23320
#  Client 3 → Loss=0.1596, Acc=0.9412, Time=5.62s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1167, Acc=0.9605
#
# [Model=CNN | Seed=7 | Round=6]
#  Client 0 → Loss=0.1437, Acc=0.9472, Time=5.80s, N=23320
#  Client 1 → Loss=0.1427, Acc=0.9485, Time=5.84s, N=23320
#  Client 2 → Loss=0.1445, Acc=0.9471, Time=5.74s, N=23320
#  Client 3 → Loss=0.1504, Acc=0.9443, Time=5.48s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1106, Acc=0.9627
#
# [Model=CNN | Seed=7 | Round=7]
#  Client 0 → Loss=0.1371, Acc=0.9509, Time=5.31s, N=23320
#  Client 1 → Loss=0.1340, Acc=0.9505, Time=5.45s, N=23320
#  Client 2 → Loss=0.1386, Acc=0.9501, Time=5.39s, N=23320
#  Client 3 → Loss=0.1450, Acc=0.9458, Time=5.29s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1075, Acc=0.9640
#
# [Model=CNN | Seed=7 | Round=8]
#  Client 0 → Loss=0.1331, Acc=0.9518, Time=5.36s, N=23320
#  Client 1 → Loss=0.1334, Acc=0.9529, Time=5.33s, N=23320
#  Client 2 → Loss=0.1342, Acc=0.9515, Time=5.22s, N=23320
#  Client 3 → Loss=0.1413, Acc=0.9475, Time=5.26s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1054, Acc=0.9647
#
# [Model=CNN | Seed=7 | Round=9]
#  Client 0 → Loss=0.1292, Acc=0.9531, Time=5.40s, N=23320
#  Client 1 → Loss=0.1269, Acc=0.9543, Time=5.37s, N=23320
#  Client 2 → Loss=0.1298, Acc=0.9515, Time=5.33s, N=23320
#  Client 3 → Loss=0.1386, Acc=0.9492, Time=5.36s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1058, Acc=0.9660
#
# [Model=CNN | Seed=7 | Round=10]
#  Client 0 → Loss=0.1272, Acc=0.9540, Time=5.44s, N=23320
#  Client 1 → Loss=0.1240, Acc=0.9560, Time=5.71s, N=23320
#  Client 2 → Loss=0.1272, Acc=0.9530, Time=5.47s, N=23320
#  Client 3 → Loss=0.1344, Acc=0.9507, Time=5.49s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1044, Acc=0.9662
#
# [Model=CNN | Seed=7 | Round=11]
#  Client 0 → Loss=0.1247, Acc=0.9549, Time=5.54s, N=23320
#  Client 1 → Loss=0.1216, Acc=0.9567, Time=5.43s, N=23320
#  Client 2 → Loss=0.1248, Acc=0.9535, Time=5.59s, N=23320
#  Client 3 → Loss=0.1330, Acc=0.9523, Time=5.63s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1024, Acc=0.9666
#
# [Model=CNN | Seed=7 | Round=12]
#  Client 0 → Loss=0.1229, Acc=0.9555, Time=5.45s, N=23320
#  Client 1 → Loss=0.1210, Acc=0.9573, Time=5.56s, N=23320
#  Client 2 → Loss=0.1232, Acc=0.9548, Time=5.34s, N=23320
#  Client 3 → Loss=0.1300, Acc=0.9531, Time=5.39s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1019, Acc=0.9670
#
# [Model=CNN | Seed=7 | Round=13]
#  Client 0 → Loss=0.1205, Acc=0.9566, Time=5.46s, N=23320
#  Client 1 → Loss=0.1206, Acc=0.9560, Time=5.43s, N=23320
#  Client 2 → Loss=0.1216, Acc=0.9551, Time=5.42s, N=23320
#  Client 3 → Loss=0.1274, Acc=0.9546, Time=5.47s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1017, Acc=0.9675
#
# [Model=CNN | Seed=7 | Round=14]
#  Client 0 → Loss=0.1195, Acc=0.9563, Time=5.45s, N=23320
#  Client 1 → Loss=0.1170, Acc=0.9588, Time=5.61s, N=23320
#  Client 2 → Loss=0.1203, Acc=0.9558, Time=5.31s, N=23320
#  Client 3 → Loss=0.1251, Acc=0.9553, Time=5.50s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1005, Acc=0.9676
#
# [Model=CNN | Seed=7 | Round=15]
#  Client 0 → Loss=0.1184, Acc=0.9569, Time=5.74s, N=23320
#  Client 1 → Loss=0.1157, Acc=0.9583, Time=5.26s, N=23320
#  Client 2 → Loss=0.1184, Acc=0.9565, Time=5.33s, N=23320
#  Client 3 → Loss=0.1247, Acc=0.9557, Time=5.31s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0995, Acc=0.9684
#
# [Model=CNN | Seed=7 | Round=16]
#  Client 0 → Loss=0.1162, Acc=0.9585, Time=5.35s, N=23320
#  Client 1 → Loss=0.1149, Acc=0.9594, Time=5.48s, N=23320
#  Client 2 → Loss=0.1176, Acc=0.9568, Time=5.86s, N=23320
#  Client 3 → Loss=0.1245, Acc=0.9556, Time=5.56s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0999, Acc=0.9681
#
# [Model=CNN | Seed=7 | Round=17]
#  Client 0 → Loss=0.1153, Acc=0.9583, Time=5.66s, N=23320
#  Client 1 → Loss=0.1107, Acc=0.9597, Time=5.48s, N=23320
#  Client 2 → Loss=0.1160, Acc=0.9569, Time=5.38s, N=23320
#  Client 3 → Loss=0.1207, Acc=0.9575, Time=5.17s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1000, Acc=0.9681
#
# [Model=CNN | Seed=7 | Round=18]
#  Client 0 → Loss=0.1161, Acc=0.9590, Time=5.20s, N=23320
#  Client 1 → Loss=0.1126, Acc=0.9589, Time=5.18s, N=23320
#  Client 2 → Loss=0.1139, Acc=0.9585, Time=5.46s, N=23320
#  Client 3 → Loss=0.1194, Acc=0.9571, Time=5.56s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0991, Acc=0.9688
#
# [Model=CNN | Seed=7 | Round=19]
#  Client 0 → Loss=0.1120, Acc=0.9599, Time=5.49s, N=23320
#  Client 1 → Loss=0.1106, Acc=0.9593, Time=5.49s, N=23320
#  Client 2 → Loss=0.1128, Acc=0.9583, Time=5.44s, N=23320
#  Client 3 → Loss=0.1201, Acc=0.9575, Time=5.62s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0987, Acc=0.9684
#
# [Model=CNN | Seed=7 | Round=20]
#  Client 0 → Loss=0.1110, Acc=0.9607, Time=5.81s, N=23320
#  Client 1 → Loss=0.1095, Acc=0.9608, Time=5.58s, N=23320
#  Client 2 → Loss=0.1129, Acc=0.9588, Time=5.63s, N=23320
#  Client 3 → Loss=0.1175, Acc=0.9584, Time=5.76s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1017, Acc=0.9681
#
# [Model=CNN | Seed=7 | Round=21]
#  Client 0 → Loss=0.1128, Acc=0.9594, Time=5.48s, N=23320
#  Client 1 → Loss=0.1091, Acc=0.9606, Time=5.54s, N=23320
#  Client 2 → Loss=0.1106, Acc=0.9587, Time=5.67s, N=23320
#  Client 3 → Loss=0.1161, Acc=0.9578, Time=5.72s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1018, Acc=0.9686
#
# [Model=CNN | Seed=7 | Round=22]
#  Client 0 → Loss=0.1093, Acc=0.9602, Time=5.70s, N=23320
#  Client 1 → Loss=0.1070, Acc=0.9621, Time=5.65s, N=23320
#  Client 2 → Loss=0.1089, Acc=0.9600, Time=5.44s, N=23320
#  Client 3 → Loss=0.1160, Acc=0.9584, Time=5.48s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0996, Acc=0.9678
#
# [Model=CNN | Seed=7 | Round=23]
#  Client 0 → Loss=0.1080, Acc=0.9616, Time=11.05s, N=23320
#  Client 1 → Loss=0.1080, Acc=0.9622, Time=5.50s, N=23320
#  Client 2 → Loss=0.1090, Acc=0.9599, Time=5.50s, N=23320
#  Client 3 → Loss=0.1139, Acc=0.9590, Time=5.49s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1004, Acc=0.9687
#
# [Model=CNN | Seed=7 | Round=24]
#  Client 0 → Loss=0.1073, Acc=0.9622, Time=5.26s, N=23320
#  Client 1 → Loss=0.1073, Acc=0.9622, Time=5.41s, N=23320
#  Client 2 → Loss=0.1095, Acc=0.9593, Time=5.37s, N=23320
#  Client 3 → Loss=0.1139, Acc=0.9588, Time=5.59s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1022, Acc=0.9678
#
# [Model=CNN | Seed=7 | Round=25]
#  Client 0 → Loss=0.1068, Acc=0.9613, Time=5.39s, N=23320
#  Client 1 → Loss=0.1045, Acc=0.9626, Time=5.49s, N=23320
#  Client 2 → Loss=0.1090, Acc=0.9605, Time=5.33s, N=23320
#  Client 3 → Loss=0.1144, Acc=0.9587, Time=5.47s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0987, Acc=0.9688
#
# [Model=CNN | Seed=7 | Round=26]
#  Client 0 → Loss=0.1067, Acc=0.9623, Time=5.49s, N=23320
#  Client 1 → Loss=0.1050, Acc=0.9634, Time=5.55s, N=23320
#  Client 2 → Loss=0.1078, Acc=0.9602, Time=5.51s, N=23320
#  Client 3 → Loss=0.1125, Acc=0.9589, Time=5.47s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0988, Acc=0.9693
#
# [Model=CNN | Seed=7 | Round=27]
#  Client 0 → Loss=0.1060, Acc=0.9624, Time=5.35s, N=23320
#  Client 1 → Loss=0.1031, Acc=0.9645, Time=5.27s, N=23320
#  Client 2 → Loss=0.1065, Acc=0.9601, Time=5.23s, N=23320
#  Client 3 → Loss=0.1107, Acc=0.9603, Time=5.41s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0964, Acc=0.9692
#
# [Model=CNN | Seed=7 | Round=28]
#  Client 0 → Loss=0.1070, Acc=0.9620, Time=5.55s, N=23320
#  Client 1 → Loss=0.1035, Acc=0.9637, Time=5.78s, N=23320
#  Client 2 → Loss=0.1063, Acc=0.9609, Time=5.45s, N=23320
#  Client 3 → Loss=0.1116, Acc=0.9597, Time=5.36s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0995, Acc=0.9687
#
# [Model=CNN | Seed=7 | Round=29]
#  Client 0 → Loss=0.1043, Acc=0.9628, Time=5.32s, N=23320
#  Client 1 → Loss=0.1046, Acc=0.9637, Time=5.44s, N=23320
#  Client 2 → Loss=0.1063, Acc=0.9609, Time=5.40s, N=23320
#  Client 3 → Loss=0.1097, Acc=0.9597, Time=5.69s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0998, Acc=0.9685
#
# [Model=CNN | Seed=7 | Round=30]
#  Client 0 → Loss=0.1044, Acc=0.9624, Time=5.41s, N=23320
#  Client 1 → Loss=0.1075, Acc=0.9636, Time=5.33s, N=23320
#  Client 2 → Loss=0.1065, Acc=0.9612, Time=5.31s, N=23320
#  Client 3 → Loss=0.1106, Acc=0.9596, Time=5.33s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0977, Acc=0.9689
#  [saved] saved_models\CNN_seed7.keras
#
# ------ SEED 72 ------
#
# [Model=CNN | Seed=72 | Round=1]
#  Client 0 → Loss=0.2637, Acc=0.9024, Time=5.51s, N=23320
#  Client 1 → Loss=0.2635, Acc=0.9021, Time=5.26s, N=23320
#  Client 2 → Loss=0.2545, Acc=0.9060, Time=5.59s, N=23320
#  Client 3 → Loss=0.2598, Acc=0.9036, Time=5.61s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.2295, Acc=0.9164
#
# [Model=CNN | Seed=72 | Round=2]
#  Client 0 → Loss=0.2075, Acc=0.9221, Time=5.73s, N=23320
#  Client 1 → Loss=0.2033, Acc=0.9236, Time=5.95s, N=23320
#  Client 2 → Loss=0.2034, Acc=0.9230, Time=5.92s, N=23320
#  Client 3 → Loss=0.2017, Acc=0.9235, Time=5.84s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1520, Acc=0.9446
#
# [Model=CNN | Seed=72 | Round=3]
#  Client 0 → Loss=0.1804, Acc=0.9325, Time=5.85s, N=23320
#  Client 1 → Loss=0.1755, Acc=0.9346, Time=5.53s, N=23320
#  Client 2 → Loss=0.1740, Acc=0.9358, Time=5.28s, N=23320
#  Client 3 → Loss=0.1764, Acc=0.9352, Time=5.54s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1337, Acc=0.9508
#
# [Model=CNN | Seed=72 | Round=4]
#  Client 0 → Loss=0.1665, Acc=0.9380, Time=5.60s, N=23320
#  Client 1 → Loss=0.1613, Acc=0.9396, Time=5.52s, N=23320
#  Client 2 → Loss=0.1611, Acc=0.9433, Time=5.55s, N=23320
#  Client 3 → Loss=0.1619, Acc=0.9419, Time=5.32s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1255, Acc=0.9548
#
# [Model=CNN | Seed=72 | Round=5]
#  Client 0 → Loss=0.1566, Acc=0.9416, Time=5.35s, N=23320
#  Client 1 → Loss=0.1516, Acc=0.9449, Time=5.39s, N=23320
#  Client 2 → Loss=0.1501, Acc=0.9465, Time=5.38s, N=23320
#  Client 3 → Loss=0.1521, Acc=0.9449, Time=5.41s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1179, Acc=0.9579
#
# [Model=CNN | Seed=72 | Round=6]
#  Client 0 → Loss=0.1495, Acc=0.9443, Time=5.39s, N=23320
#  Client 1 → Loss=0.1449, Acc=0.9463, Time=5.57s, N=23320
#  Client 2 → Loss=0.1413, Acc=0.9491, Time=5.56s, N=23320
#  Client 3 → Loss=0.1452, Acc=0.9487, Time=5.55s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1143, Acc=0.9597
#
# [Model=CNN | Seed=72 | Round=7]
#  Client 0 → Loss=0.1434, Acc=0.9467, Time=5.57s, N=23320
#  Client 1 → Loss=0.1383, Acc=0.9491, Time=5.68s, N=23320
#  Client 2 → Loss=0.1363, Acc=0.9504, Time=5.73s, N=23320
#  Client 3 → Loss=0.1389, Acc=0.9486, Time=5.81s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1099, Acc=0.9606
#
# [Model=CNN | Seed=72 | Round=8]
#  Client 0 → Loss=0.1392, Acc=0.9480, Time=5.81s, N=23320
#  Client 1 → Loss=0.1340, Acc=0.9507, Time=5.61s, N=23320
#  Client 2 → Loss=0.1321, Acc=0.9524, Time=5.46s, N=23320
#  Client 3 → Loss=0.1347, Acc=0.9515, Time=5.40s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1084, Acc=0.9614
#
# [Model=CNN | Seed=72 | Round=9]
#  Client 0 → Loss=0.1354, Acc=0.9503, Time=5.23s, N=23320
#  Client 1 → Loss=0.1304, Acc=0.9524, Time=5.67s, N=23320
#  Client 2 → Loss=0.1282, Acc=0.9545, Time=5.35s, N=23320
#  Client 3 → Loss=0.1331, Acc=0.9525, Time=5.33s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1061, Acc=0.9616
#
# [Model=CNN | Seed=72 | Round=10]
#  Client 0 → Loss=0.1316, Acc=0.9519, Time=5.27s, N=23320
#  Client 1 → Loss=0.1262, Acc=0.9534, Time=5.29s, N=23320
#  Client 2 → Loss=0.1257, Acc=0.9548, Time=5.33s, N=23320
#  Client 3 → Loss=0.1296, Acc=0.9527, Time=5.30s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1065, Acc=0.9625
#
# [Model=CNN | Seed=72 | Round=11]
#  Client 0 → Loss=0.1291, Acc=0.9522, Time=5.32s, N=23320
#  Client 1 → Loss=0.1234, Acc=0.9552, Time=5.28s, N=23320
#  Client 2 → Loss=0.1220, Acc=0.9561, Time=5.55s, N=23320
#  Client 3 → Loss=0.1279, Acc=0.9539, Time=5.41s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1057, Acc=0.9637
#
# [Model=CNN | Seed=72 | Round=12]
#  Client 0 → Loss=0.1273, Acc=0.9531, Time=5.48s, N=23320
#  Client 1 → Loss=0.1220, Acc=0.9560, Time=5.41s, N=23320
#  Client 2 → Loss=0.1198, Acc=0.9570, Time=5.42s, N=23320
#  Client 3 → Loss=0.1244, Acc=0.9552, Time=5.51s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1058, Acc=0.9638
#
# [Model=CNN | Seed=72 | Round=13]
#  Client 0 → Loss=0.1264, Acc=0.9531, Time=5.51s, N=23320
#  Client 1 → Loss=0.1197, Acc=0.9560, Time=5.63s, N=23320
#  Client 2 → Loss=0.1180, Acc=0.9582, Time=5.45s, N=23320
#  Client 3 → Loss=0.1235, Acc=0.9555, Time=5.35s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1059, Acc=0.9641
#
# [Model=CNN | Seed=72 | Round=14]
#  Client 0 → Loss=0.1239, Acc=0.9547, Time=5.37s, N=23320
#  Client 1 → Loss=0.1180, Acc=0.9567, Time=5.30s, N=23320
#  Client 2 → Loss=0.1167, Acc=0.9580, Time=5.32s, N=23320
#  Client 3 → Loss=0.1206, Acc=0.9560, Time=5.37s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1049, Acc=0.9641
#
# [Model=CNN | Seed=72 | Round=15]
#  Client 0 → Loss=0.1212, Acc=0.9554, Time=5.38s, N=23320
#  Client 1 → Loss=0.1159, Acc=0.9577, Time=5.42s, N=23320
#  Client 2 → Loss=0.1123, Acc=0.9592, Time=5.45s, N=23320
#  Client 3 → Loss=0.1200, Acc=0.9566, Time=5.44s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1049, Acc=0.9651
#
# [Model=CNN | Seed=72 | Round=16]
#  Client 0 → Loss=0.1195, Acc=0.9561, Time=5.42s, N=23320
#  Client 1 → Loss=0.1140, Acc=0.9577, Time=5.49s, N=23320
#  Client 2 → Loss=0.1115, Acc=0.9596, Time=5.48s, N=23320
#  Client 3 → Loss=0.1191, Acc=0.9568, Time=5.45s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1020, Acc=0.9648
#
# [Model=CNN | Seed=72 | Round=17]
#  Client 0 → Loss=0.1174, Acc=0.9577, Time=5.40s, N=23320
#  Client 1 → Loss=0.1127, Acc=0.9588, Time=5.42s, N=23320
#  Client 2 → Loss=0.1127, Acc=0.9597, Time=5.50s, N=23320
#  Client 3 → Loss=0.1152, Acc=0.9584, Time=5.50s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1029, Acc=0.9657
#
# [Model=CNN | Seed=72 | Round=18]
#  Client 0 → Loss=0.1170, Acc=0.9570, Time=5.80s, N=23320
#  Client 1 → Loss=0.1126, Acc=0.9590, Time=5.57s, N=23320
#  Client 2 → Loss=0.1096, Acc=0.9607, Time=5.46s, N=23320
#  Client 3 → Loss=0.1138, Acc=0.9580, Time=5.53s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1041, Acc=0.9649
#
# [Model=CNN | Seed=72 | Round=19]
#  Client 0 → Loss=0.1168, Acc=0.9570, Time=5.73s, N=23320
#  Client 1 → Loss=0.1101, Acc=0.9605, Time=5.26s, N=23320
#  Client 2 → Loss=0.1103, Acc=0.9614, Time=5.31s, N=23320
#  Client 3 → Loss=0.1127, Acc=0.9594, Time=5.40s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1030, Acc=0.9656
#
# [Model=CNN | Seed=72 | Round=20]
#  Client 0 → Loss=0.1156, Acc=0.9572, Time=5.30s, N=23320
#  Client 1 → Loss=0.1090, Acc=0.9606, Time=5.38s, N=23320
#  Client 2 → Loss=0.1096, Acc=0.9619, Time=5.47s, N=23320
#  Client 3 → Loss=0.1108, Acc=0.9596, Time=5.41s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1010, Acc=0.9662
#
# [Model=CNN | Seed=72 | Round=21]
#  Client 0 → Loss=0.1155, Acc=0.9579, Time=5.42s, N=23320
#  Client 1 → Loss=0.1084, Acc=0.9610, Time=5.36s, N=23320
#  Client 2 → Loss=0.1072, Acc=0.9627, Time=5.39s, N=23320
#  Client 3 → Loss=0.1120, Acc=0.9599, Time=5.42s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1017, Acc=0.9658
#
# [Model=CNN | Seed=72 | Round=22]
#  Client 0 → Loss=0.1139, Acc=0.9577, Time=5.55s, N=23320
#  Client 1 → Loss=0.1095, Acc=0.9602, Time=5.51s, N=23320
#  Client 2 → Loss=0.1054, Acc=0.9622, Time=5.47s, N=23320
#  Client 3 → Loss=0.1094, Acc=0.9603, Time=5.51s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1005, Acc=0.9658
#
# [Model=CNN | Seed=72 | Round=23]
#  Client 0 → Loss=0.1130, Acc=0.9591, Time=5.58s, N=23320
#  Client 1 → Loss=0.1096, Acc=0.9608, Time=5.64s, N=23320
#  Client 2 → Loss=0.1055, Acc=0.9634, Time=5.49s, N=23320
#  Client 3 → Loss=0.1087, Acc=0.9607, Time=5.50s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1021, Acc=0.9666
#
# [Model=CNN | Seed=72 | Round=24]
#  Client 0 → Loss=0.1099, Acc=0.9593, Time=5.80s, N=23320
#  Client 1 → Loss=0.1046, Acc=0.9620, Time=5.52s, N=23320
#  Client 2 → Loss=0.1054, Acc=0.9633, Time=5.35s, N=23320
#  Client 3 → Loss=0.1081, Acc=0.9611, Time=5.47s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1022, Acc=0.9667
#
# [Model=CNN | Seed=72 | Round=25]
#  Client 0 → Loss=0.1109, Acc=0.9596, Time=5.45s, N=23320
#  Client 1 → Loss=0.1054, Acc=0.9616, Time=5.39s, N=23320
#  Client 2 → Loss=0.1055, Acc=0.9629, Time=5.69s, N=23320
#  Client 3 → Loss=0.1064, Acc=0.9611, Time=5.63s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1003, Acc=0.9664
#
# [Model=CNN | Seed=72 | Round=26]
#  Client 0 → Loss=0.1093, Acc=0.9591, Time=5.58s, N=23320
#  Client 1 → Loss=0.1037, Acc=0.9617, Time=5.43s, N=23320
#  Client 2 → Loss=0.1049, Acc=0.9638, Time=5.34s, N=23320
#  Client 3 → Loss=0.1058, Acc=0.9617, Time=5.66s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1009, Acc=0.9665
#
# [Model=CNN | Seed=72 | Round=27]
#  Client 0 → Loss=0.1112, Acc=0.9587, Time=5.59s, N=23320
#  Client 1 → Loss=0.1046, Acc=0.9621, Time=5.42s, N=23320
#  Client 2 → Loss=0.1044, Acc=0.9634, Time=5.44s, N=23320
#  Client 3 → Loss=0.1051, Acc=0.9613, Time=5.51s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1022, Acc=0.9665
#
# [Model=CNN | Seed=72 | Round=28]
#  Client 0 → Loss=0.1088, Acc=0.9600, Time=5.49s, N=23320
#  Client 1 → Loss=0.1035, Acc=0.9613, Time=5.42s, N=23320
#  Client 2 → Loss=0.1038, Acc=0.9637, Time=5.45s, N=23320
#  Client 3 → Loss=0.1074, Acc=0.9621, Time=5.71s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0973, Acc=0.9678
#
# [Model=CNN | Seed=72 | Round=29]
#  Client 0 → Loss=0.1102, Acc=0.9593, Time=5.36s, N=23320
#  Client 1 → Loss=0.1028, Acc=0.9634, Time=5.34s, N=23320
#  Client 2 → Loss=0.1043, Acc=0.9633, Time=5.41s, N=23320
#  Client 3 → Loss=0.1034, Acc=0.9632, Time=5.25s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1018, Acc=0.9668
#
# [Model=CNN | Seed=72 | Round=30]
#  Client 0 → Loss=0.1095, Acc=0.9600, Time=5.40s, N=23320
#  Client 1 → Loss=0.1013, Acc=0.9625, Time=5.42s, N=23320
#  Client 2 → Loss=0.1011, Acc=0.9642, Time=5.44s, N=23320
#  Client 3 → Loss=0.1026, Acc=0.9635, Time=5.42s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1020, Acc=0.9665
#  [saved] saved_models\CNN_seed72.keras
#
# ------ SEED 82 ------
#
# [Model=CNN | Seed=82 | Round=1]
#  Client 0 → Loss=0.2668, Acc=0.9021, Time=5.66s, N=23320
#  Client 1 → Loss=0.2540, Acc=0.9060, Time=5.55s, N=23320
#  Client 2 → Loss=0.2579, Acc=0.9051, Time=5.42s, N=23320
#  Client 3 → Loss=0.2579, Acc=0.9052, Time=5.41s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.2374, Acc=0.9105
#
# [Model=CNN | Seed=82 | Round=2]
#  Client 0 → Loss=0.2084, Acc=0.9211, Time=5.39s, N=23320
#  Client 1 → Loss=0.2024, Acc=0.9232, Time=5.42s, N=23320
#  Client 2 → Loss=0.2019, Acc=0.9225, Time=5.38s, N=23320
#  Client 3 → Loss=0.2083, Acc=0.9216, Time=5.16s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1617, Acc=0.9377
#
# [Model=CNN | Seed=82 | Round=3]
#  Client 0 → Loss=0.1778, Acc=0.9341, Time=5.45s, N=23320
#  Client 1 → Loss=0.1720, Acc=0.9367, Time=5.29s, N=23320
#  Client 2 → Loss=0.1709, Acc=0.9356, Time=5.91s, N=23320
#  Client 3 → Loss=0.1774, Acc=0.9324, Time=5.64s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1374, Acc=0.9512
#
# [Model=CNN | Seed=82 | Round=4]
#  Client 0 → Loss=0.1619, Acc=0.9403, Time=5.61s, N=23320
#  Client 1 → Loss=0.1578, Acc=0.9424, Time=5.56s, N=23320
#  Client 2 → Loss=0.1559, Acc=0.9429, Time=5.55s, N=23320
#  Client 3 → Loss=0.1609, Acc=0.9400, Time=5.54s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1266, Acc=0.9565
#
# [Model=CNN | Seed=82 | Round=5]
#  Client 0 → Loss=0.1522, Acc=0.9455, Time=5.46s, N=23320
#  Client 1 → Loss=0.1468, Acc=0.9461, Time=5.49s, N=23320
#  Client 2 → Loss=0.1494, Acc=0.9455, Time=5.45s, N=23320
#  Client 3 → Loss=0.1511, Acc=0.9424, Time=5.43s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1202, Acc=0.9578
#
# [Model=CNN | Seed=82 | Round=6]
#  Client 0 → Loss=0.1430, Acc=0.9483, Time=5.38s, N=23320
#  Client 1 → Loss=0.1395, Acc=0.9493, Time=5.47s, N=23320
#  Client 2 → Loss=0.1427, Acc=0.9476, Time=5.49s, N=23320
#  Client 3 → Loss=0.1436, Acc=0.9462, Time=5.43s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1162, Acc=0.9593
#
# [Model=CNN | Seed=82 | Round=7]
#  Client 0 → Loss=0.1391, Acc=0.9500, Time=5.39s, N=23320
#  Client 1 → Loss=0.1346, Acc=0.9510, Time=5.42s, N=23320
#  Client 2 → Loss=0.1382, Acc=0.9499, Time=5.45s, N=23320
#  Client 3 → Loss=0.1387, Acc=0.9488, Time=5.52s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1138, Acc=0.9598
#
# [Model=CNN | Seed=82 | Round=8]
#  Client 0 → Loss=0.1341, Acc=0.9528, Time=5.54s, N=23320
#  Client 1 → Loss=0.1305, Acc=0.9524, Time=5.55s, N=23320
#  Client 2 → Loss=0.1328, Acc=0.9509, Time=5.80s, N=23320
#  Client 3 → Loss=0.1359, Acc=0.9505, Time=5.56s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1108, Acc=0.9614
#
# [Model=CNN | Seed=82 | Round=9]
#  Client 0 → Loss=0.1309, Acc=0.9523, Time=5.49s, N=23320
#  Client 1 → Loss=0.1263, Acc=0.9539, Time=5.50s, N=23320
#  Client 2 → Loss=0.1293, Acc=0.9534, Time=5.40s, N=23320
#  Client 3 → Loss=0.1311, Acc=0.9522, Time=5.44s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1095, Acc=0.9620
#
# [Model=CNN | Seed=82 | Round=10]
#  Client 0 → Loss=0.1298, Acc=0.9542, Time=5.46s, N=23320
#  Client 1 → Loss=0.1239, Acc=0.9549, Time=5.26s, N=23320
#  Client 2 → Loss=0.1257, Acc=0.9542, Time=5.14s, N=23320
#  Client 3 → Loss=0.1279, Acc=0.9545, Time=5.35s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1080, Acc=0.9623
#
# [Model=CNN | Seed=82 | Round=11]
#  Client 0 → Loss=0.1256, Acc=0.9551, Time=5.31s, N=23320
#  Client 1 → Loss=0.1201, Acc=0.9561, Time=5.41s, N=23320
#  Client 2 → Loss=0.1246, Acc=0.9548, Time=5.49s, N=23320
#  Client 3 → Loss=0.1248, Acc=0.9548, Time=5.48s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1068, Acc=0.9623
#
# [Model=CNN | Seed=82 | Round=12]
#  Client 0 → Loss=0.1237, Acc=0.9556, Time=5.43s, N=23320
#  Client 1 → Loss=0.1184, Acc=0.9574, Time=5.37s, N=23320
#  Client 2 → Loss=0.1209, Acc=0.9556, Time=5.32s, N=23320
#  Client 3 → Loss=0.1227, Acc=0.9560, Time=5.27s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1047, Acc=0.9643
#
# [Model=CNN | Seed=82 | Round=13]
#  Client 0 → Loss=0.1215, Acc=0.9555, Time=5.49s, N=23320
#  Client 1 → Loss=0.1164, Acc=0.9577, Time=5.33s, N=23320
#  Client 2 → Loss=0.1182, Acc=0.9568, Time=5.27s, N=23320
#  Client 3 → Loss=0.1213, Acc=0.9561, Time=5.26s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1030, Acc=0.9643
#
# [Model=CNN | Seed=82 | Round=14]
#  Client 0 → Loss=0.1201, Acc=0.9572, Time=5.37s, N=23320
#  Client 1 → Loss=0.1147, Acc=0.9589, Time=5.63s, N=23320
#  Client 2 → Loss=0.1169, Acc=0.9571, Time=5.68s, N=23320
#  Client 3 → Loss=0.1185, Acc=0.9569, Time=5.67s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1038, Acc=0.9652
#
# [Model=CNN | Seed=82 | Round=15]
#  Client 0 → Loss=0.1188, Acc=0.9568, Time=5.55s, N=23320
#  Client 1 → Loss=0.1136, Acc=0.9584, Time=5.67s, N=23320
#  Client 2 → Loss=0.1148, Acc=0.9582, Time=5.36s, N=23320
#  Client 3 → Loss=0.1178, Acc=0.9580, Time=5.51s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1032, Acc=0.9659
#
# [Model=CNN | Seed=82 | Round=16]
#  Client 0 → Loss=0.1170, Acc=0.9581, Time=5.33s, N=23320
#  Client 1 → Loss=0.1134, Acc=0.9599, Time=5.31s, N=23320
#  Client 2 → Loss=0.1146, Acc=0.9583, Time=5.32s, N=23320
#  Client 3 → Loss=0.1173, Acc=0.9586, Time=5.35s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1025, Acc=0.9659
#
# [Model=CNN | Seed=82 | Round=17]
#  Client 0 → Loss=0.1170, Acc=0.9576, Time=5.50s, N=23320
#  Client 1 → Loss=0.1098, Acc=0.9617, Time=5.43s, N=23320
#  Client 2 → Loss=0.1141, Acc=0.9579, Time=5.43s, N=23320
#  Client 3 → Loss=0.1145, Acc=0.9586, Time=5.38s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1011, Acc=0.9664
#
# [Model=CNN | Seed=82 | Round=18]
#  Client 0 → Loss=0.1161, Acc=0.9583, Time=5.39s, N=23320
#  Client 1 → Loss=0.1096, Acc=0.9620, Time=5.79s, N=23320
#  Client 2 → Loss=0.1113, Acc=0.9593, Time=5.63s, N=23320
#  Client 3 → Loss=0.1130, Acc=0.9590, Time=5.49s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0998, Acc=0.9664
#
# [Model=CNN | Seed=82 | Round=19]
#  Client 0 → Loss=0.1144, Acc=0.9594, Time=5.43s, N=23320
#  Client 1 → Loss=0.1090, Acc=0.9612, Time=5.47s, N=23320
#  Client 2 → Loss=0.1106, Acc=0.9592, Time=5.80s, N=23320
#  Client 3 → Loss=0.1133, Acc=0.9593, Time=5.68s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1007, Acc=0.9666
#
# [Model=CNN | Seed=82 | Round=20]
#  Client 0 → Loss=0.1135, Acc=0.9596, Time=5.62s, N=23320
#  Client 1 → Loss=0.1095, Acc=0.9611, Time=5.76s, N=23320
#  Client 2 → Loss=0.1099, Acc=0.9590, Time=5.54s, N=23320
#  Client 3 → Loss=0.1124, Acc=0.9584, Time=5.40s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0996, Acc=0.9664
#
# [Model=CNN | Seed=82 | Round=21]
#  Client 0 → Loss=0.1115, Acc=0.9605, Time=5.28s, N=23320
#  Client 1 → Loss=0.1072, Acc=0.9617, Time=5.22s, N=23320
#  Client 2 → Loss=0.1089, Acc=0.9599, Time=5.17s, N=23320
#  Client 3 → Loss=0.1124, Acc=0.9593, Time=5.26s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1011, Acc=0.9668
#
# [Model=CNN | Seed=82 | Round=22]
#  Client 0 → Loss=0.1113, Acc=0.9594, Time=5.29s, N=23320
#  Client 1 → Loss=0.1061, Acc=0.9627, Time=5.49s, N=23320
#  Client 2 → Loss=0.1083, Acc=0.9603, Time=5.40s, N=23320
#  Client 3 → Loss=0.1098, Acc=0.9605, Time=5.32s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0985, Acc=0.9664
#
# [Model=CNN | Seed=82 | Round=23]
#  Client 0 → Loss=0.1102, Acc=0.9598, Time=5.27s, N=23320
#  Client 1 → Loss=0.1053, Acc=0.9630, Time=5.59s, N=23320
#  Client 2 → Loss=0.1061, Acc=0.9611, Time=5.33s, N=23320
#  Client 3 → Loss=0.1102, Acc=0.9589, Time=5.58s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0984, Acc=0.9674
#
# [Model=CNN | Seed=82 | Round=24]
#  Client 0 → Loss=0.1079, Acc=0.9614, Time=5.79s, N=23320
#  Client 1 → Loss=0.1039, Acc=0.9640, Time=5.76s, N=23320
#  Client 2 → Loss=0.1055, Acc=0.9615, Time=5.84s, N=23320
#  Client 3 → Loss=0.1096, Acc=0.9607, Time=5.85s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0992, Acc=0.9675
#
# [Model=CNN | Seed=82 | Round=25]
#  Client 0 → Loss=0.1077, Acc=0.9609, Time=5.87s, N=23320
#  Client 1 → Loss=0.1035, Acc=0.9633, Time=5.59s, N=23320
#  Client 2 → Loss=0.1061, Acc=0.9616, Time=5.55s, N=23320
#  Client 3 → Loss=0.1087, Acc=0.9609, Time=5.50s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1007, Acc=0.9678
#
# [Model=CNN | Seed=82 | Round=26]
#  Client 0 → Loss=0.1071, Acc=0.9622, Time=5.31s, N=23320
#  Client 1 → Loss=0.1017, Acc=0.9637, Time=5.23s, N=23320
#  Client 2 → Loss=0.1051, Acc=0.9617, Time=5.41s, N=23320
#  Client 3 → Loss=0.1081, Acc=0.9611, Time=5.31s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0986, Acc=0.9675
#
# [Model=CNN | Seed=82 | Round=27]
#  Client 0 → Loss=0.1049, Acc=0.9628, Time=5.28s, N=23320
#  Client 1 → Loss=0.1016, Acc=0.9642, Time=5.13s, N=23320
#  Client 2 → Loss=0.1049, Acc=0.9620, Time=5.14s, N=23320
#  Client 3 → Loss=0.1074, Acc=0.9616, Time=5.16s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0988, Acc=0.9670
#
# [Model=CNN | Seed=82 | Round=28]
#  Client 0 → Loss=0.1064, Acc=0.9623, Time=5.52s, N=23320
#  Client 1 → Loss=0.1017, Acc=0.9635, Time=5.31s, N=23320
#  Client 2 → Loss=0.1050, Acc=0.9615, Time=5.35s, N=23320
#  Client 3 → Loss=0.1083, Acc=0.9617, Time=5.34s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1010, Acc=0.9674
#
# [Model=CNN | Seed=82 | Round=29]
#  Client 0 → Loss=0.1055, Acc=0.9619, Time=5.45s, N=23320
#  Client 1 → Loss=0.1021, Acc=0.9639, Time=5.42s, N=23320
#  Client 2 → Loss=0.1031, Acc=0.9624, Time=5.39s, N=23320
#  Client 3 → Loss=0.1061, Acc=0.9616, Time=5.44s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0993, Acc=0.9670
#
# [Model=CNN | Seed=82 | Round=30]
#  Client 0 → Loss=0.1050, Acc=0.9631, Time=5.46s, N=23320
#  Client 1 → Loss=0.0997, Acc=0.9643, Time=5.38s, N=23320
#  Client 2 → Loss=0.1026, Acc=0.9621, Time=5.45s, N=23320
# ...
#    CNN     7     saved_models\CNN_seed7.keras
#    CNN    72    saved_models\CNN_seed72.keras
#    CNN    82    saved_models\CNN_seed82.keras
#   LSTM    42   saved_models\LSTM_seed42.keras
#   LSTM     3    saved_models\LSTM_seed3.keras
#   LSTM     7    saved_models\LSTM_seed7.keras
#   LSTM    72   saved_models\LSTM_seed72.keras
#   LSTM    82   saved_models\LSTM_seed82.keras
# BiLSTM    42 saved_models\BiLSTM_seed42.keras
# BiLSTM     3  saved_models\BiLSTM_seed3.keras
# BiLSTM     7  saved_models\BiLSTM_seed7.keras
# BiLSTM    72 saved_models\BiLSTM_seed72.keras
# BiLSTM    82 saved_models\BiLSTM_seed82.keras
#    GRU    42    saved_models\GRU_seed42.keras
#    GRU     3     saved_models\GRU_seed3.keras
#    GRU     7     saved_models\GRU_seed7.keras
#    GRU    72    saved_models\GRU_seed72.keras
#    GRU    82    saved_models\GRU_seed82.keras
#  BiGRU    42  saved_models\BiGRU_seed42.keras
#  BiGRU     3   saved_models\BiGRU_seed3.keras
#  BiGRU     7   saved_models\BiGRU_seed7.keras
#  BiGRU    72  saved_models\BiGRU_seed72.keras
#  BiGRU    82  saved_models\BiGRU_seed82.keras
#
# OVERALL SUMMARY (all models & seeds pooled):
#                  Metric             Mean ± SD                 95% CI
# 0                 Loss       0.1011 ± 0.0113        [0.0967,0.1055]
# 1             Accuracy       0.9790 ± 0.0060        [0.9767,0.9814]
# 2            Precision       0.9419 ± 0.0205        [0.9339,0.9499]
# 3               Recall       0.9090 ± 0.0296        [0.8974,0.9206]
# 4                   F1       0.9249 ± 0.0221        [0.9163,0.9336]
# 5                  MCC       0.9131 ± 0.0252        [0.9032,0.9230]
# 6                  AUC       0.9919 ± 0.0032        [0.9907,0.9932]
# 7          Specificity       0.9907 ± 0.0035        [0.9893,0.9920]
# 8    Training_Time_sec  1777.1471 ± 741.8802  [1486.3301,2067.9641]
# 9   Inference_Time_sec       2.0131 ± 0.8882        [1.6649,2.3613]
# 10       Model_Size_MB       0.5846 ± 0.3965        [0.4292,0.7400]
# 11   Comm_per_round_MB       8.9497 ± 6.2607       [6.4955,11.4039]
# 12       Total_Comm_MB   268.4901 ± 187.8204    [194.8645,342.1157]
#
# PER-CLIENT TEST SUMMARY (mean/std over 5 seeds):
#                Accuracy         Precision          Recall              F1  \
#                   mean     std      mean     std    mean     std    mean
# Model  Client
# BiGRU  0        0.9827  0.0018    0.9421  0.0063  0.9361  0.0132  0.9391
#        1        0.9806  0.0018    0.9397  0.0094  0.9231  0.0066  0.9313
#        2        0.9801  0.0008    0.9363  0.0067  0.9231  0.0086  0.9296
#        3        0.9823  0.0015    0.9469  0.0059  0.9280  0.0077  0.9373
# BiLSTM 0        0.9836  0.0010    0.9516  0.0125  0.9323  0.0176  0.9417
#        1        0.9825  0.0016    0.9508  0.0104  0.9253  0.0065  0.9379
#        2        0.9811  0.0020    0.9487  0.0042  0.9169  0.0163  0.9324
#        3        0.9837  0.0013    0.9572  0.0043  0.9272  0.0103  0.9420
# CNN    0        0.9672  0.0017    0.9051  0.0321  0.8622  0.0300  0.8823
#        1        0.9664  0.0033    0.9114  0.0338  0.8484  0.0166  0.8782
#        2        0.9665  0.0015    0.9090  0.0289  0.8516  0.0250  0.8787
#        3        0.9685  0.0023    0.9172  0.0251  0.8573  0.0304  0.8856
# GRU    0        0.9828  0.0017    0.9537  0.0129  0.9241  0.0135  0.9386
#        1        0.9815  0.0011    0.9550  0.0092  0.9133  0.0113  0.9336
#        2        0.9798  0.0015    0.9473  0.0037  0.9089  0.0141  0.9277
#        3        0.9819  0.0008    0.9557  0.0043  0.9152  0.0068  0.9350
# LSTM   0        0.9833  0.0015    0.9542  0.0106  0.9270  0.0086  0.9404
#        1        0.9821  0.0015    0.9529  0.0095  0.9195  0.0132  0.9358
#        2        0.9810  0.0012    0.9471  0.0067  0.9176  0.0113  0.9321
#        3        0.9830  0.0014    0.9565  0.0064  0.9222  0.0077  0.9390
#
#                           MCC             AUC         Specificity          \
#                   std    mean     std    mean     std        mean     std
# Model  Client
# BiGRU  0       0.0065  0.9290  0.0075  0.9946  0.0005      0.9904  0.0011
#        1       0.0062  0.9201  0.0073  0.9939  0.0018      0.9902  0.0016
#        2       0.0030  0.9181  0.0035  0.9932  0.0013      0.9896  0.0012
#        3       0.0052  0.9271  0.0060  0.9946  0.0011      0.9914  0.0010
# BiLSTM 0       0.0042  0.9323  0.0046  0.9939  0.0009      0.9921  0.0023
#        1       0.0055  0.9278  0.0065  0.9942  0.0014      0.9920  0.0018
#        2       0.0078  0.9217  0.0087  0.9929  0.0015      0.9918  0.0008
#        3       0.0050  0.9327  0.0057  0.9939  0.0014      0.9931  0.0008
# CNN    0       0.0047  0.8642  0.0054  0.9871  0.0007      0.9847  0.0062
#        1       0.0085  0.8599  0.0112  0.9852  0.0020      0.9860  0.0063
#        2       0.0030  0.8603  0.0040  0.9844  0.0012      0.9856  0.0056
#        3       0.0093  0.8685  0.0101  0.9860  0.0031      0.9870  0.0047
# GRU    0       0.0060  0.9288  0.0070  0.9940  0.0014      0.9925  0.0022
#        1       0.0043  0.9232  0.0048  0.9936  0.0016      0.9928  0.0016
#        2       0.0061  0.9162  0.0067  0.9922  0.0018      0.9916  0.0007
#        3       0.0032  0.9248  0.0036  0.9933  0.0011      0.9930  0.0007
# LSTM   0       0.0051  0.9308  0.0059  0.9936  0.0011      0.9926  0.0018
#        1       0.0057  0.9257  0.0065  0.9934  0.0012      0.9924  0.0017
#        2       0.0047  0.9212  0.0053  0.9914  0.0019      0.9915  0.0012
#        3       0.0051  0.9293  0.0059  0.9932  0.0012      0.9930  0.0011
#
#                  Loss
#                  mean     std
# Model  Client
# BiGRU  0       0.1049  0.0117
#        1       0.1128  0.0134
#        2       0.1288  0.0103
#        3       0.1090  0.0133
# BiLSTM 0       0.1044  0.0082
#        1       0.1108  0.0168
#        2       0.1193  0.0130
#        3       0.1047  0.0131
# CNN    0       0.0987  0.0059
#        1       0.1014  0.0059
#        2       0.1042  0.0036
#        3       0.0994  0.0080
# GRU    0       0.0876  0.0114
#        1       0.0958  0.0135
#        2       0.1062  0.0124
#        3       0.0948  0.0121
# LSTM   0       0.0794  0.0128
#        1       0.0851  0.0126
#        2       0.0939  0.0089
#        3       0.0808  0.0070
#
# PAIRWISE PAIRED T-TESTS across 5 seeds (Global Test Set):
#    Metric Model A Model B  Mean A  Mean B   t-stat  p-value  Significant (p<0.05)
# Accuracy     CNN    LSTM  0.9672  0.9823 -19.8390   0.0000                  True
# Accuracy     CNN  BiLSTM  0.9672  0.9827 -19.6918   0.0000                  True
# Accuracy     CNN     GRU  0.9672  0.9815 -18.6044   0.0000                  True
# Accuracy     CNN   BiGRU  0.9672  0.9814 -29.8611   0.0000                  True
# Accuracy    LSTM  BiLSTM  0.9823  0.9827  -1.6760   0.1690                 False
# Accuracy    LSTM     GRU  0.9823  0.9815   3.6087   0.0226                  True
# Accuracy    LSTM   BiGRU  0.9823  0.9814   2.2735   0.0854                 False
# Accuracy  BiLSTM     GRU  0.9827  0.9815  12.5813   0.0002                  True
# Accuracy  BiLSTM   BiGRU  0.9827  0.9814   3.1686   0.0339                  True
# Accuracy     GRU   BiGRU  0.9815  0.9814   0.1511   0.8872                 False
#       F1     CNN    LSTM  0.8812  0.9368 -26.0179   0.0000                  True
#       F1     CNN  BiLSTM  0.8812  0.9385 -33.6419   0.0000                  True
#       F1     CNN     GRU  0.8812  0.9337 -29.3540   0.0000                  True
#       F1     CNN   BiGRU  0.8812  0.9343 -51.5863   0.0000                  True
#       F1    LSTM  BiLSTM  0.9368  0.9385  -1.6171   0.1812                 False
#       F1    LSTM     GRU  0.9368  0.9337   3.5138   0.0246                  True
#       F1    LSTM   BiGRU  0.9368  0.9343   1.6690   0.1704                 False
#       F1  BiLSTM     GRU  0.9385  0.9337  12.3316   0.0002                  True
#       F1  BiLSTM   BiGRU  0.9385  0.9343   2.7788   0.0499                  True
#       F1     GRU   BiGRU  0.9337  0.9343  -0.3980   0.7110                 False
#      AUC     CNN    LSTM  0.9857  0.9929 -16.3077   0.0001                  True
#      AUC     CNN  BiLSTM  0.9857  0.9937 -20.3834   0.0000                  True
#      AUC     CNN     GRU  0.9857  0.9932 -13.3115   0.0002                  True
#      AUC     CNN   BiGRU  0.9857  0.9941 -14.7774   0.0001                  True
#      AUC    LSTM  BiLSTM  0.9929  0.9937  -3.7061   0.0207                  True
#      AUC    LSTM     GRU  0.9929  0.9932  -1.4646   0.2169                 False
#      AUC    LSTM   BiGRU  0.9929  0.9941  -6.2257   0.0034                  True
#      AUC  BiLSTM     GRU  0.9937  0.9932   1.7708   0.1513                 False
#      AUC  BiLSTM   BiGRU  0.9937  0.9941  -1.4459   0.2217                 False
#      AUC     GRU   BiGRU  0.9932  0.9941  -5.8347   0.0043                  True
#     Loss     CNN    LSTM  0.1009  0.0848   7.2951   0.0019                  True
#     Loss     CNN  BiLSTM  0.1009  0.1098  -3.4656   0.0257                  True
#     Loss     CNN     GRU  0.1009  0.0961   1.4893   0.2107                 False
#     Loss     CNN   BiGRU  0.1009  0.1139  -4.6146   0.0099                  True
#     Loss    LSTM  BiLSTM  0.0848  0.1098 -18.8850   0.0000                  True
#     Loss    LSTM     GRU  0.0848  0.0961  -5.2721   0.0062                  True
#     Loss    LSTM   BiGRU  0.0848  0.1139 -19.4267   0.0000                  True
#     Loss  BiLSTM     GRU  0.1098  0.0961  11.7490   0.0003                  True
#     Loss  BiLSTM   BiGRU  0.1098  0.1139  -3.4068   0.0271                  True
#     Loss     GRU   BiGRU  0.0961  0.1139 -10.3410   0.0005                  True
#
# McNEMAR'S TEST — PER SEED (instance-level, Global Test Set):
#   Seed Model A Model B  A right/B wrong  A wrong/B right     stat  p-value  Significant (p<0.05)
#    42     CNN    LSTM              132              434 160.0724   0.0000                  True
#    42     CNN  BiLSTM              111              428 185.2616   0.0000                  True
#    42     CNN     GRU              127              419 155.0934   0.0000                  True
#    42     CNN   BiGRU              137              432 151.9086   0.0000                  True
#    42    LSTM  BiLSTM               95              110   0.9561   0.3282                 False
#    42    LSTM     GRU              121              111   0.3491   0.5546                 False
#    42    LSTM   BiGRU              113              106   0.1644   0.6852                 False
#    42  BiLSTM     GRU              128              103   2.4935   0.1143                 False
#    42  BiLSTM   BiGRU              110               88   2.2273   0.1356                 False
#    42     GRU   BiGRU              128              131   0.0154   0.9011                 False
#     3     CNN    LSTM              144              546 233.0449   0.0000                  True
#     3     CNN  BiLSTM              126              549 263.8281   0.0000                  True
#     3     CNN     GRU              148              543 224.6541   0.0000                  True
#     3     CNN   BiGRU              145              510 202.2840   0.0000                  True
#     3    LSTM  BiLSTM               97              118   1.8605   0.1726                 False
#     3    LSTM     GRU              131              124   0.1412   0.7071                 False
#     3    LSTM   BiGRU              141              104   5.2898   0.0215                  True
#     3  BiLSTM     GRU              112               84   3.7194   0.0538                 False
#     3  BiLSTM   BiGRU              129               71  16.2450   0.0001                  True
#     3     GRU   BiGRU              125               95   3.8227   0.0506                 False
#     7     CNN    LSTM              109              433 192.4889   0.0000                  True
#     7     CNN  BiLSTM              109              449 205.9516   0.0000                  True
#     7     CNN     GRU              113              420 175.6773   0.0000                  True
#     7     CNN   BiGRU               93              425 211.5077   0.0000                  True
#     7    LSTM  BiLSTM              108              124   0.9698   0.3247                 False
#     7    LSTM     GRU              117              100   1.1797   0.2774                 False
#     7    LSTM   BiGRU              115              123   0.2059   0.6500                 False
#     7  BiLSTM     GRU              129               96   4.5511   0.0329                  True
#     7  BiLSTM   BiGRU              104               96   0.2450   0.6206                 False
#     7     GRU   BiGRU              103              128   2.4935   0.1143                 False
#    72     CNN    LSTM              112              484 230.9413   0.0000                  True
#    72     CNN  BiLSTM              105              488 246.0776   0.0000                  True
#    72     CNN     GRU              121              469 204.0831   0.0000                  True
#    72     CNN   BiGRU              128              464 189.5693   0.0000                  True
#    72    LSTM  BiLSTM               98              109   0.4831   0.4870                 False
#    72    LSTM     GRU              128              104   2.2802   0.1310                 False
#    72    LSTM   BiGRU              129               93   5.5180   0.0188                  True
#    72  BiLSTM     GRU              127               92   5.2785   0.0216                  True
#    72  BiLSTM   BiGRU              131               84   9.8419   0.0017                  True
#    72     GRU   BiGRU              120              108   0.5307   0.4663                 False
#    82     CNN    LSTM              117              481 220.3495   0.0000                  True
#    82     CNN  BiLSTM              120              471 207.2758   0.0000                  True
#    82     CNN     GRU              128              456 183.0976   0.0000                  True
#    82     CNN   BiGRU              107              442 203.1985   0.0000                  True
#    82    LSTM  BiLSTM              124              111   0.6128   0.4337                 False
#    82    LSTM     GRU              134               98   5.2802   0.0216                  True
#    82    LSTM   BiGRU              133              104   3.3080   0.0689                 False
#    82  BiLSTM     GRU              131              108   2.0251   0.1547                 False
#    82  BiLSTM   BiGRU              129              113   0.9298   0.3349                 False
#    82     GRU   BiGRU              132              139   0.1328   0.7155                 False
#
# McNEMAR'S TEST — POOLED ACROSS 5 SEEDS (Global Test Set):
#  Model A Model B  A right/B wrong (pooled)  A wrong/B right (pooled)      stat  p-value  Significant (p<0.05)
#     CNN    LSTM                       614                      2378 1038.8265   0.0000                  True
#     CNN  BiLSTM                       571                      2385 1111.9652   0.0000                  True
#     CNN     GRU                       637                      2307  946.1824   0.0000                  True
#     CNN   BiGRU                       610                      2273  958.1145   0.0000                  True
#    LSTM  BiLSTM                       522                       572    2.1947   0.1385                 False
#    LSTM     GRU                       631                       537    7.4050   0.0065                  True
#    LSTM   BiGRU                       631                       530    8.6133   0.0033                  True
#  BiLSTM     GRU                       627                       483   18.4225   0.0000                  True
#  BiLSTM   BiGRU                       603                       452   21.3270   0.0000                  True
#     GRU   BiGRU                       608                       601    0.0298   0.8630                 False
