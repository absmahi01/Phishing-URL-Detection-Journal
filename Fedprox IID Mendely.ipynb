# %%
import numpy as np, pandas as pd, tensorflow as tf, random, time, os
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import *

from scipy.stats import ttest_rel, chi2, binom
from itertools import combinations

# ================= CONFIG =================
LR=0.001; ROUNDS=30; LOCAL_EPOCHS=2; BATCH=16; MU=0.01
CLIENTS=4; SEEDS=[42,3,7,72,82]
MODELS=["CNN","LSTM","BiLSTM","GRU","BiGRU"]
CLIENT_TEST_SIZE=0.2   # local train/test split ratio inside each client
MODEL_SAVE_DIR="saved_models"
os.makedirs(MODEL_SAVE_DIR,exist_ok=True)

# ================= LOAD =================
df=pd.read_csv("dataset_phishing(11k).csv")

# remove text columns like .txt
for col in df.columns:
    if df[col].dtype==object and df[col].astype(str).str.contains(".txt",na=False).any():
        df.drop(columns=[col],inplace=True)

df=df.fillna("unknown")

for col in df.columns:
    if df[col].dtype==object:
        df[col]=LabelEncoder().fit_transform(df[col].astype(str))

X=df.drop("status",axis=1).values
y=df["status"].values

X=StandardScaler().fit_transform(X)

# NOTE: no upfront global train_test_split anymore.
# IID partitioning is applied to the WHOLE dataset per seed below,
# then each client locally splits its own IID shard into train/test.

# ================= HELPERS =================
def set_seed(s):
    random.seed(s); np.random.seed(s); tf.random.set_seed(s)

def iid_partition(X,y,K):
    # IID partition: each class shuffled and split evenly across clients
    idx=np.arange(len(y))
    clients=[[] for _ in range(K)]
    for c in np.unique(y):
        c_idx=idx[y==c]; np.random.shuffle(c_idx)
        split=np.array_split(c_idx,K)
        for i in range(K): clients[i].extend(split[i])
    return [(X[c],y[c]) for c in clients]

def format_xy(Xc,model_name):
    return Xc.reshape(len(Xc),-1,1)

def fedprox_aggregate(global_model,locals,sizes):
    w=[m.get_weights() for m in locals]
    new=[np.average(x,axis=0,weights=sizes) for x in zip(*w)]
    global_model.set_weights(new)

def model_size(model):
    model.save("tmp.h5", include_optimizer=False)
    size=os.path.getsize("tmp.h5")/(1024*1024)
    os.remove("tmp.h5")
    return size

def stats(x,metric):
    x=np.asarray(x,dtype=float)
    x=x[~np.isnan(x)]
    if len(x)==0:
        return np.nan,np.nan,np.nan,np.nan
    mean=np.mean(x); sd=np.std(x)
    ci=1.96*sd/np.sqrt(len(x))
    low,high=mean-ci,mean+ci
    if metric in ["Accuracy","Precision","Recall","F1","AUC","Specificity"]:
        low=max(0,low); high=min(1,high)
    if metric=="MCC":
        low=max(-1,low); high=min(1,high)
    return mean,sd,low,high

def mcnemar_test(y_true_a,y_pred_a,y_true_b,y_pred_b):
    """McNemar's test between two classifiers evaluated on the SAME samples.
    Uses only the discordant pairs (one right, one wrong). Exact binomial
    for small discordant counts (n<25), continuity-corrected chi-square
    otherwise."""
    y_true_a=np.asarray(y_true_a).flatten()
    y_true_b=np.asarray(y_true_b).flatten()
    assert len(y_true_a)==len(y_true_b), "test sets must be the same size"
    assert np.array_equal(y_true_a,y_true_b), "test sets must match (same seed/instances)"

    correct_a=(np.asarray(y_pred_a).flatten()==y_true_a)
    correct_b=(np.asarray(y_pred_b).flatten()==y_true_b)

    n01=int(np.sum(correct_a & ~correct_b))   # A correct, B wrong
    n10=int(np.sum(~correct_a & correct_b))   # A wrong, B correct
    n=n01+n10

    if n==0:
        return np.nan,1.0,n01,n10
    if n<25:
        p=2*min(binom.cdf(min(n01,n10),n,0.5),0.5)   # exact two-sided binomial
        p=min(p,1.0)
        stat=np.nan
    else:
        stat=((abs(n01-n10)-1)**2)/n                  # continuity-corrected chi-square
        p=1-chi2.cdf(stat,1)
    return stat,p,n01,n10

# ================= MODELS =================
def build(name,shape=None,dim=None):
    if name=="CNN":
        m=Sequential([
            Input(shape),
            Conv1D(64,3,activation="relu"),
            Dropout(0.5),
            Conv1D(32,3,activation="relu"),
            GlobalMaxPooling1D(),
            Dense(32,activation="relu"),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="LSTM":
        m=Sequential([
            Input(shape),
            LSTM(128,return_sequences=True),
            Dropout(0.5),
            LSTM(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiLSTM":
        m=Sequential([
            Input(shape),
            Bidirectional(LSTM(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(LSTM(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="GRU":
        m=Sequential([
            Input(shape),
            GRU(128,return_sequences=True),
            Dropout(0.5),
            GRU(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiGRU":
        m=Sequential([
            Input(shape),
            Bidirectional(GRU(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(GRU(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    m.compile(optimizer=Adam(LR),loss="binary_crossentropy",metrics=["accuracy"])
    return m

# ================= STORAGE =================
rows=[]          # global (union-of-clients) test metrics, per (model, seed)
client_rows=[]   # per-client local test metrics, per (model, seed, client)
results_round={m:{"acc":[],"loss":[],"cm":[]} for m in MODELS}

# per-instance predictions, needed for McNemar's test
y_preds={}        # (model, seed) -> y_pred array (0/1), aligned to y_trues[seed]
y_trues={}        # seed -> y_test_global array (0/1) -- same across all models for a given seed

# ================= TRAIN =================
for model_name in MODELS:
    print(f"\n================ MODEL: {model_name} ================")

    for seed in SEEDS:
        print(f"\n------ SEED {seed} ------")
        set_seed(seed)

        # ---- IID partition of the WHOLE dataset across clients ----
        client_full=iid_partition(X,y,CLIENTS)

        # ---- Each client locally splits its own shard into train/test ----
        client_train,client_test=[],[]
        for cid,(Xc,yc) in enumerate(client_full):
            try:
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,stratify=yc,random_state=seed
                )
            except ValueError:
                # fallback if a client shard doesn't have enough of a class to stratify
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,random_state=seed
                )
            client_train.append((Xc_tr,yc_tr))
            client_test.append((Xc_te,yc_te))

        # ---- Global (centralized) test set = union of all clients' local test shards ----
        X_test_global=np.concatenate([Xc for Xc,_ in client_test],axis=0)
        y_test_global=np.concatenate([yc for _,yc in client_test],axis=0)

        create=lambda:build(model_name,shape=(X.shape[1],1))

        fmt=lambda Xc: format_xy(Xc,model_name)

        global_model=create()

        acc_hist,loss_hist=[],[]
        comm=0
        total_train_time=0.0

        for r in range(ROUNDS):
            print(f"\n[Model={model_name} | Seed={seed} | Round={r+1}]")

            locals_=[]; sizes=[]

            for cid,(Xc,yc) in enumerate(client_train):
                m=create()
                m.set_weights(global_model.get_weights())
                global_vars=[tf.constant(w) for w in global_model.get_weights()]

                Xc_fmt=fmt(Xc)
                yc_f=yc.astype("float32").reshape(-1,1)
                n=len(yc)
                optimizer=m.optimizer
                bce=tf.keras.losses.BinaryCrossentropy()

                t0=time.time()
                for epoch in range(LOCAL_EPOCHS):
                    perm=np.random.permutation(n)
                    for start in range(0,n,BATCH):
                        bidx=perm[start:start+BATCH]
                        xb=Xc_fmt[bidx]; yb=yc_f[bidx]
                        with tf.GradientTape() as tape:
                            preds=m(xb,training=True)
                            loss=bce(yb,preds)
                            prox=tf.add_n([
                                tf.reduce_sum(tf.square(w-gw))
                                for w,gw in zip(m.trainable_variables,global_vars)
                            ])
                            loss=loss+(MU/2.0)*prox
                        grads=tape.gradient(loss,m.trainable_variables)
                        optimizer.apply_gradients(zip(grads,m.trainable_variables))
                t1=time.time()
                total_train_time+=(t1-t0)

                train_loss,train_acc=m.evaluate(Xc_fmt,yc,verbose=0)

                print(f" Client {cid} → Loss={train_loss:.4f}, Acc={train_acc:.4f}, Time={t1-t0:.2f}s, N={len(yc)}")

                locals_.append(m); sizes.append(len(yc))

            fedprox_aggregate(global_model,locals_,sizes)

            loss,acc=global_model.evaluate(fmt(X_test_global),y_test_global,verbose=0)

            print(f" >>> GLOBAL (centralized test) → Loss={loss:.4f}, Acc={acc:.4f}")

            acc_hist.append(acc); loss_hist.append(loss)

            # bytes per weight (float32=4 bytes), sent down to each client AND back up from each client
            weight_bytes=sum([w.size for w in global_model.get_weights()])*4
            comm+=weight_bytes*CLIENTS*2

        # ================= FINAL GLOBAL TEST METRICS =================
        t0=time.time()
        y_prob=global_model.predict(fmt(X_test_global),verbose=0)
        inference_time=time.time()-t0

        y_pred=(y_prob>0.5).astype(int)

        # ---- Save per-instance predictions for McNemar's test ----
        y_preds[(model_name,seed)]=y_pred.flatten()
        if seed not in y_trues:
            y_trues[seed]=y_test_global.flatten()
        else:
            # sanity check: every model must see the identical test set for this seed
            assert np.array_equal(y_trues[seed],y_test_global.flatten()), \
                f"Test set mismatch for seed {seed} — McNemar's test requires identical instances across models."

        tn,fp,fn,tp=confusion_matrix(y_test_global,y_pred).ravel()

        # ---- Save this trained global model to disk ----
        model_path=os.path.join(MODEL_SAVE_DIR,f"{model_name}_seed{seed}.keras")
        global_model.save(model_path)
        print(f" [saved] {model_path}")

        rows.append({
            "Model":model_name,
            "Seed":seed,
            "Loss":log_loss(y_test_global,y_prob),
            "Accuracy":accuracy_score(y_test_global,y_pred),
            "Precision":precision_score(y_test_global,y_pred),
            "Recall":recall_score(y_test_global,y_pred),
            "F1":f1_score(y_test_global,y_pred),
            "MCC":matthews_corrcoef(y_test_global,y_pred),
            "AUC":roc_auc_score(y_test_global,y_prob),
            "Specificity":tn/(tn+fp),
            "Training_Time_sec":total_train_time,
            "Inference_Time_sec":inference_time,
            "Model_Size_MB":model_size(global_model),
            "Comm_per_round_MB":comm/(ROUNDS*1024*1024),
            "Total_Comm_MB":comm/(1024*1024),
            "Saved_Model_Path":model_path
        })

        results_round[model_name]["acc"].append(acc_hist)
        results_round[model_name]["loss"].append(loss_hist)
        results_round[model_name]["cm"].append(confusion_matrix(y_test_global,y_pred))

        # ================= PER-CLIENT LOCAL TEST EVALUATION =================
        for cid,(Xc_te,yc_te) in enumerate(client_test):
            yc_prob=global_model.predict(fmt(Xc_te),verbose=0)
            yc_pred=(yc_prob>0.5).astype(int)

            cm_c=confusion_matrix(yc_te,yc_pred,labels=[0,1])
            tn_c,fp_c,fn_c,tp_c=cm_c.ravel()

            auc_val=roc_auc_score(yc_te,yc_prob) if len(np.unique(yc_te))>1 else np.nan

            client_rows.append({
                "Model":model_name,
                "Seed":seed,
                "Client":cid,
                "N_test":len(yc_te),
                "Loss":log_loss(yc_te,yc_prob,labels=[0,1]),
                "Accuracy":accuracy_score(yc_te,yc_pred),
                "Precision":precision_score(yc_te,yc_pred,zero_division=0),
                "Recall":recall_score(yc_te,yc_pred,zero_division=0),
                "F1":f1_score(yc_te,yc_pred,zero_division=0),
                "MCC":matthews_corrcoef(yc_te,yc_pred),
                "AUC":auc_val,
                "Specificity":(tn_c/(tn_c+fp_c)) if (tn_c+fp_c)>0 else np.nan
            })

# ================= PRINT ALL CONFUSION MATRICES PER SEED (GLOBAL TEST) =================
for m in MODELS:
    print(f"\n=== {m}: Global Test Confusion Matrices per Seed ===")
    for seed,cm in zip(SEEDS,results_round[m]["cm"]):
        print(f"Seed {seed}:\n{cm}")

# ================= MEAN OVER SEEDS (GLOBAL TEST, per-round curves + avg cm) =================
for m in MODELS:
    results_round[m]["acc"]=np.mean(results_round[m]["acc"],axis=0)
    results_round[m]["loss"]=np.mean(results_round[m]["loss"],axis=0)
    results_round[m]["cm"]=np.mean(results_round[m]["cm"],axis=0)

for m in MODELS:
    print(f"\n=== {m} (Global Test, averaged over {len(SEEDS)} seeds) ===")
    print("Confusion Matrix (avg):\n",np.round(results_round[m]["cm"],2))
    print("Accuracy per round:",np.round(results_round[m]["acc"],4))
    print("Loss per round:",np.round(results_round[m]["loss"],4))

# ================= PER-MODEL SUMMARY (ALL METRICS incl. time & comm cost, avg over 5 seeds) =================
results_df=pd.DataFrame(rows)

summary_metrics=["Loss","Accuracy","Precision","Recall","F1","MCC","AUC","Specificity",
                  "Training_Time_sec","Inference_Time_sec","Model_Size_MB",
                  "Comm_per_round_MB","Total_Comm_MB"]

per_model_summary=[]
for m in MODELS:
    sub=results_df[results_df["Model"]==m]
    for metric in summary_metrics:
        mean,sd,low,high=stats(sub[metric],metric)
        per_model_summary.append({
            "Model":m,
            "Metric":metric,
            "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
            "95% CI":f"[{low:.4f}, {high:.4f}]"
        })

per_model_summary_df=pd.DataFrame(per_model_summary)
print(f"\nPER-MODEL SUMMARY (mean ± sd, 95% CI over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_summary_df.to_string(index=False))

# wide pivot: one row per model, one column per metric, "mean [low, high]"
per_model_wide=per_model_summary_df.copy()
per_model_wide["Mean [95% CI]"]=per_model_wide.apply(
    lambda r: r["Mean ± SD"].split(" ± ")[0]+" "+r["95% CI"], axis=1
)
per_model_wide=per_model_wide.pivot(index="Model",columns="Metric",values="Mean [95% CI]")
per_model_wide=per_model_wide[summary_metrics]  # keep original metric order
print(f"\nPER-MODEL SUMMARY, WIDE (mean [95% CI] over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_wide.to_string())

# overall pooled summary (all models & seeds together) kept for reference
overall_summary=[]
for metric in summary_metrics:
    mean,sd,low,high=stats(results_df[metric],metric)
    overall_summary.append({
        "Metric":metric,
        "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
        "95% CI":f"[{low:.4f},{high:.4f}]"
    })
overall_summary_df=pd.DataFrame(overall_summary)
print(f"\nSAVED MODELS ({len(results_df)} total, in '{MODEL_SAVE_DIR}/'):\n",
      results_df[["Model","Seed","Saved_Model_Path"]].to_string(index=False))
print("\nOVERALL SUMMARY (all models & seeds pooled):\n",overall_summary_df)

# ================= PER-CLIENT TEST SUMMARY, averaged over 5 seeds =================
client_df=pd.DataFrame(client_rows)
client_metrics=["Accuracy","Precision","Recall","F1","MCC","AUC","Specificity","Loss"]

per_client_summary=(
    client_df.groupby(["Model","Client"])[client_metrics]
    .agg(["mean","std"])
    .round(4)
)
print(f"\nPER-CLIENT TEST SUMMARY (mean/std over {len(SEEDS)} seeds):\n",per_client_summary)

# ================= PAIRWISE PAIRED T-TESTS ACROSS MODELS (same seeds) =================
paired_test_metrics=["Accuracy","F1","AUC","Loss"]

pairwise_rows=[]
for metric in paired_test_metrics:
    for m1,m2 in combinations(MODELS,2):
        a=results_df[results_df["Model"]==m1].sort_values("Seed")[metric].values
        b=results_df[results_df["Model"]==m2].sort_values("Seed")[metric].values
        t_stat,p_val=ttest_rel(a,b)
        pairwise_rows.append({
            "Metric":metric,"Model A":m1,"Model B":m2,
            "Mean A":round(a.mean(),4),"Mean B":round(b.mean(),4),
            "t-stat":round(t_stat,4),"p-value":round(p_val,4),
            "Significant (p<0.05)":p_val<0.05
        })

pairwise_df=pd.DataFrame(pairwise_rows)
print(f"\nPAIRWISE PAIRED T-TESTS across {len(SEEDS)} seeds (Global Test Set):\n",
      pairwise_df.to_string(index=False))

# ================= McNEMAR'S TEST (per-instance, per seed + pooled across seeds) =================
mcnemar_per_seed_rows=[]
for seed in SEEDS:
    y_true=y_trues[seed]
    for m1,m2 in combinations(MODELS,2):
        stat,p,n01,n10=mcnemar_test(y_true,y_preds[(m1,seed)],y_true,y_preds[(m2,seed)])
        mcnemar_per_seed_rows.append({
            "Seed":seed,"Model A":m1,"Model B":m2,
            "A right/B wrong":n01,"A wrong/B right":n10,
            "stat":round(stat,4) if not np.isnan(stat) else "exact",
            "p-value":round(p,4),"Significant (p<0.05)":p<0.05
        })

mcnemar_per_seed_df=pd.DataFrame(mcnemar_per_seed_rows)
print(f"\nMcNEMAR'S TEST — PER SEED (instance-level, Global Test Set):\n",
      mcnemar_per_seed_df.to_string(index=False))

# pooled version: sum discordant counts across all 5 seeds (more statistical power)
mcnemar_pooled_rows=[]
for m1,m2 in combinations(MODELS,2):
    n01_total=0; n10_total=0
    for seed in SEEDS:
        y_true=y_trues[seed]
        correct_a=(y_preds[(m1,seed)]==y_true)
        correct_b=(y_preds[(m2,seed)]==y_true)
        n01_total+=int(np.sum(correct_a & ~correct_b))
        n10_total+=int(np.sum(~correct_a & correct_b))
    n=n01_total+n10_total
    if n==0:
        stat,p=np.nan,1.0
    elif n<25:
        p=min(2*min(binom.cdf(min(n01_total,n10_total),n,0.5),0.5),1.0); stat=np.nan
    else:
        stat=((abs(n01_total-n10_total)-1)**2)/n
        p=1-chi2.cdf(stat,1)
    mcnemar_pooled_rows.append({
        "Model A":m1,"Model B":m2,
        "A right/B wrong (pooled)":n01_total,"A wrong/B right (pooled)":n10_total,
        "stat":round(stat,4) if not np.isnan(stat) else "exact",
        "p-value":round(p,4),"Significant (p<0.05)":p<0.05
    })

mcnemar_pooled_df=pd.DataFrame(mcnemar_pooled_rows)
print(f"\nMcNEMAR'S TEST — POOLED ACROSS {len(SEEDS)} SEEDS (Global Test Set):\n",
      mcnemar_pooled_df.to_string(index=False))

# ================= PLOTS =================
rounds=np.arange(1,ROUNDS+1)

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["acc"],label=m)
plt.title("Accuracy vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Accuracy")
plt.legend(); plt.grid(); plt.show()

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["loss"],label=m)
plt.title("Loss vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Loss")
plt.legend(); plt.grid(); plt.show()
# Out:
# C:\Users\USER\anaconda3\envs\py310\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.5.0) or chardet (6.0.0.post1)/charset_normalizer (3.4.3) doesn't match a supported version!
#   warnings.warn(
# ================ MODEL: CNN ================
#
# ------ SEED 42 ------
#
# [Model=CNN | Seed=42 | Round=1]
#  Client 0 → Loss=0.6502, Acc=0.6444, Time=7.91s, N=2286
#  Client 1 → Loss=0.6712, Acc=0.5958, Time=3.66s, N=2286
#  Client 2 → Loss=0.6579, Acc=0.6461, Time=3.55s, N=2286
#  Client 3 → Loss=0.6367, Acc=0.6607, Time=3.60s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6583, Acc=0.6289
#
# [Model=CNN | Seed=42 | Round=2]
#  Client 0 → Loss=0.6321, Acc=0.6522, Time=3.61s, N=2286
#  Client 1 → Loss=0.6493, Acc=0.6299, Time=3.63s, N=2286
#  Client 2 → Loss=0.6550, Acc=0.6207, Time=3.63s, N=2286
#  Client 3 → Loss=0.6492, Acc=0.6270, Time=3.66s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6506, Acc=0.6272
#
# [Model=CNN | Seed=42 | Round=3]
#  Client 0 → Loss=0.6344, Acc=0.6487, Time=3.69s, N=2286
#  Client 1 → Loss=0.6411, Acc=0.6605, Time=3.98s, N=2286
#  Client 2 → Loss=0.6555, Acc=0.6019, Time=4.28s, N=2286
#  Client 3 → Loss=0.6428, Acc=0.6427, Time=4.34s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6460, Acc=0.6219
#
# [Model=CNN | Seed=42 | Round=4]
#  Client 0 → Loss=0.6409, Acc=0.6181, Time=4.15s, N=2286
#  Client 1 → Loss=0.6468, Acc=0.6150, Time=4.32s, N=2286
#  Client 2 → Loss=0.6416, Acc=0.6360, Time=4.26s, N=2286
#  Client 3 → Loss=0.6118, Acc=0.6835, Time=4.28s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6435, Acc=0.6158
#
# [Model=CNN | Seed=42 | Round=5]
#  Client 0 → Loss=0.6168, Acc=0.6444, Time=3.88s, N=2286
#  Client 1 → Loss=0.6337, Acc=0.6177, Time=3.83s, N=2286
#  Client 2 → Loss=0.6183, Acc=0.6387, Time=3.78s, N=2286
#  Client 3 → Loss=0.6010, Acc=0.6664, Time=3.96s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6241, Acc=0.6158
#
# [Model=CNN | Seed=42 | Round=6]
#  Client 0 → Loss=0.6055, Acc=0.6347, Time=3.91s, N=2286
#  Client 1 → Loss=0.5713, Acc=0.6675, Time=3.80s, N=2286
#  Client 2 → Loss=0.5678, Acc=0.6697, Time=3.85s, N=2286
#  Client 3 → Loss=0.5492, Acc=0.7053, Time=3.87s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5822, Acc=0.6517
#
# [Model=CNN | Seed=42 | Round=7]
#  Client 0 → Loss=0.5640, Acc=0.6846, Time=3.98s, N=2286
#  Client 1 → Loss=0.5072, Acc=0.7353, Time=4.05s, N=2286
#  Client 2 → Loss=0.5311, Acc=0.7196, Time=3.87s, N=2286
#  Client 3 → Loss=0.4901, Acc=0.7723, Time=4.10s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5400, Acc=0.6941
#
# [Model=CNN | Seed=42 | Round=8]
#  Client 0 → Loss=0.4982, Acc=0.7555, Time=3.99s, N=2286
#  Client 1 → Loss=0.3930, Acc=0.8381, Time=3.95s, N=2286
#  Client 2 → Loss=0.4260, Acc=0.8097, Time=3.61s, N=2286
#  Client 3 → Loss=0.4220, Acc=0.8209, Time=3.61s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4452, Acc=0.7872
#
# [Model=CNN | Seed=42 | Round=9]
#  Client 0 → Loss=0.4453, Acc=0.7857, Time=3.66s, N=2286
#  Client 1 → Loss=0.4066, Acc=0.8185, Time=3.65s, N=2286
#  Client 2 → Loss=0.4258, Acc=0.7953, Time=3.58s, N=2286
#  Client 3 → Loss=0.3523, Acc=0.8555, Time=3.66s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4290, Acc=0.8016
#
# [Model=CNN | Seed=42 | Round=10]
#  Client 0 → Loss=0.3504, Acc=0.8552, Time=3.61s, N=2286
#  Client 1 → Loss=0.3925, Acc=0.8180, Time=3.91s, N=2286
#  Client 2 → Loss=0.4106, Acc=0.8097, Time=4.19s, N=2286
#  Client 3 → Loss=0.3994, Acc=0.8205, Time=4.31s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4059, Acc=0.8156
#
# [Model=CNN | Seed=42 | Round=11]
#  Client 0 → Loss=0.3523, Acc=0.8482, Time=4.18s, N=2286
#  Client 1 → Loss=0.3440, Acc=0.8478, Time=4.24s, N=2286
#  Client 2 → Loss=0.3731, Acc=0.8255, Time=4.28s, N=2286
#  Client 3 → Loss=0.3720, Acc=0.8306, Time=4.25s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3765, Acc=0.8304
#
# [Model=CNN | Seed=42 | Round=12]
#  Client 0 → Loss=0.3456, Acc=0.8504, Time=3.93s, N=2286
#  Client 1 → Loss=0.3437, Acc=0.8539, Time=3.88s, N=2286
#  Client 2 → Loss=0.3949, Acc=0.8154, Time=3.76s, N=2286
#  Client 3 → Loss=0.3127, Acc=0.8748, Time=3.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3698, Acc=0.8339
#
# [Model=CNN | Seed=42 | Round=13]
#  Client 0 → Loss=0.3275, Acc=0.8653, Time=3.81s, N=2286
#  Client 1 → Loss=0.3409, Acc=0.8521, Time=3.79s, N=2286
#  Client 2 → Loss=0.3372, Acc=0.8556, Time=3.81s, N=2286
#  Client 3 → Loss=0.3237, Acc=0.8542, Time=3.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3549, Acc=0.8483
#
# [Model=CNN | Seed=42 | Round=14]
#  Client 0 → Loss=0.3265, Acc=0.8705, Time=3.85s, N=2286
#  Client 1 → Loss=0.3135, Acc=0.8675, Time=3.92s, N=2286
#  Client 2 → Loss=0.3348, Acc=0.8508, Time=4.01s, N=2286
#  Client 3 → Loss=0.3259, Acc=0.8603, Time=3.92s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3448, Acc=0.8523
#
# [Model=CNN | Seed=42 | Round=15]
#  Client 0 → Loss=0.3270, Acc=0.8613, Time=3.93s, N=2286
#  Client 1 → Loss=0.3160, Acc=0.8675, Time=3.84s, N=2286
#  Client 2 → Loss=0.3269, Acc=0.8548, Time=3.82s, N=2286
#  Client 3 → Loss=0.3556, Acc=0.8468, Time=3.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3471, Acc=0.8540
#
# [Model=CNN | Seed=42 | Round=16]
#  Client 0 → Loss=0.3418, Acc=0.8526, Time=3.60s, N=2286
#  Client 1 → Loss=0.3179, Acc=0.8648, Time=3.63s, N=2286
#  Client 2 → Loss=0.3415, Acc=0.8473, Time=3.58s, N=2286
#  Client 3 → Loss=0.2963, Acc=0.8818, Time=3.67s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3400, Acc=0.8518
#
# [Model=CNN | Seed=42 | Round=17]
#  Client 0 → Loss=0.2959, Acc=0.8766, Time=3.67s, N=2286
#  Client 1 → Loss=0.2992, Acc=0.8745, Time=3.65s, N=2286
#  Client 2 → Loss=0.3166, Acc=0.8596, Time=3.95s, N=2286
#  Client 3 → Loss=0.3005, Acc=0.8726, Time=4.16s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3197, Acc=0.8658
#
# [Model=CNN | Seed=42 | Round=18]
#  Client 0 → Loss=0.2924, Acc=0.8858, Time=4.17s, N=2286
#  Client 1 → Loss=0.3377, Acc=0.8491, Time=4.08s, N=2286
#  Client 2 → Loss=0.3267, Acc=0.8543, Time=4.27s, N=2286
#  Client 3 → Loss=0.3111, Acc=0.8695, Time=4.21s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3298, Acc=0.8588
#
# [Model=CNN | Seed=42 | Round=19]
#  Client 0 → Loss=0.3030, Acc=0.8745, Time=4.13s, N=2286
#  Client 1 → Loss=0.2865, Acc=0.8876, Time=3.77s, N=2286
#  Client 2 → Loss=0.2804, Acc=0.8841, Time=3.72s, N=2286
#  Client 3 → Loss=0.2708, Acc=0.8905, Time=3.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2955, Acc=0.8807
#
# [Model=CNN | Seed=42 | Round=20]
#  Client 0 → Loss=0.3047, Acc=0.8745, Time=3.77s, N=2286
#  Client 1 → Loss=0.2980, Acc=0.8727, Time=3.72s, N=2286
#  Client 2 → Loss=0.2799, Acc=0.8898, Time=3.74s, N=2286
#  Client 3 → Loss=0.2883, Acc=0.8792, Time=3.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3060, Acc=0.8733
#
# [Model=CNN | Seed=42 | Round=21]
#  Client 0 → Loss=0.2874, Acc=0.8841, Time=3.87s, N=2286
#  Client 1 → Loss=0.3093, Acc=0.8670, Time=4.19s, N=2286
#  Client 2 → Loss=0.2804, Acc=0.8871, Time=4.18s, N=2286
#  Client 3 → Loss=0.2931, Acc=0.8757, Time=4.16s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3054, Acc=0.8781
#
# [Model=CNN | Seed=42 | Round=22]
#  Client 0 → Loss=0.2987, Acc=0.8753, Time=4.16s, N=2286
#  Client 1 → Loss=0.3008, Acc=0.8670, Time=4.14s, N=2286
#  Client 2 → Loss=0.2769, Acc=0.8871, Time=4.19s, N=2286
#  Client 3 → Loss=0.2799, Acc=0.8857, Time=3.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3028, Acc=0.8767
#
# [Model=CNN | Seed=42 | Round=23]
#  Client 0 → Loss=0.2821, Acc=0.8863, Time=3.49s, N=2286
#  Client 1 → Loss=0.2709, Acc=0.8963, Time=3.62s, N=2286
#  Client 2 → Loss=0.2874, Acc=0.8863, Time=3.78s, N=2286
#  Client 3 → Loss=0.2795, Acc=0.8800, Time=3.67s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2914, Acc=0.8807
#
# [Model=CNN | Seed=42 | Round=24]
#  Client 0 → Loss=0.2654, Acc=0.8994, Time=3.68s, N=2286
#  Client 1 → Loss=0.2550, Acc=0.9038, Time=3.64s, N=2286
#  Client 2 → Loss=0.2807, Acc=0.8871, Time=3.71s, N=2286
#  Client 3 → Loss=0.2640, Acc=0.8914, Time=4.08s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2800, Acc=0.8877
#
# [Model=CNN | Seed=42 | Round=25]
#  Client 0 → Loss=0.3105, Acc=0.8648, Time=4.21s, N=2286
#  Client 1 → Loss=0.2693, Acc=0.8876, Time=4.20s, N=2286
#  Client 2 → Loss=0.2630, Acc=0.8968, Time=4.27s, N=2286
#  Client 3 → Loss=0.2631, Acc=0.8897, Time=4.27s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2921, Acc=0.8776
#
# [Model=CNN | Seed=42 | Round=26]
#  Client 0 → Loss=0.3242, Acc=0.8605, Time=4.16s, N=2286
#  Client 1 → Loss=0.2576, Acc=0.8955, Time=3.97s, N=2286
#  Client 2 → Loss=0.2958, Acc=0.8740, Time=3.86s, N=2286
#  Client 3 → Loss=0.2739, Acc=0.8805, Time=3.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2931, Acc=0.8772
#
# [Model=CNN | Seed=42 | Round=27]
#  Client 0 → Loss=0.2501, Acc=0.9038, Time=3.78s, N=2286
#  Client 1 → Loss=0.2633, Acc=0.8902, Time=3.88s, N=2286
#  Client 2 → Loss=0.2451, Acc=0.9011, Time=3.83s, N=2286
#  Client 3 → Loss=0.2611, Acc=0.8879, Time=3.87s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2675, Acc=0.8890
#
# [Model=CNN | Seed=42 | Round=28]
#  Client 0 → Loss=0.2479, Acc=0.9016, Time=3.84s, N=2286
#  Client 1 → Loss=0.2658, Acc=0.8920, Time=3.91s, N=2286
#  Client 2 → Loss=0.2785, Acc=0.8863, Time=3.92s, N=2286
#  Client 3 → Loss=0.2652, Acc=0.8901, Time=3.89s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2742, Acc=0.8864
#
# [Model=CNN | Seed=42 | Round=29]
#  Client 0 → Loss=0.3223, Acc=0.8714, Time=3.80s, N=2286
#  Client 1 → Loss=0.2489, Acc=0.8994, Time=3.92s, N=2286
#  Client 2 → Loss=0.2585, Acc=0.8950, Time=3.79s, N=2286
#  Client 3 → Loss=0.2646, Acc=0.8884, Time=3.89s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2776, Acc=0.8837
#
# [Model=CNN | Seed=42 | Round=30]
#  Client 0 → Loss=0.2623, Acc=0.9024, Time=3.67s, N=2286
#  Client 1 → Loss=0.2394, Acc=0.9064, Time=3.63s, N=2286
#  Client 2 → Loss=0.2601, Acc=0.8933, Time=3.64s, N=2286
#  Client 3 → Loss=0.2531, Acc=0.8897, Time=3.64s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2646, Acc=0.8912
#  [saved] saved_models\CNN_seed42.keras
#
# ------ SEED 3 ------
#
# [Model=CNN | Seed=3 | Round=1]
#  Client 0 → Loss=0.6460, Acc=0.6417, Time=3.58s, N=2286
#  Client 1 → Loss=0.6472, Acc=0.6584, Time=3.51s, N=2286
#  Client 2 → Loss=0.6478, Acc=0.6535, Time=3.98s, N=2286
#  Client 3 → Loss=0.6548, Acc=0.6440, Time=4.08s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6574, Acc=0.6451
#
# [Model=CNN | Seed=3 | Round=2]
#  Client 0 → Loss=0.6379, Acc=0.6632, Time=4.05s, N=2286
#  Client 1 → Loss=0.6630, Acc=0.5910, Time=4.02s, N=2286
#  Client 2 → Loss=0.6367, Acc=0.6662, Time=4.11s, N=2286
#  Client 3 → Loss=0.6511, Acc=0.6493, Time=4.08s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6565, Acc=0.6385
#
# [Model=CNN | Seed=3 | Round=3]
#  Client 0 → Loss=0.6455, Acc=0.6387, Time=4.08s, N=2286
#  Client 1 → Loss=0.6382, Acc=0.6649, Time=3.76s, N=2286
#  Client 2 → Loss=0.6321, Acc=0.6575, Time=3.76s, N=2286
#  Client 3 → Loss=0.6471, Acc=0.6357, Time=3.60s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6496, Acc=0.6346
#
# [Model=CNN | Seed=3 | Round=4]
#  Client 0 → Loss=0.6412, Acc=0.6304, Time=3.77s, N=2286
#  Client 1 → Loss=0.6214, Acc=0.6658, Time=3.77s, N=2286
#  Client 2 → Loss=0.6176, Acc=0.6732, Time=3.77s, N=2286
#  Client 3 → Loss=0.6671, Acc=0.5832, Time=3.82s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6485, Acc=0.6285
#
# [Model=CNN | Seed=3 | Round=5]
#  Client 0 → Loss=0.6292, Acc=0.6509, Time=3.75s, N=2286
#  Client 1 → Loss=0.6474, Acc=0.6216, Time=3.91s, N=2286
#  Client 2 → Loss=0.5983, Acc=0.6868, Time=3.88s, N=2286
#  Client 3 → Loss=0.6392, Acc=0.6340, Time=3.85s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6393, Acc=0.6385
#
# [Model=CNN | Seed=3 | Round=6]
#  Client 0 → Loss=0.5980, Acc=0.6815, Time=3.74s, N=2286
#  Client 1 → Loss=0.6058, Acc=0.6549, Time=3.85s, N=2286
#  Client 2 → Loss=0.5929, Acc=0.6868, Time=3.83s, N=2286
#  Client 3 → Loss=0.6190, Acc=0.6462, Time=3.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6213, Acc=0.6473
#
# [Model=CNN | Seed=3 | Round=7]
#  Client 0 → Loss=0.6198, Acc=0.6172, Time=3.63s, N=2286
#  Client 1 → Loss=0.5858, Acc=0.6605, Time=3.59s, N=2286
#  Client 2 → Loss=0.5692, Acc=0.6859, Time=3.56s, N=2286
#  Client 3 → Loss=0.5748, Acc=0.6848, Time=3.58s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6081, Acc=0.6324
#
# [Model=CNN | Seed=3 | Round=8]
#  Client 0 → Loss=0.5951, Acc=0.6164, Time=3.57s, N=2286
#  Client 1 → Loss=0.5052, Acc=0.7612, Time=3.62s, N=2286
#  Client 2 → Loss=0.5413, Acc=0.6842, Time=3.59s, N=2286
#  Client 3 → Loss=0.5168, Acc=0.7592, Time=3.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5588, Acc=0.6639
#
# [Model=CNN | Seed=3 | Round=9]
#  Client 0 → Loss=0.5202, Acc=0.7231, Time=4.11s, N=2286
#  Client 1 → Loss=0.5086, Acc=0.7432, Time=4.18s, N=2286
#  Client 2 → Loss=0.4615, Acc=0.7857, Time=4.19s, N=2286
#  Client 3 → Loss=0.5402, Acc=0.6843, Time=4.17s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5299, Acc=0.7098
#
# [Model=CNN | Seed=3 | Round=10]
#  Client 0 → Loss=0.4523, Acc=0.7975, Time=4.13s, N=2286
#  Client 1 → Loss=0.4343, Acc=0.8097, Time=4.15s, N=2286
#  Client 2 → Loss=0.4847, Acc=0.7612, Time=3.96s, N=2286
#  Client 3 → Loss=0.4432, Acc=0.8030, Time=3.62s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4713, Acc=0.7802
#
# [Model=CNN | Seed=3 | Round=11]
#  Client 0 → Loss=0.5223, Acc=0.7590, Time=3.57s, N=2286
#  Client 1 → Loss=0.4709, Acc=0.7896, Time=3.58s, N=2286
#  Client 2 → Loss=0.3944, Acc=0.8263, Time=3.72s, N=2286
#  Client 3 → Loss=0.4705, Acc=0.7815, Time=3.61s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4767, Acc=0.7775
#
# [Model=CNN | Seed=3 | Round=12]
#  Client 0 → Loss=0.5260, Acc=0.7594, Time=3.60s, N=2286
#  Client 1 → Loss=0.4122, Acc=0.8198, Time=3.62s, N=2286
#  Client 2 → Loss=0.3991, Acc=0.8215, Time=4.02s, N=2286
#  Client 3 → Loss=0.4034, Acc=0.8183, Time=4.12s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4473, Acc=0.7968
#
# [Model=CNN | Seed=3 | Round=13]
#  Client 0 → Loss=0.4001, Acc=0.8198, Time=4.18s, N=2286
#  Client 1 → Loss=0.4882, Acc=0.7760, Time=4.08s, N=2286
#  Client 2 → Loss=0.4595, Acc=0.7892, Time=4.16s, N=2286
#  Client 3 → Loss=0.4062, Acc=0.8205, Time=4.32s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4605, Acc=0.7898
#
# [Model=CNN | Seed=3 | Round=14]
#  Client 0 → Loss=0.4370, Acc=0.8045, Time=4.17s, N=2286
#  Client 1 → Loss=0.3730, Acc=0.8351, Time=3.69s, N=2286
#  Client 2 → Loss=0.3964, Acc=0.8224, Time=3.67s, N=2286
#  Client 3 → Loss=0.3978, Acc=0.8152, Time=3.68s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4280, Acc=0.8112
#
# [Model=CNN | Seed=3 | Round=15]
#  Client 0 → Loss=0.4025, Acc=0.8215, Time=3.69s, N=2286
#  Client 1 → Loss=0.3355, Acc=0.8565, Time=3.64s, N=2286
#  Client 2 → Loss=0.3484, Acc=0.8526, Time=3.66s, N=2286
#  Client 3 → Loss=0.3374, Acc=0.8555, Time=3.66s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3753, Acc=0.8383
#
# [Model=CNN | Seed=3 | Round=16]
#  Client 0 → Loss=0.3602, Acc=0.8456, Time=4.05s, N=2286
#  Client 1 → Loss=0.3787, Acc=0.8316, Time=4.33s, N=2286
#  Client 2 → Loss=0.3553, Acc=0.8491, Time=4.33s, N=2286
#  Client 3 → Loss=0.3959, Acc=0.8244, Time=4.36s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3961, Acc=0.8291
#
# [Model=CNN | Seed=3 | Round=17]
#  Client 0 → Loss=0.4230, Acc=0.8088, Time=4.28s, N=2286
#  Client 1 → Loss=0.3269, Acc=0.8600, Time=4.30s, N=2286
#  Client 2 → Loss=0.3865, Acc=0.8276, Time=4.35s, N=2286
#  Client 3 → Loss=0.3831, Acc=0.8349, Time=3.94s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4035, Acc=0.8247
#
# [Model=CNN | Seed=3 | Round=18]
#  Client 0 → Loss=0.3581, Acc=0.8386, Time=3.90s, N=2286
#  Client 1 → Loss=0.3400, Acc=0.8526, Time=3.92s, N=2286
#  Client 2 → Loss=0.3453, Acc=0.8465, Time=3.88s, N=2286
#  Client 3 → Loss=0.3172, Acc=0.8651, Time=3.97s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3613, Acc=0.8365
#
# [Model=CNN | Seed=3 | Round=19]
#  Client 0 → Loss=0.3645, Acc=0.8412, Time=3.91s, N=2286
#  Client 1 → Loss=0.3197, Acc=0.8631, Time=3.93s, N=2286
#  Client 2 → Loss=0.3051, Acc=0.8701, Time=4.06s, N=2286
#  Client 3 → Loss=0.2992, Acc=0.8757, Time=4.05s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3438, Acc=0.8531
#
# [Model=CNN | Seed=3 | Round=20]
#  Client 0 → Loss=0.3947, Acc=0.8263, Time=4.02s, N=2286
#  Client 1 → Loss=0.2882, Acc=0.8797, Time=4.04s, N=2286
#  Client 2 → Loss=0.3002, Acc=0.8749, Time=3.99s, N=2286
#  Client 3 → Loss=0.2998, Acc=0.8774, Time=4.01s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3367, Acc=0.8566
#
# [Model=CNN | Seed=3 | Round=21]
#  Client 0 → Loss=0.3444, Acc=0.8447, Time=4.01s, N=2286
#  Client 1 → Loss=0.2932, Acc=0.8731, Time=3.71s, N=2286
#  Client 2 → Loss=0.3338, Acc=0.8556, Time=3.68s, N=2286
#  Client 3 → Loss=0.3221, Acc=0.8647, Time=3.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3482, Acc=0.8488
#
# [Model=CNN | Seed=3 | Round=22]
#  Client 0 → Loss=0.2963, Acc=0.8863, Time=3.69s, N=2286
#  Client 1 → Loss=0.2570, Acc=0.8998, Time=3.76s, N=2286
#  Client 2 → Loss=0.3665, Acc=0.8495, Time=3.71s, N=2286
#  Client 3 → Loss=0.2988, Acc=0.8735, Time=3.68s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3220, Acc=0.8641
#
# [Model=CNN | Seed=3 | Round=23]
#  Client 0 → Loss=0.3303, Acc=0.8574, Time=3.95s, N=2286
#  Client 1 → Loss=0.2505, Acc=0.9046, Time=4.38s, N=2286
#  Client 2 → Loss=0.3389, Acc=0.8596, Time=4.35s, N=2286
#  Client 3 → Loss=0.3235, Acc=0.8647, Time=4.30s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3282, Acc=0.8628
#
# [Model=CNN | Seed=3 | Round=24]
#  Client 0 → Loss=0.3094, Acc=0.8705, Time=4.38s, N=2286
#  Client 1 → Loss=0.3237, Acc=0.8600, Time=4.09s, N=2286
#  Client 2 → Loss=0.2693, Acc=0.8906, Time=4.32s, N=2286
#  Client 3 → Loss=0.2911, Acc=0.8770, Time=4.07s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3216, Acc=0.8636
#
# [Model=CNN | Seed=3 | Round=25]
#  Client 0 → Loss=0.3328, Acc=0.8535, Time=4.03s, N=2286
#  Client 1 → Loss=0.3024, Acc=0.8727, Time=3.90s, N=2286
#  Client 2 → Loss=0.3055, Acc=0.8731, Time=3.89s, N=2286
#  Client 3 → Loss=0.2676, Acc=0.8897, Time=3.93s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3245, Acc=0.8632
#
# [Model=CNN | Seed=3 | Round=26]
#  Client 0 → Loss=0.2932, Acc=0.8766, Time=3.92s, N=2286
#  Client 1 → Loss=0.2876, Acc=0.8766, Time=3.87s, N=2286
#  Client 2 → Loss=0.3123, Acc=0.8679, Time=3.94s, N=2286
#  Client 3 → Loss=0.2964, Acc=0.8678, Time=3.98s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3259, Acc=0.8597
#
# [Model=CNN | Seed=3 | Round=27]
#  Client 0 → Loss=0.2926, Acc=0.8766, Time=3.98s, N=2286
#  Client 1 → Loss=0.2792, Acc=0.8832, Time=4.04s, N=2286
#  Client 2 → Loss=0.3159, Acc=0.8675, Time=3.95s, N=2286
#  Client 3 → Loss=0.2640, Acc=0.8897, Time=3.85s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3129, Acc=0.8684
#
# [Model=CNN | Seed=3 | Round=28]
#  Client 0 → Loss=0.2885, Acc=0.8801, Time=3.89s, N=2286
#  Client 1 → Loss=0.2610, Acc=0.8880, Time=3.70s, N=2286
#  Client 2 → Loss=0.3309, Acc=0.8644, Time=3.64s, N=2286
#  Client 3 → Loss=0.2944, Acc=0.8752, Time=3.62s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3256, Acc=0.8680
#
# [Model=CNN | Seed=3 | Round=29]
#  Client 0 → Loss=0.3011, Acc=0.8753, Time=3.77s, N=2286
#  Client 1 → Loss=0.2899, Acc=0.8766, Time=3.68s, N=2286
#  Client 2 → Loss=0.3563, Acc=0.8526, Time=3.72s, N=2286
#  Client 3 → Loss=0.3123, Acc=0.8704, Time=3.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3509, Acc=0.8584
#
# [Model=CNN | Seed=3 | Round=30]
#  Client 0 → Loss=0.3216, Acc=0.8648, Time=3.84s, N=2286
#  Client 1 → Loss=0.2263, Acc=0.9151, Time=4.27s, N=2286
#  Client 2 → Loss=0.2763, Acc=0.8889, Time=4.27s, N=2286
#  Client 3 → Loss=0.2722, Acc=0.8849, Time=4.24s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3089, Acc=0.8741
#  [saved] saved_models\CNN_seed3.keras
#
# ------ SEED 7 ------
#
# [Model=CNN | Seed=7 | Round=1]
#  Client 0 → Loss=0.6503, Acc=0.6605, Time=3.70s, N=2286
#  Client 1 → Loss=0.6436, Acc=0.6575, Time=3.63s, N=2286
#  Client 2 → Loss=0.6556, Acc=0.6374, Time=3.60s, N=2286
#  Client 3 → Loss=0.6611, Acc=0.6187, Time=3.66s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6607, Acc=0.6442
#
# [Model=CNN | Seed=7 | Round=2]
#  Client 0 → Loss=0.6343, Acc=0.6741, Time=3.68s, N=2286
#  Client 1 → Loss=0.6373, Acc=0.6789, Time=3.64s, N=2286
#  Client 2 → Loss=0.6496, Acc=0.6343, Time=3.74s, N=2286
#  Client 3 → Loss=0.6514, Acc=0.6449, Time=3.68s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6529, Acc=0.6451
#
# [Model=CNN | Seed=7 | Round=3]
#  Client 0 → Loss=0.6297, Acc=0.6702, Time=3.62s, N=2286
#  Client 1 → Loss=0.6302, Acc=0.6802, Time=3.72s, N=2286
#  Client 2 → Loss=0.6537, Acc=0.6203, Time=4.18s, N=2286
#  Client 3 → Loss=0.6284, Acc=0.6581, Time=4.16s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6431, Acc=0.6482
#
# [Model=CNN | Seed=7 | Round=4]
#  Client 0 → Loss=0.6200, Acc=0.6820, Time=4.13s, N=2286
#  Client 1 → Loss=0.6188, Acc=0.6802, Time=4.17s, N=2286
#  Client 2 → Loss=0.6303, Acc=0.6570, Time=4.19s, N=2286
#  Client 3 → Loss=0.6273, Acc=0.6567, Time=4.23s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6328, Acc=0.6464
#
# [Model=CNN | Seed=7 | Round=5]
#  Client 0 → Loss=0.5966, Acc=0.6772, Time=4.02s, N=2286
#  Client 1 → Loss=0.5810, Acc=0.6899, Time=3.69s, N=2286
#  Client 2 → Loss=0.5879, Acc=0.6798, Time=3.60s, N=2286
#  Client 3 → Loss=0.5859, Acc=0.6944, Time=3.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5983, Acc=0.6639
#
# [Model=CNN | Seed=7 | Round=6]
#  Client 0 → Loss=0.5127, Acc=0.7686, Time=3.62s, N=2286
#  Client 1 → Loss=0.5375, Acc=0.7227, Time=3.68s, N=2286
#  Client 2 → Loss=0.5234, Acc=0.7948, Time=3.73s, N=2286
#  Client 3 → Loss=0.5252, Acc=0.7461, Time=3.66s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5292, Acc=0.7557
#
# [Model=CNN | Seed=7 | Round=7]
#  Client 0 → Loss=0.4432, Acc=0.8272, Time=4.31s, N=2286
#  Client 1 → Loss=0.4879, Acc=0.7760, Time=4.43s, N=2286
#  Client 2 → Loss=0.4808, Acc=0.7874, Time=4.40s, N=2286
#  Client 3 → Loss=0.4723, Acc=0.8074, Time=4.27s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4727, Acc=0.7981
#
# [Model=CNN | Seed=7 | Round=8]
#  Client 0 → Loss=0.3905, Acc=0.8368, Time=4.23s, N=2286
#  Client 1 → Loss=0.4147, Acc=0.8329, Time=4.21s, N=2286
#  Client 2 → Loss=0.4099, Acc=0.8438, Time=4.11s, N=2286
#  Client 3 → Loss=0.4360, Acc=0.8135, Time=3.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4179, Acc=0.8212
#
# [Model=CNN | Seed=7 | Round=9]
#  Client 0 → Loss=0.3643, Acc=0.8491, Time=3.92s, N=2286
#  Client 1 → Loss=0.3874, Acc=0.8456, Time=3.76s, N=2286
#  Client 2 → Loss=0.4026, Acc=0.8408, Time=3.73s, N=2286
#  Client 3 → Loss=0.4077, Acc=0.8240, Time=3.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3911, Acc=0.8330
#
# [Model=CNN | Seed=7 | Round=10]
#  Client 0 → Loss=0.3749, Acc=0.8346, Time=3.76s, N=2286
#  Client 1 → Loss=0.3734, Acc=0.8451, Time=3.71s, N=2286
#  Client 2 → Loss=0.4621, Acc=0.7712, Time=4.01s, N=2286
#  Client 3 → Loss=0.3739, Acc=0.8424, Time=3.99s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3918, Acc=0.8256
#
# [Model=CNN | Seed=7 | Round=11]
#  Client 0 → Loss=0.3404, Acc=0.8552, Time=3.97s, N=2286
#  Client 1 → Loss=0.3484, Acc=0.8583, Time=3.91s, N=2286
#  Client 2 → Loss=0.3702, Acc=0.8495, Time=3.97s, N=2286
#  Client 3 → Loss=0.3923, Acc=0.8240, Time=3.88s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3670, Acc=0.8396
#
# [Model=CNN | Seed=7 | Round=12]
#  Client 0 → Loss=0.3495, Acc=0.8425, Time=3.92s, N=2286
#  Client 1 → Loss=0.3427, Acc=0.8591, Time=3.68s, N=2286
#  Client 2 → Loss=0.3539, Acc=0.8530, Time=3.57s, N=2286
#  Client 3 → Loss=0.3463, Acc=0.8616, Time=3.57s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3460, Acc=0.8514
#
# [Model=CNN | Seed=7 | Round=13]
#  Client 0 → Loss=0.3253, Acc=0.8570, Time=3.60s, N=2286
#  Client 1 → Loss=0.3491, Acc=0.8443, Time=3.61s, N=2286
#  Client 2 → Loss=0.3312, Acc=0.8648, Time=3.61s, N=2286
#  Client 3 → Loss=0.3674, Acc=0.8301, Time=3.53s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3466, Acc=0.8418
#
# [Model=CNN | Seed=7 | Round=14]
#  Client 0 → Loss=0.3118, Acc=0.8648, Time=3.68s, N=2286
#  Client 1 → Loss=0.3292, Acc=0.8609, Time=4.16s, N=2286
#  Client 2 → Loss=0.3974, Acc=0.8237, Time=4.15s, N=2286
#  Client 3 → Loss=0.3305, Acc=0.8581, Time=4.09s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3503, Acc=0.8392
#
# [Model=CNN | Seed=7 | Round=15]
#  Client 0 → Loss=0.3460, Acc=0.8425, Time=4.15s, N=2286
#  Client 1 → Loss=0.3538, Acc=0.8430, Time=4.17s, N=2286
#  Client 2 → Loss=0.3725, Acc=0.8329, Time=4.07s, N=2286
#  Client 3 → Loss=0.3313, Acc=0.8638, Time=4.07s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3545, Acc=0.8392
#
# [Model=CNN | Seed=7 | Round=16]
#  Client 0 → Loss=0.3116, Acc=0.8635, Time=3.77s, N=2286
#  Client 1 → Loss=0.3031, Acc=0.8666, Time=3.76s, N=2286
#  Client 2 → Loss=0.3169, Acc=0.8710, Time=3.78s, N=2286
#  Client 3 → Loss=0.3314, Acc=0.8564, Time=3.85s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3236, Acc=0.8636
#
# [Model=CNN | Seed=7 | Round=17]
#  Client 0 → Loss=0.3150, Acc=0.8539, Time=3.77s, N=2286
#  Client 1 → Loss=0.3126, Acc=0.8718, Time=3.87s, N=2286
#  Client 2 → Loss=0.3044, Acc=0.8775, Time=3.85s, N=2286
#  Client 3 → Loss=0.3060, Acc=0.8700, Time=3.91s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3249, Acc=0.8584
#
# [Model=CNN | Seed=7 | Round=18]
#  Client 0 → Loss=0.2746, Acc=0.8959, Time=3.96s, N=2286
#  Client 1 → Loss=0.3016, Acc=0.8736, Time=3.81s, N=2286
#  Client 2 → Loss=0.3032, Acc=0.8753, Time=3.94s, N=2286
#  Client 3 → Loss=0.2972, Acc=0.8809, Time=3.90s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3076, Acc=0.8724
#
# [Model=CNN | Seed=7 | Round=19]
#  Client 0 → Loss=0.2931, Acc=0.8710, Time=4.04s, N=2286
#  Client 1 → Loss=0.2996, Acc=0.8736, Time=3.94s, N=2286
#  Client 2 → Loss=0.3087, Acc=0.8762, Time=3.62s, N=2286
#  Client 3 → Loss=0.3630, Acc=0.8402, Time=3.67s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3259, Acc=0.8615
#
# [Model=CNN | Seed=7 | Round=20]
#  Client 0 → Loss=0.3283, Acc=0.8578, Time=3.68s, N=2286
#  Client 1 → Loss=0.3125, Acc=0.8670, Time=3.76s, N=2286
#  Client 2 → Loss=0.2841, Acc=0.8911, Time=3.64s, N=2286
#  Client 3 → Loss=0.3231, Acc=0.8564, Time=3.69s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3236, Acc=0.8645
#
# [Model=CNN | Seed=7 | Round=21]
#  Client 0 → Loss=0.3055, Acc=0.8696, Time=3.68s, N=2286
#  Client 1 → Loss=0.2684, Acc=0.8933, Time=3.76s, N=2286
#  Client 2 → Loss=0.3402, Acc=0.8521, Time=4.11s, N=2286
#  Client 3 → Loss=0.3010, Acc=0.8722, Time=4.21s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3183, Acc=0.8667
#
# [Model=CNN | Seed=7 | Round=22]
#  Client 0 → Loss=0.2894, Acc=0.8758, Time=4.18s, N=2286
#  Client 1 → Loss=0.2815, Acc=0.8845, Time=4.11s, N=2286
#  Client 2 → Loss=0.3237, Acc=0.8648, Time=4.21s, N=2286
#  Client 3 → Loss=0.2705, Acc=0.8919, Time=4.16s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3106, Acc=0.8676
#
# [Model=CNN | Seed=7 | Round=23]
#  Client 0 → Loss=0.2781, Acc=0.8828, Time=4.02s, N=2286
#  Client 1 → Loss=0.3061, Acc=0.8731, Time=3.72s, N=2286
#  Client 2 → Loss=0.3172, Acc=0.8692, Time=3.74s, N=2286
#  Client 3 → Loss=0.3013, Acc=0.8730, Time=3.71s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3152, Acc=0.8706
#
# [Model=CNN | Seed=7 | Round=24]
#  Client 0 → Loss=0.2720, Acc=0.8858, Time=3.75s, N=2286
#  Client 1 → Loss=0.2526, Acc=0.9029, Time=3.71s, N=2286
#  Client 2 → Loss=0.3134, Acc=0.8692, Time=3.76s, N=2286
#  Client 3 → Loss=0.2980, Acc=0.8805, Time=3.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2989, Acc=0.8794
#
# [Model=CNN | Seed=7 | Round=25]
#  Client 0 → Loss=0.2725, Acc=0.8876, Time=4.26s, N=2286
#  Client 1 → Loss=0.3082, Acc=0.8675, Time=4.13s, N=2286
#  Client 2 → Loss=0.2767, Acc=0.8963, Time=4.15s, N=2286
#  Client 3 → Loss=0.2545, Acc=0.8971, Time=4.17s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2962, Acc=0.8816
#
# [Model=CNN | Seed=7 | Round=26]
#  Client 0 → Loss=0.2661, Acc=0.8937, Time=4.16s, N=2286
#  Client 1 → Loss=0.2764, Acc=0.8898, Time=4.16s, N=2286
#  Client 2 → Loss=0.2697, Acc=0.9007, Time=3.94s, N=2286
#  Client 3 → Loss=0.3089, Acc=0.8717, Time=3.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2949, Acc=0.8837
#
# [Model=CNN | Seed=7 | Round=27]
#  Client 0 → Loss=0.2907, Acc=0.8758, Time=3.64s, N=2286
#  Client 1 → Loss=0.2545, Acc=0.9011, Time=3.67s, N=2286
#  Client 2 → Loss=0.2729, Acc=0.8990, Time=3.65s, N=2286
#  Client 3 → Loss=0.2544, Acc=0.8932, Time=3.63s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2864, Acc=0.8894
#
# [Model=CNN | Seed=7 | Round=28]
#  Client 0 → Loss=0.2748, Acc=0.8845, Time=3.65s, N=2286
#  Client 1 → Loss=0.2652, Acc=0.8906, Time=3.63s, N=2286
#  Client 2 → Loss=0.2774, Acc=0.8871, Time=4.19s, N=2286
#  Client 3 → Loss=0.2664, Acc=0.8888, Time=4.29s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2900, Acc=0.8829
#
# [Model=CNN | Seed=7 | Round=29]
#  Client 0 → Loss=0.2433, Acc=0.9068, Time=4.23s, N=2286
#  Client 1 → Loss=0.2478, Acc=0.9016, Time=4.21s, N=2286
#  Client 2 → Loss=0.2577, Acc=0.9055, Time=4.22s, N=2286
#  Client 3 → Loss=0.2662, Acc=0.8905, Time=4.24s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2725, Acc=0.8912
#
# [Model=CNN | Seed=7 | Round=30]
#  Client 0 → Loss=0.2420, Acc=0.9029, Time=4.17s, N=2286
#  Client 1 → Loss=0.2406, Acc=0.9029, Time=3.88s, N=2286
#  Client 2 → Loss=0.2475, Acc=0.9086, Time=3.95s, N=2286
#  Client 3 → Loss=0.2535, Acc=0.9019, Time=3.90s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2620, Acc=0.8982
#  [saved] saved_models\CNN_seed7.keras
#
# ------ SEED 72 ------
#
# [Model=CNN | Seed=72 | Round=1]
#  Client 0 → Loss=0.6631, Acc=0.6382, Time=3.79s, N=2286
#  Client 1 → Loss=0.6523, Acc=0.6527, Time=3.67s, N=2286
#  Client 2 → Loss=0.6506, Acc=0.6662, Time=3.84s, N=2286
#  Client 3 → Loss=0.6584, Acc=0.6379, Time=3.92s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6669, Acc=0.6455
#
# [Model=CNN | Seed=72 | Round=2]
#  Client 0 → Loss=0.6530, Acc=0.6430, Time=3.85s, N=2286
#  Client 1 → Loss=0.6573, Acc=0.6190, Time=3.92s, N=2286
#  Client 2 → Loss=0.6364, Acc=0.6540, Time=3.79s, N=2286
#  Client 3 → Loss=0.6474, Acc=0.6594, Time=3.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6516, Acc=0.6622
#
# [Model=CNN | Seed=72 | Round=3]
#  Client 0 → Loss=0.6600, Acc=0.6181, Time=3.88s, N=2286
#  Client 1 → Loss=0.6424, Acc=0.6461, Time=3.84s, N=2286
#  Client 2 → Loss=0.6390, Acc=0.6745, Time=3.62s, N=2286
#  Client 3 → Loss=0.6461, Acc=0.6673, Time=3.55s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6515, Acc=0.6447
#
# [Model=CNN | Seed=72 | Round=4]
#  Client 0 → Loss=0.6435, Acc=0.6540, Time=3.62s, N=2286
#  Client 1 → Loss=0.6264, Acc=0.6527, Time=3.62s, N=2286
#  Client 2 → Loss=0.6379, Acc=0.6614, Time=3.61s, N=2286
#  Client 3 → Loss=0.6277, Acc=0.6607, Time=3.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6341, Acc=0.6718
#
# [Model=CNN | Seed=72 | Round=5]
#  Client 0 → Loss=0.6529, Acc=0.6146, Time=3.61s, N=2286
#  Client 1 → Loss=0.6700, Acc=0.5455, Time=3.97s, N=2286
#  Client 2 → Loss=0.6504, Acc=0.5962, Time=4.21s, N=2286
#  Client 3 → Loss=0.6247, Acc=0.6655, Time=4.22s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6530, Acc=0.5953
#
# [Model=CNN | Seed=72 | Round=6]
#  Client 0 → Loss=0.6312, Acc=0.6649, Time=4.07s, N=2286
#  Client 1 → Loss=0.6152, Acc=0.6605, Time=4.21s, N=2286
#  Client 2 → Loss=0.6282, Acc=0.6579, Time=4.20s, N=2286
#  Client 3 → Loss=0.6309, Acc=0.6427, Time=4.30s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6321, Acc=0.6416
#
# [Model=CNN | Seed=72 | Round=7]
#  Client 0 → Loss=0.6248, Acc=0.6435, Time=3.76s, N=2286
#  Client 1 → Loss=0.5931, Acc=0.6829, Time=3.73s, N=2286
#  Client 2 → Loss=0.6045, Acc=0.6815, Time=3.76s, N=2286
#  Client 3 → Loss=0.6357, Acc=0.6138, Time=3.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6189, Acc=0.6403
#
# [Model=CNN | Seed=72 | Round=8]
#  Client 0 → Loss=0.5942, Acc=0.6947, Time=3.90s, N=2286
#  Client 1 → Loss=0.5853, Acc=0.6767, Time=3.73s, N=2286
#  Client 2 → Loss=0.5880, Acc=0.6942, Time=3.68s, N=2286
#  Client 3 → Loss=0.6227, Acc=0.6055, Time=3.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5981, Acc=0.6630
#
# [Model=CNN | Seed=72 | Round=9]
#  Client 0 → Loss=0.5466, Acc=0.7651, Time=3.82s, N=2286
#  Client 1 → Loss=0.5545, Acc=0.7253, Time=3.98s, N=2286
#  Client 2 → Loss=0.5493, Acc=0.7375, Time=3.87s, N=2286
#  Client 3 → Loss=0.5725, Acc=0.6918, Time=3.92s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5574, Acc=0.7185
#
# [Model=CNN | Seed=72 | Round=10]
#  Client 0 → Loss=0.4924, Acc=0.7896, Time=3.90s, N=2286
#  Client 1 → Loss=0.5128, Acc=0.7419, Time=3.89s, N=2286
#  Client 2 → Loss=0.5486, Acc=0.6903, Time=3.82s, N=2286
#  Client 3 → Loss=0.5324, Acc=0.7194, Time=3.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5198, Acc=0.7299
#
# [Model=CNN | Seed=72 | Round=11]
#  Client 0 → Loss=0.4456, Acc=0.8381, Time=3.57s, N=2286
#  Client 1 → Loss=0.4456, Acc=0.8128, Time=3.60s, N=2286
#  Client 2 → Loss=0.4398, Acc=0.8276, Time=3.57s, N=2286
#  Client 3 → Loss=0.4250, Acc=0.8314, Time=3.57s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4320, Acc=0.8300
#
# [Model=CNN | Seed=72 | Round=12]
#  Client 0 → Loss=0.3994, Acc=0.8338, Time=3.64s, N=2286
#  Client 1 → Loss=0.4019, Acc=0.8329, Time=3.52s, N=2286
#  Client 2 → Loss=0.3939, Acc=0.8360, Time=3.83s, N=2286
#  Client 3 → Loss=0.4277, Acc=0.8082, Time=4.11s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4014, Acc=0.8330
#
# [Model=CNN | Seed=72 | Round=13]
#  Client 0 → Loss=0.3624, Acc=0.8556, Time=4.12s, N=2286
#  Client 1 → Loss=0.3604, Acc=0.8596, Time=4.17s, N=2286
#  Client 2 → Loss=0.3592, Acc=0.8635, Time=4.17s, N=2286
#  Client 3 → Loss=0.3899, Acc=0.8393, Time=4.20s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3652, Acc=0.8536
#
# [Model=CNN | Seed=72 | Round=14]
#  Client 0 → Loss=0.3563, Acc=0.8447, Time=4.20s, N=2286
#  Client 1 → Loss=0.3599, Acc=0.8657, Time=3.82s, N=2286
#  Client 2 → Loss=0.3600, Acc=0.8609, Time=3.73s, N=2286
#  Client 3 → Loss=0.3583, Acc=0.8551, Time=3.69s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3538, Acc=0.8623
#
# [Model=CNN | Seed=72 | Round=15]
#  Client 0 → Loss=0.3398, Acc=0.8600, Time=3.74s, N=2286
#  Client 1 → Loss=0.3215, Acc=0.8863, Time=3.76s, N=2286
#  Client 2 → Loss=0.3385, Acc=0.8613, Time=3.77s, N=2286
#  Client 3 → Loss=0.3791, Acc=0.8297, Time=3.72s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3407, Acc=0.8663
#
# [Model=CNN | Seed=72 | Round=16]
#  Client 0 → Loss=0.3294, Acc=0.8565, Time=3.80s, N=2286
#  Client 1 → Loss=0.3093, Acc=0.8863, Time=4.26s, N=2286
#  Client 2 → Loss=0.3197, Acc=0.8749, Time=4.19s, N=2286
#  Client 3 → Loss=0.3378, Acc=0.8638, Time=4.20s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3186, Acc=0.8750
#
# [Model=CNN | Seed=72 | Round=17]
#  Client 0 → Loss=0.3247, Acc=0.8618, Time=4.19s, N=2286
#  Client 1 → Loss=0.3105, Acc=0.8823, Time=4.14s, N=2286
#  Client 2 → Loss=0.3280, Acc=0.8675, Time=4.20s, N=2286
#  Client 3 → Loss=0.3206, Acc=0.8743, Time=3.96s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3139, Acc=0.8759
#
# [Model=CNN | Seed=72 | Round=18]
#  Client 0 → Loss=0.3056, Acc=0.8688, Time=3.60s, N=2286
#  Client 1 → Loss=0.2963, Acc=0.8854, Time=3.62s, N=2286
#  Client 2 → Loss=0.3115, Acc=0.8666, Time=3.69s, N=2286
#  Client 3 → Loss=0.3213, Acc=0.8708, Time=3.60s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3067, Acc=0.8767
#
# [Model=CNN | Seed=72 | Round=19]
#  Client 0 → Loss=0.3141, Acc=0.8644, Time=3.62s, N=2286
#  Client 1 → Loss=0.2845, Acc=0.8933, Time=3.71s, N=2286
#  Client 2 → Loss=0.3093, Acc=0.8762, Time=3.56s, N=2286
#  Client 3 → Loss=0.3274, Acc=0.8717, Time=4.16s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3056, Acc=0.8829
#
# [Model=CNN | Seed=72 | Round=20]
#  Client 0 → Loss=0.2943, Acc=0.8815, Time=4.22s, N=2286
#  Client 1 → Loss=0.2872, Acc=0.8915, Time=4.27s, N=2286
#  Client 2 → Loss=0.3188, Acc=0.8679, Time=4.25s, N=2286
#  Client 3 → Loss=0.3221, Acc=0.8682, Time=4.24s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3029, Acc=0.8776
#
# [Model=CNN | Seed=72 | Round=21]
#  Client 0 → Loss=0.3039, Acc=0.8740, Time=4.21s, N=2286
#  Client 1 → Loss=0.2766, Acc=0.8928, Time=4.17s, N=2286
#  Client 2 → Loss=0.3162, Acc=0.8626, Time=3.84s, N=2286
#  Client 3 → Loss=0.3008, Acc=0.8827, Time=3.87s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2960, Acc=0.8811
#
# [Model=CNN | Seed=72 | Round=22]
#  Client 0 → Loss=0.2904, Acc=0.8815, Time=3.87s, N=2286
#  Client 1 → Loss=0.2836, Acc=0.8906, Time=3.82s, N=2286
#  Client 2 → Loss=0.2916, Acc=0.8828, Time=3.86s, N=2286
#  Client 3 → Loss=0.3132, Acc=0.8669, Time=3.89s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2923, Acc=0.8842
#
# [Model=CNN | Seed=72 | Round=23]
#  Client 0 → Loss=0.2875, Acc=0.8780, Time=3.93s, N=2286
#  Client 1 → Loss=0.2718, Acc=0.8976, Time=4.10s, N=2286
#  Client 2 → Loss=0.3098, Acc=0.8749, Time=3.95s, N=2286
#  Client 3 → Loss=0.2956, Acc=0.8822, Time=3.90s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2930, Acc=0.8837
#
# [Model=CNN | Seed=72 | Round=24]
#  Client 0 → Loss=0.2849, Acc=0.8845, Time=4.05s, N=2286
#  Client 1 → Loss=0.2678, Acc=0.8946, Time=3.91s, N=2286
#  Client 2 → Loss=0.3051, Acc=0.8740, Time=4.05s, N=2286
#  Client 3 → Loss=0.2957, Acc=0.8743, Time=3.98s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2901, Acc=0.8811
#
# [Model=CNN | Seed=72 | Round=25]
#  Client 0 → Loss=0.3072, Acc=0.8705, Time=3.70s, N=2286
#  Client 1 → Loss=0.2808, Acc=0.8902, Time=3.64s, N=2286
#  Client 2 → Loss=0.3023, Acc=0.8714, Time=3.62s, N=2286
#  Client 3 → Loss=0.2845, Acc=0.8844, Time=3.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2933, Acc=0.8807
#
# [Model=CNN | Seed=72 | Round=26]
#  Client 0 → Loss=0.2885, Acc=0.8788, Time=3.67s, N=2286
#  Client 1 → Loss=0.2564, Acc=0.9016, Time=3.67s, N=2286
#  Client 2 → Loss=0.2882, Acc=0.8788, Time=3.64s, N=2286
#  Client 3 → Loss=0.2900, Acc=0.8765, Time=3.94s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2812, Acc=0.8851
#
# [Model=CNN | Seed=72 | Round=27]
#  Client 0 → Loss=0.2804, Acc=0.8876, Time=4.23s, N=2286
#  Client 1 → Loss=0.2777, Acc=0.8889, Time=4.23s, N=2286
#  Client 2 → Loss=0.2749, Acc=0.8854, Time=4.26s, N=2286
#  Client 3 → Loss=0.2916, Acc=0.8717, Time=4.25s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2821, Acc=0.8855
#
# [Model=CNN | Seed=72 | Round=28]
#  Client 0 → Loss=0.2811, Acc=0.8828, Time=4.15s, N=2286
#  Client 1 → Loss=0.2519, Acc=0.9016, Time=4.27s, N=2286
#  Client 2 → Loss=0.2786, Acc=0.8928, Time=3.95s, N=2286
#  Client 3 → Loss=0.2858, Acc=0.8805, Time=3.84s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2743, Acc=0.8942
#
# [Model=CNN | Seed=72 | Round=29]
#  Client 0 → Loss=0.2638, Acc=0.8972, Time=3.89s, N=2286
#  Client 1 → Loss=0.2678, Acc=0.8933, Time=3.83s, N=2286
#  Client 2 → Loss=0.2851, Acc=0.8788, Time=3.96s, N=2286
#  Client 3 → Loss=0.2945, Acc=0.8730, Time=3.98s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2775, Acc=0.8864
#
# [Model=CNN | Seed=72 | Round=30]
#  Client 0 → Loss=0.2619, Acc=0.8955, Time=3.83s, N=2286
#  Client 1 → Loss=0.2560, Acc=0.8981, Time=3.88s, N=2286
#  Client 2 → Loss=0.2724, Acc=0.8911, Time=4.00s, N=2286
#  Client 3 → Loss=0.2704, Acc=0.8910, Time=3.90s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2660, Acc=0.8973
#  [saved] saved_models\CNN_seed72.keras
#
# ------ SEED 82 ------
#
# [Model=CNN | Seed=82 | Round=1]
#  Client 0 → Loss=0.6621, Acc=0.6435, Time=3.94s, N=2286
#  Client 1 → Loss=0.6671, Acc=0.6514, Time=3.76s, N=2286
#  Client 2 → Loss=0.6550, Acc=0.6597, Time=3.88s, N=2286
#  Client 3 → Loss=0.6537, Acc=0.6602, Time=3.68s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6653, Acc=0.6403
#
# [Model=CNN | Seed=82 | Round=2]
#  Client 0 → Loss=0.6419, Acc=0.6597, Time=3.60s, N=2286
#  Client 1 → Loss=0.6567, Acc=0.6369, Time=3.58s, N=2286
#  Client 2 → Loss=0.6446, Acc=0.6776, Time=3.60s, N=2286
#  Client 3 → Loss=0.6544, Acc=0.6257, Time=3.54s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6494, Acc=0.6661
#
# [Model=CNN | Seed=82 | Round=3]
#  Client 0 → Loss=0.6348, Acc=0.6654, Time=3.64s, N=2286
#  Client 1 → Loss=0.6522, Acc=0.6295, Time=3.52s, N=2286
#  Client 2 → Loss=0.6422, Acc=0.6531, Time=3.81s, N=2286
#  Client 3 → Loss=0.6335, Acc=0.6611, Time=4.20s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6398, Acc=0.6691
#
# [Model=CNN | Seed=82 | Round=4]
#  Client 0 → Loss=0.6332, Acc=0.6509, Time=4.20s, N=2286
#  Client 1 → Loss=0.6483, Acc=0.6146, Time=4.20s, N=2286
#  Client 2 → Loss=0.6287, Acc=0.6728, Time=4.19s, N=2286
#  Client 3 → Loss=0.6401, Acc=0.6331, Time=4.19s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6374, Acc=0.6495
#
# [Model=CNN | Seed=82 | Round=5]
#  Client 0 → Loss=0.6247, Acc=0.6382, Time=4.19s, N=2286
#  Client 1 → Loss=0.6287, Acc=0.6334, Time=3.88s, N=2286
#  Client 2 → Loss=0.6175, Acc=0.6658, Time=3.65s, N=2286
#  Client 3 → Loss=0.6238, Acc=0.6559, Time=3.55s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6287, Acc=0.6399
#
# [Model=CNN | Seed=82 | Round=6]
#  Client 0 → Loss=0.6072, Acc=0.6277, Time=3.60s, N=2286
#  Client 1 → Loss=0.5984, Acc=0.6584, Time=3.68s, N=2286
#  Client 2 → Loss=0.5668, Acc=0.7288, Time=3.62s, N=2286
#  Client 3 → Loss=0.6123, Acc=0.6353, Time=3.61s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6056, Acc=0.6394
#
# [Model=CNN | Seed=82 | Round=7]
#  Client 0 → Loss=0.5284, Acc=0.7458, Time=3.67s, N=2286
#  Client 1 → Loss=0.5228, Acc=0.7200, Time=4.13s, N=2286
#  Client 2 → Loss=0.5336, Acc=0.7323, Time=4.14s, N=2286
#  Client 3 → Loss=0.5487, Acc=0.6909, Time=4.16s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5491, Acc=0.6875
#
# [Model=CNN | Seed=82 | Round=8]
#  Client 0 → Loss=0.4636, Acc=0.8049, Time=4.12s, N=2286
#  Client 1 → Loss=0.4437, Acc=0.8040, Time=4.20s, N=2286
#  Client 2 → Loss=0.4408, Acc=0.8141, Time=4.13s, N=2286
#  Client 3 → Loss=0.4859, Acc=0.7736, Time=4.09s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4634, Acc=0.8016
#
# [Model=CNN | Seed=82 | Round=9]
#  Client 0 → Loss=0.4268, Acc=0.8080, Time=3.61s, N=2286
#  Client 1 → Loss=0.4612, Acc=0.7857, Time=3.62s, N=2286
#  Client 2 → Loss=0.4946, Acc=0.7563, Time=3.60s, N=2286
#  Client 3 → Loss=0.4221, Acc=0.8091, Time=3.62s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4553, Acc=0.7941
#
# [Model=CNN | Seed=82 | Round=10]
#  Client 0 → Loss=0.4859, Acc=0.7760, Time=3.59s, N=2286
#  Client 1 → Loss=0.3735, Acc=0.8316, Time=3.66s, N=2286
#  Client 2 → Loss=0.3829, Acc=0.8434, Time=3.65s, N=2286
#  Client 3 → Loss=0.3610, Acc=0.8529, Time=3.96s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3953, Acc=0.8239
#
# [Model=CNN | Seed=82 | Round=11]
#  Client 0 → Loss=0.3877, Acc=0.8342, Time=4.23s, N=2286
#  Client 1 → Loss=0.3550, Acc=0.8535, Time=4.23s, N=2286
#  Client 2 → Loss=0.4151, Acc=0.8080, Time=4.18s, N=2286
#  Client 3 → Loss=0.4177, Acc=0.8152, Time=4.17s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3931, Acc=0.8230
#
# [Model=CNN | Seed=82 | Round=12]
#  Client 0 → Loss=0.3772, Acc=0.8399, Time=4.33s, N=2286
#  Client 1 → Loss=0.3266, Acc=0.8675, Time=4.22s, N=2286
#  Client 2 → Loss=0.3719, Acc=0.8338, Time=3.77s, N=2286
#  Client 3 → Loss=0.4087, Acc=0.8152, Time=3.82s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3681, Acc=0.8435
#
# [Model=CNN | Seed=82 | Round=13]
#  Client 0 → Loss=0.3553, Acc=0.8535, Time=3.86s, N=2286
#  Client 1 → Loss=0.3230, Acc=0.8609, Time=3.86s, N=2286
#  Client 2 → Loss=0.3430, Acc=0.8609, Time=3.82s, N=2286
#  Client 3 → Loss=0.3713, Acc=0.8358, Time=3.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3487, Acc=0.8527
#
# [Model=CNN | Seed=82 | Round=14]
#  Client 0 → Loss=0.4037, Acc=0.8268, Time=3.82s, N=2286
#  Client 1 → Loss=0.3373, Acc=0.8596, Time=4.00s, N=2286
#  Client 2 → Loss=0.3341, Acc=0.8626, Time=3.96s, N=2286
#  Client 3 → Loss=0.3445, Acc=0.8481, Time=3.86s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3549, Acc=0.8510
#
# [Model=CNN | Seed=82 | Round=15]
#  Client 0 → Loss=0.3297, Acc=0.8648, Time=4.05s, N=2286
#  Client 1 → Loss=0.2995, Acc=0.8876, Time=4.01s, N=2286
#  Client 2 → Loss=0.3023, Acc=0.8793, Time=3.96s, N=2286
#  Client 3 → Loss=0.3034, Acc=0.8695, Time=4.05s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3026, Acc=0.8802
#
# [Model=CNN | Seed=82 | Round=16]
#  Client 0 → Loss=0.3234, Acc=0.8661, Time=3.82s, N=2286
#  Client 1 → Loss=0.3340, Acc=0.8591, Time=3.64s, N=2286
#  Client 2 → Loss=0.3105, Acc=0.8784, Time=3.64s, N=2286
#  Client 3 → Loss=0.3527, Acc=0.8463, Time=3.70s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3306, Acc=0.8575
#
# [Model=CNN | Seed=82 | Round=17]
#  Client 0 → Loss=0.3442, Acc=0.8578, Time=3.66s, N=2286
#  Client 1 → Loss=0.3796, Acc=0.8316, Time=3.59s, N=2286
#  Client 2 → Loss=0.3353, Acc=0.8605, Time=3.68s, N=2286
#  Client 3 → Loss=0.3185, Acc=0.8634, Time=3.67s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3504, Acc=0.8505
#
# [Model=CNN | Seed=82 | Round=18]
#  Client 0 → Loss=0.3248, Acc=0.8657, Time=4.22s, N=2286
#  Client 1 → Loss=0.3062, Acc=0.8727, Time=4.24s, N=2286
#  Client 2 → Loss=0.3368, Acc=0.8591, Time=4.21s, N=2286
#  Client 3 → Loss=0.3007, Acc=0.8739, Time=4.18s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3258, Acc=0.8606
#
# [Model=CNN | Seed=82 | Round=19]
#  Client 0 → Loss=0.3184, Acc=0.8653, Time=4.20s, N=2286
#  Client 1 → Loss=0.2978, Acc=0.8806, Time=4.18s, N=2286
#  Client 2 → Loss=0.2786, Acc=0.8946, Time=4.14s, N=2286
#  Client 3 → Loss=0.3126, Acc=0.8608, Time=3.85s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3041, Acc=0.8746
#
# [Model=CNN | Seed=82 | Round=20]
#  Client 0 → Loss=0.2854, Acc=0.8871, Time=3.88s, N=2286
#  Client 1 → Loss=0.2597, Acc=0.9016, Time=3.84s, N=2286
#  Client 2 → Loss=0.2918, Acc=0.8775, Time=3.85s, N=2286
#  Client 3 → Loss=0.2794, Acc=0.8853, Time=3.94s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2825, Acc=0.8872
#
# [Model=CNN | Seed=82 | Round=21]
#  Client 0 → Loss=0.2923, Acc=0.8784, Time=3.82s, N=2286
#  Client 1 → Loss=0.2828, Acc=0.8902, Time=3.94s, N=2286
#  Client 2 → Loss=0.2974, Acc=0.8749, Time=4.03s, N=2286
#  Client 3 → Loss=0.3208, Acc=0.8595, Time=3.97s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3004, Acc=0.8724
#
# [Model=CNN | Seed=82 | Round=22]
#  Client 0 → Loss=0.3034, Acc=0.8727, Time=3.96s, N=2286
#  Client 1 → Loss=0.2881, Acc=0.8810, Time=3.99s, N=2286
#  Client 2 → Loss=0.2452, Acc=0.9042, Time=3.87s, N=2286
#  Client 3 → Loss=0.2717, Acc=0.8888, Time=3.93s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2797, Acc=0.8868
#
# [Model=CNN | Seed=82 | Round=23]
#  Client 0 → Loss=0.2682, Acc=0.8906, Time=3.90s, N=2286
#  Client 1 → Loss=0.2597, Acc=0.8972, Time=3.77s, N=2286
#  Client 2 → Loss=0.2761, Acc=0.8911, Time=3.65s, N=2286
#  Client 3 → Loss=0.3441, Acc=0.8573, Time=3.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2884, Acc=0.8833
#
# [Model=CNN | Seed=82 | Round=24]
#  Client 0 → Loss=0.2652, Acc=0.8928, Time=3.76s, N=2286
#  Client 1 → Loss=0.2595, Acc=0.8994, Time=3.69s, N=2286
#  Client 2 → Loss=0.2778, Acc=0.8880, Time=3.77s, N=2286
#  Client 3 → Loss=0.2368, Acc=0.9019, Time=3.64s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2675, Acc=0.8942
#
# [Model=CNN | Seed=82 | Round=25]
#  Client 0 → Loss=0.2865, Acc=0.8775, Time=3.86s, N=2286
#  Client 1 → Loss=0.2413, Acc=0.9068, Time=4.08s, N=2286
#  Client 2 → Loss=0.2505, Acc=0.8976, Time=4.10s, N=2286
#  Client 3 → Loss=0.2476, Acc=0.8962, Time=4.24s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2498, Acc=0.9030
#
# [Model=CNN | Seed=82 | Round=26]
#  Client 0 → Loss=0.2718, Acc=0.8876, Time=4.09s, N=2286
#  Client 1 → Loss=0.2755, Acc=0.8819, Time=4.04s, N=2286
#  Client 2 → Loss=0.3036, Acc=0.8740, Time=4.10s, N=2286
#  Client 3 → Loss=0.2382, Acc=0.9028, Time=3.93s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2723, Acc=0.8903
#
# [Model=CNN | Seed=82 | Round=27]
#  Client 0 → Loss=0.2557, Acc=0.8968, Time=3.87s, N=2286
#  Client 1 → Loss=0.2425, Acc=0.9020, Time=3.72s, N=2286
#  Client 2 → Loss=0.2357, Acc=0.9121, Time=3.68s, N=2286
#  Client 3 → Loss=0.2529, Acc=0.8914, Time=3.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2518, Acc=0.9025
#
# [Model=CNN | Seed=82 | Round=28]
#  Client 0 → Loss=0.2545, Acc=0.8941, Time=3.65s, N=2286
#  Client 1 → Loss=0.2474, Acc=0.9003, Time=3.74s, N=2286
#  Client 2 → Loss=0.2393, Acc=0.9020, Time=3.80s, N=2286
#  Client 3 → Loss=0.2450, Acc=0.8967, Time=4.23s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2516, Acc=0.9003
#
# [Model=CNN | Seed=82 | Round=29]
#  Client 0 → Loss=0.2442, Acc=0.8985, Time=4.21s, N=2286
#  Client 1 → Loss=0.2261, Acc=0.9125, Time=4.25s, N=2286
#  Client 2 → Loss=0.2427, Acc=0.9020, Time=4.34s, N=2286
#  Client 3 → Loss=0.2639, Acc=0.8862, Time=4.33s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2491, Acc=0.9008
#
# [Model=CNN | Seed=82 | Round=30]
#  Client 0 → Loss=0.2418, Acc=0.9077, Time=4.35s, N=2286
#  Client 1 → Loss=0.2315, Acc=0.9169, Time=3.98s, N=2286
#  Client 2 → Loss=0.2336, Acc=0.9033, Time=3.75s, N=2286
#  Client 3 → Loss=0.2261, Acc=0.9089, Time=3.73s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.2362, Acc=0.9065
#  [saved] saved_models\CNN_seed82.keras
#
# ================ MODEL: LSTM ================
#
# ------ SEED 42 ------
#
# [Model=LSTM | Seed=42 | Round=1]
#  Client 0 → Loss=0.5081, Acc=0.7563, Time=7.02s, N=2286
#  Client 1 → Loss=0.5508, Acc=0.7205, Time=7.04s, N=2286
#  Client 2 → Loss=0.5525, Acc=0.7305, Time=7.66s, N=2286
# ...
#    CNN    42    saved_models\CNN_seed42.keras
#    CNN     3     saved_models\CNN_seed3.keras
#    CNN     7     saved_models\CNN_seed7.keras
#    CNN    72    saved_models\CNN_seed72.keras
#    CNN    82    saved_models\CNN_seed82.keras
#   LSTM    42   saved_models\LSTM_seed42.keras
#   LSTM     3    saved_models\LSTM_seed3.keras
#   LSTM     7    saved_models\LSTM_seed7.keras
#   LSTM    72   saved_models\LSTM_seed72.keras
#   LSTM    82   saved_models\LSTM_seed82.keras
# BiLSTM    42 saved_models\BiLSTM_seed42.keras
# BiLSTM     3  saved_models\BiLSTM_seed3.keras
# BiLSTM     7  saved_models\BiLSTM_seed7.keras
# BiLSTM    72 saved_models\BiLSTM_seed72.keras
# BiLSTM    82 saved_models\BiLSTM_seed82.keras
#    GRU    42    saved_models\GRU_seed42.keras
#    GRU     3     saved_models\GRU_seed3.keras
#    GRU     7     saved_models\GRU_seed7.keras
#    GRU    72    saved_models\GRU_seed72.keras
#    GRU    82    saved_models\GRU_seed82.keras
#  BiGRU    42  saved_models\BiGRU_seed42.keras
#  BiGRU     3   saved_models\BiGRU_seed3.keras
#  BiGRU     7   saved_models\BiGRU_seed7.keras
#  BiGRU    72  saved_models\BiGRU_seed72.keras
#  BiGRU    82  saved_models\BiGRU_seed82.keras
#
# OVERALL SUMMARY (all models & seeds pooled):
#                  Metric            Mean ± SD                95% CI
# 0                 Loss      0.1915 ± 0.0418       [0.1751,0.2079]
# 1             Accuracy      0.9280 ± 0.0191       [0.9205,0.9355]
# 2            Precision      0.9371 ± 0.0095       [0.9333,0.9408]
# 3               Recall      0.9180 ± 0.0443       [0.9006,0.9354]
# 4                   F1      0.9267 ± 0.0219       [0.9181,0.9353]
# 5                  MCC      0.8572 ± 0.0357       [0.8432,0.8712]
# 6                  AUC      0.9772 ± 0.0081       [0.9740,0.9804]
# 7          Specificity      0.9380 ± 0.0114       [0.9335,0.9425]
# 8    Training_Time_sec  988.5574 ± 361.1641  [846.9811,1130.1337]
# 9   Inference_Time_sec      0.7475 ± 0.3844       [0.5969,0.8982]
# 10       Model_Size_MB      0.5846 ± 0.3965       [0.4292,0.7400]
# 11   Comm_per_round_MB      4.4748 ± 3.1303       [3.2477,5.7019]
# 12       Total_Comm_MB   134.2451 ± 93.9102    [97.4323,171.0578]
#
# PER-CLIENT TEST SUMMARY (mean/std over 5 seeds):
#                Accuracy         Precision          Recall              F1  \
#                   mean     std      mean     std    mean     std    mean
# Model  Client
# BiGRU  0        0.9364  0.0083    0.9288  0.0134  0.9455  0.0135  0.9369
#        1        0.9381  0.0133    0.9349  0.0166  0.9420  0.0112  0.9384
#        2        0.9339  0.0146    0.9324  0.0153  0.9357  0.0154  0.9340
#        3        0.9367  0.0069    0.9317  0.0077  0.9427  0.0165  0.9370
# BiLSTM 0        0.9483  0.0093    0.9421  0.0090  0.9552  0.0136  0.9486
#        1        0.9409  0.0084    0.9408  0.0145  0.9413  0.0109  0.9409
#        2        0.9395  0.0098    0.9393  0.0105  0.9399  0.0167  0.9395
#        3        0.9458  0.0049    0.9402  0.0109  0.9524  0.0156  0.9461
# CNN    0        0.8986  0.0179    0.9475  0.0093  0.8441  0.0368  0.8924
#        1        0.8895  0.0110    0.9459  0.0161  0.8266  0.0221  0.8820
#        2        0.8902  0.0230    0.9493  0.0129  0.8245  0.0446  0.8820
#        3        0.8955  0.0104    0.9415  0.0171  0.8441  0.0344  0.8895
# GRU    0        0.9315  0.0084    0.9328  0.0120  0.9301  0.0086  0.9314
#        1        0.9273  0.0125    0.9269  0.0192  0.9280  0.0101  0.9274
#        2        0.9280  0.0097    0.9343  0.0123  0.9210  0.0223  0.9274
#        3        0.9241  0.0083    0.9252  0.0108  0.9231  0.0171  0.9240
# LSTM   0        0.9409  0.0169    0.9385  0.0233  0.9441  0.0138  0.9412
#        1        0.9322  0.0083    0.9280  0.0058  0.9371  0.0160  0.9325
#        2        0.9413  0.0136    0.9470  0.0086  0.9350  0.0307  0.9407
#        3        0.9413  0.0102    0.9357  0.0042  0.9476  0.0185  0.9416
#
#                           MCC             AUC         Specificity          \
#                   std    mean     std    mean     std        mean     std
# Model  Client
# BiGRU  0       0.0081  0.8731  0.0166  0.9820  0.0039      0.9273  0.0147
#        1       0.0132  0.8763  0.0267  0.9812  0.0052      0.9343  0.0172
#        2       0.0145  0.8679  0.0292  0.9817  0.0045      0.9322  0.0158
#        3       0.0073  0.8737  0.0140  0.9814  0.0023      0.9308  0.0091
# BiLSTM 0       0.0094  0.8967  0.0187  0.9840  0.0034      0.9413  0.0094
#        1       0.0083  0.8820  0.0169  0.9823  0.0029      0.9406  0.0154
#        2       0.0101  0.8792  0.0196  0.9852  0.0034      0.9392  0.0112
#        3       0.0052  0.8919  0.0101  0.9847  0.0036      0.9392  0.0125
# CNN    0       0.0213  0.8024  0.0327  0.9627  0.0095      0.9531  0.0091
#        1       0.0127  0.7856  0.0211  0.9606  0.0038      0.9524  0.0158
#        2       0.0270  0.7878  0.0424  0.9615  0.0099      0.9559  0.0115
#        3       0.0136  0.7959  0.0173  0.9654  0.0043      0.9469  0.0179
# GRU    0       0.0082  0.8630  0.0168  0.9773  0.0041      0.9329  0.0127
#        1       0.0121  0.8547  0.0252  0.9763  0.0031      0.9266  0.0202
#        2       0.0103  0.8564  0.0195  0.9765  0.0067      0.9350  0.0139
#        3       0.0086  0.8485  0.0167  0.9764  0.0033      0.9252  0.0123
# LSTM   0       0.0165  0.8820  0.0338  0.9817  0.0057      0.9378  0.0241
#        1       0.0088  0.8645  0.0167  0.9800  0.0031      0.9273  0.0063
#        2       0.0144  0.8831  0.0273  0.9826  0.0052      0.9476  0.0096
#        3       0.0107  0.8827  0.0204  0.9816  0.0032      0.9350  0.0040
#
#                  Loss
#                  mean     std
# Model  Client
# BiGRU  0       0.1714  0.0203
#        1       0.1696  0.0255
#        2       0.1693  0.0242
#        3       0.1708  0.0113
# BiLSTM 0       0.1562  0.0192
#        1       0.1652  0.0171
#        2       0.1549  0.0169
#        3       0.1565  0.0166
# CNN    0       0.2665  0.0429
#        1       0.2756  0.0153
#        2       0.2707  0.0390
#        3       0.2573  0.0249
# GRU    0       0.1879  0.0160
#        1       0.1932  0.0170
#        2       0.1931  0.0276
#        3       0.1956  0.0132
# LSTM   0       0.1674  0.0281
#        1       0.1787  0.0161
#        2       0.1647  0.0256
#        3       0.1656  0.0128
#
# PAIRWISE PAIRED T-TESTS across 5 seeds (Global Test Set):
#    Metric Model A Model B  Mean A  Mean B   t-stat  p-value  Significant (p<0.05)
# Accuracy     CNN    LSTM  0.8934  0.9389 -10.4366   0.0005                  True
# Accuracy     CNN  BiLSTM  0.8934  0.9436  -9.9083   0.0006                  True
# Accuracy     CNN     GRU  0.8934  0.9277  -6.4475   0.0030                  True
# Accuracy     CNN   BiGRU  0.8934  0.9363  -8.2182   0.0012                  True
# Accuracy    LSTM  BiLSTM  0.9389  0.9436  -4.9606   0.0077                  True
# Accuracy    LSTM     GRU  0.9389  0.9277   9.0737   0.0008                  True
# Accuracy    LSTM   BiGRU  0.9389  0.9363   1.6903   0.1662                 False
# Accuracy  BiLSTM     GRU  0.9436  0.9277  10.4384   0.0005                  True
# Accuracy  BiLSTM   BiGRU  0.9436  0.9363   4.8619   0.0083                  True
# Accuracy     GRU   BiGRU  0.9277  0.9363  -5.4236   0.0056                  True
#       F1     CNN    LSTM  0.8866  0.9390  -9.3360   0.0007                  True
#       F1     CNN  BiLSTM  0.8866  0.9438  -8.9930   0.0008                  True
#       F1     CNN     GRU  0.8866  0.9276  -6.4581   0.0030                  True
#       F1     CNN   BiGRU  0.8866  0.9366  -7.7311   0.0015                  True
#       F1    LSTM  BiLSTM  0.9390  0.9438  -4.6634   0.0096                  True
#       F1    LSTM     GRU  0.9390  0.9276  11.5721   0.0003                  True
#       F1    LSTM   BiGRU  0.9390  0.9366   1.5851   0.1881                 False
#       F1  BiLSTM     GRU  0.9438  0.9276  11.8471   0.0003                  True
#       F1  BiLSTM   BiGRU  0.9438  0.9366   4.9726   0.0076                  True
#       F1     GRU   BiGRU  0.9276  0.9366  -6.6198   0.0027                  True
#      AUC     CNN    LSTM  0.9625  0.9815 -10.9179   0.0004                  True
#      AUC     CNN  BiLSTM  0.9625  0.9840 -14.4087   0.0001                  True
#      AUC     CNN     GRU  0.9625  0.9766  -6.9050   0.0023                  True
#      AUC     CNN   BiGRU  0.9625  0.9816 -10.6918   0.0004                  True
#      AUC    LSTM  BiLSTM  0.9815  0.9840  -5.0231   0.0074                  True
#      AUC    LSTM     GRU  0.9815  0.9766   7.8304   0.0014                  True
#      AUC    LSTM   BiGRU  0.9815  0.9816  -0.3774   0.7250                 False
#      AUC  BiLSTM     GRU  0.9840  0.9766   7.9563   0.0014                  True
#      AUC  BiLSTM   BiGRU  0.9840  0.9816   3.1306   0.0352                  True
#      AUC     GRU   BiGRU  0.9766  0.9816  -6.4564   0.0030                  True
#     Loss     CNN    LSTM  0.2675  0.1691  10.5773   0.0005                  True
#     Loss     CNN  BiLSTM  0.2675  0.1582  12.1170   0.0003                  True
#     Loss     CNN     GRU  0.2675  0.1925   6.3847   0.0031                  True
#     Loss     CNN   BiGRU  0.2675  0.1703   9.0637   0.0008                  True
#     Loss    LSTM  BiLSTM  0.1691  0.1582   4.5890   0.0101                  True
#     Loss    LSTM     GRU  0.1691  0.1925  -6.9638   0.0022                  True
#     Loss    LSTM   BiGRU  0.1691  0.1703  -0.3432   0.7488                 False
#     Loss  BiLSTM     GRU  0.1582  0.1925  -6.5026   0.0029                  True
#     Loss  BiLSTM   BiGRU  0.1582  0.1703  -2.8416   0.0468                  True
#     Loss     GRU   BiGRU  0.1925  0.1703   5.3690   0.0058                  True
#
# McNEMAR'S TEST — PER SEED (instance-level, Global Test Set):
#   Seed Model A Model B  A right/B wrong  A wrong/B right    stat  p-value  Significant (p<0.05)
#    42     CNN    LSTM               50              156 53.5194   0.0000                  True
#    42     CNN  BiLSTM               47              170 68.5899   0.0000                  True
#    42     CNN     GRU               76              151 24.1233   0.0000                  True
#    42     CNN   BiGRU               59              162 47.0769   0.0000                  True
#    42    LSTM  BiLSTM               40               57  2.6392   0.1043                 False
#    42    LSTM     GRU               69               38  8.4112   0.0037                  True
#    42    LSTM   BiGRU               51               48  0.0404   0.8407                 False
#    42  BiLSTM     GRU               87               39 17.5317   0.0000                  True
#    42  BiLSTM   BiGRU               47               27  4.8784   0.0272                  True
#    42     GRU   BiGRU               38               66  7.0096   0.0081                  True
#     3     CNN    LSTM               62              198 70.0962   0.0000                  True
#     3     CNN  BiLSTM               58              209 84.2697   0.0000                  True
#     3     CNN     GRU               64              180 54.2008   0.0000                  True
#     3     CNN   BiGRU               69              202 64.2952   0.0000                  True
#     3    LSTM  BiLSTM               27               42  2.8406   0.0919                 False
#     3    LSTM     GRU               56               36  3.9239   0.0476                  True
#     3    LSTM   BiGRU               51               48  0.0404   0.8407                 False
#     3  BiLSTM     GRU               67               32 11.6768   0.0006                  True
#     3  BiLSTM   BiGRU               46               28  3.9054   0.0481                  True
#     3     GRU   BiGRU               45               62  2.3925   0.1219                 False
#     7     CNN    LSTM               48              155 55.3498   0.0000                  True
#     7     CNN  BiLSTM               40              155 66.6462   0.0000                  True
#     7     CNN     GRU               52              140 39.4219   0.0000                  True
#     7     CNN   BiGRU               51              161 56.0425   0.0000                  True
#     7    LSTM  BiLSTM               34               42  0.6447   0.4220                 False
#     7    LSTM     GRU               50               31  4.0000   0.0455                  True
#     7    LSTM   BiGRU               35               38  0.0548   0.8149                 False
#     7  BiLSTM     GRU               62               35  6.9691   0.0083                  True
#     7  BiLSTM   BiGRU               38               33  0.2254   0.6350                 False
#     7     GRU   BiGRU               37               59  4.5938   0.0321                  True
#    72     CNN    LSTM               49              146 47.2615   0.0000                  True
#    72     CNN  BiLSTM               50              155 52.7610   0.0000                  True
#    72     CNN     GRU               65              137 24.9554   0.0000                  True
#    72     CNN   BiGRU               69              148 28.0369   0.0000                  True
#    72    LSTM  BiLSTM               24               32  0.8750   0.3496                 False
#    72    LSTM     GRU               43               18  9.4426   0.0021                  True
#    72    LSTM   BiGRU               54               36  3.2111   0.0731                 False
#    72  BiLSTM     GRU               58               25 12.3373   0.0004                  True
#    72  BiLSTM   BiGRU               50               24  8.4459   0.0037                  True
#    72     GRU   BiGRU               54               61  0.3130   0.5758                 False
#    82     CNN    LSTM               58              132 28.0474   0.0000                  True
#    82     CNN  BiLSTM               50              130 34.6722   0.0000                  True
#    82     CNN     GRU               88              129  7.3733   0.0066                  True
#    82     CNN   BiGRU               70              135 19.9805   0.0000                  True
#    82    LSTM  BiLSTM               37               43  0.3125   0.5762                 False
#    82    LSTM     GRU               67               34 10.1386   0.0015                  True
#    82    LSTM   BiGRU               63               54  0.5470   0.4595                 False
#    82  BiLSTM     GRU               76               37 12.7788   0.0004                  True
#    82  BiLSTM   BiGRU               58               43  1.9406   0.1636                 False
#    82     GRU   BiGRU               45               69  4.6404   0.0312                  True
#
# McNEMAR'S TEST — POOLED ACROSS 5 SEEDS (Global Test Set):
#  Model A Model B  A right/B wrong (pooled)  A wrong/B right (pooled)     stat  p-value  Significant (p<0.05)
#     CNN    LSTM                       267                       787 255.5607   0.0000                  True
#     CNN  BiLSTM                       245                       819 308.5799   0.0000                  True
#     CNN     GRU                       345                       737 141.2948   0.0000                  True
#     CNN   BiGRU                       318                       808 212.3632   0.0000                  True
#    LSTM  BiLSTM                       162                       216   7.4312   0.0064                  True
#    LSTM     GRU                       285                       157  36.4910   0.0000                  True
#    LSTM   BiGRU                       254                       224   1.7594   0.1847                 False
#  BiLSTM     GRU                       350                       168  63.2452   0.0000                  True
#  BiLSTM   BiGRU                       239                       155  17.4848   0.0000                  True
#     GRU   BiGRU                       219                       317  17.5541   0.0000                  True
