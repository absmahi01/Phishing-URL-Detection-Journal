# %%
import numpy as np, pandas as pd, tensorflow as tf, random, time, os
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import *

from scipy.stats import ttest_rel, chi2, binom
from itertools import combinations

# ================= CONFIG =================
LR=0.001; ROUNDS=30; LOCAL_EPOCHS=2; BATCH=16
CLIENTS=4; SEEDS=[42,3,7,72,82]
MODELS=["CNN","LSTM","BiLSTM","GRU","BiGRU"]
CLIENT_TEST_SIZE=0.2   # local train/test split ratio inside each client
MODEL_SAVE_DIR="saved_models"
os.makedirs(MODEL_SAVE_DIR,exist_ok=True)

# ================= LOAD =================
df=pd.read_csv("Dataset(111k).csv")

# remove text columns like .txt
for col in df.columns:
    if df[col].dtype==object and df[col].astype(str).str.contains(".txt",na=False).any():
        df.drop(columns=[col],inplace=True)

df=df.fillna("unknown")

for col in df.columns:
    if df[col].dtype==object:
        df[col]=LabelEncoder().fit_transform(df[col].astype(str))

X=df.drop("label",axis=1).values
y=df["label"].values

X=StandardScaler().fit_transform(X)

# NOTE: no upfront global train_test_split anymore.
# IID partitioning is applied to the WHOLE dataset per seed below,
# then each client locally splits its own IID shard into train/test.

# ================= HELPERS =================
def set_seed(s):
    random.seed(s); np.random.seed(s); tf.random.set_seed(s)

def iid_partition(X,y,K):
    # IID partition: each class shuffled and split evenly across clients
    idx=np.arange(len(y))
    clients=[[] for _ in range(K)]
    for c in np.unique(y):
        c_idx=idx[y==c]; np.random.shuffle(c_idx)
        split=np.array_split(c_idx,K)
        for i in range(K): clients[i].extend(split[i])
    return [(X[c],y[c]) for c in clients]

def format_xy(Xc,model_name):
    return Xc.reshape(len(Xc),-1,1)

def fedavg(global_model,locals,sizes):
    w=[m.get_weights() for m in locals]
    new=[np.average(x,axis=0,weights=sizes) for x in zip(*w)]
    global_model.set_weights(new)

def model_size(model):
    model.save("tmp.h5", include_optimizer=False)
    size=os.path.getsize("tmp.h5")/(1024*1024)
    os.remove("tmp.h5")
    return size

def stats(x,metric):
    x=np.asarray(x,dtype=float)
    x=x[~np.isnan(x)]
    if len(x)==0:
        return np.nan,np.nan,np.nan,np.nan
    mean=np.mean(x); sd=np.std(x)
    ci=1.96*sd/np.sqrt(len(x))
    low,high=mean-ci,mean+ci
    if metric in ["Accuracy","Precision","Recall","F1","AUC","Specificity"]:
        low=max(0,low); high=min(1,high)
    if metric=="MCC":
        low=max(-1,low); high=min(1,high)
    return mean,sd,low,high

def mcnemar_test(y_true_a,y_pred_a,y_true_b,y_pred_b):
    """McNemar's test between two classifiers evaluated on the SAME samples.
    Uses only the discordant pairs (one right, one wrong). Exact binomial
    for small discordant counts (n<25), continuity-corrected chi-square
    otherwise."""
    y_true_a=np.asarray(y_true_a).flatten()
    y_true_b=np.asarray(y_true_b).flatten()
    assert len(y_true_a)==len(y_true_b), "test sets must be the same size"
    assert np.array_equal(y_true_a,y_true_b), "test sets must match (same seed/instances)"

    correct_a=(np.asarray(y_pred_a).flatten()==y_true_a)
    correct_b=(np.asarray(y_pred_b).flatten()==y_true_b)

    n01=int(np.sum(correct_a & ~correct_b))   # A correct, B wrong
    n10=int(np.sum(~correct_a & correct_b))   # A wrong, B correct
    n=n01+n10

    if n==0:
        return np.nan,1.0,n01,n10
    if n<25:
        p=2*min(binom.cdf(min(n01,n10),n,0.5),0.5)   # exact two-sided binomial
        p=min(p,1.0)
        stat=np.nan
    else:
        stat=((abs(n01-n10)-1)**2)/n                  # continuity-corrected chi-square
        p=1-chi2.cdf(stat,1)
    return stat,p,n01,n10

# ================= MODELS =================
def build(name,shape=None,dim=None):
    if name=="CNN":
        m=Sequential([
            Input(shape),
            Conv1D(64,3,activation="relu"),
            Dropout(0.5),
            Conv1D(32,3,activation="relu"),
            GlobalMaxPooling1D(),
            Dense(32,activation="relu"),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="LSTM":
        m=Sequential([
            Input(shape),
            LSTM(128,return_sequences=True),
            Dropout(0.5),
            LSTM(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiLSTM":
        m=Sequential([
            Input(shape),
            Bidirectional(LSTM(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(LSTM(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="GRU":
        m=Sequential([
            Input(shape),
            GRU(128,return_sequences=True),
            Dropout(0.5),
            GRU(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiGRU":
        m=Sequential([
            Input(shape),
            Bidirectional(GRU(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(GRU(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    m.compile(optimizer=Adam(LR),loss="binary_crossentropy",metrics=["accuracy"])
    return m

# ================= STORAGE =================
rows=[]          # global (union-of-clients) test metrics, per (model, seed)
client_rows=[]   # per-client local test metrics, per (model, seed, client)
results_round={m:{"acc":[],"loss":[],"cm":[]} for m in MODELS}

# per-instance predictions, needed for McNemar's test
y_preds={}        # (model, seed) -> y_pred array (0/1), aligned to y_trues[seed]
y_trues={}        # seed -> y_test_global array (0/1) -- same across all models for a given seed

# ================= TRAIN =================
for model_name in MODELS:
    print(f"\n================ MODEL: {model_name} ================")

    for seed in SEEDS:
        print(f"\n------ SEED {seed} ------")
        set_seed(seed)

        # ---- IID partition of the WHOLE dataset across clients ----
        client_full=iid_partition(X,y,CLIENTS)

        # ---- Each client locally splits its own shard into train/test ----
        client_train,client_test=[],[]
        for cid,(Xc,yc) in enumerate(client_full):
            try:
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,stratify=yc,random_state=seed
                )
            except ValueError:
                # fallback if a client shard doesn't have enough of a class to stratify
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,random_state=seed
                )
            client_train.append((Xc_tr,yc_tr))
            client_test.append((Xc_te,yc_te))

        # ---- Global (centralized) test set = union of all clients' local test shards ----
        X_test_global=np.concatenate([Xc for Xc,_ in client_test],axis=0)
        y_test_global=np.concatenate([yc for _,yc in client_test],axis=0)

        create=lambda:build(model_name,shape=(X.shape[1],1))

        fmt=lambda Xc: format_xy(Xc,model_name)

        global_model=create()

        acc_hist,loss_hist=[],[]
        comm=0
        total_train_time=0.0

        for r in range(ROUNDS):
            print(f"\n[Model={model_name} | Seed={seed} | Round={r+1}]")

            locals_=[]; sizes=[]

            for cid,(Xc,yc) in enumerate(client_train):
                m=create()
                m.set_weights(global_model.get_weights())

                t0=time.time()
                history=m.fit(fmt(Xc),yc,epochs=LOCAL_EPOCHS,batch_size=BATCH,verbose=0)
                t1=time.time()
                total_train_time+=(t1-t0)

                train_loss=history.history["loss"][-1]
                train_acc=history.history["accuracy"][-1]

                print(f" Client {cid} → Loss={train_loss:.4f}, Acc={train_acc:.4f}, Time={t1-t0:.2f}s, N={len(yc)}")

                locals_.append(m); sizes.append(len(yc))

            fedavg(global_model,locals_,sizes)

            loss,acc=global_model.evaluate(fmt(X_test_global),y_test_global,verbose=0)

            print(f" >>> GLOBAL (centralized test) → Loss={loss:.4f}, Acc={acc:.4f}")

            acc_hist.append(acc); loss_hist.append(loss)

            # bytes per weight (float32=4 bytes), sent down to each client AND back up from each client
            weight_bytes=sum([w.size for w in global_model.get_weights()])*4
            comm+=weight_bytes*CLIENTS*2

        # ================= FINAL GLOBAL TEST METRICS =================
        t0=time.time()
        y_prob=global_model.predict(fmt(X_test_global),verbose=0)
        inference_time=time.time()-t0

        y_pred=(y_prob>0.5).astype(int)

        # ---- Save per-instance predictions for McNemar's test ----
        y_preds[(model_name,seed)]=y_pred.flatten()
        if seed not in y_trues:
            y_trues[seed]=y_test_global.flatten()
        else:
            # sanity check: every model must see the identical test set for this seed
            assert np.array_equal(y_trues[seed],y_test_global.flatten()), \
                f"Test set mismatch for seed {seed} — McNemar's test requires identical instances across models."

        tn,fp,fn,tp=confusion_matrix(y_test_global,y_pred).ravel()

        # ---- Save this trained global model to disk ----
        model_path=os.path.join(MODEL_SAVE_DIR,f"{model_name}_seed{seed}.keras")
        global_model.save(model_path)
        print(f" [saved] {model_path}")

        rows.append({
            "Model":model_name,
            "Seed":seed,
            "Loss":log_loss(y_test_global,y_prob),
            "Accuracy":accuracy_score(y_test_global,y_pred),
            "Precision":precision_score(y_test_global,y_pred),
            "Recall":recall_score(y_test_global,y_pred),
            "F1":f1_score(y_test_global,y_pred),
            "MCC":matthews_corrcoef(y_test_global,y_pred),
            "AUC":roc_auc_score(y_test_global,y_prob),
            "Specificity":tn/(tn+fp),
            "Training_Time_sec":total_train_time,
            "Inference_Time_sec":inference_time,
            "Model_Size_MB":model_size(global_model),
            "Comm_per_round_MB":comm/(ROUNDS*1024*1024),
            "Total_Comm_MB":comm/(1024*1024),
            "Saved_Model_Path":model_path
        })

        results_round[model_name]["acc"].append(acc_hist)
        results_round[model_name]["loss"].append(loss_hist)
        results_round[model_name]["cm"].append(confusion_matrix(y_test_global,y_pred))

        # ================= PER-CLIENT LOCAL TEST EVALUATION =================
        for cid,(Xc_te,yc_te) in enumerate(client_test):
            yc_prob=global_model.predict(fmt(Xc_te),verbose=0)
            yc_pred=(yc_prob>0.5).astype(int)

            cm_c=confusion_matrix(yc_te,yc_pred,labels=[0,1])
            tn_c,fp_c,fn_c,tp_c=cm_c.ravel()

            auc_val=roc_auc_score(yc_te,yc_prob) if len(np.unique(yc_te))>1 else np.nan

            client_rows.append({
                "Model":model_name,
                "Seed":seed,
                "Client":cid,
                "N_test":len(yc_te),
                "Loss":log_loss(yc_te,yc_prob,labels=[0,1]),
                "Accuracy":accuracy_score(yc_te,yc_pred),
                "Precision":precision_score(yc_te,yc_pred,zero_division=0),
                "Recall":recall_score(yc_te,yc_pred,zero_division=0),
                "F1":f1_score(yc_te,yc_pred,zero_division=0),
                "MCC":matthews_corrcoef(yc_te,yc_pred),
                "AUC":auc_val,
                "Specificity":(tn_c/(tn_c+fp_c)) if (tn_c+fp_c)>0 else np.nan
            })

# ================= PRINT ALL CONFUSION MATRICES PER SEED (GLOBAL TEST) =================
for m in MODELS:
    print(f"\n=== {m}: Global Test Confusion Matrices per Seed ===")
    for seed,cm in zip(SEEDS,results_round[m]["cm"]):
        print(f"Seed {seed}:\n{cm}")

# ================= MEAN OVER SEEDS (GLOBAL TEST, per-round curves + avg cm) =================
for m in MODELS:
    results_round[m]["acc"]=np.mean(results_round[m]["acc"],axis=0)
    results_round[m]["loss"]=np.mean(results_round[m]["loss"],axis=0)
    results_round[m]["cm"]=np.mean(results_round[m]["cm"],axis=0)

for m in MODELS:
    print(f"\n=== {m} (Global Test, averaged over {len(SEEDS)} seeds) ===")
    print("Confusion Matrix (avg):\n",np.round(results_round[m]["cm"],2))
    print("Accuracy per round:",np.round(results_round[m]["acc"],4))
    print("Loss per round:",np.round(results_round[m]["loss"],4))

# ================= PER-MODEL SUMMARY (ALL METRICS incl. time & comm cost, avg over 5 seeds) =================
results_df=pd.DataFrame(rows)

summary_metrics=["Loss","Accuracy","Precision","Recall","F1","MCC","AUC","Specificity",
                  "Training_Time_sec","Inference_Time_sec","Model_Size_MB",
                  "Comm_per_round_MB","Total_Comm_MB"]

per_model_summary=[]
for m in MODELS:
    sub=results_df[results_df["Model"]==m]
    for metric in summary_metrics:
        mean,sd,low,high=stats(sub[metric],metric)
        per_model_summary.append({
            "Model":m,
            "Metric":metric,
            "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
            "95% CI":f"[{low:.4f}, {high:.4f}]"
        })

per_model_summary_df=pd.DataFrame(per_model_summary)
print(f"\nPER-MODEL SUMMARY (mean ± sd, 95% CI over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_summary_df.to_string(index=False))

# wide pivot: one row per model, one column per metric, "mean [low, high]"
per_model_wide=per_model_summary_df.copy()
per_model_wide["Mean [95% CI]"]=per_model_wide.apply(
    lambda r: r["Mean ± SD"].split(" ± ")[0]+" "+r["95% CI"], axis=1
)
per_model_wide=per_model_wide.pivot(index="Model",columns="Metric",values="Mean [95% CI]")
per_model_wide=per_model_wide[summary_metrics]  # keep original metric order
print(f"\nPER-MODEL SUMMARY, WIDE (mean [95% CI] over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_wide.to_string())

# overall pooled summary (all models & seeds together) kept for reference
overall_summary=[]
for metric in summary_metrics:
    mean,sd,low,high=stats(results_df[metric],metric)
    overall_summary.append({
        "Metric":metric,
        "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
        "95% CI":f"[{low:.4f},{high:.4f}]"
    })
overall_summary_df=pd.DataFrame(overall_summary)
print(f"\nSAVED MODELS ({len(results_df)} total, in '{MODEL_SAVE_DIR}/'):\n",
      results_df[["Model","Seed","Saved_Model_Path"]].to_string(index=False))
print("\nOVERALL SUMMARY (all models & seeds pooled):\n",overall_summary_df)

# ================= PER-CLIENT TEST SUMMARY, averaged over 5 seeds =================
client_df=pd.DataFrame(client_rows)
client_metrics=["Accuracy","Precision","Recall","F1","MCC","AUC","Specificity","Loss"]

per_client_summary=(
    client_df.groupby(["Model","Client"])[client_metrics]
    .agg(["mean","std"])
    .round(4)
)
print(f"\nPER-CLIENT TEST SUMMARY (mean/std over {len(SEEDS)} seeds):\n",per_client_summary)

# ================= PAIRWISE PAIRED T-TESTS ACROSS MODELS (same seeds) =================
paired_test_metrics=["Accuracy","F1","AUC","Loss"]

pairwise_rows=[]
for metric in paired_test_metrics:
    for m1,m2 in combinations(MODELS,2):
        a=results_df[results_df["Model"]==m1].sort_values("Seed")[metric].values
        b=results_df[results_df["Model"]==m2].sort_values("Seed")[metric].values
        t_stat,p_val=ttest_rel(a,b)
        pairwise_rows.append({
            "Metric":metric,"Model A":m1,"Model B":m2,
            "Mean A":round(a.mean(),4),"Mean B":round(b.mean(),4),
            "t-stat":round(t_stat,4),"p-value":round(p_val,4),
            "Significant (p<0.05)":p_val<0.05
        })

pairwise_df=pd.DataFrame(pairwise_rows)
print(f"\nPAIRWISE PAIRED T-TESTS across {len(SEEDS)} seeds (Global Test Set):\n",
      pairwise_df.to_string(index=False))

# ================= McNEMAR'S TEST (per-instance, per seed + pooled across seeds) =================
mcnemar_per_seed_rows=[]
for seed in SEEDS:
    y_true=y_trues[seed]
    for m1,m2 in combinations(MODELS,2):
        stat,p,n01,n10=mcnemar_test(y_true,y_preds[(m1,seed)],y_true,y_preds[(m2,seed)])
        mcnemar_per_seed_rows.append({
            "Seed":seed,"Model A":m1,"Model B":m2,
            "A right/B wrong":n01,"A wrong/B right":n10,
            "stat":round(stat,4) if not np.isnan(stat) else "exact",
            "p-value":round(p,4),"Significant (p<0.05)":p<0.05
        })

mcnemar_per_seed_df=pd.DataFrame(mcnemar_per_seed_rows)
print(f"\nMcNEMAR'S TEST — PER SEED (instance-level, Global Test Set):\n",
      mcnemar_per_seed_df.to_string(index=False))

# pooled version: sum discordant counts across all 5 seeds (more statistical power)
mcnemar_pooled_rows=[]
for m1,m2 in combinations(MODELS,2):
    n01_total=0; n10_total=0
    for seed in SEEDS:
        y_true=y_trues[seed]
        correct_a=(y_preds[(m1,seed)]==y_true)
        correct_b=(y_preds[(m2,seed)]==y_true)
        n01_total+=int(np.sum(correct_a & ~correct_b))
        n10_total+=int(np.sum(~correct_a & correct_b))
    n=n01_total+n10_total
    if n==0:
        stat,p=np.nan,1.0
    elif n<25:
        p=min(2*min(binom.cdf(min(n01_total,n10_total),n,0.5),0.5),1.0); stat=np.nan
    else:
        stat=((abs(n01_total-n10_total)-1)**2)/n
        p=1-chi2.cdf(stat,1)
    mcnemar_pooled_rows.append({
        "Model A":m1,"Model B":m2,
        "A right/B wrong (pooled)":n01_total,"A wrong/B right (pooled)":n10_total,
        "stat":round(stat,4) if not np.isnan(stat) else "exact",
        "p-value":round(p,4),"Significant (p<0.05)":p<0.05
    })

mcnemar_pooled_df=pd.DataFrame(mcnemar_pooled_rows)
print(f"\nMcNEMAR'S TEST — POOLED ACROSS {len(SEEDS)} SEEDS (Global Test Set):\n",
      mcnemar_pooled_df.to_string(index=False))

# ================= PLOTS =================
rounds=np.arange(1,ROUNDS+1)

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["acc"],label=m)
plt.title("Accuracy vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Accuracy")
plt.legend(); plt.grid(); plt.show()

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["loss"],label=m)
plt.title("Loss vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Loss")
plt.legend(); plt.grid(); plt.show()
# Out:
# C:\Users\USER\anaconda3\envs\py310\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.5.0) or chardet (6.0.0.post1)/charset_normalizer (3.4.3) doesn't match a supported version!
#   warnings.warn(
# ================ MODEL: CNN ================
#
# ------ SEED 42 ------
#
# [Model=CNN | Seed=42 | Round=1]
#  Client 0 → Loss=0.2510, Acc=0.9049, Time=7.36s, N=23320
#  Client 1 → Loss=0.2521, Acc=0.9037, Time=5.66s, N=23320
#  Client 2 → Loss=0.2508, Acc=0.9075, Time=5.78s, N=23320
#  Client 3 → Loss=0.2642, Acc=0.9032, Time=7.14s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.2910, Acc=0.8680
#
# [Model=CNN | Seed=42 | Round=2]
#  Client 0 → Loss=0.1943, Acc=0.9265, Time=6.34s, N=23320
#  Client 1 → Loss=0.1944, Acc=0.9268, Time=5.76s, N=23320
#  Client 2 → Loss=0.1921, Acc=0.9280, Time=5.84s, N=23320
#  Client 3 → Loss=0.1945, Acc=0.9259, Time=6.05s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1478, Acc=0.9503
#
# [Model=CNN | Seed=42 | Round=3]
#  Client 0 → Loss=0.1654, Acc=0.9391, Time=5.67s, N=23320
#  Client 1 → Loss=0.1653, Acc=0.9386, Time=5.60s, N=23320
#  Client 2 → Loss=0.1644, Acc=0.9372, Time=5.51s, N=23320
#  Client 3 → Loss=0.1672, Acc=0.9394, Time=5.52s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1276, Acc=0.9564
#
# [Model=CNN | Seed=42 | Round=4]
#  Client 0 → Loss=0.1513, Acc=0.9431, Time=5.41s, N=23320
#  Client 1 → Loss=0.1502, Acc=0.9439, Time=5.43s, N=23320
#  Client 2 → Loss=0.1507, Acc=0.9439, Time=5.35s, N=23320
#  Client 3 → Loss=0.1549, Acc=0.9443, Time=5.67s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1178, Acc=0.9595
#
# [Model=CNN | Seed=42 | Round=5]
#  Client 0 → Loss=0.1428, Acc=0.9475, Time=5.56s, N=23320
#  Client 1 → Loss=0.1434, Acc=0.9477, Time=5.45s, N=23320
#  Client 2 → Loss=0.1423, Acc=0.9476, Time=5.37s, N=23320
#  Client 3 → Loss=0.1454, Acc=0.9466, Time=5.36s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1120, Acc=0.9615
#
# [Model=CNN | Seed=42 | Round=6]
#  Client 0 → Loss=0.1355, Acc=0.9495, Time=5.57s, N=23320
#  Client 1 → Loss=0.1382, Acc=0.9499, Time=5.26s, N=23320
#  Client 2 → Loss=0.1354, Acc=0.9497, Time=5.21s, N=23320
#  Client 3 → Loss=0.1388, Acc=0.9490, Time=5.28s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1083, Acc=0.9623
#
# [Model=CNN | Seed=42 | Round=7]
#  Client 0 → Loss=0.1315, Acc=0.9511, Time=5.31s, N=23320
#  Client 1 → Loss=0.1325, Acc=0.9516, Time=5.31s, N=23320
#  Client 2 → Loss=0.1304, Acc=0.9514, Time=5.32s, N=23320
#  Client 3 → Loss=0.1316, Acc=0.9524, Time=5.29s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1059, Acc=0.9640
#
# [Model=CNN | Seed=42 | Round=8]
#  Client 0 → Loss=0.1272, Acc=0.9524, Time=5.37s, N=23320
#  Client 1 → Loss=0.1300, Acc=0.9523, Time=5.62s, N=23320
#  Client 2 → Loss=0.1258, Acc=0.9545, Time=5.77s, N=23320
#  Client 3 → Loss=0.1270, Acc=0.9535, Time=6.02s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1031, Acc=0.9653
#
# [Model=CNN | Seed=42 | Round=9]
#  Client 0 → Loss=0.1240, Acc=0.9545, Time=5.59s, N=23320
#  Client 1 → Loss=0.1269, Acc=0.9530, Time=5.32s, N=23320
#  Client 2 → Loss=0.1219, Acc=0.9559, Time=5.48s, N=23320
#  Client 3 → Loss=0.1238, Acc=0.9548, Time=5.54s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1015, Acc=0.9659
#
# [Model=CNN | Seed=42 | Round=10]
#  Client 0 → Loss=0.1205, Acc=0.9556, Time=5.45s, N=23320
#  Client 1 → Loss=0.1243, Acc=0.9547, Time=5.48s, N=23320
#  Client 2 → Loss=0.1184, Acc=0.9576, Time=5.26s, N=23320
#  Client 3 → Loss=0.1216, Acc=0.9553, Time=5.52s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0999, Acc=0.9664
#
# [Model=CNN | Seed=42 | Round=11]
#  Client 0 → Loss=0.1185, Acc=0.9573, Time=5.43s, N=23320
#  Client 1 → Loss=0.1202, Acc=0.9560, Time=5.73s, N=23320
#  Client 2 → Loss=0.1163, Acc=0.9575, Time=5.94s, N=23320
#  Client 3 → Loss=0.1186, Acc=0.9575, Time=5.71s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0990, Acc=0.9666
#
# [Model=CNN | Seed=42 | Round=12]
#  Client 0 → Loss=0.1171, Acc=0.9575, Time=5.59s, N=23320
#  Client 1 → Loss=0.1175, Acc=0.9571, Time=5.61s, N=23320
#  Client 2 → Loss=0.1146, Acc=0.9587, Time=5.64s, N=23320
#  Client 3 → Loss=0.1174, Acc=0.9576, Time=5.73s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0978, Acc=0.9673
#
# [Model=CNN | Seed=42 | Round=13]
#  Client 0 → Loss=0.1145, Acc=0.9591, Time=5.48s, N=23320
#  Client 1 → Loss=0.1161, Acc=0.9572, Time=5.37s, N=23320
#  Client 2 → Loss=0.1119, Acc=0.9587, Time=5.43s, N=23320
#  Client 3 → Loss=0.1154, Acc=0.9576, Time=5.26s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0978, Acc=0.9672
#
# [Model=CNN | Seed=42 | Round=14]
#  Client 0 → Loss=0.1126, Acc=0.9599, Time=5.27s, N=23320
#  Client 1 → Loss=0.1166, Acc=0.9569, Time=5.22s, N=23320
#  Client 2 → Loss=0.1115, Acc=0.9584, Time=5.36s, N=23320
#  Client 3 → Loss=0.1149, Acc=0.9584, Time=5.32s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0964, Acc=0.9673
#
# [Model=CNN | Seed=42 | Round=15]
#  Client 0 → Loss=0.1118, Acc=0.9609, Time=5.22s, N=23320
#  Client 1 → Loss=0.1142, Acc=0.9577, Time=5.43s, N=23320
#  Client 2 → Loss=0.1085, Acc=0.9594, Time=5.43s, N=23320
#  Client 3 → Loss=0.1129, Acc=0.9590, Time=5.45s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0951, Acc=0.9682
#
# [Model=CNN | Seed=42 | Round=16]
#  Client 0 → Loss=0.1119, Acc=0.9603, Time=5.50s, N=23320
#  Client 1 → Loss=0.1129, Acc=0.9575, Time=5.41s, N=23320
#  Client 2 → Loss=0.1068, Acc=0.9604, Time=5.54s, N=23320
#  Client 3 → Loss=0.1108, Acc=0.9601, Time=5.68s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0947, Acc=0.9683
#
# [Model=CNN | Seed=42 | Round=17]
#  Client 0 → Loss=0.1089, Acc=0.9617, Time=5.54s, N=23320
#  Client 1 → Loss=0.1113, Acc=0.9593, Time=5.64s, N=23320
#  Client 2 → Loss=0.1070, Acc=0.9605, Time=5.61s, N=23320
#  Client 3 → Loss=0.1113, Acc=0.9592, Time=5.59s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0949, Acc=0.9688
#
# [Model=CNN | Seed=42 | Round=18]
#  Client 0 → Loss=0.1093, Acc=0.9622, Time=5.34s, N=23320
#  Client 1 → Loss=0.1095, Acc=0.9594, Time=5.51s, N=23320
#  Client 2 → Loss=0.1029, Acc=0.9630, Time=5.37s, N=23320
#  Client 3 → Loss=0.1099, Acc=0.9602, Time=5.30s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0945, Acc=0.9685
#
# [Model=CNN | Seed=42 | Round=19]
#  Client 0 → Loss=0.1075, Acc=0.9622, Time=5.30s, N=23320
#  Client 1 → Loss=0.1082, Acc=0.9597, Time=5.39s, N=23320
#  Client 2 → Loss=0.1031, Acc=0.9620, Time=5.16s, N=23320
#  Client 3 → Loss=0.1081, Acc=0.9612, Time=5.39s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0940, Acc=0.9690
#
# [Model=CNN | Seed=42 | Round=20]
#  Client 0 → Loss=0.1067, Acc=0.9628, Time=5.17s, N=23320
#  Client 1 → Loss=0.1070, Acc=0.9596, Time=5.03s, N=23320
#  Client 2 → Loss=0.1036, Acc=0.9623, Time=5.27s, N=23320
#  Client 3 → Loss=0.1073, Acc=0.9617, Time=5.67s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0945, Acc=0.9692
#
# [Model=CNN | Seed=42 | Round=21]
#  Client 0 → Loss=0.1049, Acc=0.9636, Time=5.67s, N=23320
#  Client 1 → Loss=0.1052, Acc=0.9606, Time=5.39s, N=23320
#  Client 2 → Loss=0.1026, Acc=0.9630, Time=5.47s, N=23320
#  Client 3 → Loss=0.1049, Acc=0.9627, Time=5.50s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0939, Acc=0.9693
#
# [Model=CNN | Seed=42 | Round=22]
#  Client 0 → Loss=0.1042, Acc=0.9635, Time=5.53s, N=23320
#  Client 1 → Loss=0.1040, Acc=0.9614, Time=5.53s, N=23320
#  Client 2 → Loss=0.1003, Acc=0.9643, Time=5.51s, N=23320
#  Client 3 → Loss=0.1077, Acc=0.9616, Time=5.50s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0935, Acc=0.9686
#
# [Model=CNN | Seed=42 | Round=23]
#  Client 0 → Loss=0.1033, Acc=0.9637, Time=5.20s, N=23320
#  Client 1 → Loss=0.1044, Acc=0.9616, Time=5.17s, N=23320
#  Client 2 → Loss=0.0984, Acc=0.9638, Time=5.13s, N=23320
#  Client 3 → Loss=0.1040, Acc=0.9635, Time=5.14s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0950, Acc=0.9691
#
# [Model=CNN | Seed=42 | Round=24]
#  Client 0 → Loss=0.1021, Acc=0.9647, Time=5.24s, N=23320
#  Client 1 → Loss=0.1043, Acc=0.9614, Time=5.30s, N=23320
#  Client 2 → Loss=0.0980, Acc=0.9628, Time=5.35s, N=23320
#  Client 3 → Loss=0.1040, Acc=0.9622, Time=5.53s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0959, Acc=0.9694
#
# [Model=CNN | Seed=42 | Round=25]
#  Client 0 → Loss=0.1026, Acc=0.9649, Time=5.51s, N=23320
#  Client 1 → Loss=0.1023, Acc=0.9618, Time=5.45s, N=23320
#  Client 2 → Loss=0.0980, Acc=0.9642, Time=5.49s, N=23320
#  Client 3 → Loss=0.1030, Acc=0.9631, Time=5.52s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0963, Acc=0.9690
#
# [Model=CNN | Seed=42 | Round=26]
#  Client 0 → Loss=0.1011, Acc=0.9649, Time=5.46s, N=23320
#  Client 1 → Loss=0.1029, Acc=0.9613, Time=5.49s, N=23320
#  Client 2 → Loss=0.0966, Acc=0.9645, Time=5.52s, N=23320
#  Client 3 → Loss=0.1026, Acc=0.9635, Time=5.45s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0960, Acc=0.9693
#
# [Model=CNN | Seed=42 | Round=27]
#  Client 0 → Loss=0.0997, Acc=0.9659, Time=5.40s, N=23320
#  Client 1 → Loss=0.1002, Acc=0.9629, Time=5.77s, N=23320
#  Client 2 → Loss=0.0963, Acc=0.9650, Time=5.73s, N=23320
#  Client 3 → Loss=0.1022, Acc=0.9633, Time=5.79s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0961, Acc=0.9692
#
# [Model=CNN | Seed=42 | Round=28]
#  Client 0 → Loss=0.1003, Acc=0.9651, Time=5.78s, N=23320
#  Client 1 → Loss=0.0997, Acc=0.9621, Time=5.71s, N=23320
#  Client 2 → Loss=0.0949, Acc=0.9648, Time=5.21s, N=23320
#  Client 3 → Loss=0.1048, Acc=0.9616, Time=5.18s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0985, Acc=0.9697
#
# [Model=CNN | Seed=42 | Round=29]
#  Client 0 → Loss=0.0966, Acc=0.9667, Time=5.58s, N=23320
#  Client 1 → Loss=0.0990, Acc=0.9627, Time=5.28s, N=23320
#  Client 2 → Loss=0.0950, Acc=0.9656, Time=5.34s, N=23320
#  Client 3 → Loss=0.1019, Acc=0.9636, Time=5.64s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0995, Acc=0.9694
#
# [Model=CNN | Seed=42 | Round=30]
#  Client 0 → Loss=0.0979, Acc=0.9657, Time=5.79s, N=23320
#  Client 1 → Loss=0.0983, Acc=0.9635, Time=5.43s, N=23320
#  Client 2 → Loss=0.0945, Acc=0.9657, Time=5.38s, N=23320
#  Client 3 → Loss=0.1012, Acc=0.9630, Time=5.40s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0999, Acc=0.9693
#  [saved] saved_models\CNN_seed42.keras
#
# ------ SEED 3 ------
#
# [Model=CNN | Seed=3 | Round=1]
#  Client 0 → Loss=0.2485, Acc=0.9042, Time=5.70s, N=23320
#  Client 1 → Loss=0.2523, Acc=0.9063, Time=5.62s, N=23320
#  Client 2 → Loss=0.2511, Acc=0.8997, Time=5.41s, N=23320
#  Client 3 → Loss=0.2536, Acc=0.8988, Time=5.42s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.2121, Acc=0.9144
#
# [Model=CNN | Seed=3 | Round=2]
#  Client 0 → Loss=0.2011, Acc=0.9223, Time=5.54s, N=23320
#  Client 1 → Loss=0.2044, Acc=0.9241, Time=5.38s, N=23320
#  Client 2 → Loss=0.1972, Acc=0.9244, Time=5.33s, N=23320
#  Client 3 → Loss=0.2048, Acc=0.9190, Time=5.49s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1558, Acc=0.9443
#
# [Model=CNN | Seed=3 | Round=3]
#  Client 0 → Loss=0.1755, Acc=0.9346, Time=5.59s, N=23320
#  Client 1 → Loss=0.1767, Acc=0.9354, Time=5.50s, N=23320
#  Client 2 → Loss=0.1715, Acc=0.9334, Time=5.39s, N=23320
#  Client 3 → Loss=0.1770, Acc=0.9349, Time=5.26s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1350, Acc=0.9532
#
# [Model=CNN | Seed=3 | Round=4]
#  Client 0 → Loss=0.1600, Acc=0.9402, Time=5.38s, N=23320
#  Client 1 → Loss=0.1599, Acc=0.9418, Time=5.35s, N=23320
#  Client 2 → Loss=0.1574, Acc=0.9404, Time=5.47s, N=23320
#  Client 3 → Loss=0.1610, Acc=0.9409, Time=5.23s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1248, Acc=0.9582
#
# [Model=CNN | Seed=3 | Round=5]
#  Client 0 → Loss=0.1501, Acc=0.9442, Time=5.30s, N=23320
#  Client 1 → Loss=0.1511, Acc=0.9457, Time=5.22s, N=23320
#  Client 2 → Loss=0.1488, Acc=0.9438, Time=5.30s, N=23320
#  Client 3 → Loss=0.1511, Acc=0.9454, Time=5.28s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1186, Acc=0.9598
#
# [Model=CNN | Seed=3 | Round=6]
#  Client 0 → Loss=0.1420, Acc=0.9471, Time=5.38s, N=23320
#  Client 1 → Loss=0.1440, Acc=0.9470, Time=5.38s, N=23320
#  Client 2 → Loss=0.1410, Acc=0.9475, Time=5.37s, N=23320
#  Client 3 → Loss=0.1443, Acc=0.9471, Time=5.37s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1136, Acc=0.9620
#
# [Model=CNN | Seed=3 | Round=7]
#  Client 0 → Loss=0.1363, Acc=0.9500, Time=5.38s, N=23320
#  Client 1 → Loss=0.1379, Acc=0.9511, Time=5.43s, N=23320
#  Client 2 → Loss=0.1360, Acc=0.9506, Time=5.51s, N=23320
#  Client 3 → Loss=0.1394, Acc=0.9491, Time=5.42s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1117, Acc=0.9629
#
# [Model=CNN | Seed=3 | Round=8]
#  Client 0 → Loss=0.1321, Acc=0.9520, Time=5.60s, N=23320
#  Client 1 → Loss=0.1338, Acc=0.9518, Time=5.34s, N=23320
#  Client 2 → Loss=0.1334, Acc=0.9510, Time=5.35s, N=23320
#  Client 3 → Loss=0.1352, Acc=0.9504, Time=5.34s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1083, Acc=0.9634
#
# [Model=CNN | Seed=3 | Round=9]
#  Client 0 → Loss=0.1275, Acc=0.9539, Time=5.44s, N=23320
#  Client 1 → Loss=0.1306, Acc=0.9531, Time=5.30s, N=23320
#  Client 2 → Loss=0.1295, Acc=0.9521, Time=5.37s, N=23320
#  Client 3 → Loss=0.1308, Acc=0.9516, Time=5.33s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1052, Acc=0.9638
#
# [Model=CNN | Seed=3 | Round=10]
#  Client 0 → Loss=0.1235, Acc=0.9549, Time=5.36s, N=23320
#  Client 1 → Loss=0.1272, Acc=0.9540, Time=5.53s, N=23320
#  Client 2 → Loss=0.1269, Acc=0.9531, Time=5.57s, N=23320
#  Client 3 → Loss=0.1280, Acc=0.9529, Time=5.54s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1048, Acc=0.9642
#
# [Model=CNN | Seed=3 | Round=11]
#  Client 0 → Loss=0.1218, Acc=0.9548, Time=5.46s, N=23320
#  Client 1 → Loss=0.1254, Acc=0.9541, Time=5.68s, N=23320
#  Client 2 → Loss=0.1236, Acc=0.9551, Time=5.50s, N=23320
#  Client 3 → Loss=0.1241, Acc=0.9559, Time=5.55s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1040, Acc=0.9648
#
# [Model=CNN | Seed=3 | Round=12]
#  Client 0 → Loss=0.1185, Acc=0.9560, Time=5.36s, N=23320
#  Client 1 → Loss=0.1217, Acc=0.9559, Time=5.58s, N=23320
#  Client 2 → Loss=0.1228, Acc=0.9544, Time=5.49s, N=23320
#  Client 3 → Loss=0.1220, Acc=0.9563, Time=5.56s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1040, Acc=0.9651
#
# [Model=CNN | Seed=3 | Round=13]
#  Client 0 → Loss=0.1190, Acc=0.9561, Time=5.73s, N=23320
#  Client 1 → Loss=0.1197, Acc=0.9573, Time=5.49s, N=23320
#  Client 2 → Loss=0.1189, Acc=0.9560, Time=5.47s, N=23320
#  Client 3 → Loss=0.1193, Acc=0.9582, Time=5.57s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1037, Acc=0.9654
#
# [Model=CNN | Seed=3 | Round=14]
#  Client 0 → Loss=0.1170, Acc=0.9573, Time=5.46s, N=23320
#  Client 1 → Loss=0.1172, Acc=0.9573, Time=5.33s, N=23320
#  Client 2 → Loss=0.1189, Acc=0.9558, Time=5.51s, N=23320
#  Client 3 → Loss=0.1177, Acc=0.9568, Time=5.47s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1056, Acc=0.9652
#
# [Model=CNN | Seed=3 | Round=15]
#  Client 0 → Loss=0.1144, Acc=0.9579, Time=5.56s, N=23320
#  Client 1 → Loss=0.1163, Acc=0.9581, Time=5.52s, N=23320
#  Client 2 → Loss=0.1177, Acc=0.9558, Time=5.54s, N=23320
#  Client 3 → Loss=0.1152, Acc=0.9577, Time=5.54s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1039, Acc=0.9660
#
# [Model=CNN | Seed=3 | Round=16]
#  Client 0 → Loss=0.1127, Acc=0.9584, Time=5.55s, N=23320
#  Client 1 → Loss=0.1141, Acc=0.9593, Time=5.48s, N=23320
#  Client 2 → Loss=0.1170, Acc=0.9568, Time=5.47s, N=23320
#  Client 3 → Loss=0.1151, Acc=0.9583, Time=5.52s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1024, Acc=0.9656
#
# [Model=CNN | Seed=3 | Round=17]
#  Client 0 → Loss=0.1118, Acc=0.9582, Time=5.73s, N=23320
#  Client 1 → Loss=0.1136, Acc=0.9592, Time=5.69s, N=23320
#  Client 2 → Loss=0.1141, Acc=0.9581, Time=5.62s, N=23320
#  Client 3 → Loss=0.1141, Acc=0.9583, Time=5.64s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1052, Acc=0.9655
#
# [Model=CNN | Seed=3 | Round=18]
#  Client 0 → Loss=0.1121, Acc=0.9590, Time=5.95s, N=23320
#  Client 1 → Loss=0.1118, Acc=0.9596, Time=5.57s, N=23320
#  Client 2 → Loss=0.1138, Acc=0.9588, Time=5.45s, N=23320
#  Client 3 → Loss=0.1130, Acc=0.9581, Time=5.39s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1028, Acc=0.9658
#
# [Model=CNN | Seed=3 | Round=19]
#  Client 0 → Loss=0.1124, Acc=0.9588, Time=5.53s, N=23320
#  Client 1 → Loss=0.1111, Acc=0.9594, Time=5.59s, N=23320
#  Client 2 → Loss=0.1125, Acc=0.9574, Time=5.55s, N=23320
#  Client 3 → Loss=0.1121, Acc=0.9583, Time=5.51s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1017, Acc=0.9668
#
# [Model=CNN | Seed=3 | Round=20]
#  Client 0 → Loss=0.1103, Acc=0.9590, Time=5.48s, N=23320
#  Client 1 → Loss=0.1107, Acc=0.9597, Time=5.62s, N=23320
#  Client 2 → Loss=0.1132, Acc=0.9589, Time=5.50s, N=23320
#  Client 3 → Loss=0.1101, Acc=0.9583, Time=5.52s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1048, Acc=0.9664
#
# [Model=CNN | Seed=3 | Round=21]
#  Client 0 → Loss=0.1089, Acc=0.9606, Time=5.58s, N=23320
#  Client 1 → Loss=0.1095, Acc=0.9605, Time=5.34s, N=23320
#  Client 2 → Loss=0.1106, Acc=0.9590, Time=5.34s, N=23320
#  Client 3 → Loss=0.1101, Acc=0.9593, Time=5.37s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1082, Acc=0.9657
#
# [Model=CNN | Seed=3 | Round=22]
#  Client 0 → Loss=0.1090, Acc=0.9602, Time=5.52s, N=23320
#  Client 1 → Loss=0.1094, Acc=0.9598, Time=5.38s, N=23320
#  Client 2 → Loss=0.1099, Acc=0.9605, Time=5.48s, N=23320
#  Client 3 → Loss=0.1092, Acc=0.9594, Time=5.59s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1074, Acc=0.9655
#
# [Model=CNN | Seed=3 | Round=23]
#  Client 0 → Loss=0.1072, Acc=0.9604, Time=5.57s, N=23320
#  Client 1 → Loss=0.1083, Acc=0.9609, Time=5.50s, N=23320
#  Client 2 → Loss=0.1082, Acc=0.9604, Time=5.48s, N=23320
#  Client 3 → Loss=0.1089, Acc=0.9588, Time=5.38s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1057, Acc=0.9664
#
# [Model=CNN | Seed=3 | Round=24]
#  Client 0 → Loss=0.1078, Acc=0.9608, Time=5.43s, N=23320
#  Client 1 → Loss=0.1081, Acc=0.9599, Time=5.61s, N=23320
#  Client 2 → Loss=0.1088, Acc=0.9606, Time=5.40s, N=23320
#  Client 3 → Loss=0.1076, Acc=0.9594, Time=5.44s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1103, Acc=0.9652
#
# [Model=CNN | Seed=3 | Round=25]
#  Client 0 → Loss=0.1059, Acc=0.9605, Time=5.44s, N=23320
#  Client 1 → Loss=0.1067, Acc=0.9607, Time=5.45s, N=23320
#  Client 2 → Loss=0.1072, Acc=0.9608, Time=5.37s, N=23320
#  Client 3 → Loss=0.1068, Acc=0.9597, Time=5.40s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1086, Acc=0.9660
#
# [Model=CNN | Seed=3 | Round=26]
#  Client 0 → Loss=0.1054, Acc=0.9615, Time=5.56s, N=23320
#  Client 1 → Loss=0.1065, Acc=0.9606, Time=5.60s, N=23320
#  Client 2 → Loss=0.1060, Acc=0.9613, Time=5.44s, N=23320
#  Client 3 → Loss=0.1061, Acc=0.9603, Time=5.39s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1117, Acc=0.9649
#
# [Model=CNN | Seed=3 | Round=27]
#  Client 0 → Loss=0.1055, Acc=0.9610, Time=5.38s, N=23320
#  Client 1 → Loss=0.1068, Acc=0.9608, Time=5.50s, N=23320
#  Client 2 → Loss=0.1061, Acc=0.9606, Time=5.36s, N=23320
#  Client 3 → Loss=0.1046, Acc=0.9611, Time=5.63s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1082, Acc=0.9660
#
# [Model=CNN | Seed=3 | Round=28]
#  Client 0 → Loss=0.1037, Acc=0.9623, Time=5.57s, N=23320
#  Client 1 → Loss=0.1065, Acc=0.9609, Time=5.48s, N=23320
#  Client 2 → Loss=0.1068, Acc=0.9600, Time=5.64s, N=23320
#  Client 3 → Loss=0.1068, Acc=0.9605, Time=5.74s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1060, Acc=0.9666
#
# [Model=CNN | Seed=3 | Round=29]
#  Client 0 → Loss=0.1036, Acc=0.9617, Time=5.69s, N=23320
#  Client 1 → Loss=0.1048, Acc=0.9604, Time=5.83s, N=23320
#  Client 2 → Loss=0.1042, Acc=0.9611, Time=5.74s, N=23320
#  Client 3 → Loss=0.1032, Acc=0.9607, Time=5.71s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1093, Acc=0.9668
#
# [Model=CNN | Seed=3 | Round=30]
#  Client 0 → Loss=0.1034, Acc=0.9613, Time=5.44s, N=23320
#  Client 1 → Loss=0.1041, Acc=0.9608, Time=5.31s, N=23320
#  Client 2 → Loss=0.1050, Acc=0.9610, Time=5.32s, N=23320
#  Client 3 → Loss=0.1032, Acc=0.9612, Time=5.35s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1066, Acc=0.9669
#  [saved] saved_models\CNN_seed3.keras
#
# ------ SEED 7 ------
#
# [Model=CNN | Seed=7 | Round=1]
#  Client 0 → Loss=0.2506, Acc=0.9074, Time=5.38s, N=23320
#  Client 1 → Loss=0.2538, Acc=0.9054, Time=5.45s, N=23320
#  Client 2 → Loss=0.2606, Acc=0.9039, Time=5.68s, N=23320
#  Client 3 → Loss=0.2558, Acc=0.9052, Time=5.52s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.2242, Acc=0.9136
#
# [Model=CNN | Seed=7 | Round=2]
#  Client 0 → Loss=0.2029, Acc=0.9226, Time=5.52s, N=23320
#  Client 1 → Loss=0.2012, Acc=0.9257, Time=5.56s, N=23320
#  Client 2 → Loss=0.2096, Acc=0.9194, Time=5.51s, N=23320
#  Client 3 → Loss=0.2082, Acc=0.9208, Time=5.54s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1592, Acc=0.9387
#
# [Model=CNN | Seed=7 | Round=3]
#  Client 0 → Loss=0.1783, Acc=0.9334, Time=5.69s, N=23320
#  Client 1 → Loss=0.1732, Acc=0.9359, Time=5.53s, N=23320
#  Client 2 → Loss=0.1826, Acc=0.9316, Time=5.53s, N=23320
#  Client 3 → Loss=0.1842, Acc=0.9297, Time=5.52s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1366, Acc=0.9492
#
# [Model=CNN | Seed=7 | Round=4]
#  Client 0 → Loss=0.1653, Acc=0.9390, Time=5.43s, N=23320
#  Client 1 → Loss=0.1605, Acc=0.9401, Time=5.54s, N=23320
#  Client 2 → Loss=0.1647, Acc=0.9386, Time=5.46s, N=23320
#  Client 3 → Loss=0.1694, Acc=0.9371, Time=5.53s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1266, Acc=0.9526
#
# [Model=CNN | Seed=7 | Round=5]
#  Client 0 → Loss=0.1568, Acc=0.9431, Time=5.55s, N=23320
#  Client 1 → Loss=0.1487, Acc=0.9448, Time=5.74s, N=23320
#  Client 2 → Loss=0.1546, Acc=0.9418, Time=5.75s, N=23320
#  Client 3 → Loss=0.1597, Acc=0.9411, Time=5.67s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1216, Acc=0.9565
#
# [Model=CNN | Seed=7 | Round=6]
#  Client 0 → Loss=0.1504, Acc=0.9458, Time=5.74s, N=23320
#  Client 1 → Loss=0.1433, Acc=0.9477, Time=5.49s, N=23320
#  Client 2 → Loss=0.1484, Acc=0.9460, Time=5.49s, N=23320
#  Client 3 → Loss=0.1553, Acc=0.9429, Time=5.39s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1172, Acc=0.9589
#
# [Model=CNN | Seed=7 | Round=7]
#  Client 0 → Loss=0.1450, Acc=0.9479, Time=5.44s, N=23320
#  Client 1 → Loss=0.1393, Acc=0.9497, Time=5.56s, N=23320
#  Client 2 → Loss=0.1421, Acc=0.9475, Time=5.57s, N=23320
#  Client 3 → Loss=0.1504, Acc=0.9452, Time=5.59s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1136, Acc=0.9607
#
# [Model=CNN | Seed=7 | Round=8]
#  Client 0 → Loss=0.1407, Acc=0.9504, Time=5.50s, N=23320
#  Client 1 → Loss=0.1353, Acc=0.9513, Time=5.56s, N=23320
#  Client 2 → Loss=0.1391, Acc=0.9493, Time=5.58s, N=23320
#  Client 3 → Loss=0.1466, Acc=0.9465, Time=5.70s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1111, Acc=0.9617
#
# [Model=CNN | Seed=7 | Round=9]
#  Client 0 → Loss=0.1372, Acc=0.9516, Time=5.54s, N=23320
#  Client 1 → Loss=0.1299, Acc=0.9518, Time=5.56s, N=23320
#  Client 2 → Loss=0.1352, Acc=0.9496, Time=5.40s, N=23320
#  Client 3 → Loss=0.1430, Acc=0.9476, Time=5.42s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1088, Acc=0.9629
#
# [Model=CNN | Seed=7 | Round=10]
#  Client 0 → Loss=0.1340, Acc=0.9521, Time=5.41s, N=23320
#  Client 1 → Loss=0.1286, Acc=0.9530, Time=5.46s, N=23320
#  Client 2 → Loss=0.1338, Acc=0.9506, Time=5.57s, N=23320
#  Client 3 → Loss=0.1395, Acc=0.9493, Time=5.44s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1073, Acc=0.9642
#
# [Model=CNN | Seed=7 | Round=11]
#  Client 0 → Loss=0.1308, Acc=0.9524, Time=5.64s, N=23320
#  Client 1 → Loss=0.1258, Acc=0.9543, Time=5.51s, N=23320
#  Client 2 → Loss=0.1309, Acc=0.9519, Time=5.64s, N=23320
#  Client 3 → Loss=0.1377, Acc=0.9494, Time=5.62s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1058, Acc=0.9657
#
# [Model=CNN | Seed=7 | Round=12]
#  Client 0 → Loss=0.1294, Acc=0.9549, Time=5.57s, N=23320
#  Client 1 → Loss=0.1232, Acc=0.9548, Time=5.60s, N=23320
#  Client 2 → Loss=0.1290, Acc=0.9521, Time=5.50s, N=23320
#  Client 3 → Loss=0.1361, Acc=0.9512, Time=5.59s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1041, Acc=0.9655
#
# [Model=CNN | Seed=7 | Round=13]
#  Client 0 → Loss=0.1277, Acc=0.9555, Time=5.50s, N=23320
#  Client 1 → Loss=0.1214, Acc=0.9554, Time=5.47s, N=23320
#  Client 2 → Loss=0.1282, Acc=0.9521, Time=5.84s, N=23320
#  Client 3 → Loss=0.1334, Acc=0.9524, Time=5.74s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1065, Acc=0.9657
#
# [Model=CNN | Seed=7 | Round=14]
#  Client 0 → Loss=0.1248, Acc=0.9568, Time=5.73s, N=23320
#  Client 1 → Loss=0.1199, Acc=0.9562, Time=5.71s, N=23320
#  Client 2 → Loss=0.1256, Acc=0.9545, Time=5.82s, N=23320
#  Client 3 → Loss=0.1317, Acc=0.9524, Time=5.59s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1029, Acc=0.9661
#
# [Model=CNN | Seed=7 | Round=15]
#  Client 0 → Loss=0.1215, Acc=0.9571, Time=5.63s, N=23320
#  Client 1 → Loss=0.1178, Acc=0.9562, Time=5.43s, N=23320
#  Client 2 → Loss=0.1240, Acc=0.9553, Time=5.41s, N=23320
#  Client 3 → Loss=0.1301, Acc=0.9539, Time=5.38s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1032, Acc=0.9669
#
# [Model=CNN | Seed=7 | Round=16]
#  Client 0 → Loss=0.1204, Acc=0.9571, Time=5.52s, N=23320
#  Client 1 → Loss=0.1168, Acc=0.9572, Time=5.65s, N=23320
#  Client 2 → Loss=0.1220, Acc=0.9561, Time=5.63s, N=23320
#  Client 3 → Loss=0.1286, Acc=0.9538, Time=5.53s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1027, Acc=0.9674
#
# [Model=CNN | Seed=7 | Round=17]
#  Client 0 → Loss=0.1199, Acc=0.9581, Time=5.83s, N=23320
#  Client 1 → Loss=0.1129, Acc=0.9587, Time=5.51s, N=23320
#  Client 2 → Loss=0.1211, Acc=0.9554, Time=5.42s, N=23320
#  Client 3 → Loss=0.1283, Acc=0.9548, Time=5.40s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1023, Acc=0.9675
#
# [Model=CNN | Seed=7 | Round=18]
#  Client 0 → Loss=0.1177, Acc=0.9588, Time=5.51s, N=23320
#  Client 1 → Loss=0.1117, Acc=0.9590, Time=5.74s, N=23320
#  Client 2 → Loss=0.1189, Acc=0.9566, Time=5.55s, N=23320
#  Client 3 → Loss=0.1261, Acc=0.9554, Time=5.50s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1018, Acc=0.9685
#
# [Model=CNN | Seed=7 | Round=19]
#  Client 0 → Loss=0.1185, Acc=0.9587, Time=5.71s, N=23320
#  Client 1 → Loss=0.1131, Acc=0.9588, Time=5.44s, N=23320
#  Client 2 → Loss=0.1192, Acc=0.9563, Time=5.59s, N=23320
#  Client 3 → Loss=0.1231, Acc=0.9557, Time=5.53s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1004, Acc=0.9686
#
# [Model=CNN | Seed=7 | Round=20]
#  Client 0 → Loss=0.1167, Acc=0.9590, Time=5.53s, N=23320
#  Client 1 → Loss=0.1122, Acc=0.9590, Time=5.51s, N=23320
#  Client 2 → Loss=0.1187, Acc=0.9563, Time=5.60s, N=23320
#  Client 3 → Loss=0.1224, Acc=0.9560, Time=5.60s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1003, Acc=0.9683
#
# [Model=CNN | Seed=7 | Round=21]
#  Client 0 → Loss=0.1153, Acc=0.9608, Time=5.49s, N=23320
#  Client 1 → Loss=0.1102, Acc=0.9588, Time=5.65s, N=23320
#  Client 2 → Loss=0.1176, Acc=0.9577, Time=5.57s, N=23320
#  Client 3 → Loss=0.1244, Acc=0.9551, Time=5.54s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1004, Acc=0.9684
#
# [Model=CNN | Seed=7 | Round=22]
#  Client 0 → Loss=0.1137, Acc=0.9602, Time=5.44s, N=23320
#  Client 1 → Loss=0.1100, Acc=0.9601, Time=5.46s, N=23320
#  Client 2 → Loss=0.1174, Acc=0.9580, Time=5.54s, N=23320
#  Client 3 → Loss=0.1210, Acc=0.9572, Time=5.45s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1005, Acc=0.9689
#
# [Model=CNN | Seed=7 | Round=23]
#  Client 0 → Loss=0.1134, Acc=0.9610, Time=5.61s, N=23320
#  Client 1 → Loss=0.1074, Acc=0.9613, Time=5.52s, N=23320
#  Client 2 → Loss=0.1155, Acc=0.9587, Time=5.70s, N=23320
#  Client 3 → Loss=0.1205, Acc=0.9575, Time=5.58s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1032, Acc=0.9684
#
# [Model=CNN | Seed=7 | Round=24]
#  Client 0 → Loss=0.1117, Acc=0.9609, Time=5.57s, N=23320
#  Client 1 → Loss=0.1119, Acc=0.9599, Time=5.54s, N=23320
#  Client 2 → Loss=0.1145, Acc=0.9582, Time=5.59s, N=23320
#  Client 3 → Loss=0.1191, Acc=0.9582, Time=5.65s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1011, Acc=0.9684
#
# [Model=CNN | Seed=7 | Round=25]
#  Client 0 → Loss=0.1102, Acc=0.9608, Time=5.44s, N=23320
#  Client 1 → Loss=0.1073, Acc=0.9605, Time=5.61s, N=23320
#  Client 2 → Loss=0.1151, Acc=0.9589, Time=5.44s, N=23320
#  Client 3 → Loss=0.1183, Acc=0.9581, Time=5.46s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1013, Acc=0.9683
#
# [Model=CNN | Seed=7 | Round=26]
#  Client 0 → Loss=0.1099, Acc=0.9615, Time=5.51s, N=23320
#  Client 1 → Loss=0.1061, Acc=0.9623, Time=5.45s, N=23320
#  Client 2 → Loss=0.1158, Acc=0.9597, Time=5.43s, N=23320
#  Client 3 → Loss=0.1165, Acc=0.9590, Time=5.40s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0987, Acc=0.9692
#
# [Model=CNN | Seed=7 | Round=27]
#  Client 0 → Loss=0.1083, Acc=0.9608, Time=5.55s, N=23320
#  Client 1 → Loss=0.1056, Acc=0.9617, Time=5.49s, N=23320
#  Client 2 → Loss=0.1124, Acc=0.9599, Time=5.48s, N=23320
#  Client 3 → Loss=0.1160, Acc=0.9584, Time=5.59s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1004, Acc=0.9686
#
# [Model=CNN | Seed=7 | Round=28]
#  Client 0 → Loss=0.1071, Acc=0.9617, Time=5.65s, N=23320
#  Client 1 → Loss=0.1052, Acc=0.9624, Time=5.57s, N=23320
#  Client 2 → Loss=0.1132, Acc=0.9588, Time=5.35s, N=23320
#  Client 3 → Loss=0.1148, Acc=0.9589, Time=5.64s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1020, Acc=0.9691
#
# [Model=CNN | Seed=7 | Round=29]
#  Client 0 → Loss=0.1087, Acc=0.9611, Time=5.60s, N=23320
#  Client 1 → Loss=0.1051, Acc=0.9614, Time=5.63s, N=23320
#  Client 2 → Loss=0.1110, Acc=0.9594, Time=5.75s, N=23320
#  Client 3 → Loss=0.1132, Acc=0.9594, Time=5.89s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1001, Acc=0.9689
#
# [Model=CNN | Seed=7 | Round=30]
#  Client 0 → Loss=0.1062, Acc=0.9627, Time=5.86s, N=23320
#  Client 1 → Loss=0.1042, Acc=0.9620, Time=5.94s, N=23320
#  Client 2 → Loss=0.1100, Acc=0.9598, Time=5.84s, N=23320
#  Client 3 → Loss=0.1132, Acc=0.9587, Time=5.70s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1001, Acc=0.9688
#  [saved] saved_models\CNN_seed7.keras
#
# ------ SEED 72 ------
#
# [Model=CNN | Seed=72 | Round=1]
#  Client 0 → Loss=0.2630, Acc=0.9038, Time=5.45s, N=23320
#  Client 1 → Loss=0.2650, Acc=0.9015, Time=5.76s, N=23320
#  Client 2 → Loss=0.2545, Acc=0.9052, Time=5.44s, N=23320
#  Client 3 → Loss=0.2609, Acc=0.9015, Time=5.53s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.2352, Acc=0.9141
#
# [Model=CNN | Seed=72 | Round=2]
#  Client 0 → Loss=0.2084, Acc=0.9208, Time=5.41s, N=23320
#  Client 1 → Loss=0.2040, Acc=0.9216, Time=5.57s, N=23320
#  Client 2 → Loss=0.2030, Acc=0.9239, Time=5.49s, N=23320
#  Client 3 → Loss=0.2034, Acc=0.9230, Time=5.46s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1551, Acc=0.9420
#
# [Model=CNN | Seed=72 | Round=3]
#  Client 0 → Loss=0.1815, Acc=0.9316, Time=5.45s, N=23320
#  Client 1 → Loss=0.1780, Acc=0.9319, Time=5.40s, N=23320
#  Client 2 → Loss=0.1755, Acc=0.9349, Time=5.70s, N=23320
#  Client 3 → Loss=0.1785, Acc=0.9345, Time=5.59s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1355, Acc=0.9508
#
# [Model=CNN | Seed=72 | Round=4]
#  Client 0 → Loss=0.1670, Acc=0.9380, Time=5.66s, N=23320
#  Client 1 → Loss=0.1653, Acc=0.9381, Time=5.44s, N=23320
#  Client 2 → Loss=0.1634, Acc=0.9412, Time=5.58s, N=23320
#  Client 3 → Loss=0.1647, Acc=0.9409, Time=5.74s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1255, Acc=0.9565
#
# [Model=CNN | Seed=72 | Round=5]
#  Client 0 → Loss=0.1574, Acc=0.9407, Time=5.66s, N=23320
#  Client 1 → Loss=0.1551, Acc=0.9423, Time=5.31s, N=23320
#  Client 2 → Loss=0.1541, Acc=0.9448, Time=5.42s, N=23320
#  Client 3 → Loss=0.1546, Acc=0.9452, Time=5.40s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1180, Acc=0.9595
#
# [Model=CNN | Seed=72 | Round=6]
#  Client 0 → Loss=0.1498, Acc=0.9443, Time=5.22s, N=23320
#  Client 1 → Loss=0.1469, Acc=0.9455, Time=5.25s, N=23320
#  Client 2 → Loss=0.1467, Acc=0.9474, Time=5.62s, N=23320
#  Client 3 → Loss=0.1459, Acc=0.9476, Time=5.35s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1137, Acc=0.9605
#
# [Model=CNN | Seed=72 | Round=7]
#  Client 0 → Loss=0.1458, Acc=0.9457, Time=5.23s, N=23320
#  Client 1 → Loss=0.1411, Acc=0.9484, Time=5.22s, N=23320
#  Client 2 → Loss=0.1397, Acc=0.9497, Time=5.19s, N=23320
#  Client 3 → Loss=0.1433, Acc=0.9499, Time=5.28s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1103, Acc=0.9620
#
# [Model=CNN | Seed=72 | Round=8]
#  Client 0 → Loss=0.1390, Acc=0.9481, Time=5.31s, N=23320
#  Client 1 → Loss=0.1378, Acc=0.9510, Time=5.35s, N=23320
#  Client 2 → Loss=0.1347, Acc=0.9512, Time=5.22s, N=23320
#  Client 3 → Loss=0.1386, Acc=0.9504, Time=5.29s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1069, Acc=0.9626
#
# [Model=CNN | Seed=72 | Round=9]
#  Client 0 → Loss=0.1370, Acc=0.9499, Time=5.39s, N=23320
#  Client 1 → Loss=0.1332, Acc=0.9516, Time=5.33s, N=23320
#  Client 2 → Loss=0.1328, Acc=0.9514, Time=5.34s, N=23320
#  Client 3 → Loss=0.1358, Acc=0.9509, Time=5.39s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1048, Acc=0.9630
#
# [Model=CNN | Seed=72 | Round=10]
#  Client 0 → Loss=0.1328, Acc=0.9508, Time=5.53s, N=23320
#  Client 1 → Loss=0.1289, Acc=0.9534, Time=5.53s, N=23320
#  Client 2 → Loss=0.1276, Acc=0.9526, Time=5.52s, N=23320
#  Client 3 → Loss=0.1315, Acc=0.9532, Time=5.46s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1035, Acc=0.9637
#
# [Model=CNN | Seed=72 | Round=11]
#  Client 0 → Loss=0.1304, Acc=0.9518, Time=5.36s, N=23320
#  Client 1 → Loss=0.1269, Acc=0.9543, Time=5.51s, N=23320
#  Client 2 → Loss=0.1247, Acc=0.9547, Time=5.41s, N=23320
#  Client 3 → Loss=0.1285, Acc=0.9539, Time=5.35s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1018, Acc=0.9635
#
# [Model=CNN | Seed=72 | Round=12]
#  Client 0 → Loss=0.1278, Acc=0.9518, Time=5.10s, N=23320
#  Client 1 → Loss=0.1229, Acc=0.9547, Time=5.11s, N=23320
#  Client 2 → Loss=0.1233, Acc=0.9548, Time=5.24s, N=23320
#  Client 3 → Loss=0.1290, Acc=0.9552, Time=5.45s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1003, Acc=0.9643
#
# [Model=CNN | Seed=72 | Round=13]
#  Client 0 → Loss=0.1238, Acc=0.9548, Time=5.36s, N=23320
#  Client 1 → Loss=0.1201, Acc=0.9567, Time=5.31s, N=23320
#  Client 2 → Loss=0.1212, Acc=0.9561, Time=5.45s, N=23320
#  Client 3 → Loss=0.1262, Acc=0.9555, Time=5.39s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0993, Acc=0.9643
#
# [Model=CNN | Seed=72 | Round=14]
#  Client 0 → Loss=0.1225, Acc=0.9552, Time=5.45s, N=23320
#  Client 1 → Loss=0.1194, Acc=0.9568, Time=5.44s, N=23320
#  Client 2 → Loss=0.1191, Acc=0.9570, Time=5.46s, N=23320
#  Client 3 → Loss=0.1242, Acc=0.9577, Time=5.46s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0982, Acc=0.9648
#
# [Model=CNN | Seed=72 | Round=15]
#  Client 0 → Loss=0.1197, Acc=0.9560, Time=5.41s, N=23320
#  Client 1 → Loss=0.1168, Acc=0.9595, Time=5.63s, N=23320
#  Client 2 → Loss=0.1161, Acc=0.9576, Time=5.58s, N=23320
#  Client 3 → Loss=0.1231, Acc=0.9574, Time=5.41s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0986, Acc=0.9654
#
# [Model=CNN | Seed=72 | Round=16]
#  Client 0 → Loss=0.1186, Acc=0.9572, Time=5.55s, N=23320
#  Client 1 → Loss=0.1148, Acc=0.9584, Time=5.58s, N=23320
#  Client 2 → Loss=0.1146, Acc=0.9588, Time=5.54s, N=23320
#  Client 3 → Loss=0.1208, Acc=0.9575, Time=5.25s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0978, Acc=0.9661
#
# [Model=CNN | Seed=72 | Round=17]
#  Client 0 → Loss=0.1164, Acc=0.9583, Time=5.54s, N=23320
#  Client 1 → Loss=0.1133, Acc=0.9599, Time=5.43s, N=23320
#  Client 2 → Loss=0.1154, Acc=0.9584, Time=5.37s, N=23320
#  Client 3 → Loss=0.1194, Acc=0.9597, Time=5.48s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0971, Acc=0.9661
#
# [Model=CNN | Seed=72 | Round=18]
#  Client 0 → Loss=0.1173, Acc=0.9588, Time=5.35s, N=23320
#  Client 1 → Loss=0.1139, Acc=0.9587, Time=5.57s, N=23320
#  Client 2 → Loss=0.1135, Acc=0.9591, Time=5.51s, N=23320
#  Client 3 → Loss=0.1179, Acc=0.9579, Time=5.33s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0969, Acc=0.9668
#
# [Model=CNN | Seed=72 | Round=19]
#  Client 0 → Loss=0.1131, Acc=0.9589, Time=5.26s, N=23320
#  Client 1 → Loss=0.1122, Acc=0.9599, Time=5.30s, N=23320
#  Client 2 → Loss=0.1119, Acc=0.9596, Time=5.48s, N=23320
#  Client 3 → Loss=0.1185, Acc=0.9589, Time=5.46s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0966, Acc=0.9668
#
# [Model=CNN | Seed=72 | Round=20]
#  Client 0 → Loss=0.1137, Acc=0.9584, Time=5.45s, N=23320
#  Client 1 → Loss=0.1104, Acc=0.9596, Time=5.43s, N=23320
#  Client 2 → Loss=0.1115, Acc=0.9600, Time=5.58s, N=23320
#  Client 3 → Loss=0.1221, Acc=0.9589, Time=5.71s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0968, Acc=0.9670
#
# [Model=CNN | Seed=72 | Round=21]
#  Client 0 → Loss=0.1123, Acc=0.9590, Time=5.37s, N=23320
#  Client 1 → Loss=0.1090, Acc=0.9613, Time=5.28s, N=23320
#  Client 2 → Loss=0.1098, Acc=0.9596, Time=5.29s, N=23320
#  Client 3 → Loss=0.1168, Acc=0.9598, Time=5.48s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0959, Acc=0.9665
#
# [Model=CNN | Seed=72 | Round=22]
#  Client 0 → Loss=0.1108, Acc=0.9598, Time=5.33s, N=23320
#  Client 1 → Loss=0.1086, Acc=0.9610, Time=5.31s, N=23320
#  Client 2 → Loss=0.1098, Acc=0.9599, Time=5.33s, N=23320
#  Client 3 → Loss=0.1146, Acc=0.9598, Time=5.34s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0962, Acc=0.9670
#
# [Model=CNN | Seed=72 | Round=23]
#  Client 0 → Loss=0.1108, Acc=0.9592, Time=5.25s, N=23320
#  Client 1 → Loss=0.1080, Acc=0.9608, Time=5.33s, N=23320
#  Client 2 → Loss=0.1082, Acc=0.9610, Time=5.32s, N=23320
#  Client 3 → Loss=0.1109, Acc=0.9599, Time=5.34s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0965, Acc=0.9672
#
# [Model=CNN | Seed=72 | Round=24]
#  Client 0 → Loss=0.1092, Acc=0.9596, Time=5.30s, N=23320
#  Client 1 → Loss=0.1059, Acc=0.9620, Time=5.39s, N=23320
#  Client 2 → Loss=0.1058, Acc=0.9616, Time=5.20s, N=23320
#  Client 3 → Loss=0.1147, Acc=0.9609, Time=5.33s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0970, Acc=0.9675
#
# [Model=CNN | Seed=72 | Round=25]
#  Client 0 → Loss=0.1070, Acc=0.9615, Time=5.47s, N=23320
#  Client 1 → Loss=0.1067, Acc=0.9600, Time=5.46s, N=23320
#  Client 2 → Loss=0.1065, Acc=0.9619, Time=5.26s, N=23320
#  Client 3 → Loss=0.1158, Acc=0.9602, Time=5.30s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0960, Acc=0.9671
#
# [Model=CNN | Seed=72 | Round=26]
#  Client 0 → Loss=0.1070, Acc=0.9605, Time=5.59s, N=23320
#  Client 1 → Loss=0.1040, Acc=0.9620, Time=5.53s, N=23320
#  Client 2 → Loss=0.1045, Acc=0.9617, Time=5.31s, N=23320
#  Client 3 → Loss=0.1111, Acc=0.9613, Time=5.37s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0970, Acc=0.9673
#
# [Model=CNN | Seed=72 | Round=27]
#  Client 0 → Loss=0.1055, Acc=0.9620, Time=5.30s, N=23320
#  Client 1 → Loss=0.1043, Acc=0.9627, Time=5.25s, N=23320
#  Client 2 → Loss=0.1022, Acc=0.9626, Time=5.26s, N=23320
#  Client 3 → Loss=0.1116, Acc=0.9624, Time=5.22s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0951, Acc=0.9671
#
# [Model=CNN | Seed=72 | Round=28]
#  Client 0 → Loss=0.1044, Acc=0.9617, Time=5.25s, N=23320
#  Client 1 → Loss=0.1024, Acc=0.9638, Time=5.37s, N=23320
#  Client 2 → Loss=0.1015, Acc=0.9640, Time=5.47s, N=23320
#  Client 3 → Loss=0.1125, Acc=0.9613, Time=5.49s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0994, Acc=0.9668
#
# [Model=CNN | Seed=72 | Round=29]
#  Client 0 → Loss=0.1044, Acc=0.9611, Time=5.46s, N=23320
#  Client 1 → Loss=0.1044, Acc=0.9638, Time=5.56s, N=23320
#  Client 2 → Loss=0.1023, Acc=0.9626, Time=5.51s, N=23320
#  Client 3 → Loss=0.1069, Acc=0.9616, Time=5.62s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0993, Acc=0.9669
#
# [Model=CNN | Seed=72 | Round=30]
#  Client 0 → Loss=0.1026, Acc=0.9621, Time=5.69s, N=23320
#  Client 1 → Loss=0.1039, Acc=0.9629, Time=5.47s, N=23320
#  Client 2 → Loss=0.1020, Acc=0.9640, Time=5.34s, N=23320
#  Client 3 → Loss=0.1109, Acc=0.9627, Time=5.49s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0961, Acc=0.9670
#  [saved] saved_models\CNN_seed72.keras
#
# ------ SEED 82 ------
#
# [Model=CNN | Seed=82 | Round=1]
#  Client 0 → Loss=0.2656, Acc=0.9003, Time=5.52s, N=23320
#  Client 1 → Loss=0.2541, Acc=0.9067, Time=5.67s, N=23320
#  Client 2 → Loss=0.2575, Acc=0.9058, Time=5.74s, N=23320
#  Client 3 → Loss=0.2535, Acc=0.9057, Time=5.65s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.2335, Acc=0.9145
#
# [Model=CNN | Seed=82 | Round=2]
#  Client 0 → Loss=0.2081, Acc=0.9190, Time=5.76s, N=23320
#  Client 1 → Loss=0.2012, Acc=0.9241, Time=5.71s, N=23320
#  Client 2 → Loss=0.2023, Acc=0.9217, Time=5.38s, N=23320
#  Client 3 → Loss=0.2069, Acc=0.9199, Time=5.32s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1639, Acc=0.9342
#
# [Model=CNN | Seed=82 | Round=3]
#  Client 0 → Loss=0.1792, Acc=0.9332, Time=5.35s, N=23320
#  Client 1 → Loss=0.1719, Acc=0.9375, Time=5.40s, N=23320
#  Client 2 → Loss=0.1749, Acc=0.9346, Time=5.47s, N=23320
#  Client 3 → Loss=0.1771, Acc=0.9322, Time=5.34s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1383, Acc=0.9479
#
# [Model=CNN | Seed=82 | Round=4]
#  Client 0 → Loss=0.1630, Acc=0.9408, Time=5.52s, N=23320
#  Client 1 → Loss=0.1571, Acc=0.9433, Time=5.46s, N=23320
#  Client 2 → Loss=0.1608, Acc=0.9395, Time=5.29s, N=23320
#  Client 3 → Loss=0.1621, Acc=0.9385, Time=5.25s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1280, Acc=0.9562
#
# [Model=CNN | Seed=82 | Round=5]
#  Client 0 → Loss=0.1521, Acc=0.9441, Time=5.41s, N=23320
#  Client 1 → Loss=0.1477, Acc=0.9464, Time=5.64s, N=23320
#  Client 2 → Loss=0.1512, Acc=0.9440, Time=5.44s, N=23320
#  Client 3 → Loss=0.1533, Acc=0.9430, Time=5.48s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1220, Acc=0.9582
#
# [Model=CNN | Seed=82 | Round=6]
#  Client 0 → Loss=0.1445, Acc=0.9469, Time=5.46s, N=23320
#  Client 1 → Loss=0.1407, Acc=0.9485, Time=5.50s, N=23320
#  Client 2 → Loss=0.1463, Acc=0.9465, Time=5.63s, N=23320
#  Client 3 → Loss=0.1452, Acc=0.9459, Time=5.56s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1176, Acc=0.9571
#
# [Model=CNN | Seed=82 | Round=7]
#  Client 0 → Loss=0.1393, Acc=0.9498, Time=5.64s, N=23320
#  Client 1 → Loss=0.1341, Acc=0.9510, Time=5.65s, N=23320
#  Client 2 → Loss=0.1398, Acc=0.9488, Time=5.51s, N=23320
#  Client 3 → Loss=0.1395, Acc=0.9486, Time=5.47s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1127, Acc=0.9615
#
# [Model=CNN | Seed=82 | Round=8]
#  Client 0 → Loss=0.1352, Acc=0.9516, Time=5.65s, N=23320
#  Client 1 → Loss=0.1302, Acc=0.9523, Time=5.56s, N=23320
#  Client 2 → Loss=0.1360, Acc=0.9502, Time=5.39s, N=23320
#  Client 3 → Loss=0.1350, Acc=0.9512, Time=5.31s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1092, Acc=0.9627
#
# [Model=CNN | Seed=82 | Round=9]
#  Client 0 → Loss=0.1302, Acc=0.9533, Time=5.27s, N=23320
#  Client 1 → Loss=0.1290, Acc=0.9527, Time=5.35s, N=23320
#  Client 2 → Loss=0.1324, Acc=0.9512, Time=5.56s, N=23320
#  Client 3 → Loss=0.1320, Acc=0.9524, Time=5.22s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1071, Acc=0.9629
#
# [Model=CNN | Seed=82 | Round=10]
#  Client 0 → Loss=0.1272, Acc=0.9558, Time=5.41s, N=23320
#  Client 1 → Loss=0.1242, Acc=0.9547, Time=5.52s, N=23320
#  Client 2 → Loss=0.1287, Acc=0.9528, Time=5.63s, N=23320
#  Client 3 → Loss=0.1285, Acc=0.9545, Time=5.36s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1054, Acc=0.9638
#
# [Model=CNN | Seed=82 | Round=11]
#  Client 0 → Loss=0.1253, Acc=0.9560, Time=5.61s, N=23320
#  Client 1 → Loss=0.1221, Acc=0.9552, Time=5.68s, N=23320
#  Client 2 → Loss=0.1262, Acc=0.9539, Time=5.76s, N=23320
#  Client 3 → Loss=0.1256, Acc=0.9551, Time=5.58s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1052, Acc=0.9637
#
# [Model=CNN | Seed=82 | Round=12]
#  Client 0 → Loss=0.1220, Acc=0.9572, Time=5.57s, N=23320
#  Client 1 → Loss=0.1193, Acc=0.9569, Time=5.41s, N=23320
#  Client 2 → Loss=0.1246, Acc=0.9544, Time=5.47s, N=23320
#  Client 3 → Loss=0.1234, Acc=0.9558, Time=5.44s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1030, Acc=0.9637
#
# [Model=CNN | Seed=82 | Round=13]
#  Client 0 → Loss=0.1184, Acc=0.9587, Time=5.39s, N=23320
#  Client 1 → Loss=0.1172, Acc=0.9581, Time=5.46s, N=23320
#  Client 2 → Loss=0.1216, Acc=0.9547, Time=5.25s, N=23320
#  Client 3 → Loss=0.1223, Acc=0.9558, Time=5.25s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1024, Acc=0.9643
#
# [Model=CNN | Seed=82 | Round=14]
#  Client 0 → Loss=0.1168, Acc=0.9583, Time=5.17s, N=23320
#  Client 1 → Loss=0.1165, Acc=0.9591, Time=5.24s, N=23320
#  Client 2 → Loss=0.1195, Acc=0.9558, Time=5.51s, N=23320
#  Client 3 → Loss=0.1200, Acc=0.9571, Time=5.45s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1013, Acc=0.9645
#
# [Model=CNN | Seed=82 | Round=15]
#  Client 0 → Loss=0.1152, Acc=0.9588, Time=5.33s, N=23320
#  Client 1 → Loss=0.1155, Acc=0.9593, Time=5.37s, N=23320
#  Client 2 → Loss=0.1172, Acc=0.9568, Time=5.66s, N=23320
#  Client 3 → Loss=0.1191, Acc=0.9562, Time=5.41s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.1010, Acc=0.9639
#
# [Model=CNN | Seed=82 | Round=16]
#  Client 0 → Loss=0.1141, Acc=0.9595, Time=5.24s, N=23320
#  Client 1 → Loss=0.1149, Acc=0.9586, Time=5.52s, N=23320
#  Client 2 → Loss=0.1155, Acc=0.9578, Time=5.26s, N=23320
#  Client 3 → Loss=0.1180, Acc=0.9573, Time=5.49s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0993, Acc=0.9645
#
# [Model=CNN | Seed=82 | Round=17]
#  Client 0 → Loss=0.1129, Acc=0.9600, Time=5.80s, N=23320
#  Client 1 → Loss=0.1132, Acc=0.9604, Time=5.78s, N=23320
#  Client 2 → Loss=0.1159, Acc=0.9571, Time=5.84s, N=23320
#  Client 3 → Loss=0.1189, Acc=0.9574, Time=5.51s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0984, Acc=0.9656
#
# [Model=CNN | Seed=82 | Round=18]
#  Client 0 → Loss=0.1115, Acc=0.9602, Time=5.59s, N=23320
#  Client 1 → Loss=0.1115, Acc=0.9611, Time=5.45s, N=23320
#  Client 2 → Loss=0.1132, Acc=0.9579, Time=5.34s, N=23320
#  Client 3 → Loss=0.1152, Acc=0.9583, Time=5.48s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0971, Acc=0.9652
#
# [Model=CNN | Seed=82 | Round=19]
#  Client 0 → Loss=0.1101, Acc=0.9599, Time=5.38s, N=23320
#  Client 1 → Loss=0.1094, Acc=0.9607, Time=5.32s, N=23320
#  Client 2 → Loss=0.1132, Acc=0.9578, Time=5.34s, N=23320
#  Client 3 → Loss=0.1159, Acc=0.9585, Time=5.42s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0977, Acc=0.9637
#
# [Model=CNN | Seed=82 | Round=20]
#  Client 0 → Loss=0.1089, Acc=0.9602, Time=5.27s, N=23320
#  Client 1 → Loss=0.1094, Acc=0.9602, Time=5.21s, N=23320
#  Client 2 → Loss=0.1127, Acc=0.9583, Time=5.46s, N=23320
#  Client 3 → Loss=0.1145, Acc=0.9578, Time=5.42s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0974, Acc=0.9646
#
# [Model=CNN | Seed=82 | Round=21]
#  Client 0 → Loss=0.1079, Acc=0.9614, Time=5.74s, N=23320
#  Client 1 → Loss=0.1081, Acc=0.9614, Time=5.52s, N=23320
#  Client 2 → Loss=0.1110, Acc=0.9582, Time=5.43s, N=23320
#  Client 3 → Loss=0.1139, Acc=0.9597, Time=5.49s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0968, Acc=0.9654
#
# [Model=CNN | Seed=82 | Round=22]
#  Client 0 → Loss=0.1072, Acc=0.9614, Time=5.32s, N=23320
#  Client 1 → Loss=0.1070, Acc=0.9618, Time=5.53s, N=23320
#  Client 2 → Loss=0.1101, Acc=0.9588, Time=5.84s, N=23320
#  Client 3 → Loss=0.1135, Acc=0.9583, Time=5.43s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0964, Acc=0.9656
#
# [Model=CNN | Seed=82 | Round=23]
#  Client 0 → Loss=0.1074, Acc=0.9612, Time=5.37s, N=23320
#  Client 1 → Loss=0.1069, Acc=0.9620, Time=5.29s, N=23320
#  Client 2 → Loss=0.1090, Acc=0.9593, Time=5.42s, N=23320
#  Client 3 → Loss=0.1119, Acc=0.9598, Time=5.39s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0962, Acc=0.9650
#
# [Model=CNN | Seed=82 | Round=24]
#  Client 0 → Loss=0.1067, Acc=0.9615, Time=5.39s, N=23320
#  Client 1 → Loss=0.1063, Acc=0.9617, Time=5.30s, N=23320
#  Client 2 → Loss=0.1119, Acc=0.9592, Time=5.37s, N=23320
#  Client 3 → Loss=0.1115, Acc=0.9600, Time=5.30s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0952, Acc=0.9660
#
# [Model=CNN | Seed=82 | Round=25]
#  Client 0 → Loss=0.1049, Acc=0.9627, Time=5.44s, N=23320
#  Client 1 → Loss=0.1051, Acc=0.9620, Time=5.21s, N=23320
#  Client 2 → Loss=0.1086, Acc=0.9593, Time=5.35s, N=23320
#  Client 3 → Loss=0.1104, Acc=0.9609, Time=5.25s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0959, Acc=0.9654
#
# [Model=CNN | Seed=82 | Round=26]
#  Client 0 → Loss=0.1056, Acc=0.9623, Time=5.24s, N=23320
#  Client 1 → Loss=0.1041, Acc=0.9625, Time=5.22s, N=23320
#  Client 2 → Loss=0.1083, Acc=0.9600, Time=5.43s, N=23320
#  Client 3 → Loss=0.1091, Acc=0.9606, Time=5.40s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0955, Acc=0.9658
#
# [Model=CNN | Seed=82 | Round=27]
#  Client 0 → Loss=0.1051, Acc=0.9630, Time=5.40s, N=23320
#  Client 1 → Loss=0.1031, Acc=0.9636, Time=5.28s, N=23320
#  Client 2 → Loss=0.1069, Acc=0.9599, Time=5.37s, N=23320
#  Client 3 → Loss=0.1090, Acc=0.9615, Time=5.57s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0955, Acc=0.9657
#
# [Model=CNN | Seed=82 | Round=28]
#  Client 0 → Loss=0.1033, Acc=0.9635, Time=5.69s, N=23320
#  Client 1 → Loss=0.1022, Acc=0.9633, Time=5.46s, N=23320
#  Client 2 → Loss=0.1053, Acc=0.9610, Time=5.36s, N=23320
#  Client 3 → Loss=0.1076, Acc=0.9617, Time=5.28s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0963, Acc=0.9664
#
# [Model=CNN | Seed=82 | Round=29]
#  Client 0 → Loss=0.1042, Acc=0.9625, Time=5.24s, N=23320
#  Client 1 → Loss=0.1014, Acc=0.9642, Time=5.23s, N=23320
#  Client 2 → Loss=0.1047, Acc=0.9599, Time=5.62s, N=23320
#  Client 3 → Loss=0.1076, Acc=0.9610, Time=5.37s, N=23320
#  >>> GLOBAL (centralized test) → Loss=0.0938, Acc=0.9661
#
# [Model=CNN | Seed=82 | Round=30]
# ...
#    CNN     7     saved_models\CNN_seed7.keras
#    CNN    72    saved_models\CNN_seed72.keras
#    CNN    82    saved_models\CNN_seed82.keras
#   LSTM    42   saved_models\LSTM_seed42.keras
#   LSTM     3    saved_models\LSTM_seed3.keras
#   LSTM     7    saved_models\LSTM_seed7.keras
#   LSTM    72   saved_models\LSTM_seed72.keras
#   LSTM    82   saved_models\LSTM_seed82.keras
# BiLSTM    42 saved_models\BiLSTM_seed42.keras
# BiLSTM     3  saved_models\BiLSTM_seed3.keras
# BiLSTM     7  saved_models\BiLSTM_seed7.keras
# BiLSTM    72 saved_models\BiLSTM_seed72.keras
# BiLSTM    82 saved_models\BiLSTM_seed82.keras
#    GRU    42    saved_models\GRU_seed42.keras
#    GRU     3     saved_models\GRU_seed3.keras
#    GRU     7     saved_models\GRU_seed7.keras
#    GRU    72    saved_models\GRU_seed72.keras
#    GRU    82    saved_models\GRU_seed82.keras
#  BiGRU    42  saved_models\BiGRU_seed42.keras
#  BiGRU     3   saved_models\BiGRU_seed3.keras
#  BiGRU     7   saved_models\BiGRU_seed7.keras
#  BiGRU    72  saved_models\BiGRU_seed72.keras
#  BiGRU    82  saved_models\BiGRU_seed82.keras
#
# OVERALL SUMMARY (all models & seeds pooled):
#                  Metric             Mean ± SD                 95% CI
# 0                 Loss       0.1008 ± 0.0115        [0.0963,0.1053]
# 1             Accuracy       0.9792 ± 0.0059        [0.9769,0.9815]
# 2            Precision       0.9430 ± 0.0172        [0.9362,0.9497]
# 3               Recall       0.9092 ± 0.0325        [0.8964,0.9219]
# 4                   F1       0.9255 ± 0.0222        [0.9168,0.9342]
# 5                  MCC       0.9138 ± 0.0250        [0.9040,0.9236]
# 6                  AUC       0.9920 ± 0.0031        [0.9908,0.9932]
# 7          Specificity       0.9909 ± 0.0029        [0.9897,0.9920]
# 8    Training_Time_sec  1782.1243 ± 753.2668  [1486.8437,2077.4049]
# 9   Inference_Time_sec       2.0564 ± 0.9202        [1.6957,2.4171]
# 10       Model_Size_MB       0.5846 ± 0.3965        [0.4292,0.7400]
# 11   Comm_per_round_MB       4.4748 ± 3.1303        [3.2477,5.7019]
# 12       Total_Comm_MB    134.2451 ± 93.9102     [97.4323,171.0578]
#
# PER-CLIENT TEST SUMMARY (mean/std over 5 seeds):
#                Accuracy         Precision          Recall              F1  \
#                   mean     std      mean     std    mean     std    mean
# Model  Client
# BiGRU  0        0.9827  0.0015    0.9430  0.0092  0.9352  0.0089  0.9390
#        1        0.9811  0.0029    0.9409  0.0151  0.9255  0.0126  0.9331
#        2        0.9800  0.0013    0.9375  0.0083  0.9212  0.0081  0.9293
#        3        0.9820  0.0017    0.9474  0.0073  0.9248  0.0057  0.9360
# BiLSTM 0        0.9838  0.0008    0.9476  0.0070  0.9386  0.0123  0.9430
#        1        0.9823  0.0013    0.9476  0.0081  0.9270  0.0099  0.9371
#        2        0.9822  0.0014    0.9478  0.0079  0.9258  0.0074  0.9366
#        3        0.9842  0.0020    0.9549  0.0076  0.9333  0.0098  0.9439
# CNN    0        0.9683  0.0010    0.9142  0.0310  0.8595  0.0296  0.8852
#        1        0.9663  0.0032    0.9179  0.0287  0.8400  0.0243  0.8767
#        2        0.9664  0.0013    0.9137  0.0233  0.8453  0.0298  0.8775
#        3        0.9696  0.0026    0.9270  0.0177  0.8545  0.0378  0.8885
# GRU    0        0.9824  0.0019    0.9503  0.0098  0.9248  0.0113  0.9373
#        1        0.9813  0.0014    0.9524  0.0072  0.9145  0.0130  0.9330
#        2        0.9800  0.0017    0.9462  0.0046  0.9116  0.0120  0.9285
#        3        0.9827  0.0016    0.9564  0.0035  0.9202  0.0091  0.9380
# LSTM   0        0.9832  0.0016    0.9547  0.0129  0.9260  0.0085  0.9401
#        1        0.9819  0.0018    0.9529  0.0105  0.9183  0.0151  0.9352
#        2        0.9807  0.0012    0.9480  0.0112  0.9149  0.0127  0.9311
#        3        0.9834  0.0014    0.9594  0.0077  0.9227  0.0043  0.9407
#
#                           MCC             AUC         Specificity          \
#                   std    mean     std    mean     std        mean     std
# Model  Client
# BiGRU  0       0.0053  0.9290  0.0062  0.9947  0.0006      0.9906  0.0016
#        1       0.0100  0.9222  0.0117  0.9940  0.0015      0.9903  0.0026
#        2       0.0046  0.9177  0.0054  0.9928  0.0015      0.9898  0.0015
#        3       0.0059  0.9256  0.0068  0.9948  0.0010      0.9915  0.0012
# BiLSTM 0       0.0034  0.9336  0.0038  0.9941  0.0007      0.9914  0.0013
#        1       0.0046  0.9270  0.0054  0.9940  0.0014      0.9915  0.0014
#        2       0.0050  0.9263  0.0058  0.9933  0.0015      0.9915  0.0014
#        3       0.0070  0.9349  0.0081  0.9940  0.0010      0.9927  0.0013
# CNN    0       0.0016  0.8679  0.0019  0.9867  0.0018      0.9863  0.0060
#        1       0.0109  0.8587  0.0126  0.9855  0.0020      0.9873  0.0053
#        2       0.0068  0.8594  0.0065  0.9849  0.0017      0.9866  0.0046
#        3       0.0125  0.8724  0.0126  0.9871  0.0013      0.9887  0.0035
# GRU    0       0.0067  0.9273  0.0078  0.9940  0.0009      0.9920  0.0017
#        1       0.0056  0.9224  0.0062  0.9934  0.0018      0.9924  0.0013
#        2       0.0065  0.9172  0.0073  0.9922  0.0018      0.9914  0.0008
#        3       0.0058  0.9281  0.0066  0.9938  0.0010      0.9930  0.0006
# LSTM   0       0.0056  0.9305  0.0067  0.9931  0.0012      0.9927  0.0022
#        1       0.0069  0.9249  0.0078  0.9932  0.0017      0.9924  0.0018
#        2       0.0043  0.9201  0.0050  0.9915  0.0016      0.9916  0.0020
#        3       0.0048  0.9313  0.0056  0.9933  0.0012      0.9935  0.0013
#
#                  Loss
#                  mean     std
# Model  Client
# BiGRU  0       0.1051  0.0133
#        1       0.1140  0.0132
#        2       0.1303  0.0135
#        3       0.1112  0.0142
# BiLSTM 0       0.1021  0.0115
#        1       0.1115  0.0141
#        2       0.1207  0.0109
#        3       0.1027  0.0167
# CNN    0       0.0979  0.0085
#        1       0.0988  0.0059
#        2       0.1026  0.0048
#        3       0.0950  0.0026
# GRU    0       0.0895  0.0089
#        1       0.0961  0.0114
#        2       0.1047  0.0159
#        3       0.0911  0.0091
# LSTM   0       0.0807  0.0119
#        1       0.0876  0.0097
#        2       0.0955  0.0082
#        3       0.0794  0.0091
#
# PAIRWISE PAIRED T-TESTS across 5 seeds (Global Test Set):
#    Metric Model A Model B  Mean A  Mean B   t-stat  p-value  Significant (p<0.05)
# Accuracy     CNN    LSTM  0.9677  0.9823 -27.5933   0.0000                  True
# Accuracy     CNN  BiLSTM  0.9677  0.9831 -22.3784   0.0000                  True
# Accuracy     CNN     GRU  0.9677  0.9816 -20.6029   0.0000                  True
# Accuracy     CNN   BiGRU  0.9677  0.9815 -19.3582   0.0000                  True
# Accuracy    LSTM  BiLSTM  0.9823  0.9831  -4.7068   0.0093                  True
# Accuracy    LSTM     GRU  0.9823  0.9816   2.5847   0.0610                 False
# Accuracy    LSTM   BiGRU  0.9823  0.9815   2.1272   0.1005                 False
# Accuracy  BiLSTM     GRU  0.9831  0.9816   4.5822   0.0102                  True
# Accuracy  BiLSTM   BiGRU  0.9831  0.9815   5.0182   0.0074                  True
# Accuracy     GRU   BiGRU  0.9816  0.9815   0.2316   0.8282                 False
#       F1     CNN    LSTM  0.8820  0.9368 -18.6506   0.0000                  True
#       F1     CNN  BiLSTM  0.8820  0.9402 -16.2923   0.0001                  True
#       F1     CNN     GRU  0.8820  0.9342 -16.9860   0.0001                  True
#       F1     CNN   BiGRU  0.8820  0.9344 -13.5149   0.0002                  True
#       F1    LSTM  BiLSTM  0.9368  0.9402  -4.6729   0.0095                  True
#       F1    LSTM     GRU  0.9368  0.9342   2.9341   0.0426                  True
#       F1    LSTM   BiGRU  0.9368  0.9344   1.6559   0.1731                 False
#       F1  BiLSTM     GRU  0.9402  0.9342   4.5399   0.0105                  True
#       F1  BiLSTM   BiGRU  0.9402  0.9344   5.6220   0.0049                  True
#       F1     GRU   BiGRU  0.9342  0.9344  -0.0540   0.9595                 False
#      AUC     CNN    LSTM  0.9860  0.9928 -13.2742   0.0002                  True
#      AUC     CNN  BiLSTM  0.9860  0.9938 -12.0734   0.0003                  True
#      AUC     CNN     GRU  0.9860  0.9933 -11.5468   0.0003                  True
#      AUC     CNN   BiGRU  0.9860  0.9941 -10.9376   0.0004                  True
#      AUC    LSTM  BiLSTM  0.9928  0.9938  -4.6829   0.0094                  True
#      AUC    LSTM     GRU  0.9928  0.9933  -3.7531   0.0199                  True
#      AUC    LSTM   BiGRU  0.9928  0.9941  -5.4725   0.0054                  True
#      AUC  BiLSTM     GRU  0.9938  0.9933   1.7164   0.1612                 False
#      AUC  BiLSTM   BiGRU  0.9938  0.9941  -0.9449   0.3982                 False
#      AUC     GRU   BiGRU  0.9933  0.9941  -5.1314   0.0068                  True
#     Loss     CNN    LSTM  0.0986  0.0858   6.4965   0.0029                  True
#     Loss     CNN  BiLSTM  0.0986  0.1092  -3.7497   0.0200                  True
#     Loss     CNN     GRU  0.0986  0.0954   1.0058   0.3714                 False
#     Loss     CNN   BiGRU  0.0986  0.1152  -5.1747   0.0066                  True
#     Loss    LSTM  BiLSTM  0.0858  0.1092 -14.4339   0.0001                  True
#     Loss    LSTM     GRU  0.0858  0.0954  -4.2885   0.0128                  True
#     Loss    LSTM   BiGRU  0.0858  0.1152 -19.4521   0.0000                  True
#     Loss  BiLSTM     GRU  0.1092  0.0954   3.7161   0.0205                  True
#     Loss  BiLSTM   BiGRU  0.1092  0.1152  -3.8415   0.0184                  True
#     Loss     GRU   BiGRU  0.0954  0.1152  -6.2034   0.0034                  True
#
# McNEMAR'S TEST — PER SEED (instance-level, Global Test Set):
#   Seed Model A Model B  A right/B wrong  A wrong/B right     stat  p-value  Significant (p<0.05)
#    42     CNN    LSTM              130              427 157.2998   0.0000                  True
#    42     CNN  BiLSTM              122              426 167.5347   0.0000                  True
#    42     CNN     GRU              144              414 129.6792   0.0000                  True
#    42     CNN   BiGRU              140              421 139.7504   0.0000                  True
#    42    LSTM  BiLSTM              103              110   0.1690   0.6810                 False
#    42    LSTM     GRU              135              108   2.7819   0.0953                 False
#    42    LSTM   BiGRU              103               87   1.1842   0.2765                 False
#    42  BiLSTM     GRU              141              107   4.3911   0.0361                  True
#    42  BiLSTM   BiGRU              112               89   2.4080   0.1207                 False
#    42     GRU   BiGRU              106              117   0.4484   0.5031                 False
#     3     CNN    LSTM              140              480 185.3565   0.0000                  True
#     3     CNN  BiLSTM              143              497 194.7016   0.0000                  True
#     3     CNN     GRU              122              465 199.2572   0.0000                  True
#     3     CNN   BiGRU              140              431 147.2855   0.0000                  True
#     3    LSTM  BiLSTM               98              112   0.8048   0.3697                 False
#     3    LSTM     GRU              108              111   0.0183   0.8925                 False
#     3    LSTM   BiGRU              157              108   8.6943   0.0032                  True
#     3  BiLSTM     GRU              115              104   0.4566   0.4992                 False
#     3  BiLSTM   BiGRU              144               81  17.0844   0.0000                  True
#     3     GRU   BiGRU              150               98  10.4879   0.0012                  True
#     7     CNN    LSTM              119              461 200.4845   0.0000                  True
#     7     CNN  BiLSTM              108              473 228.0482   0.0000                  True
#     7     CNN     GRU              121              431 172.9728   0.0000                  True
#     7     CNN   BiGRU              101              433 205.1704   0.0000                  True
#     7    LSTM  BiLSTM              114              137   1.9283   0.1649                 False
#     7    LSTM     GRU              128               96   4.2902   0.0383                  True
#     7    LSTM   BiGRU              120              110   0.3522   0.5529                 False
#     7  BiLSTM     GRU              139               84  13.0762   0.0003                  True
#     7  BiLSTM   BiGRU              119               86   4.9951   0.0254                  True
#     7     GRU   BiGRU              101              123   1.9688   0.1606                 False
#    72     CNN    LSTM              108              469 224.6101   0.0000                  True
#    72     CNN  BiLSTM               94              476 254.6684   0.0000                  True
#    72     CNN     GRU              105              458 220.0782   0.0000                  True
#    72     CNN   BiGRU              128              459 185.5196   0.0000                  True
#    72    LSTM  BiLSTM               93              114   1.9324   0.1645                 False
#    72    LSTM     GRU              109              101   0.2333   0.6291                 False
#    72    LSTM   BiGRU              142              112   3.3110   0.0688                 False
#    72  BiLSTM     GRU              116               87   3.8621   0.0494                  True
#    72  BiLSTM   BiGRU              145               94  10.4603   0.0012                  True
#    72     GRU   BiGRU              123              101   1.9688   0.1606                 False
#    82     CNN    LSTM              124              492 218.6510   0.0000                  True
#    82     CNN  BiLSTM              109              508 256.7326   0.0000                  True
#    82     CNN     GRU              136              486 195.8215   0.0000                  True
#    82     CNN   BiGRU              110              484 234.2239   0.0000                  True
#    82    LSTM  BiLSTM               89              120   4.3062   0.0380                  True
#    82    LSTM     GRU              133              115   1.1653   0.2804                 False
#    82    LSTM   BiGRU              112              118   0.1087   0.7416                 False
#    82  BiLSTM     GRU              154              105   8.8958   0.0029                  True
#    82  BiLSTM   BiGRU              109               84   2.9845   0.0841                 False
#    82     GRU   BiGRU              119              143   2.0191   0.1553                 False
#
# McNEMAR'S TEST — POOLED ACROSS 5 SEEDS (Global Test Set):
#  Model A Model B  A right/B wrong (pooled)  A wrong/B right (pooled)      stat  p-value  Significant (p<0.05)
#     CNN    LSTM                       621                      2329  987.7454   0.0000                  True
#     CNN  BiLSTM                       576                      2380 1099.7324   0.0000                  True
#     CNN     GRU                       628                      2254  916.2474   0.0000                  True
#     CNN   BiGRU                       619                      2228  908.2065   0.0000                  True
#    LSTM  BiLSTM                       497                       593    8.2798   0.0040                  True
#    LSTM     GRU                       613                       531    5.7351   0.0166                  True
#    LSTM   BiGRU                       634                       535    8.2156   0.0042                  True
#  BiLSTM     GRU                       665                       487   27.1953   0.0000                  True
#  BiLSTM   BiGRU                       629                       434   35.4055   0.0000                  True
#     GRU   BiGRU                       599                       582    0.2168   0.6415                 False
