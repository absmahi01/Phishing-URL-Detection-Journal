# %%
import numpy as np, pandas as pd, tensorflow as tf, random, time, os
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import *

from scipy.stats import ttest_rel, chi2, binom
from itertools import combinations

# ================= CONFIG =================
LR=0.001; ROUNDS=30; LOCAL_EPOCHS=2; BATCH=16
CLIENTS=4; SEEDS=[42,3,7,72,82]
MODELS=["CNN","LSTM","BiLSTM","GRU","BiGRU"]
CLIENT_TEST_SIZE=0.2   # local train/test split ratio inside each client
MODEL_SAVE_DIR="saved_models"
os.makedirs(MODEL_SAVE_DIR,exist_ok=True)

# ================= LOAD =================
df=pd.read_csv("dataset_phishing(11k).csv")

# remove text columns like .txt
for col in df.columns:
    if df[col].dtype==object and df[col].astype(str).str.contains(".txt",na=False).any():
        df.drop(columns=[col],inplace=True)

df=df.fillna("unknown")

for col in df.columns:
    if df[col].dtype==object:
        df[col]=LabelEncoder().fit_transform(df[col].astype(str))

X=df.drop("status",axis=1).values
y=df["status"].values

X=StandardScaler().fit_transform(X)

# NOTE: no upfront global train_test_split anymore.
# IID partitioning is applied to the WHOLE dataset per seed below,
# then each client locally splits its own IID shard into train/test.

# ================= HELPERS =================
def set_seed(s):
    random.seed(s); np.random.seed(s); tf.random.set_seed(s)

def iid_partition(X,y,K):
    # IID partition: each class shuffled and split evenly across clients
    idx=np.arange(len(y))
    clients=[[] for _ in range(K)]
    for c in np.unique(y):
        c_idx=idx[y==c]; np.random.shuffle(c_idx)
        split=np.array_split(c_idx,K)
        for i in range(K): clients[i].extend(split[i])
    return [(X[c],y[c]) for c in clients]

def format_xy(Xc,model_name):
    return Xc.reshape(len(Xc),-1,1)

def fedavg(global_model,locals,sizes):
    w=[m.get_weights() for m in locals]
    new=[np.average(x,axis=0,weights=sizes) for x in zip(*w)]
    global_model.set_weights(new)

def model_size(model):
    model.save("tmp.h5", include_optimizer=False)
    size=os.path.getsize("tmp.h5")/(1024*1024)
    os.remove("tmp.h5")
    return size

def stats(x,metric):
    x=np.asarray(x,dtype=float)
    x=x[~np.isnan(x)]
    if len(x)==0:
        return np.nan,np.nan,np.nan,np.nan
    mean=np.mean(x); sd=np.std(x)
    ci=1.96*sd/np.sqrt(len(x))
    low,high=mean-ci,mean+ci
    if metric in ["Accuracy","Precision","Recall","F1","AUC","Specificity"]:
        low=max(0,low); high=min(1,high)
    if metric=="MCC":
        low=max(-1,low); high=min(1,high)
    return mean,sd,low,high

def mcnemar_test(y_true_a,y_pred_a,y_true_b,y_pred_b):
    """McNemar's test between two classifiers evaluated on the SAME samples.
    Uses only the discordant pairs (one right, one wrong). Exact binomial
    for small discordant counts (n<25), continuity-corrected chi-square
    otherwise."""
    y_true_a=np.asarray(y_true_a).flatten()
    y_true_b=np.asarray(y_true_b).flatten()
    assert len(y_true_a)==len(y_true_b), "test sets must be the same size"
    assert np.array_equal(y_true_a,y_true_b), "test sets must match (same seed/instances)"

    correct_a=(np.asarray(y_pred_a).flatten()==y_true_a)
    correct_b=(np.asarray(y_pred_b).flatten()==y_true_b)

    n01=int(np.sum(correct_a & ~correct_b))   # A correct, B wrong
    n10=int(np.sum(~correct_a & correct_b))   # A wrong, B correct
    n=n01+n10

    if n==0:
        return np.nan,1.0,n01,n10
    if n<25:
        p=2*min(binom.cdf(min(n01,n10),n,0.5),0.5)   # exact two-sided binomial
        p=min(p,1.0)
        stat=np.nan
    else:
        stat=((abs(n01-n10)-1)**2)/n                  # continuity-corrected chi-square
        p=1-chi2.cdf(stat,1)
    return stat,p,n01,n10

# ================= MODELS =================
def build(name,shape=None,dim=None):
    if name=="CNN":
        m=Sequential([
            Input(shape),
            Conv1D(64,3,activation="relu"),
            Dropout(0.5),
            Conv1D(32,3,activation="relu"),
            GlobalMaxPooling1D(),
            Dense(32,activation="relu"),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="LSTM":
        m=Sequential([
            Input(shape),
            LSTM(128,return_sequences=True),
            Dropout(0.5),
            LSTM(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiLSTM":
        m=Sequential([
            Input(shape),
            Bidirectional(LSTM(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(LSTM(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="GRU":
        m=Sequential([
            Input(shape),
            GRU(128,return_sequences=True),
            Dropout(0.5),
            GRU(64),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    elif name=="BiGRU":
        m=Sequential([
            Input(shape),
            Bidirectional(GRU(128,return_sequences=True)),
            Dropout(0.5),
            Bidirectional(GRU(64)),
            Dropout(0.5),
            Dense(1,activation="sigmoid")
        ])

    m.compile(optimizer=Adam(LR),loss="binary_crossentropy",metrics=["accuracy"])
    return m

# ================= STORAGE =================
rows=[]          # global (union-of-clients) test metrics, per (model, seed)
client_rows=[]   # per-client local test metrics, per (model, seed, client)
results_round={m:{"acc":[],"loss":[],"cm":[]} for m in MODELS}

# per-instance predictions, needed for McNemar's test
y_preds={}        # (model, seed) -> y_pred array (0/1), aligned to y_trues[seed]
y_trues={}        # seed -> y_test_global array (0/1) -- same across all models for a given seed

# ================= TRAIN =================
for model_name in MODELS:
    print(f"\n================ MODEL: {model_name} ================")

    for seed in SEEDS:
        print(f"\n------ SEED {seed} ------")
        set_seed(seed)

        # ---- IID partition of the WHOLE dataset across clients ----
        client_full=iid_partition(X,y,CLIENTS)

        # ---- Each client locally splits its own shard into train/test ----
        client_train,client_test=[],[]
        for cid,(Xc,yc) in enumerate(client_full):
            try:
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,stratify=yc,random_state=seed
                )
            except ValueError:
                # fallback if a client shard doesn't have enough of a class to stratify
                Xc_tr,Xc_te,yc_tr,yc_te=train_test_split(
                    Xc,yc,test_size=CLIENT_TEST_SIZE,random_state=seed
                )
            client_train.append((Xc_tr,yc_tr))
            client_test.append((Xc_te,yc_te))

        # ---- Global (centralized) test set = union of all clients' local test shards ----
        X_test_global=np.concatenate([Xc for Xc,_ in client_test],axis=0)
        y_test_global=np.concatenate([yc for _,yc in client_test],axis=0)

        create=lambda:build(model_name,shape=(X.shape[1],1))

        fmt=lambda Xc: format_xy(Xc,model_name)

        global_model=create()

        acc_hist,loss_hist=[],[]
        comm=0
        total_train_time=0.0

        for r in range(ROUNDS):
            print(f"\n[Model={model_name} | Seed={seed} | Round={r+1}]")

            locals_=[]; sizes=[]

            for cid,(Xc,yc) in enumerate(client_train):
                m=create()
                m.set_weights(global_model.get_weights())

                t0=time.time()
                history=m.fit(fmt(Xc),yc,epochs=LOCAL_EPOCHS,batch_size=BATCH,verbose=0)
                t1=time.time()
                total_train_time+=(t1-t0)

                train_loss=history.history["loss"][-1]
                train_acc=history.history["accuracy"][-1]

                print(f" Client {cid} → Loss={train_loss:.4f}, Acc={train_acc:.4f}, Time={t1-t0:.2f}s, N={len(yc)}")

                locals_.append(m); sizes.append(len(yc))

            fedavg(global_model,locals_,sizes)

            loss,acc=global_model.evaluate(fmt(X_test_global),y_test_global,verbose=0)

            print(f" >>> GLOBAL (centralized test) → Loss={loss:.4f}, Acc={acc:.4f}")

            acc_hist.append(acc); loss_hist.append(loss)

            # bytes per weight (float32=4 bytes), sent down to each client AND back up from each client
            weight_bytes=sum([w.size for w in global_model.get_weights()])*4
            comm+=weight_bytes*CLIENTS*2

        # ================= FINAL GLOBAL TEST METRICS =================
        t0=time.time()
        y_prob=global_model.predict(fmt(X_test_global),verbose=0)
        inference_time=time.time()-t0

        y_pred=(y_prob>0.5).astype(int)

        # ---- Save per-instance predictions for McNemar's test ----
        y_preds[(model_name,seed)]=y_pred.flatten()
        if seed not in y_trues:
            y_trues[seed]=y_test_global.flatten()
        else:
            # sanity check: every model must see the identical test set for this seed
            assert np.array_equal(y_trues[seed],y_test_global.flatten()), \
                f"Test set mismatch for seed {seed} — McNemar's test requires identical instances across models."

        tn,fp,fn,tp=confusion_matrix(y_test_global,y_pred).ravel()

        # ---- Save this trained global model to disk ----
        model_path=os.path.join(MODEL_SAVE_DIR,f"{model_name}_seed{seed}.keras")
        global_model.save(model_path)
        print(f" [saved] {model_path}")

        rows.append({
            "Model":model_name,
            "Seed":seed,
            "Loss":log_loss(y_test_global,y_prob),
            "Accuracy":accuracy_score(y_test_global,y_pred),
            "Precision":precision_score(y_test_global,y_pred),
            "Recall":recall_score(y_test_global,y_pred),
            "F1":f1_score(y_test_global,y_pred),
            "MCC":matthews_corrcoef(y_test_global,y_pred),
            "AUC":roc_auc_score(y_test_global,y_prob),
            "Specificity":tn/(tn+fp),
            "Training_Time_sec":total_train_time,
            "Inference_Time_sec":inference_time,
            "Model_Size_MB":model_size(global_model),
            "Comm_per_round_MB":comm/(ROUNDS*1024*1024),
            "Total_Comm_MB":comm/(1024*1024),
            "Saved_Model_Path":model_path
        })

        results_round[model_name]["acc"].append(acc_hist)
        results_round[model_name]["loss"].append(loss_hist)
        results_round[model_name]["cm"].append(confusion_matrix(y_test_global,y_pred))

        # ================= PER-CLIENT LOCAL TEST EVALUATION =================
        for cid,(Xc_te,yc_te) in enumerate(client_test):
            yc_prob=global_model.predict(fmt(Xc_te),verbose=0)
            yc_pred=(yc_prob>0.5).astype(int)

            cm_c=confusion_matrix(yc_te,yc_pred,labels=[0,1])
            tn_c,fp_c,fn_c,tp_c=cm_c.ravel()

            auc_val=roc_auc_score(yc_te,yc_prob) if len(np.unique(yc_te))>1 else np.nan

            client_rows.append({
                "Model":model_name,
                "Seed":seed,
                "Client":cid,
                "N_test":len(yc_te),
                "Loss":log_loss(yc_te,yc_prob,labels=[0,1]),
                "Accuracy":accuracy_score(yc_te,yc_pred),
                "Precision":precision_score(yc_te,yc_pred,zero_division=0),
                "Recall":recall_score(yc_te,yc_pred,zero_division=0),
                "F1":f1_score(yc_te,yc_pred,zero_division=0),
                "MCC":matthews_corrcoef(yc_te,yc_pred),
                "AUC":auc_val,
                "Specificity":(tn_c/(tn_c+fp_c)) if (tn_c+fp_c)>0 else np.nan
            })

# ================= PRINT ALL CONFUSION MATRICES PER SEED (GLOBAL TEST) =================
for m in MODELS:
    print(f"\n=== {m}: Global Test Confusion Matrices per Seed ===")
    for seed,cm in zip(SEEDS,results_round[m]["cm"]):
        print(f"Seed {seed}:\n{cm}")

# ================= MEAN OVER SEEDS (GLOBAL TEST, per-round curves + avg cm) =================
for m in MODELS:
    results_round[m]["acc"]=np.mean(results_round[m]["acc"],axis=0)
    results_round[m]["loss"]=np.mean(results_round[m]["loss"],axis=0)
    results_round[m]["cm"]=np.mean(results_round[m]["cm"],axis=0)

for m in MODELS:
    print(f"\n=== {m} (Global Test, averaged over {len(SEEDS)} seeds) ===")
    print("Confusion Matrix (avg):\n",np.round(results_round[m]["cm"],2))
    print("Accuracy per round:",np.round(results_round[m]["acc"],4))
    print("Loss per round:",np.round(results_round[m]["loss"],4))

# ================= PER-MODEL SUMMARY (ALL METRICS incl. time & comm cost, avg over 5 seeds) =================
results_df=pd.DataFrame(rows)

summary_metrics=["Loss","Accuracy","Precision","Recall","F1","MCC","AUC","Specificity",
                  "Training_Time_sec","Inference_Time_sec","Model_Size_MB",
                  "Comm_per_round_MB","Total_Comm_MB"]

per_model_summary=[]
for m in MODELS:
    sub=results_df[results_df["Model"]==m]
    for metric in summary_metrics:
        mean,sd,low,high=stats(sub[metric],metric)
        per_model_summary.append({
            "Model":m,
            "Metric":metric,
            "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
            "95% CI":f"[{low:.4f}, {high:.4f}]"
        })

per_model_summary_df=pd.DataFrame(per_model_summary)
print(f"\nPER-MODEL SUMMARY (mean ± sd, 95% CI over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_summary_df.to_string(index=False))

# wide pivot: one row per model, one column per metric, "mean [low, high]"
per_model_wide=per_model_summary_df.copy()
per_model_wide["Mean [95% CI]"]=per_model_wide.apply(
    lambda r: r["Mean ± SD"].split(" ± ")[0]+" "+r["95% CI"], axis=1
)
per_model_wide=per_model_wide.pivot(index="Model",columns="Metric",values="Mean [95% CI]")
per_model_wide=per_model_wide[summary_metrics]  # keep original metric order
print(f"\nPER-MODEL SUMMARY, WIDE (mean [95% CI] over {len(SEEDS)} seeds, Global Test Set):\n",
      per_model_wide.to_string())

# overall pooled summary (all models & seeds together) kept for reference
overall_summary=[]
for metric in summary_metrics:
    mean,sd,low,high=stats(results_df[metric],metric)
    overall_summary.append({
        "Metric":metric,
        "Mean ± SD":f"{mean:.4f} ± {sd:.4f}",
        "95% CI":f"[{low:.4f},{high:.4f}]"
    })
overall_summary_df=pd.DataFrame(overall_summary)
print(f"\nSAVED MODELS ({len(results_df)} total, in '{MODEL_SAVE_DIR}/'):\n",
      results_df[["Model","Seed","Saved_Model_Path"]].to_string(index=False))
print("\nOVERALL SUMMARY (all models & seeds pooled):\n",overall_summary_df)

# ================= PER-CLIENT TEST SUMMARY, averaged over 5 seeds =================
client_df=pd.DataFrame(client_rows)
client_metrics=["Accuracy","Precision","Recall","F1","MCC","AUC","Specificity","Loss"]

per_client_summary=(
    client_df.groupby(["Model","Client"])[client_metrics]
    .agg(["mean","std"])
    .round(4)
)
print(f"\nPER-CLIENT TEST SUMMARY (mean/std over {len(SEEDS)} seeds):\n",per_client_summary)

# ================= PAIRWISE PAIRED T-TESTS ACROSS MODELS (same seeds) =================
paired_test_metrics=["Accuracy","F1","AUC","Loss"]

pairwise_rows=[]
for metric in paired_test_metrics:
    for m1,m2 in combinations(MODELS,2):
        a=results_df[results_df["Model"]==m1].sort_values("Seed")[metric].values
        b=results_df[results_df["Model"]==m2].sort_values("Seed")[metric].values
        t_stat,p_val=ttest_rel(a,b)
        pairwise_rows.append({
            "Metric":metric,"Model A":m1,"Model B":m2,
            "Mean A":round(a.mean(),4),"Mean B":round(b.mean(),4),
            "t-stat":round(t_stat,4),"p-value":round(p_val,4),
            "Significant (p<0.05)":p_val<0.05
        })

pairwise_df=pd.DataFrame(pairwise_rows)
print(f"\nPAIRWISE PAIRED T-TESTS across {len(SEEDS)} seeds (Global Test Set):\n",
      pairwise_df.to_string(index=False))

# ================= McNEMAR'S TEST (per-instance, per seed + pooled across seeds) =================
mcnemar_per_seed_rows=[]
for seed in SEEDS:
    y_true=y_trues[seed]
    for m1,m2 in combinations(MODELS,2):
        stat,p,n01,n10=mcnemar_test(y_true,y_preds[(m1,seed)],y_true,y_preds[(m2,seed)])
        mcnemar_per_seed_rows.append({
            "Seed":seed,"Model A":m1,"Model B":m2,
            "A right/B wrong":n01,"A wrong/B right":n10,
            "stat":round(stat,4) if not np.isnan(stat) else "exact",
            "p-value":round(p,4),"Significant (p<0.05)":p<0.05
        })

mcnemar_per_seed_df=pd.DataFrame(mcnemar_per_seed_rows)
print(f"\nMcNEMAR'S TEST — PER SEED (instance-level, Global Test Set):\n",
      mcnemar_per_seed_df.to_string(index=False))

# pooled version: sum discordant counts across all 5 seeds (more statistical power)
mcnemar_pooled_rows=[]
for m1,m2 in combinations(MODELS,2):
    n01_total=0; n10_total=0
    for seed in SEEDS:
        y_true=y_trues[seed]
        correct_a=(y_preds[(m1,seed)]==y_true)
        correct_b=(y_preds[(m2,seed)]==y_true)
        n01_total+=int(np.sum(correct_a & ~correct_b))
        n10_total+=int(np.sum(~correct_a & correct_b))
    n=n01_total+n10_total
    if n==0:
        stat,p=np.nan,1.0
    elif n<25:
        p=min(2*min(binom.cdf(min(n01_total,n10_total),n,0.5),0.5),1.0); stat=np.nan
    else:
        stat=((abs(n01_total-n10_total)-1)**2)/n
        p=1-chi2.cdf(stat,1)
    mcnemar_pooled_rows.append({
        "Model A":m1,"Model B":m2,
        "A right/B wrong (pooled)":n01_total,"A wrong/B right (pooled)":n10_total,
        "stat":round(stat,4) if not np.isnan(stat) else "exact",
        "p-value":round(p,4),"Significant (p<0.05)":p<0.05
    })

mcnemar_pooled_df=pd.DataFrame(mcnemar_pooled_rows)
print(f"\nMcNEMAR'S TEST — POOLED ACROSS {len(SEEDS)} SEEDS (Global Test Set):\n",
      mcnemar_pooled_df.to_string(index=False))

# ================= PLOTS =================
rounds=np.arange(1,ROUNDS+1)

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["acc"],label=m)
plt.title("Accuracy vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Accuracy")
plt.legend(); plt.grid(); plt.show()

plt.figure()
for m in MODELS:
    plt.plot(rounds,results_round[m]["loss"],label=m)
plt.title("Loss vs Rounds (Global Test)")
plt.xlabel("Communication Round")
plt.ylabel("Loss")
plt.legend(); plt.grid(); plt.show()
# Out:
# ================ MODEL: CNN ================
#
# ------ SEED 42 ------
#
# [Model=CNN | Seed=42 | Round=1]
#  Client 0 → Loss=0.6694, Acc=0.6155, Time=1.22s, N=2286
#  Client 1 → Loss=0.6724, Acc=0.6216, Time=0.84s, N=2286
#  Client 2 → Loss=0.6658, Acc=0.6089, Time=0.87s, N=2286
#  Client 3 → Loss=0.6522, Acc=0.6414, Time=0.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6616, Acc=0.6198
#
# [Model=CNN | Seed=42 | Round=2]
#  Client 0 → Loss=0.6495, Acc=0.6509, Time=0.81s, N=2286
#  Client 1 → Loss=0.6508, Acc=0.6321, Time=0.85s, N=2286
#  Client 2 → Loss=0.6463, Acc=0.6426, Time=0.83s, N=2286
#  Client 3 → Loss=0.6340, Acc=0.6581, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6438, Acc=0.6442
#
# [Model=CNN | Seed=42 | Round=3]
#  Client 0 → Loss=0.6304, Acc=0.6632, Time=0.86s, N=2286
#  Client 1 → Loss=0.6323, Acc=0.6509, Time=0.81s, N=2286
#  Client 2 → Loss=0.6319, Acc=0.6527, Time=0.79s, N=2286
#  Client 3 → Loss=0.6193, Acc=0.6624, Time=0.87s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6359, Acc=0.6285
#
# [Model=CNN | Seed=42 | Round=4]
#  Client 0 → Loss=0.6032, Acc=0.6872, Time=0.78s, N=2286
#  Client 1 → Loss=0.6080, Acc=0.6754, Time=0.85s, N=2286
#  Client 2 → Loss=0.6076, Acc=0.6794, Time=1.14s, N=2286
#  Client 3 → Loss=0.5984, Acc=0.6808, Time=0.94s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6149, Acc=0.6364
#
# [Model=CNN | Seed=42 | Round=5]
#  Client 0 → Loss=0.5578, Acc=0.7275, Time=0.86s, N=2286
#  Client 1 → Loss=0.5580, Acc=0.7231, Time=0.82s, N=2286
#  Client 2 → Loss=0.5566, Acc=0.7266, Time=0.83s, N=2286
#  Client 3 → Loss=0.5540, Acc=0.7277, Time=0.87s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5745, Acc=0.6560
#
# [Model=CNN | Seed=42 | Round=6]
#  Client 0 → Loss=0.4990, Acc=0.7664, Time=0.85s, N=2286
#  Client 1 → Loss=0.4905, Acc=0.7712, Time=0.84s, N=2286
#  Client 2 → Loss=0.4910, Acc=0.7664, Time=0.80s, N=2286
#  Client 3 → Loss=0.4924, Acc=0.7706, Time=0.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5188, Acc=0.7163
#
# [Model=CNN | Seed=42 | Round=7]
#  Client 0 → Loss=0.4448, Acc=0.7944, Time=0.98s, N=2286
#  Client 1 → Loss=0.4346, Acc=0.8045, Time=0.79s, N=2286
#  Client 2 → Loss=0.4399, Acc=0.7966, Time=0.80s, N=2286
#  Client 3 → Loss=0.4429, Acc=0.7982, Time=0.92s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4731, Acc=0.7631
#
# [Model=CNN | Seed=42 | Round=8]
#  Client 0 → Loss=0.4038, Acc=0.8211, Time=0.94s, N=2286
#  Client 1 → Loss=0.3979, Acc=0.8241, Time=0.82s, N=2286
#  Client 2 → Loss=0.4045, Acc=0.8193, Time=0.82s, N=2286
#  Client 3 → Loss=0.4112, Acc=0.8148, Time=0.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4520, Acc=0.7736
#
# [Model=CNN | Seed=42 | Round=9]
#  Client 0 → Loss=0.3847, Acc=0.8381, Time=1.00s, N=2286
#  Client 1 → Loss=0.3725, Acc=0.8408, Time=0.81s, N=2286
#  Client 2 → Loss=0.3794, Acc=0.8320, Time=0.83s, N=2286
#  Client 3 → Loss=0.3844, Acc=0.8323, Time=1.01s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4429, Acc=0.7854
#
# [Model=CNN | Seed=42 | Round=10]
#  Client 0 → Loss=0.3611, Acc=0.8508, Time=0.80s, N=2286
#  Client 1 → Loss=0.3572, Acc=0.8500, Time=0.80s, N=2286
#  Client 2 → Loss=0.3589, Acc=0.8399, Time=0.80s, N=2286
#  Client 3 → Loss=0.3641, Acc=0.8437, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4430, Acc=0.7885
#
# [Model=CNN | Seed=42 | Round=11]
#  Client 0 → Loss=0.3436, Acc=0.8583, Time=0.82s, N=2286
#  Client 1 → Loss=0.3419, Acc=0.8591, Time=0.80s, N=2286
#  Client 2 → Loss=0.3417, Acc=0.8460, Time=0.78s, N=2286
#  Client 3 → Loss=0.3506, Acc=0.8503, Time=0.88s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4378, Acc=0.7963
#
# [Model=CNN | Seed=42 | Round=12]
#  Client 0 → Loss=0.3266, Acc=0.8670, Time=0.83s, N=2286
#  Client 1 → Loss=0.3259, Acc=0.8640, Time=0.85s, N=2286
#  Client 2 → Loss=0.3276, Acc=0.8609, Time=0.92s, N=2286
#  Client 3 → Loss=0.3407, Acc=0.8612, Time=0.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4575, Acc=0.7867
#
# [Model=CNN | Seed=42 | Round=13]
#  Client 0 → Loss=0.3117, Acc=0.8766, Time=0.84s, N=2286
#  Client 1 → Loss=0.3146, Acc=0.8731, Time=0.92s, N=2286
#  Client 2 → Loss=0.3148, Acc=0.8696, Time=0.85s, N=2286
#  Client 3 → Loss=0.3298, Acc=0.8630, Time=0.82s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4540, Acc=0.7885
#
# [Model=CNN | Seed=42 | Round=14]
#  Client 0 → Loss=0.3037, Acc=0.8797, Time=0.85s, N=2286
#  Client 1 → Loss=0.3017, Acc=0.8762, Time=0.85s, N=2286
#  Client 2 → Loss=0.3034, Acc=0.8788, Time=0.81s, N=2286
#  Client 3 → Loss=0.3183, Acc=0.8660, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4521, Acc=0.7915
#
# [Model=CNN | Seed=42 | Round=15]
#  Client 0 → Loss=0.2912, Acc=0.8845, Time=0.79s, N=2286
#  Client 1 → Loss=0.2910, Acc=0.8775, Time=1.18s, N=2286
#  Client 2 → Loss=0.2928, Acc=0.8823, Time=0.80s, N=2286
#  Client 3 → Loss=0.3130, Acc=0.8726, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4538, Acc=0.7937
#
# [Model=CNN | Seed=42 | Round=16]
#  Client 0 → Loss=0.2832, Acc=0.8845, Time=0.80s, N=2286
#  Client 1 → Loss=0.2823, Acc=0.8858, Time=0.79s, N=2286
#  Client 2 → Loss=0.2838, Acc=0.8889, Time=0.78s, N=2286
#  Client 3 → Loss=0.3018, Acc=0.8735, Time=0.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4664, Acc=0.7902
#
# [Model=CNN | Seed=42 | Round=17]
#  Client 0 → Loss=0.2775, Acc=0.8906, Time=0.82s, N=2286
#  Client 1 → Loss=0.2744, Acc=0.8915, Time=0.81s, N=2286
#  Client 2 → Loss=0.2738, Acc=0.8976, Time=0.82s, N=2286
#  Client 3 → Loss=0.2939, Acc=0.8787, Time=0.94s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4736, Acc=0.7911
#
# [Model=CNN | Seed=42 | Round=18]
#  Client 0 → Loss=0.2659, Acc=0.8976, Time=0.79s, N=2286
#  Client 1 → Loss=0.2663, Acc=0.8933, Time=0.79s, N=2286
#  Client 2 → Loss=0.2653, Acc=0.8972, Time=0.80s, N=2286
#  Client 3 → Loss=0.2886, Acc=0.8840, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4785, Acc=0.7885
#
# [Model=CNN | Seed=42 | Round=19]
#  Client 0 → Loss=0.2579, Acc=0.9051, Time=0.93s, N=2286
#  Client 1 → Loss=0.2598, Acc=0.8941, Time=0.80s, N=2286
#  Client 2 → Loss=0.2593, Acc=0.8994, Time=0.78s, N=2286
#  Client 3 → Loss=0.2808, Acc=0.8905, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4790, Acc=0.7885
#
# [Model=CNN | Seed=42 | Round=20]
#  Client 0 → Loss=0.2506, Acc=0.9073, Time=0.86s, N=2286
#  Client 1 → Loss=0.2500, Acc=0.8990, Time=0.83s, N=2286
#  Client 2 → Loss=0.2537, Acc=0.9011, Time=1.06s, N=2286
#  Client 3 → Loss=0.2743, Acc=0.8936, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4863, Acc=0.7906
#
# [Model=CNN | Seed=42 | Round=21]
#  Client 0 → Loss=0.2471, Acc=0.9059, Time=0.81s, N=2286
#  Client 1 → Loss=0.2446, Acc=0.9046, Time=0.80s, N=2286
#  Client 2 → Loss=0.2471, Acc=0.9042, Time=0.87s, N=2286
#  Client 3 → Loss=0.2718, Acc=0.8945, Time=0.86s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4878, Acc=0.7937
#
# [Model=CNN | Seed=42 | Round=22]
#  Client 0 → Loss=0.2375, Acc=0.9129, Time=0.86s, N=2286
#  Client 1 → Loss=0.2395, Acc=0.9064, Time=0.93s, N=2286
#  Client 2 → Loss=0.2521, Acc=0.8998, Time=0.85s, N=2286
#  Client 3 → Loss=0.2680, Acc=0.8958, Time=0.86s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4975, Acc=0.7906
#
# [Model=CNN | Seed=42 | Round=23]
#  Client 0 → Loss=0.2364, Acc=0.9134, Time=0.81s, N=2286
#  Client 1 → Loss=0.2312, Acc=0.9116, Time=0.82s, N=2286
#  Client 2 → Loss=0.2408, Acc=0.9024, Time=0.82s, N=2286
#  Client 3 → Loss=0.2592, Acc=0.9024, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5205, Acc=0.7876
#
# [Model=CNN | Seed=42 | Round=24]
#  Client 0 → Loss=0.2307, Acc=0.9125, Time=0.83s, N=2286
#  Client 1 → Loss=0.2231, Acc=0.9125, Time=0.84s, N=2286
#  Client 2 → Loss=0.2340, Acc=0.9068, Time=0.82s, N=2286
#  Client 3 → Loss=0.2533, Acc=0.9011, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5109, Acc=0.7906
#
# [Model=CNN | Seed=42 | Round=25]
#  Client 0 → Loss=0.2384, Acc=0.9121, Time=0.83s, N=2286
#  Client 1 → Loss=0.2198, Acc=0.9186, Time=0.83s, N=2286
#  Client 2 → Loss=0.2281, Acc=0.9081, Time=0.78s, N=2286
#  Client 3 → Loss=0.2513, Acc=0.9063, Time=1.04s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5266, Acc=0.7858
#
# [Model=CNN | Seed=42 | Round=26]
#  Client 0 → Loss=0.2349, Acc=0.9116, Time=0.79s, N=2286
#  Client 1 → Loss=0.2139, Acc=0.9217, Time=0.85s, N=2286
#  Client 2 → Loss=0.2233, Acc=0.9108, Time=0.79s, N=2286
#  Client 3 → Loss=0.2434, Acc=0.9063, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5366, Acc=0.7867
#
# [Model=CNN | Seed=42 | Round=27]
#  Client 0 → Loss=0.2202, Acc=0.9116, Time=0.89s, N=2286
#  Client 1 → Loss=0.2081, Acc=0.9217, Time=0.80s, N=2286
#  Client 2 → Loss=0.2181, Acc=0.9103, Time=0.83s, N=2286
#  Client 3 → Loss=0.2350, Acc=0.9107, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5885, Acc=0.7784
#
# [Model=CNN | Seed=42 | Round=28]
#  Client 0 → Loss=0.2179, Acc=0.9173, Time=0.80s, N=2286
#  Client 1 → Loss=0.2012, Acc=0.9230, Time=0.80s, N=2286
#  Client 2 → Loss=0.2147, Acc=0.9125, Time=0.79s, N=2286
#  Client 3 → Loss=0.2295, Acc=0.9111, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6028, Acc=0.7802
#
# [Model=CNN | Seed=42 | Round=29]
#  Client 0 → Loss=0.2189, Acc=0.9208, Time=0.78s, N=2286
#  Client 1 → Loss=0.2008, Acc=0.9234, Time=0.83s, N=2286
#  Client 2 → Loss=0.2113, Acc=0.9195, Time=0.81s, N=2286
#  Client 3 → Loss=0.2270, Acc=0.9111, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5469, Acc=0.7950
#
# [Model=CNN | Seed=42 | Round=30]
#  Client 0 → Loss=0.2144, Acc=0.9160, Time=0.86s, N=2286
#  Client 1 → Loss=0.2023, Acc=0.9278, Time=0.84s, N=2286
#  Client 2 → Loss=0.2085, Acc=0.9186, Time=0.83s, N=2286
#  Client 3 → Loss=0.2175, Acc=0.9155, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5558, Acc=0.7906
#  [saved] saved_models\CNN_seed42.keras
#
# ------ SEED 3 ------
#
# [Model=CNN | Seed=3 | Round=1]
#  Client 0 → Loss=0.6568, Acc=0.6129, Time=1.25s, N=2286
#  Client 1 → Loss=0.6569, Acc=0.6304, Time=0.89s, N=2286
#  Client 2 → Loss=0.6561, Acc=0.6435, Time=0.86s, N=2286
#  Client 3 → Loss=0.6672, Acc=0.5976, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6586, Acc=0.6464
#
# [Model=CNN | Seed=3 | Round=2]
#  Client 0 → Loss=0.6434, Acc=0.6321, Time=0.80s, N=2286
#  Client 1 → Loss=0.6412, Acc=0.6426, Time=0.79s, N=2286
#  Client 2 → Loss=0.6392, Acc=0.6540, Time=0.79s, N=2286
#  Client 3 → Loss=0.6534, Acc=0.6200, Time=0.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6493, Acc=0.6473
#
# [Model=CNN | Seed=3 | Round=3]
#  Client 0 → Loss=0.6300, Acc=0.6544, Time=0.81s, N=2286
#  Client 1 → Loss=0.6265, Acc=0.6562, Time=0.80s, N=2286
#  Client 2 → Loss=0.6249, Acc=0.6675, Time=0.78s, N=2286
#  Client 3 → Loss=0.6445, Acc=0.6261, Time=0.82s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6419, Acc=0.6534
#
# [Model=CNN | Seed=3 | Round=4]
#  Client 0 → Loss=0.6174, Acc=0.6658, Time=0.81s, N=2286
#  Client 1 → Loss=0.6151, Acc=0.6662, Time=0.77s, N=2286
#  Client 2 → Loss=0.6126, Acc=0.6710, Time=0.84s, N=2286
#  Client 3 → Loss=0.6356, Acc=0.6362, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6329, Acc=0.6425
#
# [Model=CNN | Seed=3 | Round=5]
#  Client 0 → Loss=0.6026, Acc=0.6789, Time=0.81s, N=2286
#  Client 1 → Loss=0.5981, Acc=0.6785, Time=0.80s, N=2286
#  Client 2 → Loss=0.5970, Acc=0.6815, Time=0.82s, N=2286
#  Client 3 → Loss=0.6233, Acc=0.6528, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6234, Acc=0.6464
#
# [Model=CNN | Seed=3 | Round=6]
#  Client 0 → Loss=0.5729, Acc=0.7017, Time=1.01s, N=2286
#  Client 1 → Loss=0.5685, Acc=0.7095, Time=0.80s, N=2286
#  Client 2 → Loss=0.5730, Acc=0.6955, Time=0.81s, N=2286
#  Client 3 → Loss=0.5991, Acc=0.6786, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5964, Acc=0.6495
#
# [Model=CNN | Seed=3 | Round=7]
#  Client 0 → Loss=0.5295, Acc=0.7388, Time=0.80s, N=2286
#  Client 1 → Loss=0.5209, Acc=0.7568, Time=0.77s, N=2286
#  Client 2 → Loss=0.5287, Acc=0.7419, Time=0.78s, N=2286
#  Client 3 → Loss=0.5544, Acc=0.7290, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5505, Acc=0.6976
#
# [Model=CNN | Seed=3 | Round=8]
#  Client 0 → Loss=0.4906, Acc=0.7629, Time=0.79s, N=2286
#  Client 1 → Loss=0.4758, Acc=0.7795, Time=0.78s, N=2286
#  Client 2 → Loss=0.4869, Acc=0.7699, Time=0.80s, N=2286
#  Client 3 → Loss=0.5147, Acc=0.7618, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5219, Acc=0.7168
#
# [Model=CNN | Seed=3 | Round=9]
#  Client 0 → Loss=0.4573, Acc=0.7922, Time=0.78s, N=2286
#  Client 1 → Loss=0.4396, Acc=0.7970, Time=0.76s, N=2286
#  Client 2 → Loss=0.4544, Acc=0.7843, Time=0.74s, N=2286
#  Client 3 → Loss=0.4823, Acc=0.7789, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5104, Acc=0.7334
#
# [Model=CNN | Seed=3 | Round=10]
#  Client 0 → Loss=0.4377, Acc=0.7970, Time=0.76s, N=2286
#  Client 1 → Loss=0.4128, Acc=0.8150, Time=0.78s, N=2286
#  Client 2 → Loss=0.4291, Acc=0.7975, Time=0.76s, N=2286
#  Client 3 → Loss=0.4567, Acc=0.8047, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5104, Acc=0.7404
#
# [Model=CNN | Seed=3 | Round=11]
#  Client 0 → Loss=0.4161, Acc=0.8145, Time=0.86s, N=2286
#  Client 1 → Loss=0.3901, Acc=0.8276, Time=0.77s, N=2286
#  Client 2 → Loss=0.4073, Acc=0.8097, Time=0.77s, N=2286
#  Client 3 → Loss=0.4346, Acc=0.8069, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5097, Acc=0.7439
#
# [Model=CNN | Seed=3 | Round=12]
#  Client 0 → Loss=0.3996, Acc=0.8241, Time=0.79s, N=2286
#  Client 1 → Loss=0.3723, Acc=0.8399, Time=0.76s, N=2286
#  Client 2 → Loss=0.3903, Acc=0.8259, Time=0.76s, N=2286
#  Client 3 → Loss=0.4146, Acc=0.8196, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5296, Acc=0.7413
#
# [Model=CNN | Seed=3 | Round=13]
#  Client 0 → Loss=0.3858, Acc=0.8303, Time=0.75s, N=2286
#  Client 1 → Loss=0.3560, Acc=0.8451, Time=0.76s, N=2286
#  Client 2 → Loss=0.3730, Acc=0.8386, Time=0.74s, N=2286
#  Client 3 → Loss=0.3943, Acc=0.8266, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5282, Acc=0.7426
#
# [Model=CNN | Seed=3 | Round=14]
#  Client 0 → Loss=0.3711, Acc=0.8386, Time=0.78s, N=2286
#  Client 1 → Loss=0.3396, Acc=0.8561, Time=0.77s, N=2286
#  Client 2 → Loss=0.3608, Acc=0.8456, Time=0.74s, N=2286
#  Client 3 → Loss=0.3787, Acc=0.8384, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5662, Acc=0.7356
#
# [Model=CNN | Seed=3 | Round=15]
#  Client 0 → Loss=0.3595, Acc=0.8416, Time=0.85s, N=2286
#  Client 1 → Loss=0.3264, Acc=0.8644, Time=0.80s, N=2286
#  Client 2 → Loss=0.3466, Acc=0.8530, Time=0.75s, N=2286
#  Client 3 → Loss=0.3674, Acc=0.8468, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5730, Acc=0.7356
#
# [Model=CNN | Seed=3 | Round=16]
#  Client 0 → Loss=0.3469, Acc=0.8543, Time=0.76s, N=2286
#  Client 1 → Loss=0.3129, Acc=0.8740, Time=0.78s, N=2286
#  Client 2 → Loss=0.3337, Acc=0.8570, Time=0.78s, N=2286
#  Client 3 → Loss=0.3562, Acc=0.8498, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5909, Acc=0.7330
#
# [Model=CNN | Seed=3 | Round=17]
#  Client 0 → Loss=0.3355, Acc=0.8631, Time=0.76s, N=2286
#  Client 1 → Loss=0.3029, Acc=0.8766, Time=0.79s, N=2286
#  Client 2 → Loss=0.3227, Acc=0.8644, Time=0.79s, N=2286
#  Client 3 → Loss=0.3452, Acc=0.8577, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6261, Acc=0.7303
#
# [Model=CNN | Seed=3 | Round=18]
#  Client 0 → Loss=0.3246, Acc=0.8661, Time=0.78s, N=2286
#  Client 1 → Loss=0.2937, Acc=0.8784, Time=0.84s, N=2286
#  Client 2 → Loss=0.3174, Acc=0.8670, Time=0.78s, N=2286
#  Client 3 → Loss=0.3358, Acc=0.8665, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6132, Acc=0.7382
#
# [Model=CNN | Seed=3 | Round=19]
#  Client 0 → Loss=0.3123, Acc=0.8692, Time=0.79s, N=2286
#  Client 1 → Loss=0.2857, Acc=0.8823, Time=0.81s, N=2286
#  Client 2 → Loss=0.3046, Acc=0.8731, Time=0.78s, N=2286
#  Client 3 → Loss=0.3292, Acc=0.8643, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6304, Acc=0.7378
#
# [Model=CNN | Seed=3 | Round=20]
#  Client 0 → Loss=0.3055, Acc=0.8727, Time=0.78s, N=2286
#  Client 1 → Loss=0.2772, Acc=0.8885, Time=0.79s, N=2286
#  Client 2 → Loss=0.2997, Acc=0.8736, Time=0.75s, N=2286
#  Client 3 → Loss=0.3174, Acc=0.8708, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6387, Acc=0.7378
#
# [Model=CNN | Seed=3 | Round=21]
#  Client 0 → Loss=0.2982, Acc=0.8788, Time=0.79s, N=2286
#  Client 1 → Loss=0.2695, Acc=0.8928, Time=0.84s, N=2286
#  Client 2 → Loss=0.2862, Acc=0.8801, Time=0.82s, N=2286
#  Client 3 → Loss=0.3089, Acc=0.8704, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6658, Acc=0.7360
#
# [Model=CNN | Seed=3 | Round=22]
#  Client 0 → Loss=0.2910, Acc=0.8845, Time=1.02s, N=2286
#  Client 1 → Loss=0.2599, Acc=0.8963, Time=0.78s, N=2286
#  Client 2 → Loss=0.2783, Acc=0.8832, Time=0.77s, N=2286
#  Client 3 → Loss=0.3047, Acc=0.8735, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6682, Acc=0.7391
#
# [Model=CNN | Seed=3 | Round=23]
#  Client 0 → Loss=0.2797, Acc=0.8902, Time=0.78s, N=2286
#  Client 1 → Loss=0.2514, Acc=0.8976, Time=0.77s, N=2286
#  Client 2 → Loss=0.2696, Acc=0.8858, Time=0.79s, N=2286
#  Client 3 → Loss=0.2921, Acc=0.8822, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.7558, Acc=0.7273
#
# [Model=CNN | Seed=3 | Round=24]
#  Client 0 → Loss=0.2739, Acc=0.8911, Time=0.78s, N=2286
#  Client 1 → Loss=0.2469, Acc=0.8994, Time=0.78s, N=2286
#  Client 2 → Loss=0.2643, Acc=0.8871, Time=0.83s, N=2286
#  Client 3 → Loss=0.2841, Acc=0.8778, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.7610, Acc=0.7308
#
# [Model=CNN | Seed=3 | Round=25]
#  Client 0 → Loss=0.2700, Acc=0.8911, Time=0.82s, N=2286
#  Client 1 → Loss=0.2429, Acc=0.9055, Time=0.82s, N=2286
#  Client 2 → Loss=0.2612, Acc=0.8885, Time=0.84s, N=2286
#  Client 3 → Loss=0.2781, Acc=0.8879, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.7820, Acc=0.7347
#
# [Model=CNN | Seed=3 | Round=26]
#  Client 0 → Loss=0.2611, Acc=0.8950, Time=0.78s, N=2286
#  Client 1 → Loss=0.2422, Acc=0.9077, Time=0.77s, N=2286
#  Client 2 → Loss=0.2503, Acc=0.8955, Time=0.77s, N=2286
#  Client 3 → Loss=0.2737, Acc=0.8835, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.7920, Acc=0.7330
#
# [Model=CNN | Seed=3 | Round=27]
#  Client 0 → Loss=0.2530, Acc=0.8950, Time=0.79s, N=2286
#  Client 1 → Loss=0.2330, Acc=0.9081, Time=1.07s, N=2286
#  Client 2 → Loss=0.2430, Acc=0.8946, Time=0.79s, N=2286
#  Client 3 → Loss=0.2653, Acc=0.8923, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.8272, Acc=0.7277
#
# [Model=CNN | Seed=3 | Round=28]
#  Client 0 → Loss=0.2506, Acc=0.8998, Time=0.79s, N=2286
#  Client 1 → Loss=0.2266, Acc=0.9121, Time=0.80s, N=2286
#  Client 2 → Loss=0.2352, Acc=0.9029, Time=0.78s, N=2286
#  Client 3 → Loss=0.2606, Acc=0.8901, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.8336, Acc=0.7290
#
# [Model=CNN | Seed=3 | Round=29]
#  Client 0 → Loss=0.2479, Acc=0.9011, Time=0.83s, N=2286
#  Client 1 → Loss=0.2229, Acc=0.9169, Time=0.79s, N=2286
#  Client 2 → Loss=0.2270, Acc=0.9068, Time=0.79s, N=2286
#  Client 3 → Loss=0.2531, Acc=0.8958, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.8991, Acc=0.7233
#
# [Model=CNN | Seed=3 | Round=30]
#  Client 0 → Loss=0.2445, Acc=0.9059, Time=0.77s, N=2286
#  Client 1 → Loss=0.2237, Acc=0.9116, Time=0.82s, N=2286
#  Client 2 → Loss=0.2234, Acc=0.9094, Time=0.83s, N=2286
#  Client 3 → Loss=0.2429, Acc=0.8975, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.9385, Acc=0.7203
#  [saved] saved_models\CNN_seed3.keras
#
# ------ SEED 7 ------
#
# [Model=CNN | Seed=7 | Round=1]
#  Client 0 → Loss=0.6666, Acc=0.6129, Time=0.81s, N=2286
#  Client 1 → Loss=0.6531, Acc=0.6404, Time=0.81s, N=2286
#  Client 2 → Loss=0.6666, Acc=0.6063, Time=0.79s, N=2286
#  Client 3 → Loss=0.6616, Acc=0.6081, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6553, Acc=0.6394
#
# [Model=CNN | Seed=7 | Round=2]
#  Client 0 → Loss=0.6471, Acc=0.6286, Time=0.82s, N=2286
#  Client 1 → Loss=0.6370, Acc=0.6540, Time=0.79s, N=2286
#  Client 2 → Loss=0.6505, Acc=0.6330, Time=1.03s, N=2286
#  Client 3 → Loss=0.6482, Acc=0.6261, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6412, Acc=0.6547
#
# [Model=CNN | Seed=7 | Round=3]
#  Client 0 → Loss=0.6357, Acc=0.6465, Time=0.77s, N=2286
#  Client 1 → Loss=0.6235, Acc=0.6636, Time=0.86s, N=2286
#  Client 2 → Loss=0.6397, Acc=0.6483, Time=0.78s, N=2286
#  Client 3 → Loss=0.6384, Acc=0.6322, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6259, Acc=0.6622
#
# [Model=CNN | Seed=7 | Round=4]
#  Client 0 → Loss=0.6222, Acc=0.6553, Time=0.78s, N=2286
#  Client 1 → Loss=0.6098, Acc=0.6732, Time=0.79s, N=2286
#  Client 2 → Loss=0.6242, Acc=0.6592, Time=0.79s, N=2286
#  Client 3 → Loss=0.6231, Acc=0.6432, Time=0.82s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6087, Acc=0.6726
#
# [Model=CNN | Seed=7 | Round=5]
#  Client 0 → Loss=0.6000, Acc=0.6702, Time=0.77s, N=2286
#  Client 1 → Loss=0.5900, Acc=0.6916, Time=0.77s, N=2286
#  Client 2 → Loss=0.6003, Acc=0.6820, Time=0.83s, N=2286
#  Client 3 → Loss=0.6016, Acc=0.6721, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5739, Acc=0.6958
#
# [Model=CNN | Seed=7 | Round=6]
#  Client 0 → Loss=0.5563, Acc=0.7279, Time=0.80s, N=2286
#  Client 1 → Loss=0.5529, Acc=0.7253, Time=0.79s, N=2286
#  Client 2 → Loss=0.5639, Acc=0.7178, Time=0.79s, N=2286
#  Client 3 → Loss=0.5648, Acc=0.7106, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5095, Acc=0.7601
#
# [Model=CNN | Seed=7 | Round=7]
#  Client 0 → Loss=0.5036, Acc=0.7730, Time=0.80s, N=2286
#  Client 1 → Loss=0.5012, Acc=0.7651, Time=0.80s, N=2286
#  Client 2 → Loss=0.5153, Acc=0.7572, Time=0.77s, N=2286
#  Client 3 → Loss=0.5120, Acc=0.7614, Time=1.05s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4549, Acc=0.8068
#
# [Model=CNN | Seed=7 | Round=8]
#  Client 0 → Loss=0.4586, Acc=0.8018, Time=0.86s, N=2286
#  Client 1 → Loss=0.4600, Acc=0.7878, Time=0.75s, N=2286
#  Client 2 → Loss=0.4744, Acc=0.7852, Time=0.77s, N=2286
#  Client 3 → Loss=0.4670, Acc=0.7741, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4211, Acc=0.8195
#
# [Model=CNN | Seed=7 | Round=9]
#  Client 0 → Loss=0.4274, Acc=0.8136, Time=0.77s, N=2286
#  Client 1 → Loss=0.4300, Acc=0.8023, Time=0.78s, N=2286
#  Client 2 → Loss=0.4451, Acc=0.7997, Time=0.75s, N=2286
#  Client 3 → Loss=0.4376, Acc=0.8008, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4029, Acc=0.8226
#
# [Model=CNN | Seed=7 | Round=10]
#  Client 0 → Loss=0.3978, Acc=0.8298, Time=0.78s, N=2286
#  Client 1 → Loss=0.4063, Acc=0.8198, Time=0.77s, N=2286
#  Client 2 → Loss=0.4235, Acc=0.8123, Time=0.79s, N=2286
#  Client 3 → Loss=0.4161, Acc=0.8174, Time=0.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3954, Acc=0.8212
#
# [Model=CNN | Seed=7 | Round=11]
#  Client 0 → Loss=0.3799, Acc=0.8416, Time=0.87s, N=2286
#  Client 1 → Loss=0.3838, Acc=0.8303, Time=0.79s, N=2286
#  Client 2 → Loss=0.4092, Acc=0.8255, Time=0.76s, N=2286
#  Client 3 → Loss=0.3971, Acc=0.8253, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3985, Acc=0.8221
#
# [Model=CNN | Seed=7 | Round=12]
#  Client 0 → Loss=0.3643, Acc=0.8456, Time=0.77s, N=2286
#  Client 1 → Loss=0.3687, Acc=0.8373, Time=0.75s, N=2286
#  Client 2 → Loss=0.3913, Acc=0.8338, Time=0.77s, N=2286
#  Client 3 → Loss=0.3792, Acc=0.8345, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.3945, Acc=0.8221
#
# [Model=CNN | Seed=7 | Round=13]
#  Client 0 → Loss=0.3473, Acc=0.8552, Time=0.79s, N=2286
#  Client 1 → Loss=0.3526, Acc=0.8478, Time=0.80s, N=2286
#  Client 2 → Loss=0.3757, Acc=0.8434, Time=0.77s, N=2286
#  Client 3 → Loss=0.3657, Acc=0.8371, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4138, Acc=0.8186
#
# [Model=CNN | Seed=7 | Round=14]
#  Client 0 → Loss=0.3335, Acc=0.8631, Time=0.85s, N=2286
#  Client 1 → Loss=0.3358, Acc=0.8570, Time=0.81s, N=2286
#  Client 2 → Loss=0.3623, Acc=0.8486, Time=0.84s, N=2286
#  Client 3 → Loss=0.3491, Acc=0.8511, Time=0.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4005, Acc=0.8252
#
# [Model=CNN | Seed=7 | Round=15]
#  Client 0 → Loss=0.3218, Acc=0.8683, Time=0.80s, N=2286
#  Client 1 → Loss=0.3221, Acc=0.8648, Time=0.80s, N=2286
#  Client 2 → Loss=0.3480, Acc=0.8552, Time=0.82s, N=2286
#  Client 3 → Loss=0.3397, Acc=0.8625, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4128, Acc=0.8212
#
# [Model=CNN | Seed=7 | Round=16]
#  Client 0 → Loss=0.3124, Acc=0.8745, Time=0.82s, N=2286
#  Client 1 → Loss=0.3095, Acc=0.8727, Time=0.82s, N=2286
#  Client 2 → Loss=0.3342, Acc=0.8648, Time=0.82s, N=2286
#  Client 3 → Loss=0.3250, Acc=0.8665, Time=0.88s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4199, Acc=0.8212
#
# [Model=CNN | Seed=7 | Round=17]
#  Client 0 → Loss=0.3016, Acc=0.8797, Time=0.80s, N=2286
#  Client 1 → Loss=0.2995, Acc=0.8727, Time=0.80s, N=2286
#  Client 2 → Loss=0.3254, Acc=0.8710, Time=0.83s, N=2286
#  Client 3 → Loss=0.3189, Acc=0.8660, Time=0.84s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4149, Acc=0.8226
#
# [Model=CNN | Seed=7 | Round=18]
#  Client 0 → Loss=0.2923, Acc=0.8832, Time=0.83s, N=2286
#  Client 1 → Loss=0.2879, Acc=0.8775, Time=0.80s, N=2286
#  Client 2 → Loss=0.3176, Acc=0.8775, Time=0.83s, N=2286
#  Client 3 → Loss=0.3090, Acc=0.8770, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4360, Acc=0.8177
#
# [Model=CNN | Seed=7 | Round=19]
#  Client 0 → Loss=0.2858, Acc=0.8858, Time=0.79s, N=2286
#  Client 1 → Loss=0.2760, Acc=0.8858, Time=0.85s, N=2286
#  Client 2 → Loss=0.3099, Acc=0.8806, Time=0.80s, N=2286
#  Client 3 → Loss=0.3008, Acc=0.8787, Time=0.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4301, Acc=0.8234
#
# [Model=CNN | Seed=7 | Round=20]
#  Client 0 → Loss=0.2749, Acc=0.8933, Time=0.83s, N=2286
#  Client 1 → Loss=0.2626, Acc=0.8941, Time=0.82s, N=2286
#  Client 2 → Loss=0.3064, Acc=0.8841, Time=0.82s, N=2286
#  Client 3 → Loss=0.2937, Acc=0.8818, Time=0.88s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4452, Acc=0.8199
#
# [Model=CNN | Seed=7 | Round=21]
#  Client 0 → Loss=0.2689, Acc=0.8941, Time=0.81s, N=2286
#  Client 1 → Loss=0.2525, Acc=0.8990, Time=0.76s, N=2286
#  Client 2 → Loss=0.2946, Acc=0.8902, Time=0.82s, N=2286
#  Client 3 → Loss=0.2800, Acc=0.8905, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4598, Acc=0.8212
#
# [Model=CNN | Seed=7 | Round=22]
#  Client 0 → Loss=0.2604, Acc=0.8976, Time=0.74s, N=2286
#  Client 1 → Loss=0.2487, Acc=0.9016, Time=0.79s, N=2286
#  Client 2 → Loss=0.2877, Acc=0.8928, Time=0.81s, N=2286
#  Client 3 → Loss=0.2775, Acc=0.8901, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4576, Acc=0.8221
#
# [Model=CNN | Seed=7 | Round=23]
#  Client 0 → Loss=0.2530, Acc=0.8994, Time=0.87s, N=2286
#  Client 1 → Loss=0.2397, Acc=0.9033, Time=0.76s, N=2286
#  Client 2 → Loss=0.2852, Acc=0.8920, Time=0.78s, N=2286
#  Client 3 → Loss=0.2632, Acc=0.8975, Time=0.74s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4731, Acc=0.8164
#
# [Model=CNN | Seed=7 | Round=24]
#  Client 0 → Loss=0.2475, Acc=0.9007, Time=0.85s, N=2286
#  Client 1 → Loss=0.2314, Acc=0.9112, Time=0.76s, N=2286
#  Client 2 → Loss=0.2776, Acc=0.8946, Time=0.73s, N=2286
#  Client 3 → Loss=0.2642, Acc=0.8997, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4804, Acc=0.8151
#
# [Model=CNN | Seed=7 | Round=25]
#  Client 0 → Loss=0.2403, Acc=0.9077, Time=0.75s, N=2286
#  Client 1 → Loss=0.2275, Acc=0.9103, Time=0.74s, N=2286
#  Client 2 → Loss=0.2714, Acc=0.8968, Time=0.75s, N=2286
#  Client 3 → Loss=0.2548, Acc=0.8997, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4821, Acc=0.8164
#
# [Model=CNN | Seed=7 | Round=26]
#  Client 0 → Loss=0.2374, Acc=0.9038, Time=0.81s, N=2286
#  Client 1 → Loss=0.2182, Acc=0.9186, Time=0.84s, N=2286
#  Client 2 → Loss=0.2667, Acc=0.8928, Time=0.75s, N=2286
#  Client 3 → Loss=0.2682, Acc=0.8993, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4863, Acc=0.8182
#
# [Model=CNN | Seed=7 | Round=27]
#  Client 0 → Loss=0.2322, Acc=0.9103, Time=0.80s, N=2286
#  Client 1 → Loss=0.2101, Acc=0.9234, Time=0.78s, N=2286
#  Client 2 → Loss=0.2594, Acc=0.8994, Time=0.76s, N=2286
#  Client 3 → Loss=0.2480, Acc=0.9050, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4989, Acc=0.8186
#
# [Model=CNN | Seed=7 | Round=28]
#  Client 0 → Loss=0.2288, Acc=0.9147, Time=0.75s, N=2286
#  Client 1 → Loss=0.2101, Acc=0.9239, Time=0.76s, N=2286
#  Client 2 → Loss=0.2580, Acc=0.9042, Time=0.80s, N=2286
#  Client 3 → Loss=0.2436, Acc=0.9028, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4920, Acc=0.8191
#
# [Model=CNN | Seed=7 | Round=29]
#  Client 0 → Loss=0.2180, Acc=0.9164, Time=1.03s, N=2286
#  Client 1 → Loss=0.1972, Acc=0.9283, Time=0.79s, N=2286
#  Client 2 → Loss=0.2497, Acc=0.9073, Time=0.76s, N=2286
#  Client 3 → Loss=0.2349, Acc=0.9124, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5111, Acc=0.8195
#
# [Model=CNN | Seed=7 | Round=30]
#  Client 0 → Loss=0.2207, Acc=0.9169, Time=0.74s, N=2286
#  Client 1 → Loss=0.1958, Acc=0.9304, Time=0.81s, N=2286
#  Client 2 → Loss=0.2474, Acc=0.9073, Time=0.76s, N=2286
#  Client 3 → Loss=0.2368, Acc=0.9063, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5034, Acc=0.8221
#  [saved] saved_models\CNN_seed7.keras
#
# ------ SEED 72 ------
#
# [Model=CNN | Seed=72 | Round=1]
#  Client 0 → Loss=0.6735, Acc=0.5941, Time=0.77s, N=2286
#  Client 1 → Loss=0.6649, Acc=0.6260, Time=0.78s, N=2286
#  Client 2 → Loss=0.6619, Acc=0.6269, Time=0.74s, N=2286
#  Client 3 → Loss=0.6683, Acc=0.6003, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6666, Acc=0.6399
#
# [Model=CNN | Seed=72 | Round=2]
#  Client 0 → Loss=0.6641, Acc=0.6142, Time=0.74s, N=2286
#  Client 1 → Loss=0.6505, Acc=0.6264, Time=0.80s, N=2286
#  Client 2 → Loss=0.6459, Acc=0.6426, Time=0.78s, N=2286
#  Client 3 → Loss=0.6582, Acc=0.6375, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6478, Acc=0.6482
#
# [Model=CNN | Seed=72 | Round=3]
#  Client 0 → Loss=0.6496, Acc=0.6312, Time=0.77s, N=2286
#  Client 1 → Loss=0.6365, Acc=0.6422, Time=0.75s, N=2286
#  Client 2 → Loss=0.6332, Acc=0.6557, Time=0.77s, N=2286
#  Client 3 → Loss=0.6509, Acc=0.6327, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6356, Acc=0.6600
#
# [Model=CNN | Seed=72 | Round=4]
#  Client 0 → Loss=0.6351, Acc=0.6470, Time=0.76s, N=2286
#  Client 1 → Loss=0.6256, Acc=0.6461, Time=0.98s, N=2286
#  Client 2 → Loss=0.6222, Acc=0.6636, Time=0.75s, N=2286
#  Client 3 → Loss=0.6350, Acc=0.6462, Time=0.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6271, Acc=0.6696
#
# [Model=CNN | Seed=72 | Round=5]
#  Client 0 → Loss=0.6253, Acc=0.6570, Time=0.75s, N=2286
#  Client 1 → Loss=0.6134, Acc=0.6601, Time=0.75s, N=2286
#  Client 2 → Loss=0.6127, Acc=0.6684, Time=0.84s, N=2286
#  Client 3 → Loss=0.6243, Acc=0.6585, Time=0.75s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6228, Acc=0.6543
#
# [Model=CNN | Seed=72 | Round=6]
#  Client 0 → Loss=0.6103, Acc=0.6689, Time=0.76s, N=2286
#  Client 1 → Loss=0.6036, Acc=0.6667, Time=0.77s, N=2286
#  Client 2 → Loss=0.5991, Acc=0.6846, Time=0.75s, N=2286
#  Client 3 → Loss=0.6111, Acc=0.6681, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6153, Acc=0.6503
#
# [Model=CNN | Seed=72 | Round=7]
#  Client 0 → Loss=0.5916, Acc=0.6855, Time=0.73s, N=2286
#  Client 1 → Loss=0.5862, Acc=0.6934, Time=0.79s, N=2286
#  Client 2 → Loss=0.5820, Acc=0.6907, Time=0.75s, N=2286
#  Client 3 → Loss=0.5972, Acc=0.6821, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6033, Acc=0.6578
#
# [Model=CNN | Seed=72 | Round=8]
#  Client 0 → Loss=0.5648, Acc=0.7113, Time=0.76s, N=2286
#  Client 1 → Loss=0.5543, Acc=0.7209, Time=0.75s, N=2286
#  Client 2 → Loss=0.5542, Acc=0.7091, Time=0.77s, N=2286
#  Client 3 → Loss=0.5701, Acc=0.7088, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5769, Acc=0.6788
#
# [Model=CNN | Seed=72 | Round=9]
#  Client 0 → Loss=0.5214, Acc=0.7537, Time=0.75s, N=2286
#  Client 1 → Loss=0.5087, Acc=0.7537, Time=0.84s, N=2286
#  Client 2 → Loss=0.5130, Acc=0.7537, Time=1.00s, N=2286
#  Client 3 → Loss=0.5262, Acc=0.7408, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5278, Acc=0.7413
#
# [Model=CNN | Seed=72 | Round=10]
#  Client 0 → Loss=0.4838, Acc=0.7747, Time=0.77s, N=2286
#  Client 1 → Loss=0.4612, Acc=0.7865, Time=0.79s, N=2286
#  Client 2 → Loss=0.4666, Acc=0.7887, Time=0.78s, N=2286
#  Client 3 → Loss=0.4816, Acc=0.7793, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4991, Acc=0.7579
#
# [Model=CNN | Seed=72 | Round=11]
#  Client 0 → Loss=0.4517, Acc=0.7935, Time=0.77s, N=2286
#  Client 1 → Loss=0.4289, Acc=0.8049, Time=0.81s, N=2286
#  Client 2 → Loss=0.4346, Acc=0.8093, Time=0.76s, N=2286
#  Client 3 → Loss=0.4500, Acc=0.7920, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4647, Acc=0.7806
#
# [Model=CNN | Seed=72 | Round=12]
#  Client 0 → Loss=0.4280, Acc=0.8040, Time=0.79s, N=2286
#  Client 1 → Loss=0.4016, Acc=0.8198, Time=0.77s, N=2286
#  Client 2 → Loss=0.4076, Acc=0.8198, Time=0.76s, N=2286
#  Client 3 → Loss=0.4222, Acc=0.8074, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4470, Acc=0.7950
#
# [Model=CNN | Seed=72 | Round=13]
#  Client 0 → Loss=0.4072, Acc=0.8154, Time=0.80s, N=2286
#  Client 1 → Loss=0.3812, Acc=0.8272, Time=0.84s, N=2286
#  Client 2 → Loss=0.3869, Acc=0.8338, Time=0.79s, N=2286
#  Client 3 → Loss=0.3970, Acc=0.8310, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4366, Acc=0.8024
#
# [Model=CNN | Seed=72 | Round=14]
#  Client 0 → Loss=0.3944, Acc=0.8202, Time=0.81s, N=2286
#  Client 1 → Loss=0.3592, Acc=0.8460, Time=0.78s, N=2286
#  Client 2 → Loss=0.3708, Acc=0.8438, Time=0.76s, N=2286
#  Client 3 → Loss=0.3788, Acc=0.8393, Time=1.05s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4240, Acc=0.8125
#
# [Model=CNN | Seed=72 | Round=15]
#  Client 0 → Loss=0.3779, Acc=0.8307, Time=0.76s, N=2286
#  Client 1 → Loss=0.3444, Acc=0.8574, Time=0.77s, N=2286
#  Client 2 → Loss=0.3541, Acc=0.8526, Time=0.75s, N=2286
#  Client 3 → Loss=0.3647, Acc=0.8489, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4215, Acc=0.8134
#
# [Model=CNN | Seed=72 | Round=16]
#  Client 0 → Loss=0.3631, Acc=0.8395, Time=0.77s, N=2286
#  Client 1 → Loss=0.3309, Acc=0.8653, Time=0.80s, N=2286
#  Client 2 → Loss=0.3423, Acc=0.8561, Time=0.80s, N=2286
#  Client 3 → Loss=0.3521, Acc=0.8573, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4162, Acc=0.8182
#
# [Model=CNN | Seed=72 | Round=17]
#  Client 0 → Loss=0.3523, Acc=0.8456, Time=0.83s, N=2286
#  Client 1 → Loss=0.3184, Acc=0.8736, Time=0.78s, N=2286
#  Client 2 → Loss=0.3315, Acc=0.8591, Time=0.81s, N=2286
#  Client 3 → Loss=0.3399, Acc=0.8638, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4262, Acc=0.8147
#
# [Model=CNN | Seed=72 | Round=18]
#  Client 0 → Loss=0.3432, Acc=0.8504, Time=0.80s, N=2286
#  Client 1 → Loss=0.3112, Acc=0.8736, Time=0.76s, N=2286
#  Client 2 → Loss=0.3226, Acc=0.8661, Time=0.78s, N=2286
#  Client 3 → Loss=0.3316, Acc=0.8695, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4345, Acc=0.8103
#
# [Model=CNN | Seed=72 | Round=19]
#  Client 0 → Loss=0.3332, Acc=0.8552, Time=0.79s, N=2286
#  Client 1 → Loss=0.2994, Acc=0.8819, Time=0.87s, N=2286
#  Client 2 → Loss=0.3110, Acc=0.8723, Time=0.80s, N=2286
#  Client 3 → Loss=0.3227, Acc=0.8700, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4390, Acc=0.8103
#
# [Model=CNN | Seed=72 | Round=20]
#  Client 0 → Loss=0.3252, Acc=0.8622, Time=0.77s, N=2286
#  Client 1 → Loss=0.2920, Acc=0.8832, Time=1.03s, N=2286
#  Client 2 → Loss=0.3015, Acc=0.8801, Time=0.78s, N=2286
#  Client 3 → Loss=0.3152, Acc=0.8783, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4405, Acc=0.8129
#
# [Model=CNN | Seed=72 | Round=21]
#  Client 0 → Loss=0.3145, Acc=0.8635, Time=0.76s, N=2286
#  Client 1 → Loss=0.2872, Acc=0.8836, Time=0.77s, N=2286
#  Client 2 → Loss=0.2944, Acc=0.8819, Time=0.81s, N=2286
#  Client 3 → Loss=0.3075, Acc=0.8778, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4534, Acc=0.8077
#
# [Model=CNN | Seed=72 | Round=22]
#  Client 0 → Loss=0.3082, Acc=0.8657, Time=0.75s, N=2286
#  Client 1 → Loss=0.2784, Acc=0.8898, Time=0.79s, N=2286
#  Client 2 → Loss=0.2885, Acc=0.8841, Time=0.78s, N=2286
#  Client 3 → Loss=0.3007, Acc=0.8809, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4498, Acc=0.8103
#
# [Model=CNN | Seed=72 | Round=23]
#  Client 0 → Loss=0.3025, Acc=0.8701, Time=0.82s, N=2286
#  Client 1 → Loss=0.2746, Acc=0.8906, Time=0.77s, N=2286
#  Client 2 → Loss=0.2838, Acc=0.8845, Time=0.76s, N=2286
#  Client 3 → Loss=0.2947, Acc=0.8822, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4655, Acc=0.8059
#
# [Model=CNN | Seed=72 | Round=24]
#  Client 0 → Loss=0.2943, Acc=0.8714, Time=0.78s, N=2286
#  Client 1 → Loss=0.2674, Acc=0.8941, Time=0.76s, N=2286
#  Client 2 → Loss=0.2817, Acc=0.8854, Time=0.77s, N=2286
#  Client 3 → Loss=0.2887, Acc=0.8844, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4655, Acc=0.8103
#
# [Model=CNN | Seed=72 | Round=25]
#  Client 0 → Loss=0.2903, Acc=0.8745, Time=0.79s, N=2286
#  Client 1 → Loss=0.2618, Acc=0.8963, Time=0.81s, N=2286
#  Client 2 → Loss=0.2750, Acc=0.8876, Time=0.78s, N=2286
#  Client 3 → Loss=0.2858, Acc=0.8910, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4785, Acc=0.8073
#
# [Model=CNN | Seed=72 | Round=26]
#  Client 0 → Loss=0.2899, Acc=0.8771, Time=0.76s, N=2286
#  Client 1 → Loss=0.2543, Acc=0.9033, Time=0.79s, N=2286
#  Client 2 → Loss=0.2674, Acc=0.8911, Time=0.79s, N=2286
#  Client 3 → Loss=0.2797, Acc=0.8940, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4741, Acc=0.8046
#
# [Model=CNN | Seed=72 | Round=27]
#  Client 0 → Loss=0.2802, Acc=0.8784, Time=0.83s, N=2286
#  Client 1 → Loss=0.2500, Acc=0.9051, Time=0.78s, N=2286
#  Client 2 → Loss=0.2638, Acc=0.8955, Time=0.78s, N=2286
#  Client 3 → Loss=0.2716, Acc=0.8967, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4734, Acc=0.8068
#
# [Model=CNN | Seed=72 | Round=28]
#  Client 0 → Loss=0.2698, Acc=0.8850, Time=0.79s, N=2286
#  Client 1 → Loss=0.2485, Acc=0.9046, Time=0.80s, N=2286
#  Client 2 → Loss=0.2589, Acc=0.8976, Time=0.85s, N=2286
#  Client 3 → Loss=0.2656, Acc=0.9019, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4934, Acc=0.8029
#
# [Model=CNN | Seed=72 | Round=29]
#  Client 0 → Loss=0.2686, Acc=0.8832, Time=0.77s, N=2286
#  Client 1 → Loss=0.2378, Acc=0.9121, Time=0.77s, N=2286
#  Client 2 → Loss=0.2548, Acc=0.9011, Time=0.82s, N=2286
#  Client 3 → Loss=0.2614, Acc=0.9015, Time=0.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4989, Acc=0.7968
#
# [Model=CNN | Seed=72 | Round=30]
#  Client 0 → Loss=0.2602, Acc=0.8867, Time=0.80s, N=2286
#  Client 1 → Loss=0.2312, Acc=0.9134, Time=0.77s, N=2286
#  Client 2 → Loss=0.2523, Acc=0.9042, Time=0.80s, N=2286
#  Client 3 → Loss=0.2608, Acc=0.9019, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5038, Acc=0.7998
#  [saved] saved_models\CNN_seed72.keras
#
# ------ SEED 82 ------
#
# [Model=CNN | Seed=82 | Round=1]
#  Client 0 → Loss=0.6673, Acc=0.6028, Time=0.83s, N=2286
#  Client 1 → Loss=0.6639, Acc=0.6203, Time=0.81s, N=2286
#  Client 2 → Loss=0.6592, Acc=0.6286, Time=0.78s, N=2286
#  Client 3 → Loss=0.6543, Acc=0.6270, Time=0.82s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6607, Acc=0.6530
#
# [Model=CNN | Seed=82 | Round=2]
#  Client 0 → Loss=0.6576, Acc=0.6260, Time=0.80s, N=2286
#  Client 1 → Loss=0.6502, Acc=0.6207, Time=0.80s, N=2286
#  Client 2 → Loss=0.6456, Acc=0.6531, Time=0.81s, N=2286
#  Client 3 → Loss=0.6446, Acc=0.6405, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6506, Acc=0.6670
#
# [Model=CNN | Seed=82 | Round=3]
#  Client 0 → Loss=0.6436, Acc=0.6400, Time=0.79s, N=2286
#  Client 1 → Loss=0.6366, Acc=0.6312, Time=0.78s, N=2286
#  Client 2 → Loss=0.6349, Acc=0.6557, Time=0.79s, N=2286
#  Client 3 → Loss=0.6330, Acc=0.6511, Time=0.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6417, Acc=0.6604
#
# [Model=CNN | Seed=82 | Round=4]
#  Client 0 → Loss=0.6328, Acc=0.6461, Time=0.82s, N=2286
#  Client 1 → Loss=0.6209, Acc=0.6448, Time=0.81s, N=2286
#  Client 2 → Loss=0.6241, Acc=0.6645, Time=0.81s, N=2286
#  Client 3 → Loss=0.6203, Acc=0.6651, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6357, Acc=0.6503
#
# [Model=CNN | Seed=82 | Round=5]
#  Client 0 → Loss=0.6129, Acc=0.6728, Time=0.79s, N=2286
#  Client 1 → Loss=0.5974, Acc=0.6719, Time=0.77s, N=2286
#  Client 2 → Loss=0.6061, Acc=0.6794, Time=0.83s, N=2286
#  Client 3 → Loss=0.5968, Acc=0.6826, Time=1.02s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6253, Acc=0.6145
#
# [Model=CNN | Seed=82 | Round=6]
#  Client 0 → Loss=0.5739, Acc=0.7157, Time=0.79s, N=2286
#  Client 1 → Loss=0.5590, Acc=0.7100, Time=0.77s, N=2286
#  Client 2 → Loss=0.5658, Acc=0.7108, Time=0.76s, N=2286
#  Client 3 → Loss=0.5598, Acc=0.7150, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6000, Acc=0.6071
#
# [Model=CNN | Seed=82 | Round=7]
#  Client 0 → Loss=0.5245, Acc=0.7410, Time=0.77s, N=2286
#  Client 1 → Loss=0.4963, Acc=0.7642, Time=0.83s, N=2286
#  Client 2 → Loss=0.5112, Acc=0.7625, Time=0.76s, N=2286
#  Client 3 → Loss=0.5125, Acc=0.7627, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5554, Acc=0.6836
#
# [Model=CNN | Seed=82 | Round=8]
#  Client 0 → Loss=0.4728, Acc=0.7725, Time=0.80s, N=2286
#  Client 1 → Loss=0.4501, Acc=0.7883, Time=0.77s, N=2286
#  Client 2 → Loss=0.4623, Acc=0.7948, Time=0.80s, N=2286
#  Client 3 → Loss=0.4698, Acc=0.7881, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4988, Acc=0.7434
#
# [Model=CNN | Seed=82 | Round=9]
#  Client 0 → Loss=0.4404, Acc=0.7953, Time=0.76s, N=2286
#  Client 1 → Loss=0.4136, Acc=0.8154, Time=0.77s, N=2286
#  Client 2 → Loss=0.4219, Acc=0.8228, Time=0.82s, N=2286
#  Client 3 → Loss=0.4363, Acc=0.8109, Time=0.77s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4818, Acc=0.7579
#
# [Model=CNN | Seed=82 | Round=10]
#  Client 0 → Loss=0.4138, Acc=0.8150, Time=0.78s, N=2286
#  Client 1 → Loss=0.3868, Acc=0.8342, Time=0.78s, N=2286
#  Client 2 → Loss=0.3952, Acc=0.8325, Time=0.84s, N=2286
#  Client 3 → Loss=0.4106, Acc=0.8262, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4836, Acc=0.7601
#
# [Model=CNN | Seed=82 | Round=11]
#  Client 0 → Loss=0.3931, Acc=0.8276, Time=0.82s, N=2286
#  Client 1 → Loss=0.3656, Acc=0.8495, Time=1.07s, N=2286
#  Client 2 → Loss=0.3761, Acc=0.8421, Time=0.81s, N=2286
#  Client 3 → Loss=0.3908, Acc=0.8358, Time=0.76s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4694, Acc=0.7688
#
# [Model=CNN | Seed=82 | Round=12]
#  Client 0 → Loss=0.3752, Acc=0.8421, Time=0.83s, N=2286
#  Client 1 → Loss=0.3515, Acc=0.8561, Time=0.80s, N=2286
#  Client 2 → Loss=0.3606, Acc=0.8513, Time=0.75s, N=2286
#  Client 3 → Loss=0.3761, Acc=0.8402, Time=0.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4648, Acc=0.7815
#
# [Model=CNN | Seed=82 | Round=13]
#  Client 0 → Loss=0.3601, Acc=0.8478, Time=0.91s, N=2286
#  Client 1 → Loss=0.3367, Acc=0.8605, Time=0.83s, N=2286
#  Client 2 → Loss=0.3452, Acc=0.8578, Time=0.80s, N=2286
#  Client 3 → Loss=0.3632, Acc=0.8446, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4731, Acc=0.7797
#
# [Model=CNN | Seed=82 | Round=14]
#  Client 0 → Loss=0.3484, Acc=0.8526, Time=0.78s, N=2286
#  Client 1 → Loss=0.3252, Acc=0.8692, Time=0.85s, N=2286
#  Client 2 → Loss=0.3330, Acc=0.8666, Time=0.78s, N=2286
#  Client 3 → Loss=0.3534, Acc=0.8494, Time=0.84s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4711, Acc=0.7845
#
# [Model=CNN | Seed=82 | Round=15]
#  Client 0 → Loss=0.3368, Acc=0.8565, Time=0.85s, N=2286
#  Client 1 → Loss=0.3112, Acc=0.8731, Time=0.79s, N=2286
#  Client 2 → Loss=0.3236, Acc=0.8688, Time=0.81s, N=2286
#  Client 3 → Loss=0.3443, Acc=0.8546, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4862, Acc=0.7810
#
# [Model=CNN | Seed=82 | Round=16]
#  Client 0 → Loss=0.3263, Acc=0.8688, Time=0.80s, N=2286
#  Client 1 → Loss=0.3035, Acc=0.8810, Time=0.80s, N=2286
#  Client 2 → Loss=0.3099, Acc=0.8771, Time=0.86s, N=2286
#  Client 3 → Loss=0.3344, Acc=0.8577, Time=1.04s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5052, Acc=0.7780
#
# [Model=CNN | Seed=82 | Round=17]
#  Client 0 → Loss=0.3174, Acc=0.8727, Time=0.80s, N=2286
#  Client 1 → Loss=0.2926, Acc=0.8845, Time=0.86s, N=2286
#  Client 2 → Loss=0.3011, Acc=0.8784, Time=0.80s, N=2286
#  Client 3 → Loss=0.3271, Acc=0.8616, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5019, Acc=0.7819
#
# [Model=CNN | Seed=82 | Round=18]
#  Client 0 → Loss=0.3081, Acc=0.8801, Time=0.80s, N=2286
#  Client 1 → Loss=0.2869, Acc=0.8867, Time=0.85s, N=2286
#  Client 2 → Loss=0.2906, Acc=0.8858, Time=0.84s, N=2286
#  Client 3 → Loss=0.3226, Acc=0.8638, Time=0.85s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.4944, Acc=0.7880
#
# [Model=CNN | Seed=82 | Round=19]
#  Client 0 → Loss=0.2979, Acc=0.8854, Time=0.82s, N=2286
#  Client 1 → Loss=0.2755, Acc=0.8906, Time=0.81s, N=2286
#  Client 2 → Loss=0.2850, Acc=0.8963, Time=0.80s, N=2286
#  Client 3 → Loss=0.3162, Acc=0.8691, Time=0.80s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5067, Acc=0.7832
#
# [Model=CNN | Seed=82 | Round=20]
#  Client 0 → Loss=0.2869, Acc=0.8880, Time=0.82s, N=2286
#  Client 1 → Loss=0.2678, Acc=0.8950, Time=0.85s, N=2286
#  Client 2 → Loss=0.2739, Acc=0.8981, Time=0.85s, N=2286
#  Client 3 → Loss=0.3062, Acc=0.8748, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5116, Acc=0.7854
#
# [Model=CNN | Seed=82 | Round=21]
#  Client 0 → Loss=0.2764, Acc=0.8928, Time=0.86s, N=2286
#  Client 1 → Loss=0.2563, Acc=0.8976, Time=0.87s, N=2286
#  Client 2 → Loss=0.2667, Acc=0.8985, Time=0.85s, N=2286
#  Client 3 → Loss=0.3052, Acc=0.8743, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5078, Acc=0.7950
#
# [Model=CNN | Seed=82 | Round=22]
#  Client 0 → Loss=0.2694, Acc=0.8990, Time=1.10s, N=2286
#  Client 1 → Loss=0.2543, Acc=0.8981, Time=0.83s, N=2286
#  Client 2 → Loss=0.2592, Acc=0.9024, Time=0.89s, N=2286
#  Client 3 → Loss=0.2982, Acc=0.8796, Time=0.82s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5075, Acc=0.7976
#
# [Model=CNN | Seed=82 | Round=23]
#  Client 0 → Loss=0.2642, Acc=0.8976, Time=0.81s, N=2286
#  Client 1 → Loss=0.2488, Acc=0.9029, Time=0.86s, N=2286
#  Client 2 → Loss=0.2488, Acc=0.9046, Time=0.81s, N=2286
#  Client 3 → Loss=0.2881, Acc=0.8835, Time=0.85s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5271, Acc=0.7981
#
# [Model=CNN | Seed=82 | Round=24]
#  Client 0 → Loss=0.2576, Acc=0.9011, Time=0.82s, N=2286
#  Client 1 → Loss=0.2378, Acc=0.9099, Time=0.82s, N=2286
#  Client 2 → Loss=0.2410, Acc=0.9099, Time=0.80s, N=2286
#  Client 3 → Loss=0.2853, Acc=0.8813, Time=0.87s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5378, Acc=0.7950
#
# [Model=CNN | Seed=82 | Round=25]
#  Client 0 → Loss=0.2495, Acc=0.9086, Time=0.80s, N=2286
#  Client 1 → Loss=0.2322, Acc=0.9112, Time=0.83s, N=2286
#  Client 2 → Loss=0.2367, Acc=0.9112, Time=0.81s, N=2286
#  Client 3 → Loss=0.2848, Acc=0.8818, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5482, Acc=0.7968
#
# [Model=CNN | Seed=82 | Round=26]
#  Client 0 → Loss=0.2447, Acc=0.9094, Time=0.80s, N=2286
#  Client 1 → Loss=0.2260, Acc=0.9099, Time=0.80s, N=2286
#  Client 2 → Loss=0.2283, Acc=0.9116, Time=0.85s, N=2286
#  Client 3 → Loss=0.2802, Acc=0.8879, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5358, Acc=0.8068
#
# [Model=CNN | Seed=82 | Round=27]
#  Client 0 → Loss=0.2372, Acc=0.9103, Time=0.80s, N=2286
#  Client 1 → Loss=0.2203, Acc=0.9173, Time=0.79s, N=2286
#  Client 2 → Loss=0.2231, Acc=0.9143, Time=1.13s, N=2286
#  Client 3 → Loss=0.2739, Acc=0.8857, Time=0.81s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5506, Acc=0.8038
#
# [Model=CNN | Seed=82 | Round=28]
#  Client 0 → Loss=0.2332, Acc=0.9125, Time=0.87s, N=2286
#  Client 1 → Loss=0.2175, Acc=0.9164, Time=0.81s, N=2286
#  Client 2 → Loss=0.2200, Acc=0.9199, Time=0.82s, N=2286
#  Client 3 → Loss=0.2745, Acc=0.8849, Time=0.79s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5173, Acc=0.8121
#
# [Model=CNN | Seed=82 | Round=29]
#  Client 0 → Loss=0.2320, Acc=0.9160, Time=0.77s, N=2286
#  Client 1 → Loss=0.2195, Acc=0.9160, Time=0.80s, N=2286
#  Client 2 → Loss=0.2152, Acc=0.9191, Time=0.82s, N=2286
#  Client 3 → Loss=0.2669, Acc=0.8914, Time=0.83s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5641, Acc=0.8020
#
# [Model=CNN | Seed=82 | Round=30]
#  Client 0 → Loss=0.2285, Acc=0.9178, Time=0.79s, N=2286
#  Client 1 → Loss=0.2121, Acc=0.9164, Time=0.76s, N=2286
#  Client 2 → Loss=0.2148, Acc=0.9156, Time=0.79s, N=2286
#  Client 3 → Loss=0.2632, Acc=0.8932, Time=0.78s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.5733, Acc=0.8051
#  [saved] saved_models\CNN_seed82.keras
#
# ================ MODEL: LSTM ================
#
# ------ SEED 42 ------
#
# [Model=LSTM | Seed=42 | Round=1]
#  Client 0 → Loss=0.5433, Acc=0.7415, Time=3.96s, N=2286
#  Client 1 → Loss=0.5675, Acc=0.7170, Time=3.70s, N=2286
#  Client 2 → Loss=0.5785, Acc=0.7122, Time=3.16s, N=2286
#  Client 3 → Loss=0.5557, Acc=0.7312, Time=3.44s, N=2284
#  >>> GLOBAL (centralized test) → Loss=0.6017, Acc=0.7268
#
# [Model=LSTM | Seed=42 | Round=2]
#  Client 0 → Loss=0.5046, Acc=0.7572, Time=3.87s, N=2286
# ...
#    CNN     3     saved_models\CNN_seed3.keras
#    CNN     7     saved_models\CNN_seed7.keras
#    CNN    72    saved_models\CNN_seed72.keras
#    CNN    82    saved_models\CNN_seed82.keras
#   LSTM    42   saved_models\LSTM_seed42.keras
#   LSTM     3    saved_models\LSTM_seed3.keras
#   LSTM     7    saved_models\LSTM_seed7.keras
#   LSTM    72   saved_models\LSTM_seed72.keras
#   LSTM    82   saved_models\LSTM_seed82.keras
# BiLSTM    42 saved_models\BiLSTM_seed42.keras
# BiLSTM     3  saved_models\BiLSTM_seed3.keras
# BiLSTM     7  saved_models\BiLSTM_seed7.keras
# BiLSTM    72 saved_models\BiLSTM_seed72.keras
# BiLSTM    82 saved_models\BiLSTM_seed82.keras
#    GRU    42    saved_models\GRU_seed42.keras
#    GRU     3     saved_models\GRU_seed3.keras
#    GRU     7     saved_models\GRU_seed7.keras
#    GRU    72    saved_models\GRU_seed72.keras
#    GRU    82    saved_models\GRU_seed82.keras
#  BiGRU    42  saved_models\BiGRU_seed42.keras
#  BiGRU     3   saved_models\BiGRU_seed3.keras
#  BiGRU     7   saved_models\BiGRU_seed7.keras
#  BiGRU    72  saved_models\BiGRU_seed72.keras
#  BiGRU    82  saved_models\BiGRU_seed82.keras
#
# OVERALL SUMMARY (all models & seeds pooled):
#                  Metric            Mean ± SD               95% CI
# 0                 Loss      0.3679 ± 0.1690      [0.3017,0.4342]
# 1             Accuracy      0.9105 ± 0.0639      [0.8854,0.9355]
# 2            Precision      0.9501 ± 0.0128      [0.9451,0.9551]
# 3               Recall      0.8680 ± 0.1407      [0.8128,0.9232]
# 4                   F1      0.8995 ± 0.0873      [0.8653,0.9338]
# 5                  MCC      0.8307 ± 0.1074      [0.7886,0.8728]
# 6                  AUC      0.9726 ± 0.0209      [0.9644,0.9808]
# 7          Specificity      0.9529 ± 0.0165      [0.9465,0.9594]
# 8    Training_Time_sec  482.6004 ± 247.2212  [385.6897,579.5111]
# 9   Inference_Time_sec      0.6872 ± 0.3735      [0.5408,0.8336]
# 10       Model_Size_MB      0.5846 ± 0.3965      [0.4292,0.7400]
# 11   Comm_per_round_MB      4.4748 ± 3.1303      [3.2477,5.7019]
# 12       Total_Comm_MB   134.2451 ± 93.9102   [97.4323,171.0578]
#
# PER-CLIENT TEST SUMMARY (mean/std over 5 seeds):
#                Accuracy         Precision          Recall              F1  \
#                   mean     std      mean     std    mean     std    mean
# Model  Client
# BiGRU  0        0.9406  0.0062    0.9434  0.0160  0.9378  0.0120  0.9404
#        1        0.9437  0.0094    0.9453  0.0117  0.9420  0.0084  0.9436
#        2        0.9462  0.0107    0.9508  0.0147  0.9413  0.0195  0.9459
#        3        0.9413  0.0032    0.9445  0.0085  0.9378  0.0117  0.9410
# BiLSTM 0        0.9542  0.0109    0.9541  0.0165  0.9545  0.0119  0.9542
#        1        0.9472  0.0089    0.9513  0.0059  0.9427  0.0137  0.9469
#        2        0.9497  0.0095    0.9535  0.0079  0.9455  0.0159  0.9494
#        3        0.9514  0.0076    0.9530  0.0089  0.9497  0.0080  0.9513
# CNN    0        0.7874  0.0452    0.9711  0.0154  0.5923  0.0910  0.7325
#        1        0.7836  0.0316    0.9648  0.0106  0.5888  0.0662  0.7294
#        2        0.7895  0.0411    0.9690  0.0152  0.5986  0.0861  0.7368
#        3        0.7899  0.0445    0.9660  0.0066  0.6014  0.0954  0.7372
# GRU    0        0.9262  0.0101    0.9322  0.0182  0.9196  0.0086  0.9258
#        1        0.9297  0.0135    0.9368  0.0133  0.9217  0.0158  0.9291
#        2        0.9322  0.0031    0.9391  0.0094  0.9245  0.0123  0.9316
#        3        0.9255  0.0093    0.9283  0.0117  0.9224  0.0155  0.9253
# LSTM   0        0.9483  0.0094    0.9535  0.0115  0.9427  0.0169  0.9479
#        1        0.9441  0.0079    0.9491  0.0059  0.9385  0.0125  0.9437
#        2        0.9381  0.0091    0.9499  0.0059  0.9252  0.0229  0.9372
#        3        0.9409  0.0081    0.9478  0.0144  0.9336  0.0199  0.9404
#
#                           MCC             AUC         Specificity          \
#                   std    mean     std    mean     std        mean     std
# Model  Client
# BiGRU  0       0.0059  0.8814  0.0126  0.9857  0.0039      0.9434  0.0168
#        1       0.0093  0.8874  0.0187  0.9836  0.0035      0.9455  0.0120
#        2       0.0110  0.8926  0.0213  0.9856  0.0044      0.9510  0.0156
#        3       0.0034  0.8827  0.0063  0.9833  0.0042      0.9448  0.0094
# BiLSTM 0       0.0107  0.9085  0.0219  0.9875  0.0041      0.9538  0.0170
#        1       0.0091  0.8945  0.0177  0.9844  0.0029      0.9517  0.0057
#        2       0.0098  0.8994  0.0191  0.9882  0.0028      0.9538  0.0080
#        3       0.0075  0.9028  0.0151  0.9887  0.0032      0.9531  0.0091
# CNN    0       0.0753  0.6247  0.0724  0.9359  0.0146      0.9825  0.0096
#        1       0.0533  0.6162  0.0490  0.9277  0.0133      0.9783  0.0076
#        2       0.0686  0.6273  0.0633  0.9293  0.0151      0.9804  0.0104
#        3       0.0768  0.6268  0.0671  0.9363  0.0122      0.9783  0.0067
# GRU    0       0.0097  0.8527  0.0205  0.9740  0.0064      0.9329  0.0189
#        1       0.0137  0.8596  0.0270  0.9736  0.0070      0.9378  0.0132
#        2       0.0034  0.8646  0.0063  0.9773  0.0070      0.9399  0.0106
#        3       0.0096  0.8512  0.0185  0.9766  0.0027      0.9287  0.0128
# LSTM   0       0.0097  0.8967  0.0187  0.9844  0.0044      0.9538  0.0120
#        1       0.0082  0.8882  0.0158  0.9822  0.0028      0.9497  0.0059
#        2       0.0099  0.8768  0.0179  0.9842  0.0054      0.9510  0.0070
#        3       0.0086  0.8823  0.0158  0.9837  0.0038      0.9483  0.0157
#
#                  Loss
#                  mean     std
# Model  Client
# BiGRU  0       0.3782  0.0490
#        1       0.3890  0.0692
#        2       0.3549  0.0673
#        3       0.3863  0.0626
# BiLSTM 0       0.2124  0.0548
#        1       0.2593  0.0441
#        2       0.2086  0.0370
#        3       0.2098  0.0444
# CNN    0       0.6046  0.2190
#        1       0.6376  0.1669
#        2       0.6226  0.1532
#        3       0.5852  0.1948
# GRU    0       0.4358  0.0898
#        1       0.4517  0.1090
#        2       0.4038  0.0724
#        3       0.4268  0.0366
# LSTM   0       0.1852  0.0380
#        1       0.2073  0.0295
#        2       0.1999  0.0486
#        3       0.2001  0.0391
#
# PAIRWISE PAIRED T-TESTS across 5 seeds (Global Test Set):
#    Metric Model A Model B  Mean A  Mean B   t-stat  p-value  Significant (p<0.05)
# Accuracy     CNN    LSTM  0.7876  0.9428  -9.9075   0.0006                  True
# Accuracy     CNN  BiLSTM  0.7876  0.9506  -9.8527   0.0006                  True
# Accuracy     CNN     GRU  0.7876  0.9284  -8.3357   0.0011                  True
# Accuracy     CNN   BiGRU  0.7876  0.9429  -8.8580   0.0009                  True
# Accuracy    LSTM  BiLSTM  0.9428  0.9506  -4.5746   0.0102                  True
# Accuracy    LSTM     GRU  0.9428  0.9284   8.5779   0.0010                  True
# Accuracy    LSTM   BiGRU  0.9428  0.9429  -0.0350   0.9738                 False
# Accuracy  BiLSTM     GRU  0.9506  0.9284  11.0749   0.0004                  True
# Accuracy  BiLSTM   BiGRU  0.9506  0.9429   2.8197   0.0478                  True
# Accuracy     GRU   BiGRU  0.9284  0.9429 -13.6221   0.0002                  True
#       F1     CNN    LSTM  0.7341  0.9424  -7.4237   0.0018                  True
#       F1     CNN  BiLSTM  0.7341  0.9505  -7.4854   0.0017                  True
#       F1     CNN     GRU  0.7341  0.9280  -6.6189   0.0027                  True
#       F1     CNN   BiGRU  0.7341  0.9427  -6.9630   0.0022                  True
#       F1    LSTM  BiLSTM  0.9424  0.9505  -4.6105   0.0100                  True
#       F1    LSTM     GRU  0.9424  0.9280   8.5842   0.0010                  True
#       F1    LSTM   BiGRU  0.9424  0.9427  -0.1462   0.8909                 False
#       F1  BiLSTM     GRU  0.9505  0.9280  11.6099   0.0003                  True
#       F1  BiLSTM   BiGRU  0.9505  0.9427   2.8167   0.0480                  True
#       F1     GRU   BiGRU  0.9280  0.9427 -12.5057   0.0002                  True
#      AUC     CNN    LSTM  0.9323  0.9836 -13.6170   0.0002                  True
#      AUC     CNN  BiLSTM  0.9323  0.9872 -13.6194   0.0002                  True
#      AUC     CNN     GRU  0.9323  0.9754 -15.0533   0.0001                  True
#      AUC     CNN   BiGRU  0.9323  0.9845 -12.9014   0.0002                  True
#      AUC    LSTM  BiLSTM  0.9836  0.9872  -6.5796   0.0028                  True
#      AUC    LSTM     GRU  0.9836  0.9754   6.9055   0.0023                  True
#      AUC    LSTM   BiGRU  0.9836  0.9845  -1.1873   0.3008                 False
#      AUC  BiLSTM     GRU  0.9872  0.9754   9.6119   0.0007                  True
#      AUC  BiLSTM   BiGRU  0.9872  0.9845   3.9645   0.0166                  True
#      AUC     GRU   BiGRU  0.9754  0.9845  -6.4635   0.0030                  True
#     Loss     CNN    LSTM  0.6125  0.1981   5.5004   0.0053                  True
#     Loss     CNN  BiLSTM  0.6125  0.2225   5.1985   0.0065                  True
#     Loss     CNN     GRU  0.6125  0.4295   2.1339   0.0998                 False
#     Loss     CNN   BiGRU  0.6125  0.3771   3.0159   0.0393                  True
#     Loss    LSTM  BiLSTM  0.1981  0.2225  -3.6211   0.0223                  True
#     Loss    LSTM     GRU  0.1981  0.4295 -11.7234   0.0003                  True
#     Loss    LSTM   BiGRU  0.1981  0.3771 -19.8157   0.0000                  True
#     Loss  BiLSTM     GRU  0.2225  0.4295 -13.0734   0.0002                  True
#     Loss  BiLSTM   BiGRU  0.2225  0.3771 -12.9152   0.0002                  True
#     Loss     GRU   BiGRU  0.4295  0.3771   2.9373   0.0425                  True
#
# McNEMAR'S TEST — PER SEED (instance-level, Global Test Set):
#   Seed Model A Model B  A right/B wrong  A wrong/B right     stat  p-value  Significant (p<0.05)
#    42     CNN    LSTM               44              394 278.0845   0.0000                  True
#    42     CNN  BiLSTM               39              418 312.6565   0.0000                  True
#    42     CNN     GRU               62              384 231.0336   0.0000                  True
#    42     CNN   BiGRU               42              396 284.4954   0.0000                  True
#    42    LSTM  BiLSTM               32               61   8.4301   0.0037                  True
#    42    LSTM     GRU               60               32   7.9239   0.0049                  True
#    42    LSTM   BiGRU               48               52   0.0900   0.7642                 False
#    42  BiLSTM     GRU               85               28  27.7522   0.0000                  True
#    42  BiLSTM   BiGRU               54               29   6.9398   0.0084                  True
#    42     GRU   BiGRU               38               70   8.8981   0.0029                  True
#     3     CNN    LSTM               57              549 397.8234   0.0000                  True
#     3     CNN  BiLSTM               54              567 422.1320   0.0000                  True
#     3     CNN     GRU               67              537 364.1738   0.0000                  True
#     3     CNN   BiGRU               54              564 419.2249   0.0000                  True
#     3    LSTM  BiLSTM               35               56   4.3956   0.0360                  True
#     3    LSTM     GRU               47               25   6.1250   0.0133                  True
#     3    LSTM   BiGRU               48               66   2.5351   0.1113                 False
#     3  BiLSTM     GRU               70               27  18.1856   0.0000                  True
#     3  BiLSTM   BiGRU               42               39   0.0494   0.8241                 False
#     3     GRU   BiGRU               43               83  12.0714   0.0005                  True
#     7     CNN    LSTM               47              331 211.8757   0.0000                  True
#     7     CNN  BiLSTM               44              333 220.0106   0.0000                  True
#     7     CNN     GRU               59              311 170.2730   0.0000                  True
#     7     CNN   BiGRU               53              340 208.1323   0.0000                  True
#     7    LSTM  BiLSTM               36               41   0.2078   0.6485                 False
#     7    LSTM     GRU               59               27  11.1744   0.0008                  True
#     7    LSTM   BiGRU               37               40   0.0519   0.8197                 False
#     7  BiLSTM     GRU               70               33  12.5825   0.0004                  True
#     7  BiLSTM   BiGRU               41               39   0.0125   0.9110                 False
#     7     GRU   BiGRU               29               64  12.4301   0.0004                  True
#    72     CNN    LSTM               40              371 264.9635   0.0000                  True
#    72     CNN  BiLSTM               43              390 276.4804   0.0000                  True
#    72     CNN     GRU               80              371 186.4745   0.0000                  True
#    72     CNN   BiGRU               61              377 226.5411   0.0000                  True
#    72    LSTM  BiLSTM               27               43   3.2143   0.0730                 False
#    72    LSTM     GRU               72               32  14.6250   0.0001                  True
#    72    LSTM   BiGRU               50               35   2.3059   0.1289                 False
#    72  BiLSTM     GRU               85               29  26.5351   0.0000                  True
#    72  BiLSTM   BiGRU               53               22  12.0000   0.0005                  True
#    72     GRU   BiGRU               46               71   4.9231   0.0265                  True
#    82     CNN    LSTM               53              372 237.9388   0.0000                  True
#    82     CNN  BiLSTM               42              379 268.1615   0.0000                  True
#    82     CNN     GRU               75              351 177.5235   0.0000                  True
#    82     CNN   BiGRU               61              371 221.0208   0.0000                  True
#    82    LSTM  BiLSTM               26               44   4.1286   0.0422                  True
#    82    LSTM     GRU               74               31  16.8000   0.0000                  True
#    82    LSTM   BiGRU               55               46   0.6337   0.4260                 False
#    82  BiLSTM     GRU               84               23  33.6449   0.0000                  True
#    82  BiLSTM   BiGRU               50               23   9.2603   0.0023                  True
#    82     GRU   BiGRU               38               72   9.9000   0.0017                  True
#
# McNEMAR'S TEST — POOLED ACROSS 5 SEEDS (Global Test Set):
#  Model A Model B  A right/B wrong (pooled)  A wrong/B right (pooled)      stat  p-value  Significant (p<0.05)
#     CNN    LSTM                       241                      2017 1395.3167      0.0                  True
#     CNN  BiLSTM                       222                      2087 1504.7622      0.0                  True
#     CNN     GRU                       343                      1954 1128.4719      0.0                  True
#     CNN   BiGRU                       271                      2048 1360.1449      0.0                  True
#    LSTM  BiLSTM                       156                       245   19.3117      0.0                  True
#    LSTM     GRU                       312                       147   58.5969      0.0                  True
#    LSTM   BiGRU                       238                       239    0.0000      1.0                 False
#  BiLSTM     GRU                       394                       140  119.8670      0.0                  True
#  BiLSTM   BiGRU                       240                       152   19.3087      0.0                  True
#     GRU   BiGRU                       194                       360   49.1426      0.0                  True
